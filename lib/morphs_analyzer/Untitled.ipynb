# %%
import sys

# %%
sys.path.insert(0, '/home/onAd/OnAD_project')

# %%
from lib.contact_db.member import TwitchChat
from lib.contact_db.anal_data import select_twitch_chat

# %%
from lib.morphs_analyzer.morphs_modules import tokenize_tolist

# %%
DB_URL = 'onad.cbjjamtlar2t.ap-northeast-2.rds.amazonaws.com'
DB_USER = 'onad'
DB_PASSWORD = 'rkdghktn12'
DB_DATABASE = 'onad'
DB_CHARSET = 'utf8mb4'
DB_LOGFLAG  = 'False'
DB_PORT = 3306

db_url = "mysql+pymysql://%s:%s@%s:%s/%s?charset=%s" % (
    DB_USER, DB_PASSWORD,
    DB_URL, DB_PORT,
    DB_DATABASE, DB_CHARSET
)

# %%
df = select_twitch_chat(db_url, 'zilioner', '2019-01-11' )

# %%
df
# Out:
#         chat_id streamer_name  broad_date               chatterer chat_time  \
# 0      23990100      zilioner  2019-01-11  <%그림이그림그림 (somegreen)>  10:39:33
# 1      23990101      zilioner  2019-01-11        <폴록 (novapop32)>  10:44:00
# 2      23990102      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  10:58:36
# 3      23990103      zilioner  2019-01-11            <krmnmvyrqs>  10:58:37
# 4      23990104      zilioner  2019-01-11      <이게죽네 (mrsip1986)>  10:58:45
# 5      23990105      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  10:59:02
# 6      23990106      zilioner  2019-01-11            <krmnmvyrqs>  10:59:03
# 7      23990107      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  10:59:08
# 8      23990108      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  10:59:15
# 9      23990109      zilioner  2019-01-11      <이게죽네 (mrsip1986)>  10:59:19
# 10     23990110      zilioner  2019-01-11            <jinjin8848>  10:59:50
# 11     23990111      zilioner  2019-01-11        <@싹둑 (ssakdook)>  10:59:53
# 12     23990112      zilioner  2019-01-11           <Pioneer1547>  10:59:56
# 13     23990113      zilioner  2019-01-11     <그머누 (supbros0816)>  11:00:02
# 14     23990114      zilioner  2019-01-11     <그머누 (supbros0816)>  11:00:05
# 15     23990115      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  11:00:07
# 16     23990116      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  11:00:09
# 17     23990117      zilioner  2019-01-11      <이게죽네 (mrsip1986)>  11:00:09
# 18     23990118      zilioner  2019-01-11           <Pioneer1547>  11:00:14
# 19     23990119      zilioner  2019-01-11     <%웅이아버지 (dndgml57)>  11:00:14
# 20     23990120      zilioner  2019-01-11      <이게죽네 (mrsip1986)>  11:00:16
# 21     23990121      zilioner  2019-01-11  <%그림이그림그림 (somegreen)>  11:00:50
# 22     23990122      zilioner  2019-01-11     <그머누 (supbros0816)>  11:01:07
# 23     23990123      zilioner  2019-01-11  <%그림이그림그림 (somegreen)>  11:01:09
# 24     23990124      zilioner  2019-01-11       <+꿀청귤 (koyoonha)>  11:01:27
# 25     23990125      zilioner  2019-01-11    <울었습니다 (maison2500)>  11:01:28
# 26     23990126      zilioner  2019-01-11    <휴지훈 (free_from777)>  11:02:17
# 12                                       오늘이 정전협정 맺은 날임?
# 13                                            오늘 1시에 오셔요
# 14                                           얼른 들어가서 더 자
# 15                                                  아 맞다
# 16                                                   ...
# 17                                                아 11신데
# 18                                            정전협정 맺었음..
# 19                                           1시에 온다고했었구나
# 20                                              난 일하는중이라
# 21                                               앗..아아..
# 22                                갤 공지는 수정 안하셔서 11시라 되있네
# 23                                    일찍일어난김에 보려고 했는데...
# 24                                                  오뱅없?
# 25                                 요즘 좀 달리시더니 아직 방송 안여셨네
# 26                                            오늘 안허는 날인가
# 27                                 오늘 작업실 정전으로 1시에 오신댑니다
# 28                                              오오 1시 ㄳㄳ
# 29                                             꿀정보 감사합니다
# ...                                                  ...
# 30750                                           일해야겠다...
# 30751                                                빠이구
# 30752                                킹구갓구 오랫만에보니 재밌네요 ㅋㅋ
# 30753                                        모두 킹구갓구 합시다
# 30754                                    말밥맨들 올 시간이다....
# 30755                                          히오스나 하러가자
# 30756                               가기전에 호스팅해주고가!!!!1!!!
# 30757                                    ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 분기게임
# 30758                                              6시입니다
# 30759                                              퇴근합시다
# 30760                                            킹 구 갓 구
# 30761                                              칼퇴,,,
# 30762                                   식당이라 지금 부터 바쁨...
# 30763                                                 ㅇ?
# 30764                                          ccaChoouk
# 30765                                    뭐야 밥먹고 오니까 방종했네
# 30766                                                829
# 30767                                       호스팅은 걸어서 갑시당
# 30768                                                 음?
# 30769                                        저녁 맛있게드셔요~~
# 30770                                             방종했어여?
# 30771                               왜 마구마구 카테고리 이름이 이래요?
# 30772                                               방종임?
# 30773                                           오프라인이에여?
# 30774                                머지 방송이라곤 뜨는데 안나오넹..
# 30775                                              저도요..
# 30776                                              방금 종함
# 30777  침투부에서 방송 하이라이트영상이 올라갑니다. https://www.youtube.c...
# 30778                                                 ㅎㅇ
# 30779                                                 ㄷㅊ
#
# [30780 rows x 6 columns]

# %%
df['morphs'] = df['chat_contents'][:20].apply(lambda x : tokenize_tolist(x))
# Out:
# 0                                       [착, -, 석, ----]
# 1                                                [석, 착]
# 2                                            [언제, 오, 나]
# 3                                       [하, 아, 명, 하, 아]
# 4                                          [아, 왜, 안, 옴]
# 5                                                [ㅂㄷㅂㄷ]
# 6                                       [지각, 권, 까, ㅂ니다]
# 7                                               [59븐인데]
# 8                        [밤새, 프, 마, 하, 았, 다는, 것, 이, 정설]
# 9                [아, 진짜, 저놈, 에, 지각, 권, 꼴, 배기, 싫, 다, ㅋㅋ]
# 10                                   [절, 대, 지, 각, 하, 아]
# 11    [침투, 부, 에서, 방송, 하이라이트, 영상, 이, 올라가, ㅂ니다, ., htt...
# 12                    [오늘, 이, 정전, 협정, 맺, 은, 날, 이, ㅁ, ?]
# 13                              [오늘, 1, 시, 에, 오, 시, 어요]
# 14                                  [얼른, 들어가, 아서, 더, 자]
# 15                                            [아, 맞, 다]
# 16                                                [...]
# 17                                        [아, 11, 신, 데]
# 18                              [정전, 협정, 맺, 었, 음, ., .]
# 19                         [1, 시, 에, 오, ㄴ다고, 하, 았었, 구나]
# Name: chat_contents, dtype: object
