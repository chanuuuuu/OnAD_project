# %%
import pickle

# %%
with open('이말년181206.pickle', 'rb') as f : 
        a = pickle.load(f)

# %%
a
# Out:
# [('ㅋㅋ', 33481),
#  ('이', 4632),
#  ('하', 4253),
#  ('ㄴ', 3678),
#  ('ㅇ', 3320),
#  ('아', 3261),
#  ('?', 3056),
#  ('다', 2335),
#  ('어', 2298),
#  ('네', 2151),
#  ('ㅗ', 2134),
#  ('는', 1800),
#  ('가', 1767),
#  ('ㅁ', 1758),
#  ('ㄱ', 1755),
#  ('ㄹ', 1636),
#  ('되', 1226),
#  ('지', 1196),
#  ('ㅠ', 1111),
#  ('에', 1077),
#  ('.', 1075),
#  ('었', 1073),
#  ('거', 1048),
#  ('게', 1021),
#  ('ㅋㅋㅋ', 989),
#  ('있', 956),
#  ('았', 934),
#  ('명', 927),
#  ('시', 917),
#  ('ㄷㄷ', 903),
#  ('안', 871),
#  ('기', 849),
#  ('ㄴㄴ', 846),
#  ('!', 834),
#  ('은', 811),
#  ('고', 802),
#  ('죠', 797),
#  ('오', 792),
#  ('키', 791),
#  (';', 786),
#  ('~', 751),
#  ('나', 742),
#  ('아니', 739),
#  ('면', 728),
#  ('보', 700),
#  ('마왕', 700),
#  ('ㄱㄱ', 682),
#  ('도', 666),
#  ('대', 639),
#  ('...', 633),
#  ('들', 612),
#  ('는데', 603),
#  ('을', 584),
#  ('절', 580),
#  ('그', 561),
#  ('맨', 551),
#  ('의', 550),
#  ('ㅋㅋㅋㅋㅋ', 545),
#  ('개', 534),
#  ('자', 530),
#  ('앗', 529),
#  ('바', 502),
#  ('못', 498),
# ...
