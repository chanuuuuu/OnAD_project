# %%
import pickle
import sys

# %%
import os

# %%
mod = sys.modules[__name__]

# %%
def call_file_list(path) : 
    """
        path : 파일 경로
    """
    from os import listdir
    path_dir = path
    file_list = listdir(path_dir)
    return file_list

# %%
folder_list = call_file_list('../top_words')[:-2]

# %%
folder_list
# Out:
# ['#beyou0728',
#  '#cocopopp671',
#  '#ddahyoni',
#  '#hanryang1125',
#  '#looksam',
#  '#rhdgurwns',
#  '#saddummy',
#  '#yapyap30',
#  '#zilioner']

# %%
i = 0
for folder in folder_list : 
    file_list = call_file_list('./%s'%folder) 
    try : 
        for file in file_list : 
            i +=1
            my = re.compile('(\d{4})[-](\d{2})[-](\d{2})([_][#])(\w*)')
            mytxt = my.search(file)
            
            with open('./{}/{}'.format(folder, file), 'rb') as f : 
                setattr(mod, '{}{}'.format(mytxt.group(2)+mytxt.group(3),mytxt.group(5)), pickle.load(f))
            print('{}{}'.format(mytxt.group(2)+mytxt.group(3),mytxt.group(5)))
    except Exception as e :
        print(e)
# Out:
# [Errno 21] Is a directory: './#beyou0728/.ipynb_checkpoints'
# 1205cocopopp6712글자이상형태소
# 1205cocopopp671기본형태소
# 1206cocopopp6712글자이상형태소
# 1206cocopopp671기본형태소
# 1207cocopopp6712글자이상형태소
# 1207cocopopp671기본형태소
# 1208cocopopp6712글자이상형태소
# 1208cocopopp671기본형태소
# 1209cocopopp6712글자이상형태소
# 1209cocopopp671기본형태소
# 1210cocopopp6712글자이상형태소
# 1210cocopopp671기본형태소
# 1211cocopopp6712글자이상형태소
# 1211cocopopp671기본형태소
# 1212cocopopp6712글자이상형태소
# 1212cocopopp671기본형태소
# 1213cocopopp6712글자이상형태소
# 1213cocopopp671기본형태소
# 1214cocopopp6712글자이상형태소
# 1214cocopopp671기본형태소
# 1215cocopopp6712글자이상형태소
# 1215cocopopp671기본형태소
# 1216cocopopp6712글자이상형태소
# 1216cocopopp671기본형태소
# 1217cocopopp6712글자이상형태소
# 1217cocopopp671기본형태소
# 1218cocopopp6712글자이상형태소
# 1218cocopopp671기본형태소
# 1219cocopopp6712글자이상형태소
# 1219cocopopp671기본형태소
# 1220cocopopp6712글자이상형태소
# 1220cocopopp671기본형태소
# 1221cocopopp6712글자이상형태소
# 1221cocopopp671기본형태소
# 1222cocopopp6712글자이상형태소
# 1222cocopopp671기본형태소
# 1223cocopopp6712글자이상형태소
# 1223cocopopp671기본형태소
# 1224cocopopp6712글자이상형태소
# 1224cocopopp671기본형태소
# 1225cocopopp6712글자이상형태소
# 1225cocopopp671기본형태소
# 1226cocopopp6712글자이상형태소
# 1226cocopopp671기본형태소
# 1227cocopopp6712글자이상형태소
# 1227cocopopp671기본형태소
# 1205ddahyoni2글자이상형태소
# 1205ddahyoni기본형태소
# 1206ddahyoni2글자이상형태소
# 1206ddahyoni기본형태소
# 1207ddahyoni2글자이상형태소
# 1207ddahyoni기본형태소
# 1208ddahyoni2글자이상형태소
# 1208ddahyoni기본형태소
# 1209ddahyoni2글자이상형태소
# 1209ddahyoni기본형태소
# 1210ddahyoni2글자이상형태소
# 1210ddahyoni기본형태소
# 1211ddahyoni2글자이상형태소
# 1211ddahyoni기본형태소
# 1212ddahyoni2글자이상형태소
# 1212ddahyoni기본형태소
# 1213ddahyoni2글자이상형태소
# 1213ddahyoni기본형태소
# 1214ddahyoni2글자이상형태소
# 1214ddahyoni기본형태소
# 1215ddahyoni2글자이상형태소
# 1215ddahyoni기본형태소
# 1216ddahyoni2글자이상형태소
# 1216ddahyoni기본형태소
# 1217ddahyoni2글자이상형태소
# 1217ddahyoni기본형태소
# 1218ddahyoni2글자이상형태소
# 1218ddahyoni기본형태소
# 1219ddahyoni2글자이상형태소
# 1219ddahyoni기본형태소
# 1220ddahyoni2글자이상형태소
# 1220ddahyoni기본형태소
# 1221ddahyoni2글자이상형태소
# 1221ddahyoni기본형태소
# 1222ddahyoni2글자이상형태소
# 1222ddahyoni기본형태소
# 1223ddahyoni2글자이상형태소
# 1223ddahyoni기본형태소
# 1224ddahyoni2글자이상형태소
# 1224ddahyoni기본형태소
# 1225ddahyoni2글자이상형태소
# 1225ddahyoni기본형태소
# 1226ddahyoni2글자이상형태소
# 1226ddahyoni기본형태소
# 1227ddahyoni2글자이상형태소
# 1227ddahyoni기본형태소
# 1228ddahyoni2글자이상형태소
# 1228ddahyoni기본형태소
# 1205hanryang11252글자이상형태소
# 1205hanryang1125기본형태소
# 1206hanryang11252글자이상형태소
# 1206hanryang1125기본형태소
# 1207hanryang11252글자이상형태소
# 1207hanryang1125기본형태소
# 1208hanryang11252글자이상형태소
# 1208hanryang1125기본형태소
# 1209hanryang11252글자이상형태소
# 1209hanryang1125기본형태소
# 1210hanryang11252글자이상형태소
# 1210hanryang1125기본형태소
# 1211hanryang11252글자이상형태소
# 1211hanryang1125기본형태소
# 1212hanryang11252글자이상형태소
# 1212hanryang1125기본형태소
# 1213hanryang11252글자이상형태소
# 1213hanryang1125기본형태소
# 1214hanryang11252글자이상형태소
# 1214hanryang1125기본형태소
# 1215hanryang11252글자이상형태소
# 1215hanryang1125기본형태소
# 1216hanryang11252글자이상형태소
# 1216hanryang1125기본형태소
# 1217hanryang11252글자이상형태소
# 1217hanryang1125기본형태소
# 1218hanryang11252글자이상형태소
# 1218hanryang1125기본형태소
# 1219hanryang11252글자이상형태소
# 1219hanryang1125기본형태소
# 1220hanryang11252글자이상형태소
# 1220hanryang1125기본형태소
# 1221hanryang11252글자이상형태소
# 1221hanryang1125기본형태소
# 1222hanryang11252글자이상형태소
# 1222hanryang1125기본형태소
# 1223hanryang11252글자이상형태소
# 1223hanryang1125기본형태소
# 1224hanryang11252글자이상형태소
# 1224hanryang1125기본형태소
# 1225hanryang11252글자이상형태소
# 1225hanryang1125기본형태소
# 1226hanryang11252글자이상형태소
# 1226hanryang1125기본형태소
# 1227hanryang11252글자이상형태소
# 1227hanryang1125기본형태소
# 1205looksam2글자이상형태소
# 1205looksam기본형태소
# 1206looksam2글자이상형태소
# 1206looksam기본형태소
# 1207looksam2글자이상형태소
# 1207looksam기본형태소
# 1208looksam2글자이상형태소
# 1208looksam기본형태소
# 1209looksam2글자이상형태소
# 1209looksam기본형태소
# 1210looksam2글자이상형태소
# 1210looksam기본형태소
# 1211looksam2글자이상형태소
# 1211looksam기본형태소
# 1212looksam2글자이상형태소
# 1212looksam기본형태소
# 1213looksam2글자이상형태소
# 1213looksam기본형태소
# 1214looksam2글자이상형태소
# 1214looksam기본형태소
# 1215looksam2글자이상형태소
# 1215looksam기본형태소
# 1216looksam2글자이상형태소
# 1216looksam기본형태소
# 1217looksam2글자이상형태소
# 1217looksam기본형태소
# 1218looksam2글자이상형태소
# 1218looksam기본형태소
# 1219looksam2글자이상형태소
# 1219looksam기본형태소
# 1220looksam2글자이상형태소
# 1220looksam기본형태소
# 1221looksam2글자이상형태소
# 1221looksam기본형태소
# 1222looksam2글자이상형태소
# 1222looksam기본형태소
# 1223looksam2글자이상형태소
# 1223looksam기본형태소
# 1224looksam2글자이상형태소
# 1224looksam기본형태소
# 1225looksam2글자이상형태소
# 1225looksam기본형태소
# 1226looksam2글자이상형태소
# 1226looksam기본형태소
# 1227looksam2글자이상형태소
# 1227looksam기본형태소
# 1205rhdgurwns2글자이상형태소
# 1205rhdgurwns기본형태소
# 1206rhdgurwns2글자이상형태소
# 1206rhdgurwns기본형태소
# 1207rhdgurwns2글자이상형태소
# 1207rhdgurwns기본형태소
# 1208rhdgurwns2글자이상형태소
# 1208rhdgurwns기본형태소
# 1209rhdgurwns2글자이상형태소
# 1209rhdgurwns기본형태소
# 1211rhdgurwns2글자이상형태소
# 1211rhdgurwns기본형태소
# 1212rhdgurwns2글자이상형태소
# 1212rhdgurwns기본형태소
# 1213rhdgurwns2글자이상형태소
# 1213rhdgurwns기본형태소
# 1214rhdgurwns2글자이상형태소
# 1214rhdgurwns기본형태소
# 1215rhdgurwns2글자이상형태소
# 1215rhdgurwns기본형태소
# 1216rhdgurwns2글자이상형태소
# 1216rhdgurwns기본형태소
# 1217rhdgurwns2글자이상형태소
# 1217rhdgurwns기본형태소
# 1218rhdgurwns2글자이상형태소
# 1218rhdgurwns기본형태소
# 1219rhdgurwns2글자이상형태소
# 1219rhdgurwns기본형태소
# 1220rhdgurwns2글자이상형태소
# 1220rhdgurwns기본형태소
# 1221rhdgurwns2글자이상형태소
# 1221rhdgurwns기본형태소
# 1222rhdgurwns2글자이상형태소
# 1222rhdgurwns기본형태소
# 1223rhdgurwns2글자이상형태소
# 1223rhdgurwns기본형태소
# 1224rhdgurwns2글자이상형태소
# 1224rhdgurwns기본형태소
# 1225rhdgurwns2글자이상형태소
# 1225rhdgurwns기본형태소
# 1226rhdgurwns2글자이상형태소
# 1226rhdgurwns기본형태소
# 1227rhdgurwns2글자이상형태소
# 1227rhdgurwns기본형태소
# 1228rhdgurwns2글자이상형태소
# 1228rhdgurwns기본형태소
# 1205saddummy2글자이상형태소
# 1205saddummy기본형태소
# 1206saddummy2글자이상형태소
# 1206saddummy기본형태소
# 1207saddummy2글자이상형태소
# 1207saddummy기본형태소
# 1208saddummy2글자이상형태소
# 1208saddummy기본형태소
# 1209saddummy2글자이상형태소
# 1209saddummy기본형태소
# 1210saddummy2글자이상형태소
# 1210saddummy기본형태소
# 1211saddummy2글자이상형태소
# 1211saddummy기본형태소
# 1212saddummy2글자이상형태소
# 1212saddummy기본형태소
# 1213saddummy2글자이상형태소
# 1213saddummy기본형태소
# 1214saddummy2글자이상형태소
# 1214saddummy기본형태소
# 1215saddummy2글자이상형태소
# 1215saddummy기본형태소
# 1216saddummy2글자이상형태소
# 1216saddummy기본형태소
# 1217saddummy2글자이상형태소
# 1217saddummy기본형태소
# 1218saddummy2글자이상형태소
# 1218saddummy기본형태소
# 1219saddummy2글자이상형태소
# 1219saddummy기본형태소
# 1220saddummy2글자이상형태소
# 1220saddummy기본형태소
# 1221saddummy2글자이상형태소
# 1221saddummy기본형태소
# 1222saddummy2글자이상형태소
# 1222saddummy기본형태소
# 1223saddummy2글자이상형태소
# 1223saddummy기본형태소
# 1224saddummy2글자이상형태소
# 1224saddummy기본형태소
# 1225saddummy2글자이상형태소
# 1225saddummy기본형태소
# 1226saddummy2글자이상형태소
# 1226saddummy기본형태소
# 1227saddummy2글자이상형태소
# 1227saddummy기본형태소
# 1203yapyap302글자이상형태소
# 1203yapyap30기본형태소
# 1204yapyap302글자이상형태소
# 1204yapyap30기본형태소
# 1205yapyap302글자이상형태소
# 1205yapyap30기본형태소
# 1206yapyap302글자이상형태소
# 1206yapyap30기본형태소
# 1207yapyap302글자이상형태소
# 1207yapyap30기본형태소
# 1208yapyap302글자이상형태소
# 1208yapyap30기본형태소
# 1209yapyap302글자이상형태소
# 1209yapyap30기본형태소
# 1210yapyap302글자이상형태소
# 1210yapyap30기본형태소
# 1211yapyap302글자이상형태소
# 1211yapyap30기본형태소
# 1212yapyap302글자이상형태소
# 1212yapyap30기본형태소
# 1213yapyap302글자이상형태소
# 1213yapyap30기본형태소
# 1214yapyap302글자이상형태소
# 1214yapyap30기본형태소
# 1215yapyap302글자이상형태소
# 1215yapyap30기본형태소
# 1216yapyap302글자이상형태소
# 1216yapyap30기본형태소
# 1217yapyap302글자이상형태소
# 1217yapyap30기본형태소
# 1218yapyap302글자이상형태소
# 1218yapyap30기본형태소
# 1219yapyap302글자이상형태소
# 1219yapyap30기본형태소
# 1220yapyap302글자이상형태소
# 1220yapyap30기본형태소
# 1221yapyap302글자이상형태소
# 1221yapyap30기본형태소
# 1222yapyap302글자이상형태소
# 1222yapyap30기본형태소
# 1223yapyap302글자이상형태소
# 1223yapyap30기본형태소
# 1224yapyap302글자이상형태소
# 1224yapyap30기본형태소
# 1225yapyap302글자이상형태소
# 1225yapyap30기본형태소
# 1226yapyap302글자이상형태소
# 1226yapyap30기본형태소
# 1227yapyap302글자이상형태소
# 1227yapyap30기본형태소
# 1203zilioner2글자이상형태소
# 1203zilioner기본형태소
# 1205zilioner2글자이상형태소
# 1205zilioner기본형태소
# 1206zilioner2글자이상형태소
# 1206zilioner기본형태소
# 1207zilioner2글자이상형태소
# 1207zilioner기본형태소
# 1208zilioner2글자이상형태소
# 1208zilioner기본형태소
# 1209zilioner2글자이상형태소
# 1209zilioner기본형태소
# 1210zilioner2글자이상형태소
# 1210zilioner기본형태소
# 1211zilioner2글자이상형태소
# 1211zilioner기본형태소
# 1212zilioner2글자이상형태소
# 1212zilioner기본형태소
# 1213zilioner2글자이상형태소
# 1213zilioner기본형태소
# 1214zilioner2글자이상형태소
# 1214zilioner기본형태소
# 1215zilioner2글자이상형태소
# 1215zilioner기본형태소
# 1216zilioner2글자이상형태소
# 1216zilioner기본형태소
# 1217zilioner2글자이상형태소
# 1217zilioner기본형태소
# 1218zilioner2글자이상형태소
# 1218zilioner기본형태소
# 1219zilioner2글자이상형태소
# 1219zilioner기본형태소
# 1220zilioner2글자이상형태소
# 1220zilioner기본형태소
# 1221zilioner2글자이상형태소
# 1221zilioner기본형태소
# 1222zilioner2글자이상형태소
# 1222zilioner기본형태소
# 1223zilioner2글자이상형태소
# 1223zilioner기본형태소
# 1224zilioner2글자이상형태소
# 1224zilioner기본형태소
# 1225zilioner2글자이상형태소
# 1225zilioner기본형태소
# 1226zilioner2글자이상형태소
# 1226zilioner기본형태소
# 1227zilioner2글자이상형태소
# 1227zilioner기본형태소
# 1228zilioner2글자이상형태소
# 1228zilioner기본형태소

# %%
1206ddahyoni기본형태소
# Out:
#   File "<ipython-input-121-714513595903>", line 1
#     1206ddahyoni기본형태소
#                     ^
# SyntaxError: invalid syntax
