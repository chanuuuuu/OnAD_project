# %%
import pickle
with open('./#zilioner/2018-12-12_#zilioner_기본형태소.pickle', 'rb') as f : 
    p = pickle.load(f)

# %%
p
# Out:
# [('ㅋㅋ', 62975),
#  ('ㅠ', 8489),
#  ('ㄴ', 6492),
#  ('이', 5873),
#  ('ㅇ', 4771),
#  ('?', 4496),
#  ('아', 4418),
#  ('하', 4280),
#  ('ㄱ', 3314),
#  ('ㅗ', 2922),
#  ('어', 2164),
#  ('ㄷㄷ', 2137),
#  ('는', 2081),
#  ('다', 1970),
#  ('ㅇㅈ', 1947),
#  ('풍', 1888),
#  ('네', 1866),
#  ('.', 1862),
#  ('ㄹ', 1801),
#  ('보', 1567),
#  ('앗', 1521),
#  ('지', 1402),
#  ('...', 1349),
#  ('~', 1343),
#  ('가', 1334),
#  ('오', 1328),
#  ('ㅁ', 1231),
#  ('ㅋㅋㅋ', 1211),
#  ('시', 1210),
#  ('었', 1118),
#  ('!', 1111),
#  ('맨', 1101),
#  ('BibleThump', 1095),
#  ('매', 1082),
#  ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 1067),
#  ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 1065),
#  ('ㄷㄷㄷ', 1027),
#  ('그', 1025),
#  ('은', 994),
#  (';', 976),
#  ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 974),
#  ('키', 946),
#  ('에', 935),
#  ('ㅋㅋㅋㅋㅋㅋㅋ', 916),
#  ('았', 901),
#  ('기', 877),
#  ('ㅋㅋㅋㅋㅋ', 873),
#  ('거', 841),
#  ('게', 800),
#  ('펄', 799),
#  ('김풍', 783),
#  ('나', 757),
#  ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 725),
#  ('야', 694),
#  ('데', 685),
#  ('절', 680),
#  ('바', 659),
#  ('침', 656),
#  ('의', 652),
# ...

# %%
print('dkdkdkkd{}{}'.format(2,3))
# Out:
# dkdkdkkd23
