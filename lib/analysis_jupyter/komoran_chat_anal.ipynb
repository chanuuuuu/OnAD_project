# %%
from konlpy.tag import Komoran
from nltk.tokenize import word_tokenize
import nltk

# %%
ko = Komoran()

# %%
text = open('../../data/chat_logs/2018-12-04_yapyap30-Copy1.log').readlines()

# %%
import re
my = re.compile('\[([0-9:]*)\] <(\S*[ ]*\S*)> (\w.*)')
word_list = []
for line in text:
    mytext = my.search(line)
    if mytext :
        word_list.append(mytext.group(3))
word_list
# Out:
# ['앗 점검',
#  '점검?',
#  '겁나 빠르네',
#  '로스트아크입니다',
#  '누구나 다 계획은 있지',
#  '무기좀 보여주세요',
#  '점검 가나연',
#  '회복무조건 사야댐',
#  '방송키고 400찍으실거죠? ㅋㅋ 아니면 인정안함 ㄹㅇ;;',
#  '점검 저거 나올때마다 불안해 죽것어',
#  '벽에붙어서가면 망자해역 안거치고 돌아갈수잇어요 성태님',
#  '뭐없네',
#  '므ㅏ애',
#  '꽝',
#  '회복형배틀 저거사샘',
#  '닥불 ㅋㅋ',
#  'ㅁㄷㅂ',
#  '킹닥불은 사야지',
#  '포션',
#  '회복약 ㄱㄱ',
#  '선물상자 사쉴?',
#  'ㅇㅇ',
#  '짱닥불',
#  '회복형 사야지',
#  '킹닥불',
#  '저거 아마 아침에 점검하지아늘까',
#  '왜혼없어',
#  '포션도 이득아님??',
#  '모닥불은 언제나 쓰니까',
#  '요즘 잘뜨더니 이번꺼 별로네',
#  '1234567',
#  '여기레려~~',
#  '포션이 개이득인데',
#  '야부야부상 견갑이 나오리라는 생각을버리십시오',
#  '포션사야지;ㅣ',
#  '선물상자도사세여 나중에 개필요함',
#  '룬 사야지',
#  'ㄴㄴ',
#  '다 사야지',
#  '어차피 2티어가자나',
#  '지갑전사니까 사자',
#  '포션만사',
#  '이제 2티어인데',
#  '사지마',
#  '얍얍이 380 넘었네 ㄷㄷ',
#  '방송키고 400찍는거 아니면 인정안하는거 아시죠? ㅋㅋ;;',
#  '2티어 금방인데 룬웨사',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '포션만 사지 포션이 개쌉이득인데',
#  '빻',
#  '2티어 ㅇㅈ',
#  '포션은?',
#  '지갑전사',
#  '빻빻빻',
#  '포션은 골드대비 이득인데',
#  '어디가?',
#  '포션은 가성비 많이이득임',
#  '7가호 쓰는데 포션이 왜 필요',
#  'ㄹㅇ 개빡치는게 그때그때 초기화 하는거',
#  '채팅 왜케 느려 머야',
#  '망자 취-약',
#  '망자 ㅅㄱ',
#  '수칸님하고 이혼함?',
#  '지도 켜',
#  '취약ㅋㅋㅋ',
#  '레이드 두피쓰나 써야해여?',
#  '회복형 배틀아이템 상자 저게 모닥불 상위호완임',
#  '대륙붙어서 가면 망자 안가도대',
#  '이틀동안 숙제로 생활도 뜷어놓으면 400 무난히 가겟다',
#  '망자의해역에서 유령선 나오냐?',
#  '아직 팔팔하네',
#  'ㄵ',
#  '왼쪽으로더ㅏ가',
#  '30',
#  'ㄴㅈ',
#  'pvp셋 2개나써야함?',
#  '느ㅡㅡㅡㅡㅡ릿',
#  '난파선있다',
#  '난파선 ㄱㄱ',
#  '돌아갈때 난파 ㅋㅋㅋ',
#  '난파선이다',
#  '난파선이ㅏㄷ',
#  '난파선도 하시지',
#  '옆에 난파선 아깝네 ㅋ',
#  '오 난파선도 있다',
#  '저기 난파선',
#  'ㅂㅂ',
#  '초기화 벌써쓴 흑우없제?',
#  '난파선',
#  '근데 이거 지도 이제 400찍어도 안바뀜?',
#  '난파 각인데',
#  '난파선부터 ㄱㄱ',
#  '금방 400이네',
#  '프뉴마-',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난파선 못함 ㅋ',
#  '터짐 이제 ㅋㅋㅋㅋㅋ',
#  '난파각인데',
#  '이걸안당하냐',
#  '난파선 먹어',
#  '백프로 돌아갈때 난파다 ㅋㅋㅋ',
#  '난파선 머함',
#  '잼파선',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅇㅇ먹어져',
#  '망자에서 난파선 못함 ㅋㅋ',
#  '먹긴하겠다',
#  '안댐',
#  '난파선 못먹음',
#  '난파각',
#  '못함',
#  '망자 취약에서 못함',
#  'ㅇㅇ',
#  '취약 ㄷㄷ',
#  '먹을수있어',
#  '없음',
#  '글쎄요 ㅎㅎ',
#  'ㅇㅇ',
#  '못들어가지 ㅋㅋ',
#  'ㅋㅋㅋㅋㅋ',
#  '내구도 팍깎임',
#  'ㅋㅋㅋㅋㅋㅋ',
#  'ㄵ',
#  '됨',
#  'ㄵ',
#  'R있자너',
#  '오',
#  '먹을수잇네',
#  '난파선 취약이라 못먹어요',
#  '바로째 ㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱ',
#  'ㄲㅂ',
#  '엥 망자가 취약이네',
#  'ㄵ',
#  '난파선 먹어 아깝다 ㅋㅋㅋ',
#  'ㄴㅈㅡㅡ',
#  '와 나 저거 어딘지몰랐는데 고맙읍니다',
#  'ㄲㅂ',
#  '취약이면 난파선못해요',
#  '얍스런',
#  'ㄴㅈ',
#  'ㄵ',
#  'ㄵ',
#  'ㄵ',
#  'ㄴㅈ',
#  '이걸 찾네',
#  '얍바',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아까 난파선있었음',
#  '빨리 가기나 하셈 ㅋㅋㅋ',
#  'ㄵ',
#  '개아프죠',
#  '왓던데로 돌아가야지 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '냠냠',
#  '아 원정대렙 30안되는구나',
#  '못나오면 레전드',
#  '들어올땐 마음대로지만 난파다',
#  '난파선만 못먹나',
#  '제발 유령선',
#  '제발 난파',
#  '취약이면 못 먹는대',
#  '난파선안ㅁ거냐?>',
#  'ㄵ',
#  '고건 몰랐네',
#  'ㄴㅈ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난파선 ㄱㄱ',
#  '엌',
#  '마리상점 확인했음?',
#  'ㅈㄴ아프죠 ㅋㅋ',
#  '여기 신세계인가',
#  '위에난파선',
#  'ㅅㄱ',
#  '난-파',
#  'ㅋㅋㅋㅋㅋ',
#  '와 개빨리단다',
#  'ㅋㅋㅋㅋ 킹자해역',
#  '응 난파야~',
#  '난파각이네',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '파사삭',
#  '난ㅡ파',
#  'ㅅㄱ',
#  '난파되라',
#  '얍바~~',
#  '위험하다',
#  'ㅋㅋㅋㅋㅋㅋㅋ ㅂㅂ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선어택하라',
#  '배 깨져',
#  '원정대 30찍어야 망자 내성 주는데',
#  '왜 그쪽으로가',
#  '빈사상태',
#  '난파 당하겟네',
#  '난파 ㅅㅅ',
#  '취-------------약',
#  '위에 난파선',
#  'ㅅㄱ',
#  '아니 왜 오른쪽으로 가냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '얍 바이무 힝',
#  '여기 난파선 한개추가요',
#  '조니뎁나옴',
#  '망자해역을 갈라하네',
#  '절 대 난 파 해',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '얍바 ㅋㅋㅋㅋ',
#  '무조건 난파임',
#  '위',
#  'ㅅㄱ',
#  'ㅅㄱ',
#  '유령선 어택해!',
#  '절머난파해',
#  '난-파',
#  '그쪽으로 가면 어떻해',
#  '응 난파',
#  'ㅅㄱ',
#  '제발 난파',
#  '일단 가긴 ㅎ야',
#  '얍바',
#  '난파 ㅅㄱ',
#  '유령선 만나라 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난파내...',
#  '못버텨',
#  '먹고 난파되겟는데?',
#  '절 대 난 파 해',
#  '난파 ㅅㄱ',
#  '위로갔어야지',
#  '난파임 ㅅㄱ',
#  '난파',
#  '망자 패널티 개빨라서',
#  '유령선 만나라 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난감자선',
#  'ㅅㄱ',
#  '바보냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난 파',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅅㄱㅇ',
#  '제발난파',
#  '난파 ㅅㄱㅇ',
#  '탭 켜놓고 가면 되는데',
#  '댕청',
#  '난파 ㅅㄱ',
#  '으휴 ㅋㅋ',
#  '괜히 원정대30랩 국룰이 아닌데',
#  '절 대 난 파 해',
#  '난파 ㅅㄱ',
#  '난파선 넌감자선 엌ㅋㅋ',
#  '킬각',
#  '800',
#  '늦었어',
#  '750',
#  '난파임',
#  '800',
#  '750아님?',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '750인가',
#  '노잼',
#  'ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '지능 오졌다',
#  '펑',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㄱㄱ',
#  'ㅂㅂ',
#  'ㅂㅂ',
#  'ㅅㄱ',
#  '오르비스섬으로 도망 ㄱ',
#  'ㅂㅂ',
#  'ㅂㅂ',
#  '환각섬 17분 남음',
#  'ㄴ난파각',
#  '얍바',
#  '그래도 싸게 잘먹었네',
#  '난 파',
#  '탭 켜놓고 가셈',
#  '펑~',
#  '절 대 난 파 해',
#  'ㅂㅂㅂㅂㅂㅂㅂㅂㅂㅂ',
#  '와 ! 오르비스',
#  '난 ㅡ파',
#  '77ㅓ억~~~~ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난파얍 ㅋㅋ',
#  'ㅂㅂ',
#  '난파각',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '킹 령 선',
#  '난파확정 쏼지ㅣㄹ러',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '들가지도못함',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '이거 되냐 ?ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅎㅇ',
#  '얍바~~~~~',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㄱㅋ',
#  '유령선 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '킹 령 선',
#  '어 유령선이다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어?',
#  '킹령선',
#  '잼령선',
#  '납치',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 떳다',
#  '킹령성ㄴㅋㅋ',
#  'DIQQK',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '납치',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선',
#  'ㅂㅇ',
#  '아직도 망자 선원이 없어??',
#  '얍바',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '헐',
#  '유령선 ㅅㄱ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅋㅋ',
#  '킹령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 ㅋㅋㅋ',
#  'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '얍바',
#  '빨린다 ㅅㄱ',
#  '유령선이다 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선',
#  'ㅈ됨',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3령선 ㅋㅋㅋㅋㅋㅋㅋ 조졋다',
#  '캐리비안 ㄷㄷ',
#  'ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '킹련선',
#  '킹령선이다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난데없이 ㅋㅋㅋ',
#  '유령선 3렙 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어차피난파인데 유령선만남 ㅋㅋㅋㅋ',
#  '킹 령 선',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅇㄱㅇ',
#  'ㅈ댐',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선 ㅋㅋ',
#  'ㅅㄱ',
#  'ㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '킹령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난파전 잡힘 ㅋㅋㅋㅋㅋ',
#  '이거 잡으면 전설선원줌',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼령선',
#  '킹령선',
#  'ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '처음본다',
#  '가즈아ㅏㅏㅏㅏㅏㅏㅏㅏ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅈ댐',
#  '짱령선',
#  '잼령선ㅋㅋㅋㅋㅋ',
#  '하이하이~~~~~~~',
#  '납치 머냐 ㅋㅋㅋ',
#  '3렙이라 ㅋㅋ',
#  '잡으면 템줌',
#  '갓령선 ㄷㄷㄷㄷㄷㄷㄷㄷ',
#  '3령선임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3레벨 개아픔',
#  '잼령선',
#  '3렙이야?',
#  '잼령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'zzzzzzz',
#  '잼령선 ㅋㅋㅋㅋ',
#  'ㄱㅇㄷ',
#  '3렙이네',
#  'ㅅㄱ',
#  '유령선...',
#  '넌뒤졋다 ㅋㅋ',
#  'ㅋㅋㅋㅋ개꿀',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '걍바로탈출하면됨',
#  '와난파선이벤트다',
#  '엌 ㅋㅋㅋㅋㅋㅋㅋ',
#  '3렙 유령선이다 ㅋㅋㅋ',
#  '탈출 ㄱ',
#  '3렙 유령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이거 깨면 전설 선원줌',
#  '와 유령선!',
#  '다잡아야죠',
#  '3랩 유령선 실화 ???????????????????????????????',
#  '유령선 3렙 ㅈㄴ 셈',
#  '선장 나온다',
#  '얍바',
#  '꺼어어억',
#  '개쌔네',
#  '이걸 유령선 만나넼ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3레벨 절대못잡는다 존나게쎄다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '플라잉 더치맨 ㄷㄷ',
#  '잼령선',
#  '너 여기서 깃털 다 빨릴껄',
#  '3렙이네 ㅋㅋㅋㅋㅋ',
#  'ㅈㄴ쌔죠',
#  '개쎔 ㅋㅋㅋ',
#  'ㅋㅋ',
#  '와 이거 첨본다',
#  '겁나셈 ㅋㅋ',
#  '그냥 나가면 배터짐 ㅋ',
#  '깃털 3개 각',
#  '튀어',
#  '3렙 유령선 못잡죠 ㅋㅋㅋ',
#  '3렙짜리임?',
#  '겁나쌤',
#  '잼령선 ㅇㄱㅇ',
#  '3랩이네익서',
#  '띠용',
#  '노 ㅡ딜',
#  '피 안달죠?',
#  '깃털3개 언더 오버',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유하 ㅋㅋㅋ',
#  '빨렸다',
#  '데미지 왜저래?',
#  '보상줌',
#  '애들 피봐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '딜 ㅋㅋ',
#  '5렙이님?',
#  '3렙이네 ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3렙 절때 못깨',
#  '얍 플 랭 크',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어엌ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '튀어야해',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '왤캐안다냐',
#  '결국걸렸네 ㅋㅋㅋ',
#  '깃털 다 빨립니다',
#  '겁나쌔죠 ㅋㅋ',
#  '유령선 존나높은데왔네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '딜이 안다네',
#  '망함 ㅋㅋㅋㅋ',
#  '탈출로나가야됨 ㅋㅋ',
#  '3령선 개쎔 ㅋㅋㅋㅋㅋㅋ',
#  'ㅈㄴ쌔서',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '존나아프죠',
#  '겁나세',
#  '3랩',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '안죽죠?',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잡몹 피보소 ㅋㅋ',
#  '3렙유령선 ;',
#  '얍바~~~~~~',
#  '탈출해 빨리',
#  '3렙 ㅈㄴ 셈 못잡음',
#  'ㅈㄴ쎄져 ㅈㅈ',
#  '3랩 ㅈㄴ쎄',
#  '개레어전설줌',
#  '3렙이죠?',
#  '피를봐 ㅋㅋ',
#  '3렙유령선 ㅋㅋㅋㅋㅋ',
#  '그냥 죽어',
#  '왜 안달까?',
#  '걍 탈출하면 되는데 ㅋㅋ',
#  '쥰내쌔거든 ㅋㅋ',
#  '조온나쌔네',
#  '아니 이거 그냥 뒤지고 나가 애들 존나쎄',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '3렙은 파티로잡는거',
#  '3랩이라',
#  '플라잉더치맨',
#  '참고로 겁.나.셉.니.다',
#  '스치면 뒤짐',
#  '정예니까요ㅛ',
#  '잡으면 유령선줌',
#  '높아서그럼',
#  'ㅋㅋㅋㅋㅋㅋ ㅈㄴ쌔네',
#  '걍나가 여긴 ㅋㅋㅋㅋㅋㅋㅋ',
#  '안뒤진다 ㅋㅋㅋ',
#  '권장렙 최소 400',
#  '잡으면 전설선원줌',
#  '피 안닳음 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '너여기서주굼 ㅅㄱ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '절대못이김',
#  '3렙 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '처음부터 3렙을 가네 ㅋㅋㅋㅋㅋㅋ',
#  '3렙이라 못잡음',
#  '몰이사냥하네 ㄷㄷ',
#  '3렙 유령선 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '컨으로 10가능',
#  '440도 3렙유령선한테 털리죠 ㅋㅋ?',
#  '유령선 나이따~',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '애들 레벨 450넘어',
#  '3렙 유령선임? ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개쎄다 ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '탈출하셈',
#  '망자가 산 자의 영혼을 원한다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '걍 나가',
#  '얍바 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3랩 유령선 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '탗룰',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령이랑 pvp하시던지~',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '체력 5만',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '레전드 ㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '톡',
#  '자살',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3렙 유령',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '풉',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '배터졌죠?',
#  'zzzzzzzzzzz',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잡으면 유령선 줍니다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '나가기 ㄱ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ나가',
#  '평타한방에 1700',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋ ㅁㅊ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '한 방',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개어렵구요ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엌ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '와 개쌔네',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '걍 나가',
#  '난파 확정',
#  '으허허허허',
#  '하하하하하핳하',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '난 파',
#  'ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '흐하하하 으억!',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '깃써서 가능',
#  '어엌ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이거 절대못깨',
#  'ㅋzzzz',
#  '크림슨발록 ㅋㅋㅋ',
#  '440도 털림 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㄴㄴ',
#  '잡으면ㅇ ㅠ령선얻어ㅇ',
#  '개쌔네 ㅋㅋㅋㅋㅋㅋㅋ',
#  '나가',
#  '나가',
#  '나가걍',
#  '유령선 선박 최초 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ',
#  '끔살',
#  '난파 ㅅㄱ',
#  'ㅋㅋㅋㅋㅋ',
#  '유령선 개꿀인데',
#  '이걸 나가네 ㅡㅡ',
#  '두방 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '쫄?',
#  '나가',
#  'NAGA',
#  '나가셈',
#  '쓰레기임',
#  '나가',
#  'ㄴㄴㄴ',
#  'ㅋㅋㅋㅋㅋ',
#  '사나이 자존심이 있지',
#  'ㄴㄴ',
#  '개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅇㅇ',
#  '빤스런 ㄱ',
#  '나가',
#  'anwhrjs',
#  '아크 ㅅㄱ',
#  '앗',
#  '절대못깨',
#  '트라이 ㄱㄱ',
#  'ㄴㄴ',
#  '절대못잡음',
#  'ㄴㄴ',
#  '이걸 빤쓰런하네',
#  'ㅇㅇ 나가',
#  'ㅇㅇ 나가',
#  '나가야됨',
#  'ㄴㄴ 못깨',
#  '나가',
#  '3렙이라 무리',
#  '나가세요',
#  '나가셈 그냥',
#  '나가',
#  'ㄴㄴㄴ',
#  '이거못해',
#  '나가',
#  '이걸안함?ㄷㄷ',
#  '무조건해야되',
#  '개좋음 해야됨',
#  'ㄴㄴㄴ',
#  '런해',
#  '못잡아',
#  '애들 450 넘어',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '와 3랩 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'wjfeogo',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '나가 못깨 절대로',
#  '나가',
#  '걍 나가셈',
#  '유령선 어차피 먹을거없어',
#  '절대못함',
#  '빤스런',
#  '못잡아 도망가',
#  '해야지',
#  '못잡으니까',
#  'ㄴㄴ',
#  '3렙못잡음',
#  'ㄴㄴ 무리',
#  '이거 어챂 ㅣ못깨',
#  '440도 걍털림',
#  '나가',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '쫄 ?',
#  '이거 보상 개좋은데',
#  '무조건해야함 개사기 선원줌',
#  '절대못깸',
#  '애바야',
#  '못깸',
#  '그거 맨날 있어',
#  '절대못깨',
#  '얘 600렙으로 와야해',
#  '무조건해',
#  '좋은거 주긴함',
#  '깃써야됨',
#  '쫄?',
#  '500랩은되야 잡을걸',
#  '전 설 선 원 뜹 니 다',
#  '야 자존심이있지',
#  'ㄴㄴㄴ',
#  '나가면 난파확정',
#  '절대 못깨',
#  '당연히 해야지',
#  '절대못갬 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '못잡음',
#  '크림슨발록 ㅋㅋㅋㅋㅋ',
#  '못잡아',
#  '쫄?',
#  'ㄴㄴㄴ못함',
#  '최초클 안해?',
#  '못잡음',
#  '이걸 나가네 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '나가',
#  '애들 레벨 450 넘어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '런',
#  '나가센',
#  '버프있어야돼',
#  '시간낭비임',
#  '440도죽어',
#  '남자도아니네요 성태씨',
#  '절대 못깸',
#  '스트리머라면 트라이해야지',
#  '이걸 나가네 ㅋㅋ',
#  '데비존스 ㄷ ㄷ ㄷ ㄷ',
#  '쫄쫄 ?',
#  '500넘겨야해 이거',
#  '못꺠고 탈출 눌러요',
#  '여기서 유령선 설계도줌',
#  '선원 존나좋은애줌',
#  '나가 절대 멋해',
#  '400넘어도 털리는거야',
#  '난파얍',
#  '쫄?',
#  '이거 해야되는데 ㅋㅋ;',
#  '가능해',
#  '이걸 나간다고?ㅋㅋㅋㅋ',
#  '쫄려?',
#  '이서못깨',
#  '별로 보상도 안 좋음',
#  '남자도 아니다 ㅡㅡ',
#  '깨면 500',
#  '게이특 ㅋㅋ',
#  'ㄴㅈ',
#  '깨도 별 ㅈ도 안줘 아무것도 안줘',
#  '깃써야됨 이거',
#  '난 하',
#  '못이김',
#  '쫄?',
#  '쫄?',
#  '보상 개좋긴한대 못잡어',
#  '캐릭초기화 나이따',
#  '크림슨발록 ㅋㅋㅋ',
#  '좋은 거 주겠지',
#  '못깨짘ㅋㅋㅋㅋㅋㅋㅋ',
#  '쫄앗냐?',
#  '3렙 유령선 어차피 맨날 있어 못꺨뿐이야',
#  '못 잡 아',
#  '절대 깃털써',
#  '쫄 설 태',
#  '깃털전사 하면 가능',
#  '절대못자방',
#  '이걸나가네 ㅋㅋㅋㅋ;;',
#  '이걸나가네 ㅡㅡ',
#  '쫄?',
#  '쫄',
#  '이걸 나가네?',
#  '500넘겨야됨',
#  '아크줌',
#  '데비존스자 ㅋㅋ',
#  '잡아도 루페온 인장만 줌',
#  '500은 되야할텐데',
#  '전설선원줘',
#  '이걸나가?ㄷㄷ',
#  '쫄 성 태',
#  '켠왕 ㄱ?',
#  '절 대 못 잡 아',
#  '만나기 ㅈㄴ힘들긴함',
#  '유령선 설계도 준다고',
#  '절대못깸',
#  '이걸 나가네 ㅋㅋㅋㅋ',
#  '템겁나줌',
#  '이거 깨면 에픽템준다고',
#  '전설',
#  '깨면 템주는데',
#  '절대못깨',
#  '유령선 ㄱㄱ',
#  '쫄?',
#  '유령선 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ',
#  '3렙절대못잡아',
#  '그냥 나가면 ㅈ됨',
#  'ㅈ도안줘',
#  '못해',
#  '유령선 만들수있는 템나오는거아님?',
#  '해봤자 못깸',
#  '잡으면개꿀임',
#  '못 깨고 보상도 후짐',
#  '쫄',
#  '전설선원줌',
#  '유령선줌',
#  '좆도엇ㅂ어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '500랩은되야 잡음',
#  '전 설 선 원 줍 니 다',
#  '데비존스좌 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '템렙 500 넘어야한다',
#  '절대 못잡아',
#  '시간제한까지있어서 못깨',
#  '유령선뜸 확률로',
#  '전설줌',
#  '보스 개무섭게생겼다 ㅋㅋㅋ',
#  '유령선',
#  '못잡아',
#  '전설선원줌',
#  'ㅉ?',
#  '아 절대못깬다고 그냥 나가',
#  '이걸째네',
#  '선원 줘 깨면',
#  '이걸나가네',
#  '보상좋은데',
#  '지금 렙에 절대못해',
#  '쫄성태',
#  '좋은거줌',
#  '선원줌',
#  '에이번의 유령선',
#  '쫄?',
#  '이거 꺠면 아크라시움 2준다고',
#  '아니 성공못한다니까',
#  '유령선은 보상도 쓰레기',
#  '사나이 김성태 쫄?',
#  '유령선, 전설선원',
#  '세계최초 ㄷㄷㄷ',
#  '여기서 에이번의 상처 주는데',
#  '못잡음',
#  '성공하면 각인서 주더라 하지마',
#  '500짜리 컨텐츠',
#  '보상 유령선',
#  '전설지도줌',
#  '선원 확률로 떨굼',
#  '개털임',
#  '안준다고 쓰레기만줘',
#  '아크 기본 4개임',
#  '전설선원주는데 이걸거르네',
#  '그냥 선원줌',
#  '이거 왜 나가',
#  '템 오지는거 줌',
#  '유령선',
#  '절대 포기해',
#  '절대못깨',
#  '크림슨발록 ㅋㅋㅋㅋㅋㅋ',
#  '성공하면 유령선줌',
#  '유령선 줌',
#  '텝겁나줌 ㅋㅋㅋㅋㅋ',
#  '별루 좋은거 안줌',
#  '해봤자 못깸 하지마셈',
#  '개쩌는 전설선원',
#  '전설해적선원 줌',
#  '전설줌',
#  '500 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유령선 줘 이거 꺠면',
#  '배 줘요',
#  '업적',
#  '켠왕 ㄱ?',
#  '깃털500개로도 불가능',
#  '전설줌',
#  '딜이안들어가는데 어캐깰려고 ㅋㅋ',
#  '유령선',
#  '루페온 인장만 ㅈㄴ 나옴',
#  '절대못잡음',
#  '쓰레기만줌',
#  '유령선 재료',
#  '3랩유령선 깨긴 깻음 전설 선원줌',
#  '넌 절대로 못 깨',
#  '이거 꺠면 지존템준다고',
#  '유령선',
#  '사나이 김성태!!',
#  '하나만 써보자',
#  '500짜리 컨텐츠야',
#  '템줌',
#  'ㅖ',
#  '선원 확률로 줌',
#  'ㅔ',
#  '370이상이면 할만해',
#  '너 못잡아',
#  '유령선 전용 선원 개사기줌',
#  '꺠면 여친 생김',
#  '블랙펄줌',
#  '유령선을 나가네 ㅋㅋㅋ',
#  '데비존스 가능?',
#  '성공할 생각을 하네',
#  '구라임',
#  'ㄱㄱ',
#  '쫄?',
#  '유령선줌',
#  '유령선 설계도',
#  '선원확률로 주는데 절대 못잡아',
#  '유령선 세계 최초 ㄷㄷㄷㄷㄷㄷㄷㄷ',
#  '8000골 줌',
#  '12분만에 못깸',
#  '그거 500렙 되야 ...',
#  '3레벨 못잡어',
#  '유령선이요',
#  '깃털 63개 다쓰려고?',
#  '보상 실링임 ;',
#  '최초되겠네',
#  '그냥 나가면 ㅈㅈ 됩니다',
#  '확률임',
#  '스폰지밥줌',
#  '헤딩하자',
#  '못한다니까 ㅋㅋ',
#  '좋은거 안줌',
#  '님컨에 무리아님?',
#  '좋은거 주는데 넌 안댐',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개좋은거줌',
#  '사ㅡ나이김서앹',
#  '크림슨발록이야 못이김',
#  '운빨임',
#  '에픽템',
#  '깸;;',
#  '못 잡어 절대 혼자',
#  '못잡아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '500\\',
#  '대신 유령선에만 태울수있어',
#  '이거 꺠면 유령선준다고',
#  '컨텐츠는 봐야지',
#  '남자면 고다',
#  '파티해야깨',
#  '잡으면개꿀임 ㄹㅇ;',
#  '못깨니까 하지마셈',
#  '유령선줘',
#  'ㅇㅇ 선원주는거맞음',
#  '유령선 줄수도 있음',
#  '전설 선원줌',
#  '유령선줌',
#  '스폰지밥 줌 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남자 김성태',
#  '시간 없어서 못 꺰',
#  '가보자 감자야',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '깰생각을하네',
#  '1억줌',
#  '걍나가',
#  '유령선도 줘',
#  '김성태 넌 못해',
#  '사나이 김성태!!!',
#  '가자ㅏㅏㅏㅏㅏㅏㅏㅏㅏ',
#  '일정 확률로 유령선 전용 전설선원',
#  '개소리야 쓰레기만줌',
#  '확률로 줘 확률로 준다고',
#  '유령선 전용 선원이야',
#  '370이상이면 할만해 ;;',
#  '시간낭비야',
#  '운빨임',
#  '쫄?',
#  '전설 유령선원줌',
#  'ㄱ?',
#  '못깸',
#  '사나이 김성태 포기란 모른다',
#  '유령선도 있음',
#  '또 오기생긴다',
#  '못깸',
#  '못깬다니깐',
#  '확률이야 그것도',
#  '어려운 만큼 전설 주지!',
#  '유령선 배 줌',
#  '유령선 세계최초 ㄷㄷ',
#  '스폰지밥 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '낮은확률로 선원 유령선줌',
#  '사나이 김성태',
#  'ㅋㅋㅋㅋㅋ',
#  'ㄴㄴ 별거 안줌',
#  '얻어도 못써',
#  '응못깨',
#  '너 이정도야?',
#  '전설지도줌 ㄱㄱㄱ',
#  '1시간 켠왕 해야돼 진짜로',
#  '별ㄹ안주ㅝ',
#  '님 절대못잡음',
#  ...]

# %%
len(word_list)
# Out:
# 74846

# %%
word_joint = ' '.join(word_list)

# %%
len(word_joint)
# Out:
# 793310

# %%
# i = 0
# word = str()
# for tuplist in pos_list : 
# #     print(len(tuplist))
#     for tup in tuplist : 
#         i += 1
#         if i == len(tuplist): 
#             word += (' ' + tup[0])
#             i = 0
#         else : 
#             word += tup[0]
            
# word

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin' :#맥
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows' : 
    #폰트 차후 확인
    fontPath = 'c:/Windows/Fonts/malgun.ttf'
    fontName = font_manager.FontProperties(fname=fontPath).get_name()
    rc('font', family=fontName)
elif platform.system() == 'Linux' : 
    fontPath = '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf'
    fontName = font_manager.FontProperties(fname=fontPath).get_name()
    rc('font', family=fontName)
#     fontPath =  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEco.ttf',

else : print('알수없음')
import seaborn as sns

# %%
tokens_ko = ko.nouns(word_joint)
# Out:
# ---------------------------------------------------------------------------
# java.lang.OutOfMemoryErrorPyRaisable      Traceback (most recent call last)
# <ipython-input-10-2096884ded09> in <module>
# ----> 1 tokens_ko = ko.nouns(word_joint)
#
# ~/anaconda3/lib/python3.6/site-packages/konlpy/tag/_komoran.py in nouns(self, phrase)
#      79         """Noun extractor."""
#      80
# ---> 81         tagged = self.pos(phrase)
#      82         return [s for s, t in tagged if t.startswith('NN')]
#      83
#
# ~/anaconda3/lib/python3.6/site-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten, join)
#      64
#      65         for sentence in sentences:
# ---> 66             result = self.jki.analyze(sentence).getTokenList()
#      67             result = [(token.getMorph(), token.getPos()) for token in result]
#      68
#
# java.lang.OutOfMemoryErrorPyRaisable: java.lang.OutOfMemoryError: GC overhead limit exceeded

# %%
tk = nltk.Text(tokens_ko)

# %%
# tokens_ko = []
# for wd in word_list : 
#     tokens_ko.append(ko.morphs(wd))

# %%
tokens_ko
# Out:
# [['앗', '점검'],
#  ['점검', '?'],
#  ['겁나', '아', '빠르', '네'],
#  ['로스트', '아크', '이', 'ㅂ니다'],
#  ['누구', '나', '다', '계획', '은', '있', '지'],
#  ['무기', '좀', '보이', '어', '주', '시', '어요'],
#  ['점검', '가', '나연'],
#  ['회복', '무조건', '사', '아야', '대', 'ㅁ'],
#  ['방송',
#   '하',
#   '기',
#   '이',
#   '고',
#   '400',
#   '찍',
#   '으시',
#   'ㄹ',
#   '거',
#   '죠',
#   '?',
#   'ㅋㅋ',
#   '아니',
#   '면',
#   '인정',
#   '안함',
#   'ㄹㅇ;;'],
#  ['점검', '저것', '나오', 'ㄹ', '때', '마다', '불안', '하', '아', '죽', '것', '어'],
#  ['벽',
#   '에',
#   '붙',
#   '어서',
#   '가',
#   '면',
#   '망자',
#   '해역',
#   '안',
#   '거치',
#   '고',
#   '돌아가',
#   'ㄹ',
#   '수',
#   '잇',
#   '어요',
#   '성태',
#   '님'],
#  ['뭐', '없', '네'],
#  ['므ㅏ애'],
#  ['꽝'],
#  ['회복', '형', '배틀', '저', '거사', '샘'],
#  ['다고', '학부', 'ㄹ', 'ㅋㅋ'],
#  ['ㅁㄷㅂ'],
#  ['킹', '다고', '학', '불', '은', '사', '아야지'],
#  ['포', '션'],
#  ['회복', '약', 'ㄱㄱ'],
#  ['선물', '상자', '사', '쉬', 'ㄹ', '?'],
#  ['ㅇㅇ'],
#  ['짱닥불'],
#  ['회복', '형', '사', '아야지'],
#  ['킹', '다고', '학부', 'ㄹ'],
#  ['저것', '아마', '아침', '에', '점검', '하', '지', '아', '늘', 'ㄹ까'],
#  ['왜', '혼', '없어'],
#  ['포', '션', '도', '이득', '아', '님', '?', '?'],
#  ['모닥불', '은', '언제나', '쓰', '니까'],
#  ['요즘', '잘', '뜨', '더니', '이번', '꺼', '별로', '네'],
#  ['1234567'],
#  ['여기레려~~'],
#  ['포', '션', '이', '개', '이득', '이', 'ㄴ데'],
#  ['야',
#   '부',
#   '야',
#   '부상',
#   '견',
#   '갑',
#   '이',
#   '나오',
#   '리라는',
#   '생각',
#   '을',
#   '버리',
#   '시',
#   'ㅂ시오'],
#  ['포션사야지;ㅣ'],
#  ['선물', '상자', '도사', '세', '이', '어', '나중', '에', '개', '필요', '하', 'ㅁ'],
#  ['루', 'ㄴ', '사', '아야지'],
#  ['ㄴ', 'ㄴ'],
#  ['다', '사', '아야지'],
#  ['어차피', '2', '티어', '가자', '나'],
#  ['지갑', '전사', '이', '니까', '사자'],
#  ['포', '션', '만사'],
#  ['이제', '2', '티어', '이', 'ㄴ데'],
#  ['사', '지', '말', '아'],
#  ['아야', '합', '아야', '합', '이', '380', '넘', '었', '네', 'ㄷㄷ'],
#  ['방송',
#   '하',
#   '기',
#   '이',
#   '고',
#   '400',
#   '찍',
#   '는',
#   '거',
#   '아니',
#   '면',
#   '인정',
#   '안',
#   '하',
#   '는',
#   '거',
#   '알',
#   '시',
#   '죠',
#   '?',
#   'ㅋㅋ;;'],
#  ['2', '티어', '금방', '이', 'ㄴ데', '룬웨사'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['포', '션', '만', '사지', '포', '션', '이', '개쌉이득인데'],
#  ['빻'],
#  ['2', '티어', 'ㅇㅈ'],
#  ['포', '션', '은', '?'],
#  ['지갑', '전사'],
#  ['빻', '빻', '빻'],
#  ['포', '션', '은', '골드', '대비', '이득', '이', 'ㄴ데'],
#  ['어디', '가', '?'],
#  ['포', '션', '은', '가', '성비', '많이', '이득', '이', 'ㅁ'],
#  ['7', '가호', '쓰', '는데', '포', '션', '이', '왜', '필요'],
#  ['ㄹㅇ', '개빡치는게', '그때그때', '초기', '화', '하', '는', '거'],
#  ['채팅', '왜', '하', '게', '느리', '어', '머', '야'],
#  ['망자', '취-약'],
#  ['망자', 'ㅅㄱ'],
#  ['수', '칸', '님', '하', '고', '이혼', '하', 'ㅁ', '?'],
#  ['지도', '켜', '어'],
#  ['취약ㅋㅋㅋ'],
#  ['레이드', '두피', '쓰', '나', '쓰', '어야', '하', '아', '이', '어', '?'],
#  ['회복',
#   '형',
#   '배틀',
#   '아이템',
#   '상자',
#   '저',
#   '게',
#   '모닥불',
#   '상위',
#   '호',
#   '와',
#   'ㄴ',
#   '이',
#   'ㅁ'],
#  ['대륙', '붙', '어서', '가', '면', '망자', '알', 'ㄴ', '가도', '대'],
#  ['이틀', '동안', '숙제', '로', '생활', '도', '뜷어놓으면', '400', '무난히', '가겟다'],
#  ['망', '자의', '해역', '에서', '유령선', '나오', '냐', '?'],
#  ['아직', '팔', '팔', '하네'],
#  ['ㄵ'],
#  ['왼쪽으로더ㅏ가'],
#  ['30'],
#  ['ㄴㅈ'],
#  ['pvp셋', '2', '개', '나', '쓰', '어야', '하', 'ㅁ', '?'],
#  ['느ㅡㅡㅡㅡㅡ릿'],
#  ['난파선', '있다'],
#  ['난파선', 'ㄱㄱ'],
#  ['돌아가', 'ㄹ', '때', '난파', 'ㅋㅋㅋ'],
#  ['난파선', '이다'],
#  ['난파선이ㅏㄷ'],
#  ['난파선', '도', '하', '시', '지'],
#  ['옆', '에', '난파선', '아깝', '네', 'ㅋ'],
#  ['오', '난파선', '도', '있', '다'],
#  ['저기', '난파선'],
#  ['ㅂㅂ'],
#  ['초기', '화', '벌써', '쓰', 'ㄴ', '흑우', '없', '제', '?'],
#  ['난파선'],
#  ['근데', '이것', '지도', '이제', '400', '찍', '어도', '안', '바뀌', 'ㅁ', '?'],
#  ['난파', '각', '이', 'ㄴ데'],
#  ['난파선', '부터', 'ㄱㄱ'],
#  ['금방', '400', '이', '네'],
#  ['프뉴마-'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난파선', '못하', 'ㅁ', 'ㅋ'],
#  ['터지', 'ㅁ', '이제', 'ㅋㅋㅋㅋㅋ'],
#  ['난파', '각', '이', 'ㄴ데'],
#  ['이', '걸', '안', '당하', '냐'],
#  ['난파선', '먹', '어'],
#  ['백프로', '돌아가', 'ㄹ', '때', '난파', '다', 'ㅋㅋㅋ'],
#  ['난파선', '머', '하', 'ㅁ'],
#  ['재', 'ㅁ', '파', '아서', 'ㄴ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅇㅇ먹어져'],
#  ['망자', '에서', '난파선', '못하', 'ㅁ', 'ㅋㅋ'],
#  ['먹', '기', 'ㄴ', '하', '겠', '다'],
#  ['안', '댐'],
#  ['난파선', '못', '먹', '음'],
#  ['난파', '각'],
#  ['못하', 'ㅁ'],
#  ['망자', '취약', '에서', '못하', 'ㅁ'],
#  ['ㅇㅇ'],
#  ['취약', 'ㄷㄷ'],
#  ['먹', '을', '수', '있', '어'],
#  ['없', '음'],
#  ['글쎄요', 'ㅎㅎ'],
#  ['ㅇㅇ'],
#  ['못', '들어가', '지', 'ㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['내구', '도', '팍', '깎이', 'ㅁ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['ㄵ'],
#  ['되', 'ㅁ'],
#  ['ㄵ'],
#  ['R', '있', '자', '너'],
#  ['오'],
#  ['먹', '을', '수', '잇', '네'],
#  ['난파선', '취약', '이', '라', '못', '먹', '어요'],
#  ['바로', '째', 'ㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱㄱ'],
#  ['ㄲㅂ'],
#  ['엥', '망자', '가', '취약', '이', '네'],
#  ['ㄵ'],
#  ['난파선', '먹', '어', '아깝', '다', 'ㅋㅋㅋ'],
#  ['ㄴ즈ㅡ'],
#  ['오', '아', '나', '저것', '어디', 'ㄴ지', '모르', '았', '는데', '고맙', '읍니다'],
#  ['ㄲㅂ'],
#  ['취약', '이', '면', '난파선', '못', '하', '아요'],
#  ['아야', '합', '스럽', 'ㄴ'],
#  ['ㄴㅈ'],
#  ['ㄵ'],
#  ['ㄵ'],
#  ['ㄵ'],
#  ['ㄴㅈ'],
#  ['이거', 'ㄹ', '찾', '네'],
#  ['아야', '합', '바'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['아까', '난파선', '있', '었', '음'],
#  ['빨리', '가', '기', '나', '하', '셈', 'ㅋㅋㅋ'],
#  ['ㄵ'],
#  ['개', '아프', '죠'],
#  ['오', '앗', '던', '데', '로', '돌아가', '아야지', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['냠냠'],
#  ['아', '원정대렙', '30', '안', '되', '는구나'],
#  ['못', '나오', '면', '레전드'],
#  ['들어오', 'ㄹ', '때', 'ㄴ', '마음', '대로', '이', '지만', '난파', '다'],
#  ['난파선', '만', '못', '먹', '나'],
#  ['제발', '유령선'],
#  ['제발', '난파'],
#  ['취약', '이', '면', '못', '먹', '는', '대'],
#  ['난파선', '안', 'ㅁ', '거냐', '?', '>'],
#  ['ㄵ'],
#  ['고건', '모르', '았', '네'],
#  ['ㄴㅈ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난파선', 'ㄱㄱ'],
#  ['엌'],
#  ['마리', '상점', '확인', '하', '았', '음', '?'],
#  ['ㅈㄴ아프죠', 'ㅋㅋ'],
#  ['여기', '신세계', '인가'],
#  ['위', '에', '난파선'],
#  ['ㅅㄱ'],
#  ['난', '-', '파'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['오', '아', '개', '빨리', '단다'],
#  ['ㅋㅋㅋㅋ', '킹', '자', '해역'],
#  ['응', '나', 'ㄴ', '파야', '~'],
#  ['난파', '각', '이', '네'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['파사', '삭'],
#  ['나', '느', '파'],
#  ['ㅅㄱ'],
#  ['난파', '되', '라'],
#  ['아야', '합', '바', '~', '~'],
#  ['위험', '하', '다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋ', 'ㅂㅂ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', '어택', '하', '라'],
#  ['배', '깨지', '어'],
#  ['원정', '대', '30', '찍', '어야', '망자', '내성', '주', '는데'],
#  ['왜', '그쪽', '으로', '가'],
#  ['빈사', '상태'],
#  ['난파', '당하겟네'],
#  ['난파', 'ㅅㅅ'],
#  ['취-------------약'],
#  ['위', '에', '난파선'],
#  ['ㅅㄱ'],
#  ['아니', '왜', '오른쪽', '으로', '가', '냐', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['아야', '합', '바', '이', '무', '힝'],
#  ['여기', '난파선', '한', '개', '추', '가요'],
#  ['조니뎁나옴'],
#  ['망자', '해역', '을', '갈라', '하네'],
#  ['절', '대', '나', 'ㄴ', '파', '하', '아'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['아야', '합', '바', 'ㅋㅋㅋㅋ'],
#  ['무조건', '난파', '임'],
#  ['위'],
#  ['ㅅㄱ'],
#  ['ㅅㄱ'],
#  ['유령선', '어택', '하', '아', '!'],
#  ['절', '머', '난파', '하', '아'],
#  ['난', '-', '파'],
#  ['그쪽', '으로', '가', '면', '어떻해'],
#  ['응', '난파'],
#  ['ㅅㄱ'],
#  ['제발', '난파'],
#  ['일단', '가', '기', 'ㄴ', 'ㅎ야'],
#  ['아야', '합', '바'],
#  ['난파', 'ㅅㄱ'],
#  ['유령선', '만나', '라', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난파', '내', '...'],
#  ['못', '버티', '어'],
#  ['먹', '고', '난파되겟는데?'],
#  ['절', '대', '나', 'ㄴ', '파', '하', '아'],
#  ['난파', 'ㅅㄱ'],
#  ['위로', '가', '았', '어야지'],
#  ['난파', '임', 'ㅅㄱ'],
#  ['난파'],
#  ['망자', '패널', '티', '개', '빠르', '아서'],
#  ['유령선', '만나', '라', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난감', '자선'],
#  ['ㅅㄱ'],
#  ['바', '보', '냐', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나', 'ㄴ', '파'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅅㄱㅇ'],
#  ['제', '발', '난파'],
#  ['난파', 'ㅅㄱㅇ'],
#  ['탭', '켜', '어', '놓', '고', '가', '면', '되', '는데'],
#  ['댕', '청'],
#  ['난파', 'ㅅㄱ'],
#  ['으', '휴', 'ㅋㅋ'],
#  ['괜히', '원정', '대', '30', '랩', '국', '룰', '이', '아니', 'ㄴ데'],
#  ['절', '대', '나', 'ㄴ', '파', '하', '아'],
#  ['난파', 'ㅅㄱ'],
#  ['난파선', '넌', '감자', '선', '엌ㅋㅋ'],
#  ['키', 'ㄹ', '각'],
#  ['800'],
#  ['늦', '었', '어'],
#  ['750'],
#  ['난파', '임'],
#  ['800'],
#  ['750', '아', '님', '?'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['750', '인가'],
#  ['노', '재', 'ㅁ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['지능', '오', '어', '지', '었', '다'],
#  ['펑'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㄱㄱ'],
#  ['ㅂㅂ'],
#  ['ㅂㅂ'],
#  ['ㅅㄱ'],
#  ['오르비스섬으로', '도망', 'ㄱ'],
#  ['ㅂㅂ'],
#  ['ㅂㅂ'],
#  ['환각', '섬', '17', '분', '남', '음'],
#  ['ㄴ', '난파', '각'],
#  ['아야', '합', '바'],
#  ['그래도', '싸', '게', '잘', '먹', '었', '네'],
#  ['나', 'ㄴ', '파'],
#  ['탭', '켜', '어', '놓', '고', '가', '셈'],
#  ['펑', '~'],
#  ['절', '대', '나', 'ㄴ', '파', '하', '아'],
#  ['ㅂㅂㅂㅂㅂㅂㅂㅂㅂㅂ'],
#  ['오', '아', '!', '오르비스'],
#  ['나', 'ㄴ', 'ㅡ파'],
#  ['77ㅓ억~~~~ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난', '파', '아야', '합', 'ㅋㅋ'],
#  ['ㅂㅂ'],
#  ['난파', '각'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['킹', '령', '서', 'ㄴ'],
#  ['난파', '확정', '쏼지ㅣㄹ러'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['들', 'ㄹ', '가지', '도', '못하', 'ㅁ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['이것', '되', '냐', '?ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅎㅇ'],
#  ['아야', '합', '바', '~', '~', '~', '~', '~'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㄱㅋ'],
#  ['유령선', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['킹', '령', '서', 'ㄴ'],
#  ['어', '유령선', '이다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['어', '?'],
#  ['킹령선'],
#  ['잼령선'],
#  ['납치'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', '뜨', '엇', '다'],
#  ['킹령성ㄴㅋㅋ'],
#  ['DIQQK'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['납치'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선'],
#  ['ㅂㅇ'],
#  ['아직', '도', '망자', '선원', '이', '없', '어', '?', '?'],
#  ['아야', '합', '바'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['허', 'ㄹ'],
#  ['유령선', 'ㅅㄱ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅋㅋ'],
#  ['킹령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', 'ㅋㅋㅋ'],
#  ['zzzzzzzzzzzzzzzzzzzzzzzzzzzzzz'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['아야', '합', '바'],
#  ['빨리', 'ㄴ다', 'ㅅㄱ'],
#  ['유령선', '이다', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선'],
#  ['ㅈ됨'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3령선', 'ㅋㅋㅋㅋㅋㅋㅋ', '조지', '엇', '다'],
#  ['캐리', '비아', 'ㄴ', 'ㄷㄷ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['킹', '려', 'ㄴ', '서', 'ㄴ'],
#  ['킹령선이다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난데없이', 'ㅋㅋㅋ'],
#  ['유령선', '3렙', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['어차피', '난파', '이', 'ㄴ데', '유령선', '만남', 'ㅋㅋㅋㅋ'],
#  ['킹', '령', '서', 'ㄴ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅇㄱㅇ'],
#  ['ㅈ댐'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선', 'ㅋㅋ'],
#  ['ㅅㄱ'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['킹령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['난파', '전', '잡히', 'ㅁ', 'ㅋㅋㅋㅋㅋ'],
#  ['이것', '잡', '으면', '전설', '선원', '줌'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잼령선'],
#  ['킹령선'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['처음', '보', 'ㄴ다'],
#  ['가즈아ㅏㅏㅏㅏㅏㅏㅏㅏ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅈ댐'],
#  ['짱령선'],
#  ['잼령선ㅋㅋㅋㅋㅋ'],
#  ['하이', '하이', '~', '~', '~', '~', '~', '~', '~'],
#  ['납치', '멀', '냐', 'ㅋㅋㅋ'],
#  ['3렙이라', 'ㅋㅋ'],
#  ['잡', '으면', '템줌'],
#  ['갓령선', 'ㄷㄷㄷㄷㄷㄷㄷㄷ'],
#  ['3령선임', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3', '레벨', '개', '아픔'],
#  ['잼령선'],
#  ['3렙이야?'],
#  ['잼령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['zzzzzzz'],
#  ['잼령선', 'ㅋㅋㅋㅋ'],
#  ['ㄱㅇㄷ'],
#  ['3렙이네'],
#  ['ㅅㄱ'],
#  ['유령선', '...'],
#  ['넌', '뒤지', '엇', '다', 'ㅋㅋ'],
#  ['ㅋㅋㅋㅋ개꿀'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['걍바로탈출하면됨'],
#  ['와', '난파선', '이벤트', '다'],
#  ['엌', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3렙', '유령선', '이다', 'ㅋㅋㅋ'],
#  ['탈출', 'ㄱ'],
#  ['3렙', '유령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['이것', '깨', '면', '전설', '선원', '줌'],
#  ['오', '아', '유령선', '!'],
#  ['다잡', '아야죠'],
#  ['3',
#   '랩',
#   '유령선',
#   '실화',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['유령선', '3렙', 'ㅈㄴ', '셈'],
#  ['선장', '나오', 'ㄴ다'],
#  ['아야', '합', '바'],
#  ['꺼', '어', '어', '억'],
#  ['개쌔네'],
#  ['이거', 'ㄹ', '유령선', '만나넼ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3', '레벨', '절대', '못', '잡', '는다', '존', '나', '게', '쎄', '다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['프', 'ㄹ라', '잉', '더치', '맨', 'ㄷㄷ'],
#  ['잼령선'],
#  ['너', '여기', '서', '깃털', '다', '빨리', 'ㄹ', '꺼', 'ㄹ'],
#  ['3렙이네', 'ㅋㅋㅋㅋㅋ'],
#  ['ㅈㄴ쌔죠'],
#  ['개', '쎄', 'ㅁ', 'ㅋㅋㅋ'],
#  ['ㅋㅋ'],
#  ['오', '아', '이것', '첨', '보', 'ㄴ다'],
#  ['겁', '나', '셈', 'ㅋㅋ'],
#  ['그냥', '나가', '면', '배', '터지', 'ㅁ', 'ㅋ'],
#  ['깃털', '3', '개', '각'],
#  ['튀', '어'],
#  ['3렙', '유령선', '못', '잡', '죠', 'ㅋㅋㅋ'],
#  ['3렙짜리임?'],
#  ['겁나쌤'],
#  ['잼령선', 'ㅇㄱㅇ'],
#  ['3', '랩', '이', '네', '익', '서'],
#  ['띠', '용'],
#  ['노', 'ㅡ딜'],
#  ['피', '안', '달', '죠', '?'],
#  ['깃털', '3', '개', '언더', '오버'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유하', 'ㅋㅋㅋ'],
#  ['빨리', '었', '다'],
#  ['데미지', '왜', '저러', '어', '하', '아', '?'],
#  ['보상', '줌'],
#  ['애', '들', '피', '보', '아', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['디', 'ㄹ', 'ㅋㅋ'],
#  ['5렙이님?'],
#  ['3렙이네', 'ㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3렙', '절', '때', '못', '깨', '어'],
#  ['아야', '합', '프', 'ㄹ', '랭', '크'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['어엌ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['튀', '어야', '하', '아'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['왜', 'ㄹ', '캐', '아', 'ㄴ', '달', '냐'],
#  ['결국', '걸리', '었', '네', 'ㅋㅋㅋ'],
#  ['깃털', '다', '빨리', 'ㅂ니다'],
#  ['겁나쌔죠', 'ㅋㅋ'],
#  ['유령선', '존', '나', '높', '은데', '오', '았', '네', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['디', 'ㄹ', '이', '안', '다네'],
#  ['망하', 'ㅁ', 'ㅋㅋㅋㅋ'],
#  ['탈출', '로나', '가야', '되', 'ㅁ', 'ㅋㅋ'],
#  ['3령선', '개', '쎄', 'ㅁ', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅈㄴ쌔서'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['존', '나', '아프', '죠'],
#  ['겁', '나세'],
#  ['3', '랩'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['안', '죽', '죠', '?'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잡몹', '피', '보소', 'ㅋㅋ'],
#  ['3렙유령선', ';'],
#  ['아야', '합', '바', '~', '~', '~', '~', '~', '~'],
#  ['탈출', '하', '아', '빨리'],
#  ['3렙', 'ㅈㄴ', '셈', '못', '잡음'],
#  ['ㅈㄴ쎄져', 'ㅈㅈ'],
#  ['3', '랩', 'ㅈㄴ쎄'],
#  ['개', '레어', '전설', '줌'],
#  ['3렙이죠?'],
#  ['피', '를', '보', '아', 'ㅋㅋ'],
#  ['3렙유령선', 'ㅋㅋㅋㅋㅋ'],
#  ['그냥', '죽', '어'],
#  ['왜', '안', '다고', '하', 'ㄹ까', '?'],
#  ['걍', '탈출', '하', '면', '되', '는데', 'ㅋㅋ'],
#  ['쥰내쌔거든', 'ㅋㅋ'],
#  ['조온나쌔네'],
#  ['아니', '이것', '그냥', '뒤지', '고', '나', '가', '애', '들', '존나쎄'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['3렙은', '파티', '로', '잡', '는', '거'],
#  ['3', '랩', '이', '라'],
#  ['프', 'ㄹ라', '잉', '더', '하', '지', '매', 'ㄴ'],
#  ['참고', '로', '겁.나.셉.니.다'],
#  ['스치', '면', '뒤지', 'ㅁ'],
#  ['정예니까요ㅛ'],
#  ['잡', '으면', '유령선', '줌'],
#  ['높', '아서', '그러', 'ㅁ'],
#  ['ㅋㅋㅋㅋㅋㅋ', 'ㅈㄴ쌔네'],
#  ['걍나가', '여기', 'ㄴ', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['안', '뒤지', 'ㄴ다', 'ㅋㅋㅋ'],
#  ['권장렙', '최소', '400'],
#  ['잡', '으면', '전설', '선원', '줌'],
#  ['피', '안', '닳', '음', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['너여기서주굼', 'ㅅㄱ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['절대', '못', '이', '김'],
#  ['3렙', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['처음', '부터', '3렙을', '가', '네', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['3렙이라', '못', '잡음'],
#  ['몰이', '사냥', '하네', 'ㄷㄷ'],
#  ['3렙', '유령선', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['크', '어', 'ㄴ', '으로', '10', '가능'],
#  ['440', '도', '3렙유령선한테', '털리', '죠', 'ㅋㅋ?'],
#  ['유령선', '나이', '따', '~'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['애', '들', '레벨', '450', '넘', '어'],
#  ['3렙', '유령선', '임', '?', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['개', '쎄', '다', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['탈출', '하', '셈'],
#  ['망자', '가', '살', 'ㄴ', '자', '의', '영혼', '을', '원하', 'ㄴ다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['걍', '나', '가'],
#  ['아야', '합', '바', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3', '랩', '유령선', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['탗룰'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령', '이랑', 'pvp', '하', '시', '던지', '~'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['체력', '5', '만'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['레전드', 'ㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['톡'],
#  ['자살'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3렙', '유령'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['풉'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['배', '터지', '었', '죠', '?'],
#  ['zzzzzzzzzzz'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['잡', '으면', '유령선', '주', 'ㅂ니다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나가', '기', 'ㄱ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ나가'],
#  ['평', '타', '한방', '에', '1700'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋ', 'ㅁㅊ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['한', '방'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['개어렵구요ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['엌ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['오', '아', '개쌔네'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['걍', '나', '가'],
#  ['난파', '확정'],
#  ['으', '허허', '허허'],
#  ['하하하하하핳하'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나', 'ㄴ', '파'],
#  ['ㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['흐하하하', '으', '억', '!'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['깃', '쓰', '어서', '가능'],
#  ['어엌ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['이것', '절대', '못', '깨', '어'],
#  ['ㅋzzzz'],
#  ['크림슨', '발', '록', 'ㅋㅋㅋ'],
#  ['440', '도', '털리', 'ㅁ', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㄴ', 'ㄴ'],
#  ['잡으면ㅇ', 'ㅠ령선얻어ㅇ'],
#  ['개쌔네', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나', '가'],
#  ['나', '가'],
#  ['나가걍'],
#  ['유령선', '선박', '최초', 'ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ'],
#  ['끔', '살'],
#  ['난파', 'ㅅㄱ'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['유령선', '개', '꿀', '이', 'ㄴ데'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅡㅡ'],
#  ['두', '방', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['쪼', 'ㄹ', '?'],
#  ['나', '가'],
#  ['NAGA'],
#  ['나가', '셈'],
#  ['쓰레기', '이', 'ㅁ'],
#  ['나', '가'],
#  ['ㄴ', 'ㄴ', 'ㄴ'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['사나이', '자존심', '이', '있', '지'],
#  ['ㄴ', 'ㄴ'],
#  ['개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅇㅇ'],
#  ['빤스', '런', 'ㄱ'],
#  ['나', '가'],
#  ['anwhrjs'],
#  ['아크', 'ㅅㄱ'],
#  ['앗'],
#  ['절대', '못', '깨', '어'],
#  ['트라이', 'ㄱㄱ'],
#  ['ㄴ', 'ㄴ'],
#  ['절대', '못', '잡음'],
#  ['ㄴ', 'ㄴ'],
#  ['이거', 'ㄹ', '빠', 'ㄴ', '쓰', '러', 'ㄴ', '하네'],
#  ['ㅇㅇ', '나', '가'],
#  ['ㅇㅇ', '나', '가'],
#  ['나가야', '되', 'ㅁ'],
#  ['ㄴ', 'ㄴ', '못', '깨', '어'],
#  ['나', '가'],
#  ['3렙이라', '무리'],
#  ['나가', '시', '어요'],
#  ['나가', '셈', '그냥'],
#  ['나', '가'],
#  ['ㄴ', 'ㄴ', 'ㄴ'],
#  ['이것', '못', '하', '아'],
#  ['나', '가'],
#  ['이걸안함?ㄷㄷ'],
#  ['무조건', '하', '아야', '하', '되'],
#  ['개', '좋', '음', '하', '아야', '되', 'ㅁ'],
#  ['ㄴ', 'ㄴ', 'ㄴ'],
#  ['런', '하', '아'],
#  ['못', '잡', '아'],
#  ['애', '들', '450', '넘', '어'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['오', '아', '3', '랩', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['wjfeogo'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나', '가', '못', '깨', '어', '절대로'],
#  ['나', '가'],
#  ['걍', '나가', '셈'],
#  ['유령선', '어차피', '먹', '을', '거', '없어'],
#  ['절대', '못하', 'ㅁ'],
#  ['빤스', '런'],
#  ['못', '잡', '아', '도망가', '아'],
#  ['하', '아야지'],
#  ['못', '잡', '으니까'],
#  ['ㄴ', 'ㄴ'],
#  ['3렙못잡음'],
#  ['ㄴ', 'ㄴ', '무리'],
#  ['이것', '어챂', 'ㅣ못깨'],
#  ['440', '도', '걍털림'],
#  ['나', '가'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['쪼', 'ㄹ', '?'],
#  ['이것', '보상', '개', '좋', '은데'],
#  ['무조건', '하', '아야', '하', 'ㅁ', '개', '사기', '선원', '줌'],
#  ['절대', '못', '깨', 'ㅁ'],
#  ['애', '바', '야'],
#  ['못', '깨', 'ㅁ'],
#  ['그것', '맨날', '있', '어'],
#  ['절대', '못', '깨', '어'],
#  ['얘', '600렙으로', '오', '아야', '하', '아'],
#  ['무조건', '하', '아'],
#  ['좋', '은', '거', '주', '기', 'ㄴ', '하', 'ㅁ'],
#  ['깃', '쓰', '어야', '되', 'ㅁ'],
#  ['쪼', 'ㄹ', '?'],
#  ['500', '랩', '은', '되', '어야', '잡', '을', '거', 'ㄹ'],
#  ['전', '설', '서', 'ㄴ', '원', '뜹', '니', '다'],
#  ['야', '자존심', '이', '있', '지'],
#  ['ㄴ', 'ㄴ', 'ㄴ'],
#  ['나가', '면', '난파', '확정'],
#  ['절대', '못', '깨', '어'],
#  ['당연히', '하', '아야지'],
#  ['절대', '못', '개', 'ㅁ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['못', '잡음'],
#  ['크림슨', '발', '록', 'ㅋㅋㅋㅋㅋ'],
#  ['못', '잡', '아'],
#  ['쪼', 'ㄹ', '?'],
#  ['ㄴ', 'ㄴ', 'ㄴ', '못하', 'ㅁ'],
#  ['최초', '크', 'ㄹ', '안', '하', '아', '?'],
#  ['못', '잡음'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['나', '가'],
#  ['애', '들', '레벨', '450', '넘', '어', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['런'],
#  ['나가', '센'],
#  ['버프', '있', '어야', '되', '어'],
#  ['시간', '낭비', '이', 'ㅁ'],
#  ['440', '도', '죽', '어'],
#  ['남자', '도', '아니', '네요', '성태', '씨'],
#  ['절대', '못', '깨', 'ㅁ'],
#  ['스트리머라면', '트라이', '하', '아야지'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅋㅋ'],
#  ['데비', '존스', 'ㄷ', 'ㄷ', 'ㄷ', 'ㄷ'],
#  ['쫄', '쪼', 'ㄹ', '?'],
#  ['500', '넘기', '어야', '하', '아', '이것'],
#  ['못꺠고', '탈출', '누르', '어요'],
#  ['여기', '서', '유령선', '설계도', '줌'],
#  ['선원', '존', '나', '좋', '은', '애', '줌'],
#  ['나', '가', '절대', '멋', '하', '아'],
#  ['400', '넘', '어도', '털리', '는', '거', '야'],
#  ['난', '파', '아야', '합'],
#  ['쪼', 'ㄹ', '?'],
#  ['이것', '하', '아야', '되', '는데', 'ㅋㅋ;'],
#  ['가능', '하', '아'],
#  ['이거', 'ㄹ', '나간다고?ㅋㅋㅋㅋ'],
#  ['쫄', '려', '?'],
#  ['이서', '못', '깨'],
#  ['별로', '보상', '도', '안', '좋', '음'],
#  ['남자', '도', '아니', '다', 'ㅡㅡ'],
#  ['깨', '면', '500'],
#  ['게', '이특', 'ㅋㅋ'],
#  ['ㄴㅈ'],
#  ['깨', '어도', '별', 'ㅈ도', '안', '주', '어', '아무것', '도', '안', '주', '어'],
#  ['깃', '쓰', '어야', '되', 'ㅁ', '이것'],
#  ['나', 'ㄴ', '하'],
#  ['못', '이', '김'],
#  ['쪼', 'ㄹ', '?'],
#  ['쪼', 'ㄹ', '?'],
#  ['보상', '개', '좋', '기', 'ㄴ', '한대', '못', '잡', '어'],
#  ['캐릭초기화', '나이', '따', '아'],
#  ['크림슨', '발', '록', 'ㅋㅋㅋ'],
#  ['좋', '은', '거', '주', '겠', '지'],
#  ['못깨짘ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['쫄', '앗', '냐', '?'],
#  ['3렙', '유령선', '어차피', '맨날', '있', '어', '못꺨뿐이야'],
#  ['못', '잡', '아'],
#  ['절대', '깃털', '쓰', '어'],
#  ['쪼', 'ㄹ', '설', '태'],
#  ['깃털', '전사', '하', '면', '가능'],
#  ['절대', '못', '자', '방'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅋㅋㅋㅋ;;'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅡㅡ'],
#  ['쪼', 'ㄹ', '?'],
#  ['쪼', 'ㄹ'],
#  ['이거', 'ㄹ', '나가', '네', '?'],
#  ['500', '넘기', '어야', '되', 'ㅁ'],
#  ['아크', '줌'],
#  ['데비', '존스', '자', 'ㅋㅋ'],
#  ['잡', '아도', '루페온', '인장', '만', '주', 'ㅁ'],
#  ['500', '은', '되', '어야', '하', 'ㄹ텐데'],
#  ['전설', '선원', '주', '어'],
#  ['이걸나가?ㄷㄷ'],
#  ['쪼', 'ㄹ', '성', '태'],
#  ['켠', '왕', 'ㄱ?'],
#  ['절', '대', '못', '잡', '아'],
#  ['만나', '기', 'ㅈㄴ힘들긴함'],
#  ['유령선', '설계도', '주', 'ㄴ다고'],
#  ['절대', '못', '깨', 'ㅁ'],
#  ['이거', 'ㄹ', '나가', '네', 'ㅋㅋㅋㅋ'],
#  ['템겁나줌'],
#  ['이것', '깨', '면', '에픽템준다고'],
#  ['전설'],
#  ['깨', '면', '템주는데'],
#  ['절대', '못', '깨', '어'],
#  ['유령선', 'ㄱㄱ'],
#  ['쪼', 'ㄹ', '?'],
#  ['유령선', 'ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ'],
#  ['3렙절대못잡아'],
#  ['그냥', '나가', '면', 'ㅈ됨'],
#  ['ㅈ도안줘'],
#  ['못하', '아'],
#  ['유령선', '만들', '수', '있', '는', '템나오는거아님?'],
#  ['해보', '았', '자', '못', '깨', 'ㅁ'],
#  ['잡', '으면', '개', '꿀', '이', 'ㅁ'],
#  ['못', '깨', '고', '보상', '도', '후', '짐'],
#  ['쪼', 'ㄹ'],
#  ['전설', '선원', '줌'],
#  ['유령선', '줌'],
#  ['좆도엇ㅂ어', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['500', '랩', '은', '되', '어야', '잡음'],
#  ['전', '설', '서', 'ㄴ', '원', '줍', '니', '다'],
#  ['데비', '존스', '좌', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['템렙', '500', '넘', '어야', '하', 'ㄴ다'],
#  ['절대', '못', '잡', '아'],
#  ['시간제한', '까지', '있', '어서', '못', '깨', '어'],
#  ['유령선', '뜸', '확률', '로'],
#  ['전설', '줌'],
#  ['보스', '개', '무섭', '게', '생기', '었', '다', 'ㅋㅋㅋ'],
#  ['유령선'],
#  ['못', '잡', '아'],
#  ['전설', '선원', '줌'],
#  ['ㅉ?'],
#  ['아', '절대', '못', '깨', 'ㄴ다고', '그냥', '나', '가'],
#  ['이', '걸', '째', '네'],
#  ['선원', '주', '어', '깨', '면'],
#  ['이거', 'ㄹ', '나가', '네'],
#  ['보상', '좋', '은데'],
#  ['지금', '렙에', '절대', '못', '하', '아'],
#  ['쪼', 'ㄹ', '성태'],
#  ['좋', '은', '거', '주', 'ㅁ'],
#  ['선원', '줌'],
#  ['에이번', '의', '유령선'],
#  ['쪼', 'ㄹ', '?'],
#  ['이것', '꺠면', '아크라시움', '2', '주', 'ㄴ다고'],
#  ['아니', '성공', '못하', 'ㄴ다니까'],
#  ['유령선', '은', '보상', '도', '쓰레기'],
#  ['사나이', '김성태', '쪼', 'ㄹ', '?'],
#  ['유령선', ',', '전설', '선원'],
#  ['세계', '최초', 'ㄷㄷㄷ'],
#  ['여기', '서', '에이번', '의', '상처', '주', '는데'],
#  ['못', '잡음'],
#  ['성공', '하', '면', '각인', '서', '주', '더라', '하', '지', '말', '아'],
#  ['500', '짜리', '컨텐츠'],
#  ['보상', '유령선'],
#  ['전설', '지도', '줌'],
#  ['선원', '확률', '로', '떨구', 'ㅁ'],
#  ['개털', '이', 'ㅁ'],
#  ['안', '주', 'ㄴ다고', '쓰레기', '만', '주', '어'],
#  ['아크', '기본', '4', '개', '이', 'ㅁ'],
#  ['전설', '선원', '주', '는데', '이', '걸', '것', '르네'],
#  ['그냥', '선원', '줌'],
#  ['이것', '왜', '나', '가'],
#  ['템', '오지', '는', '거', '주', 'ㅁ'],
#  ['유령선'],
#  ['절대', '포기', '하', '아'],
#  ['절대', '못', '깨', '어'],
#  ['크림슨', '발', '록', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['성공', '하', '면', '유령선', '줌'],
#  ['유령선', '주', 'ㅁ'],
#  ['텝겁나줌', 'ㅋㅋㅋㅋㅋ'],
#  ['별루', '좋', '은', '거', '안', '주', 'ㅁ'],
#  ['해보', '았', '자', '못', '깨', 'ㅁ', '하', '지', '말', '아', '셈'],
#  ['개', '쩌', '는', '전설', '선원'],
#  ['전설', '해적', '선원', '주', 'ㅁ'],
#  ['전설', '줌'],
#  ['500', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['유령선', '주', '어', '이것', '꺠면'],
#  ['배', '주', '어요'],
#  ['업적'],
#  ['켠', '왕', 'ㄱ?'],
#  ['깃털', '500', '개', '로', '도', '불', '가능'],
#  ['전설', '줌'],
#  ['디', 'ㄹ', '이안', '들어가', '는데', '어', '캐', '어', '깨', 'ㄹ려고', 'ㅋㅋ'],
#  ['유령선'],
#  ['루페온', '인장', '만', 'ㅈㄴ', '나오', 'ㅁ'],
#  ['절대', '못', '잡음'],
#  ['쓰레기', '만', '주', 'ㅁ'],
#  ['유령선', '재료'],
#  ['3', '랩', '유령선', '깨', '기', 'ㄴ', '깨', '엇', '음', '전설', '선원', '줌'],
#  ['넌', '절대로', '못', '깨', '어'],
#  ['이것', '꺠면', '지존템준다고'],
#  ['유령선'],
#  ['사나이', '김성태', '!!'],
#  ['하나', '만', '쓰', '어', '보', '자'],
#  ['500', '짜리', '컨텐츠야'],
#  ['템줌'],
#  ['ㅖ'],
#  ['선원', '확률', '로', '주', 'ㅁ'],
#  ['ㅔ'],
#  ['370', '이상', '이', '면', '하', 'ㄹ', '만해'],
#  ['너', '못', '잡', '아'],
#  ['유령선', '전용', '선원', '개', '사기', '줌'],
#  ['꺠면', '여치', 'ㄴ', '생기', 'ㅁ'],
#  ['블랙펄', '줌'],
#  ['유령선', '을', '나가', '네', 'ㅋㅋㅋ'],
#  ['데비', '존스', '가능', '?'],
#  ['성공', '하', 'ㄹ', '생각', '을', '하네'],
#  ['구', '라임'],
#  ['ㄱㄱ'],
#  ['쪼', 'ㄹ', '?'],
#  ['유령선', '줌'],
#  ['유령선', '설계도'],
#  ['선원', '확률', '로', '주', '는데', '절대', '못', '잡', '아'],
#  ['유령선', '세계', '최초', 'ㄷㄷㄷㄷㄷㄷㄷㄷ'],
#  ['8000', '골', '주', 'ㅁ'],
#  ['12', '분만', '에', '못', '깨', 'ㅁ'],
#  ['그것', '500렙', '되', '어야', '...'],
#  ['3', '레벨', '못', '잡', '어'],
#  ['유령선', '이', '요'],
#  ['깃털', '63', '개', '다', '쓰', '려고', '?'],
#  ['보상', '실링', '임', ';'],
#  ['최초', '되', '겠', '네'],
#  ['그냥', '나가', '면', 'ㅈㅈ', '되', 'ㅂ니다'],
#  ['확률', '임'],
#  ['스포', 'ㄴ', '지', '밥', '줌'],
#  ['헤딩하자'],
#  ['못하', 'ㄴ다니까', 'ㅋㅋ'],
#  ['좋', '은', '거', '안', '주', 'ㅁ'],
#  ['님', '크', '어', 'ㄴ', '에', '무', '리아', '님', '?'],
#  ['좋', '은', '거', '주', '는데', '넌', '안', '댐'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['개', '좋', '은', '거', '주', 'ㅁ'],
#  ['사ㅡ나이김서앹'],
#  ['크림슨', '발', '록', '이야', '못', '이', '김'],
#  ['운', '빨', 'ㄹ', '임'],
#  ['에픽템'],
#  ['깨', 'ㅁ', ';', ';'],
#  ['못', '잡', '어', '절대', '혼자'],
#  ['못', '잡', '아', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['500', '\\'],
#  ['대신', '유령선', '에', '만', '태우', 'ㄹ', '수', '있', '어'],
#  ['이것', '꺠면', '유령선', '주', 'ㄴ다고'],
#  ['컨텐츠는', '보', '아야지'],
#  ['남', '자면', '고', '다'],
#  ['파티', '하', '아야', '깨', '어'],
#  ['잡', '으면', '개', '꿀', '이', 'ㅁ', 'ㄹㅇ;'],
#  ['못', '깨', '니까', '하', '지', '말', '아', '셈'],
#  ['유령선', '주', '어'],
#  ['ㅇㅇ', '선원', '주', '는', '거', '맞', '음'],
#  ['유령선', '줄', '수도', '있', '음'],
#  ['전설', '선원', '줌'],
#  ['유령선', '줌'],
#  ['스포', 'ㄴ', '지', '밥', '주', 'ㅁ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['남자', '김성태'],
#  ['시간', '없', '어서', '못', '꺰'],
#  ['가', '아', '보', '자', '감자', '야'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['깨', 'ㄹ', '생각', '을', '하네'],
#  ['1', '억', '줌'],
#  ['걍나가'],
#  ['유령선', '도', '주', '어'],
#  ['김성태', '넌', '못하', '아'],
#  ['사나이', '김성태', '!!!'],
#  ['가자ㅏㅏㅏㅏㅏㅏㅏㅏㅏ'],
#  ['일정', '확률', '로', '유령선', '전용', '전설', '선원'],
#  ['개소', '리야', '쓰레기', '만', '주', 'ㅁ'],
#  ['확률', '로', '주', '어', '확률', '로', '주', 'ㄴ다고'],
#  ['유령선', '전용', '선원', '이야'],
#  ['370', '이상', '이', '면', '하', 'ㄹ', '만해', ';', ';'],
#  ['시간', '낭비', '야'],
#  ['운', '빨', 'ㄹ', '임'],
#  ['쪼', 'ㄹ', '?'],
#  ['전설', '유령', '선원', '줌'],
#  ['ㄱ?'],
#  ['못', '깨', 'ㅁ'],
#  ['사나이', '김성태', '포기', '란', '모르', 'ㄴ다'],
#  ['유령선', '도', '있', '음'],
#  ['또', '오기', '생기', 'ㄴ다'],
#  ['못', '깨', 'ㅁ'],
#  ['못', '깨', 'ㄴ다니까', 'ㄴ'],
#  ['확률', '이야', '그것', '도'],
#  ['어렵', 'ㄴ', '만큼', '전설', '주', '지', '!'],
#  ['유령선', '배', '주', 'ㅁ'],
#  ['유령선', '세계', '최초', 'ㄷㄷ'],
#  ['스포', 'ㄴ', '지', '밥', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['낮', '은', '확률', '로', '선원', '유령선', '줌'],
#  ['사나이', '김성태'],
#  ['ㅋㅋㅋㅋㅋ'],
#  ['ㄴ', 'ㄴ', '별거', '안', '주', 'ㅁ'],
#  ['얻', '어도', '못', '쓰', '어'],
#  ['응', '못', '깨', '어'],
#  ['너', '이', '정도', '야', '?'],
#  ['전설', '지도', '줌', 'ㄱㄱㄱ'],
#  ['1', '시간', '켠', '왕', '하', '아야', '되', '어', '진짜', '로'],
#  ['별ㄹ안주ㅝ'],
#  ['님', '절대', '못', '잡음'],
#  ...]

# %%
tk = []
for wd in tokens_ko : 
    tk.append(nltk.Text(wd))

# %%
# Out:
# [<Text: 점검...>,
#  <Text: 점검...>,
#  <Text: ...>,
#  <Text: 로스트 아크...>,
#  <Text: 계획...>,
#  <Text: 무기...>,
#  <Text: 점검 나연...>,
#  <Text: 회복...>,
#  <Text: 방송 거 인정 안함...>,
#  <Text: 점검 때 불안...>,
#  <Text: 벽 망자 해역 수 성태...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 회복 형 배틀 거사 샘...>,
#  <Text: 학부...>,
#  <Text: ...>,
#  <Text: 킹 학 불...>,
#  <Text: 포 션...>,
#  <Text: 회복...>,
#  <Text: 선물 상자 사...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 회복...>,
#  <Text: 킹 학부...>,
#  <Text: 아침 점검...>,
#  <Text: 혼 없어...>,
#  <Text: 포 션 이득 아...>,
#  <Text: 모닥불...>,
#  <Text: 요즘 이번 꺼...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 포 션 개 이득...>,
#  <Text: 야 부 야 부상 견 갑 생각...>,
#  <Text: ...>,
#  <Text: 선물 상자 도사 세 나중 개 필요...>,
#  <Text: 루...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 티어 가자...>,
#  <Text: 지갑 전사 사자...>,
#  <Text: 포 션 만사...>,
#  <Text: 티어...>,
#  <Text: ...>,
#  <Text: 합 합...>,
#  <Text: 방송 거 인정 안 거...>,
#  <Text: 티어...>,
#  <Text: ...>,
#  <Text: 포 션 사지 포 션...>,
#  <Text: ...>,
#  <Text: 티어...>,
#  <Text: 포 션...>,
#  <Text: 지갑 전사...>,
#  <Text: ...>,
#  <Text: 포 션 골드 대비 이득...>,
#  <Text: ...>,
#  <Text: 포 션 성비 이득...>,
#  <Text: 가호 포 션 필요...>,
#  <Text: 초기 거...>,
#  <Text: 채팅...>,
#  <Text: 망자...>,
#  <Text: 망자...>,
#  <Text: 수 칸 이혼...>,
#  <Text: 지도...>,
#  <Text: ...>,
#  <Text: 레이드 두피...>,
#  <Text: 회복 배틀 아이템 상자 모닥불 상위 호...>,
#  <Text: 대륙 망자 가도 대...>,
#  <Text: 이틀 동안 숙제 생활...>,
#  <Text: 망 자의 해역 유령선...>,
#  <Text: 팔 하네...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: ...>,
#  <Text: 난파선 있다...>,
#  <Text: 난파선...>,
#  <Text: 때 난파...>,
#  <Text: 난파선 이다...>,
#  <Text: ...>,
#  <Text: 난파선...>,
#  <Text: 옆 난파선...>,
#  <Text: 오 난파선...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: 초기 흑우...>,
#  <Text: 난파선...>,
#  <Text: 지도...>,
#  <Text: 난파 각...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: 난파 각...>,
#  <Text: 걸 안...>,
#  <Text: 난파선...>,
#  <Text: 백프로 때 난파...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 망자 난파선...>,
#  <Text: ...>,
#  <Text: 안 댐...>,
#  <Text: 난파선...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: 망자...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 수...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 내구...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 오...>,
#  <Text: 수...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 엥 망자...>,
#  <Text: ...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파선 못...>,
#  <Text: 합...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: 난파선...>,
#  <Text: 하 셈...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: 데...>,
#  <Text: ...>,
#  <Text: 안...>,
#  <Text: 레전드...>,
#  <Text: 때 마음 대로 난파...>,
#  <Text: 난파선...>,
#  <Text: 유령선...>,
#  <Text: 난파...>,
#  <Text: 대...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: 고건...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파선...>,
#  <Text: ...>,
#  <Text: 마리 상점 확인...>,
#  <Text: ...>,
#  <Text: 신세계 인가...>,
#  <Text: 위 에 난파선...>,
#  <Text: ...>,
#  <Text: 난 파...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: 킹 자 해역...>,
#  <Text: 파야...>,
#  <Text: 난파 각...>,
#  <Text: ...>,
#  <Text: 파사 삭...>,
#  <Text: 느 파...>,
#  <Text: ...>,
#  <Text: 난파...>,
#  <Text: 합 바...>,
#  <Text: 위험...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선 어택...>,
#  <Text: 배...>,
#  <Text: 원정 대 망자 내성...>,
#  <Text: ...>,
#  <Text: 빈사 상태...>,
#  <Text: 난파...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: 위 난파선...>,
#  <Text: ...>,
#  <Text: 오른쪽...>,
#  <Text: 합 바 이 무...>,
#  <Text: 난파선 개 추 가요...>,
#  <Text: ...>,
#  <Text: 망자 해역 갈라 하네...>,
#  <Text: 절 대 파...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: 난파 임...>,
#  <Text: 위...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선 어택...>,
#  <Text: 절 난파...>,
#  <Text: 난 파...>,
#  <Text: ...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: 난파...>,
#  <Text: 유령선...>,
#  <Text: 난파 내...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절 대 파...>,
#  <Text: 난파...>,
#  <Text: 위로...>,
#  <Text: 난파 임...>,
#  <Text: 난파...>,
#  <Text: 망자 패널 티 개...>,
#  <Text: 유령선...>,
#  <Text: 자선...>,
#  <Text: ...>,
#  <Text: 바...>,
#  <Text: 파...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 발 난파...>,
#  <Text: 난파...>,
#  <Text: 탭...>,
#  <Text: 청...>,
#  <Text: 난파...>,
#  <Text: 으 휴...>,
#  <Text: 원정 랩 국 룰...>,
#  <Text: 절 대 파...>,
#  <Text: 난파...>,
#  <Text: 난파선 넌 감자 선...>,
#  <Text: 각...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파 임...>,
#  <Text: ...>,
#  <Text: 아...>,
#  <Text: ...>,
#  <Text: 인가...>,
#  <Text: 노...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 지능...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 도망...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 환각 섬 분...>,
#  <Text: 난파...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: 파...>,
#  <Text: 탭 가 셈...>,
#  <Text: ...>,
#  <Text: 절 대 파...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난 합...>,
#  <Text: ...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 킹...>,
#  <Text: 난파 확정...>,
#  <Text: ...>,
#  <Text: 가지...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 킹...>,
#  <Text: 유령선 이다...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 납치...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 납치...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 망자 선원...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: 유령선 이다...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 캐리 비아...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 킹...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 난파 유령선 만남...>,
#  <Text: 킹...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파 전...>,
#  <Text: 전설 선원 줌...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 처음...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 하이 하이...>,
#  <Text: 납치...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 레벨 개 아픔...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 넌...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 와 난파선 이벤트...>,
#  <Text: ...>,
#  <Text: 유령선 이다...>,
#  <Text: 탈출...>,
#  <Text: 유령선...>,
#  <Text: 전설 선원 줌...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 랩 유령선 실화...>,
#  <Text: 유령선 셈...>,
#  <Text: 선장...>,
#  <Text: 합 바...>,
#  <Text: 꺼 어 어...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 레벨 절대 존...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 더치...>,
#  <Text: ...>,
#  <Text: 깃털 꺼...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: ...>,
#  <Text: 첨...>,
#  <Text: 겁 셈...>,
#  <Text: 배...>,
#  <Text: 깃털 개...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 랩...>,
#  <Text: 띠...>,
#  <Text: 노...>,
#  <Text: 피...>,
#  <Text: 깃털 개 언더 오버...>,
#  <Text: ...>,
#  <Text: 유하...>,
#  <Text: ...>,
#  <Text: 데미지...>,
#  <Text: 보상 줌...>,
#  <Text: 애 피...>,
#  <Text: 디...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절 때...>,
#  <Text: 합...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 왜...>,
#  <Text: ...>,
#  <Text: 깃털...>,
#  <Text: ...>,
#  <Text: 유령선 존...>,
#  <Text: 디 이...>,
#  <Text: ...>,
#  <Text: 탈출 로나 가야...>,
#  <Text: 개...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 존...>,
#  <Text: 겁 나세...>,
#  <Text: 랩...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 보소...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: 탈출...>,
#  <Text: 셈 못 잡음...>,
#  <Text: ...>,
#  <Text: 랩...>,
#  <Text: 개 레어 전설 줌...>,
#  <Text: ...>,
#  <Text: 피...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 탈출...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 애...>,
#  <Text: ...>,
#  <Text: 파티 거...>,
#  <Text: 랩...>,
#  <Text: ...>,
#  <Text: 참고...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선 줌...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 최소...>,
#  <Text: 전설 선원 줌...>,
#  <Text: 피...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절대 못 이 김...>,
#  <Text: ...>,
#  <Text: 처음...>,
#  <Text: 못 잡음...>,
#  <Text: 몰이 사냥 하네...>,
#  <Text: 유령선...>,
#  <Text: 가능...>,
#  <Text: 440...>,
#  <Text: 유령선 나이...>,
#  <Text: ...>,
#  <Text: 애 레벨...>,
#  <Text: 유령선 임...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: ...>,
#  <Text: 탈출 하 셈...>,
#  <Text: 망자 자 영혼...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 합 바...>,
#  <Text: ...>,
#  <Text: 랩 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령 이랑...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 체력...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 레전드...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 자살...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 배...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 평 타 한방...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 방...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 난파 확정...>,
#  <Text: 으 허허 허허...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 파...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 으...>,
#  <Text: ...>,
#  <Text: 깃...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: ...>,
#  <Text: 크림슨 발 록...>,
#  <Text: 440...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선 선박 최초...>,
#  <Text: 끔 살...>,
#  <Text: 난파...>,
#  <Text: ...>,
#  <Text: 유령선 개 꿀...>,
#  <Text: ...>,
#  <Text: 방...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 나가 셈...>,
#  <Text: 쓰레기...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 사나이 자존심...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 빤스 런...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 아크...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: 트라이...>,
#  <Text: ...>,
#  <Text: 절대 못 잡음...>,
#  <Text: ...>,
#  <Text: 빠 하네...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 나가야...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 무리...>,
#  <Text: ...>,
#  <Text: 나가 셈...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 못...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 개...>,
#  <Text: ...>,
#  <Text: 런...>,
#  <Text: ...>,
#  <Text: 애...>,
#  <Text: ...>,
#  <Text: 랩...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 나가 셈...>,
#  <Text: 유령선 거 없어...>,
#  <Text: 절대...>,
#  <Text: 빤스 런...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 무리...>,
#  <Text: ...>,
#  <Text: 440...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 보상 개...>,
#  <Text: 개 사기 선원 줌...>,
#  <Text: 절대...>,
#  <Text: 애 바...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 거...>,
#  <Text: 깃...>,
#  <Text: ...>,
#  <Text: 랩 거...>,
#  <Text: 설 원...>,
#  <Text: 자존심...>,
#  <Text: ...>,
#  <Text: 난파 확정...>,
#  <Text: 절대...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: 못 잡음...>,
#  <Text: 크림슨 발 록...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 최초 안...>,
#  <Text: 못 잡음...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 애 레벨...>,
#  <Text: 런...>,
#  <Text: 나가 센...>,
#  <Text: 버프...>,
#  <Text: 시간 낭비...>,
#  <Text: 440...>,
#  <Text: 남자 성태 씨...>,
#  <Text: 절대...>,
#  <Text: 트라이...>,
#  <Text: ...>,
#  <Text: 데비 존스...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 탈출...>,
#  <Text: 유령선 설계도 줌...>,
#  <Text: 선원 존 애 줌...>,
#  <Text: 절대 멋...>,
#  <Text: 거...>,
#  <Text: 난 합...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 이서 못 깨...>,
#  <Text: 보상...>,
#  <Text: 남자...>,
#  <Text: ...>,
#  <Text: 게 이특...>,
#  <Text: ...>,
#  <Text: 아무것...>,
#  <Text: 깃...>,
#  <Text: 하...>,
#  <Text: 못 이 김...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 보상 개 한대...>,
#  <Text: 나이...>,
#  <Text: 크림슨 발 록...>,
#  <Text: 거...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 잡...>,
#  <Text: 절대 깃털...>,
#  <Text: 설 태...>,
#  <Text: 깃털 전사...>,
#  <Text: 절대 못 자 방...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 아크 줌...>,
#  <Text: 데비 존스 자...>,
#  <Text: 인장...>,
#  <Text: 500...>,
#  <Text: 전설 선원...>,
#  <Text: ...>,
#  <Text: 성 태...>,
#  <Text: 켠 왕...>,
#  <Text: 절 대 잡...>,
#  <Text: ...>,
#  <Text: 유령선 설계도...>,
#  <Text: 절대...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 전설...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 개 꿀...>,
#  <Text: 보상 후 짐...>,
#  <Text: ...>,
#  <Text: 전설 선원 줌...>,
#  <Text: 유령선 줌...>,
#  <Text: ...>,
#  <Text: 랩 잡음...>,
#  <Text: 설 원...>,
#  <Text: 데비 존스 좌...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: 시간제한...>,
#  <Text: 유령선 뜸 확률...>,
#  <Text: 전설 줌...>,
#  <Text: 보스 개...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 전설 선원 줌...>,
#  <Text: ...>,
#  <Text: 절대...>,
#  <Text: 걸...>,
#  <Text: 선원...>,
#  <Text: ...>,
#  <Text: 보상...>,
#  <Text: 절대 못...>,
#  <Text: 성태...>,
#  <Text: 거...>,
#  <Text: 선원 줌...>,
#  <Text: 에이번 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 성공...>,
#  <Text: 유령선 보상 쓰레기...>,
#  <Text: 사나이 김성태...>,
#  <Text: 유령선 전설 선원...>,
#  <Text: 세계 최초...>,
#  <Text: 에이번 상처...>,
#  <Text: 못 잡음...>,
#  <Text: 성공 각인...>,
#  <Text: ...>,
#  <Text: 보상 유령선...>,
#  <Text: 전설 지도 줌...>,
#  <Text: 선원 확률...>,
#  <Text: 개털...>,
#  <Text: 쓰레기...>,
#  <Text: 아크 기본 개...>,
#  <Text: 전설 선원 걸 것 르네...>,
#  <Text: 선원 줌...>,
#  <Text: ...>,
#  <Text: 오지 거...>,
#  <Text: 유령선...>,
#  <Text: 절대 포기...>,
#  <Text: 절대...>,
#  <Text: 크림슨 발 록...>,
#  <Text: 성공 유령선 줌...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: 거...>,
#  <Text: 셈...>,
#  <Text: 전설 선원...>,
#  <Text: 전설 해적 선원...>,
#  <Text: 전설 줌...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 배...>,
#  <Text: 업적...>,
#  <Text: 켠 왕...>,
#  <Text: 깃털 개...>,
#  <Text: 전설 줌...>,
#  <Text: 디 이안 어...>,
#  <Text: 유령선...>,
#  <Text: 인장...>,
#  <Text: 절대 못 잡음...>,
#  <Text: 쓰레기...>,
#  <Text: 유령선 재료...>,
#  <Text: 랩 유령선 전설 선원 줌...>,
#  <Text: 넌...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 사나이 김성태 !!...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 선원 확률...>,
#  <Text: ...>,
#  <Text: 이상 만해...>,
#  <Text: ...>,
#  <Text: 유령선 전용 선원 개 사기 줌...>,
#  <Text: 여치...>,
#  <Text: 블랙펄 줌...>,
#  <Text: 유령선...>,
#  <Text: 데비 존스...>,
#  <Text: 성공 생각 하네...>,
#  <Text: 라임...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 유령선 줌...>,
#  <Text: 유령선 설계도...>,
#  <Text: 선원 확률 절대...>,
#  <Text: 유령선 세계 최초...>,
#  <Text: 골...>,
#  <Text: 분만...>,
#  <Text: ...>,
#  <Text: 레벨...>,
#  <Text: 유령선...>,
#  <Text: 깃털 개...>,
#  <Text: 보상 실링 임...>,
#  <Text: 최초...>,
#  <Text: ...>,
#  <Text: 확률 임...>,
#  <Text: 스포 지 밥 줌...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 거...>,
#  <Text: 님 리아...>,
#  <Text: 거 넌 안 댐...>,
#  <Text: ...>,
#  <Text: 개 거...>,
#  <Text: ...>,
#  <Text: 크림슨 발 록 못 이 김...>,
#  <Text: 운 임...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 절대 혼자...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 대신 유령선 수...>,
#  <Text: 유령선...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 파티...>,
#  <Text: 개 꿀...>,
#  <Text: 셈...>,
#  <Text: 유령선...>,
#  <Text: 선원 거...>,
#  <Text: 유령선 줄 수도...>,
#  <Text: 전설 선원 줌...>,
#  <Text: 유령선 줌...>,
#  <Text: 스포 지 밥...>,
#  <Text: 남자 김성태...>,
#  <Text: 시간...>,
#  <Text: 감자...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 생각 을 하네...>,
#  <Text: 줌...>,
#  <Text: ...>,
#  <Text: 유령선...>,
#  <Text: 김성태 넌...>,
#  <Text: 사나이 김성태 !!!...>,
#  <Text: ...>,
#  <Text: 일정 확률 유령선 전용 전설 선원...>,
#  <Text: 개소 리야 쓰레기...>,
#  <Text: 확률 확률...>,
#  <Text: 유령선 전용 선원...>,
#  <Text: 이상 만해...>,
#  <Text: 시간 낭비...>,
#  <Text: 운 임...>,
#  <Text: ...>,
#  <Text: 전설 유령 선원 줌...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 사나이 김성태 포기...>,
#  <Text: 유령선...>,
#  <Text: 오기...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 확률...>,
#  <Text: 만큼 전설...>,
#  <Text: 유령선 배...>,
#  <Text: 유령선 세계 최초...>,
#  <Text: 스포 지 밥...>,
#  <Text: 확률 선원 유령선 줌...>,
#  <Text: 사나이 김성태...>,
#  <Text: ...>,
#  <Text: 별거...>,
#  <Text: ...>,
#  <Text: ...>,
#  <Text: 정도...>,
#  <Text: 전설 지도 줌...>,
#  <Text: 시간 켠 왕 진짜...>,
#  <Text: ...>,
#  <Text: 님 절대 못 잡음...>,
#  ...]

# %%
# tk = ""
# for wd in word_list : 
#     tokens_ko = ko.nouns(wd)
#     tk += nltk.(nltk.Text(tokens_ko))
# tk

# %%
plt.figure(figsize=(12,6))
# 상위 10개
tk.plot(30)
plt.show()

# %%
data=  tk.vocab().most_common(300)
data
