# %%
dict1 = {'각':'n',
 '가즈아':1,
 '갓':1,
 '개':'n',
 '고고씽':1,
 'ㄱㄱ' :1,
 '고인물':1,
 '개인전':0,
 '개인톡':0,
 '관심병':0,
 '귀요미':1,
 '커엽' : 1,
 '귀차니즘':0,
 '그린라이트':1,
 '급식충':0,
 '기레기':0,
 '김여사':0,
 '까':0,
 '꿀잼':1,
 '끝판왕':0,
 '낫닝겐':1,
 '낚시':0,
 '냥집사':0,
 '노답':0,
 'ㄴㄷ' :0,
 '노잼':0,
 'ㄴㅈ':0,
 'ㅆㄴㅈ':0,
 'ㅈㄴㅈ':0,
 '뇌피셜':0,
 '눈팅':0,
 '뉴비':0,
 '늅늅':0,
 '느금마':0,
 '느개비':0,
 '느님':1,
 '누물보':0,
 '네다씹':0,
 '다능':0,
 '덕통사고':1,
 '돋다':1,
 '딸바보':1,
 '떡실신':0,
 '똥꼬충':0,
 '동의?어보감':0,
 '뒷담화':0,
 '뚝배기':1,
 '리즈시절':0,
 '마초맨':1,
 '머글':0,
 '먹튀':0,
 '멍 때리다':0,
 '메퇘지':0,
 '몸짱':1,
 '므흣하다':1,
 '밍아웃':0,
 '반품남':0,
 '반품녀':0,
 '방가요':0,
 '번개':0,
 '볍신':0,
 '보슬아치':0,
 '보이루':0,
 '복돌이':0,
 '부심':0,
 '불곰국':0,
 '뷁':0,
 '뷔페미니즘':0,
 '벅세권':1,
 '빠':0,
 '빡돌다':0,
 '빡세다':0,
 '빡치다':0,
 '빵국':0,
 '빵터지다':1,
 '빵셔틀':0,
 '뽀록':0,
 '뿜다':1,
 '뿜다':1,
 '사스가':1,
 '스까':0,
 '스까국':0,
 '신컨':1,
 '쉴드':0,
 '썸':1,
 '사이다':1,
 '성진국':1,
 '썰':0,
 '수치플':1,
 '스브스':0,
 '시발비용':0,
 '신박하다':1,
 '씹다':0,
 '씹덕':0,
 '선비':0,
 '솔까말':0,
 '쌉':'n',
 '아몰랑':0,
 '안구 정화':1,
 '안구 테러':0,
 '안 생겨요':0,
 '알못':'n',
 '앙 기모띠':1,
 '얀데레':0,
 '어장 관리':0,
 '오나전':0,
 '오덕후':0,
 '오덕':0,
 'ㅗㅜㅑ':1,
 '퍄' : 1,
 '오크' : 0,
 '올ㅋ':1,
 '외계어':0,
 '웅앵웅':0,
 '웜퇘지':0,
 '욜로':2,
 '용자':1,
 '이생망':0,
 '인증':2,
 '인정하는 부분':2,
 '일베충':0,
 '일진':0,
 '잉여':0,
 '오뱅알':1,
 'ㅇㅂㅇ':1,
 '왜구루냥':2,
 '잠수': 2,
 '작붕': 0,
 '저런하다':0,
 '조무사':0,
 '종결자':2,
 '좆문가':0,
 '주작':0,
 '지름신':2,
 '진지충':0,
 '짐승남':1,
 '짐승돌':1,
 '짜지다':2,
 '짱':1,
 '쩐':2,
 '찰지구나':1,
 '창렬':0,
 '총알':2,
 '추카포카':2,
 '천조국':1,
 '츤데레':0,
 '충':1,
 '철컹철컹':2,
 '칼빵':2,
 "캐":'n',
 '케미':2,
 '캣맘':2,
 '컴백':2,
 '컴백하다':2,
 '코렁탕':0,
 '콩라인':2,
 '쿰척쿰척':2,
 '쿵푸믹 걸스':2,
 '클라스':1,
 '킹왕짱':1,
 '탕진잼':2,
 '토끼다':1,
 '투더':2,
 '틀딱충':0,
 '품절남':2,
 '품절녀':2,
 '포스':1,
 '퍄':1,
 '파오후':0,
 '파오후 쿰척쿰척':0,
 '품절대란':2,
 '하이루':2,
 '함정':2,
 '헐':2,
 '혜자':1,
 '호갱님':0,
 '호모나게이뭐야':2,
 '호모나 섹상에 게이뭐람':2,
 '호옹이':1,
 '혼모노':2,
 '홋치':2,
 '홍팍':2,
 '후방주의':2,
 '흑역사':2,
 '흑우':2,
 '흙수저':2,
 '흔한':2,
 '흠냐뤼':2,
 '히익':1,
 '훼이크':2,
 'ㄱ':2,
 'ㄱㄱ':2,
 'ㄱㄱㅅ':2,
 'ㄱㄷ':2,
 'ㄳ':1,
 'ㄱㅅ':1,
 'ㄱㅇㄷ':1,
 'ㄱㅊ':1,
 'ㄲ':2,
 'ㄲㅂ':2,
 'ㄲㅈ':2,
 'ㄴ':0,
 'ㄴㄴ':2,
 'ㄷㄷ':1,
 'ㄷㄷㄷ':1,
 'ㄷㅊ':0,
 'ㅁㄴㅇㄹ':2,
 'ㅁㅊ':1,
 'ㅂㅂ':2,
 'ㅄ':0,
 'ㅂㅅ':0,
 'ㅅㄱ':2,
 'ㅅㅂ':0,
 'ㅆㅂ':0,
 'ㅅㅅ':1,
 'ㅇ':2, 
 'ㅇㅇ':2,
 'ㅇㄱㄹㅇ':1,
 'ㅇㄴ':0,
 'ㅇㄷ':2,
 'ㅇㅂ':0,
 'ㅇㅈ':1,
 'ㅇㅋ':2,
 'ㅇㅎ':2,
 'ㅈㄱㄴ':0,
 'ㅈㄴ':2,
 'ㅈㄹ':0,
 'ㅈㅁ':1,
 'ㅈㅅ':2,
 'ㅉㅉ':0,
 'ㅊㅊ':1,
 'ㅊㅋ':1,
 'ㅋㄷ':1,
 'ㅎㅇ':2,
 'ㅎㅎ':1,
 'ㅗ':0,
 'ㅗㅜㅑ':1,
 '20000':2,
 'ㄴㄴ':2,
 'ㄷㄷㄷ':1,
 '갑분싸':2,
 '갑툭튀':2,
 '강전':2,
 '강추':1,
 '강퇴':1,
 '개취':2,
 '갠소':1,
 '갠전':2,
 '광탈':0,
 '겨털':2,
 '게이':2,
 '공구':2,
 '귀척':0,
 '극혐':0,
 '근자감':0,
 '글설리':2,
 '금사빠':2,
 '까':0,
 '깜놀':2,
 '깝':2,
 '까비':2,
 '끔살':2,
 '낄끼빠빠':2,
 '알잘딱깔센':2,
 '남사친':2,
 '여사친':2,
 '남친':2,
 '낮져밤이':2,
 '내로남불':0,
 '냉무':2,
 '넘사벽':2,
 '너또다':2,
 '노모':2,
 '눈새':0,
 '닥본사':1,
 '답정너':0,
 '데꿀멍':2,
 '돌싱':2,
 '듣보잡':0,
 '디시':2,
 '딩':2,
 '롯백':2,
 '레기':0,
 '맥날':2,
 '멘붕':0,
 '명존세':0,
 '문상':2,
 '미드':2,
 '미방':2,
 '밀당':2,
 '반반무':2,
 '반반무마니':2,
 '발연기':0,
 '버정':2,
 '버카충':2,
 '본방':2,
 '볼매':1,
 '불금':2,
 '비매':0,
 '빛삭':2,
 '광삭':2,
 '브금':2,
 '뽀샵':2,
 '빨':0,
 '빼박캔트':2,
 '빼박':2,
 '별다줄':2,
 '빠샤':2,
 '사캐':0,
 '사파':2,
 '새등':2,
 '생선':2,
 '생파':2,
 '생얼':2,
 '쌩얼':2,
 '셀카':2,
 '솔까말':2,
 '수꼴':0,
 '스포':0,
 '시망':0,
 '신상':1,
 '심쿵':1,
 '썩소':0,
 '아만보':0,
 '아오안':0,
 '악플':0,
 '안물':0,
 '안궁':0,
 '안습':0,
 '야동':2,
 '야필패':2,
 '은꼴사':1,
 '어쩔':0,
 '엄빠주의':1,
 '엄친아':1,
 '엑박':0,
 '여병추':0,
 '여친':1,
 '연덕':0,
 '열공':1,
 '열폭':0,
 '영정':1,
 '오유':0,
 '완소':1,
 '옥희':1,
 '우좀':0,
 '움짤':2,
 '웃대':2,
 '웃프다':1,
 '음마':1,
 '이뭐병':0,
 '일코':0,
 '위꼴사':1,
 '일베':0,
 '자게이':0,
 '자삭':0,
 '잤잤':1,
 '존망':2,
 '좌빨':0,
'좌좀':0,
 '절친':1,
 '정팅':1,
 '제곧내':2,
 '존잘':1,
 '존예':1,
'존잘':1,
'존못':0,
 '주존꼬':0,
 '주존찢':0,
 '즐':0,
 '지못미':1,
 '직찍':2,
 '짝남':1,
'짝녀':1,
 '짤':1,
'짤방':1,
 '차도남':1,
 '채금':0,
 '출첵':1,
 '충공깽':0,
 '치맥':1,
 '취존':1,
 '카공족':2,
 '캐':2,
 '캐붕':0,
 '케바케':2,
 '키배':1,
 '타륵':1,
 '트인낭':0,
 '패완얼':1,
 '프사':2,
 '피꺼솟':0,
 '피방': 2,
 '한남':0,
 '현백':2,
 '현시창':1,
 '혐짤':0,
 '흠좀무':0,
 '흑형':1,
 'ASKY':0,
 'CC':0,
 'DDR':1,
 'DTD':0,
 'chABC':1,
 'CUF':1,
 '고나리':0,
 'o미':2,
 '수듄':2,
 '오나전':2,
 '항가항가':1,
 '스빈다':2,
 '젭라':1,
 '말안드뤄':1,
 '각':1,
 '개이득':1,
'ㄱㅇㄷ':1,
'ㅆㄱㅇㄷ':1,
 '개피':1,
 '갱':2,
 '광클':1,
 '길막':2,
 '너프':2,
 '다굴':2,
 '득템':1,
 '렙업':1,
 '롤':1,
 '만렙':1,
 '스틸':1,
'먹자':1,
 '몹':1,
 '물고기방':2,
 '반샷':2,
 '발컨':0,
 '백섭':0,
 '본캐':1,
 '부캐':1,
 '뽀헤':0,
 '샷충':0,
 '순삭':1,
 '스틸':1,
 '앵벌이':0,
 '어그로':0,
 '열렙':1,
 '입롤':0,
 '젠':2,
 '종특':0,
'주차':2,
'지지' : 2, 
'gg' : 2,
'ㅈㅈ': 2,
 '쩔': 2,
 'ㅋㅋ':1,
 '캐리':1,
'하드캐리':1,
 '캐삭':0,
 '크리':1,
 '킬딸':0,
 '탐': 2,
'테크트리' : 2, 
'테크' : 2,
'트리' : 2,
'트롤': 0,
 '팀전': 2,
 '쿨타임':2,
'쿨탐' :2,
 'ㅌㅌ':2,
 '팀킬':0,
'Team Kill' :0,
'TeamKill' :0,
 'PK':0,
'PlayerKill':0,
'Player Kill':0,
'현질':0,
'현피':0,
'작':2,
'가놈':0,
'가년':0,
'개드립':0,
 '갤럼':2,
 '관광':0,
 '고담':0,
 '네덕':0,
 '대첩':0,
 '레알':2,
 '무뇌충':0,
 '발컨':0,
 '병림픽':0,
 '병머금':0,
'병먹금':0,
'ㅂㅁㄱ':0,
 '병맛':0,
 '삼일한':0,
 'ㅇㅇ':2,
 '운지(Unji)':0,
 '유식대장':2,
 '일기방패':2,
 '일기방패튼튼데스네':2,
 '종범':0,
 '클린디시':1,
 '클린야갤':1,
 '탈갤':2,
 '퇴갤':2,
 'ㅍㅌㅊ':2,
 '후새드':2,
 '甲':1,
'갑':1,
 '게이':2,
 '대륙':2,
 '떡밥':2,
 '반도':2,
 '발기':2,
 '분탕':0,
 '아재':0,
 '열도':0,
 '오그라들다':0,
 '오글거리다':0,
 '쩔다':1,
 '찌르다':0,
 '하다':2,
 'ㅠ':0,
'ㅜㅜ':0,
'TT':0, 
'ㅜ.ㅜ':0,
'ㅠ.ㅠ':0,
'T^T':0, 
'T0T':0, 
'ㅜ0ㅜ':0,
'ㅠ0ㅠ':0,
 '-_-':0,
'-_-;;':0, 
'ㄱ-':0,
'ㅡㅡ':0,
 ':(' :0,
 '^^':1,
':)':1,
':-)':1, 
'^o^':1,
'^-^':1,
'^_^':1,
'^v^':1,
':D':1,
'ㅇ-ㅇ':2,
'ㅇ_ㅇ':2,
'ㅇㅅㅇ':2,
'ㅇㅂㅇ':2,
'ㅇㅁㅇ':2,
 'OTL':0,
'orz':0,
 '...':0,
 '^^7':1,
 '깨알같다':1,
 '나만 아니면 돼':0,
 '리얼돋다':2,
 '먹방':2,
 '무한이기주의':0,
 '빵꾸똥꾸':0,
 '옥동자':0,
 '작업':2,
 '좋은가봉가':1,
 '29만원':0,
 '503':0,
 '706':0,
 '간철수':0,
 '가카':1,
 '닭' : 0,
'닭근혜':0,
'더듬어민주당':0,
'더듬어만진당':0,
 '땅크성님':0,
 '런승만':0,
 '레이디가카':1,
 '맹바기':0,
 '반인반신':1,
'데미갓':1,
 '슨상님':0,
 '원숭이':0,
 '원조가카':1,
 '저승만':0,
 '재규어':0,
 '쥐박이':0,
 '쩔뚝이':0,
 '전땅크':0,
 '펭귄':0,
 '형보수지':0,
 '홍찍자지':0,
 'MC무현':0,
 '고무통':0,
 '노시개':0,
 '노알라':0,
 '노짱':0,
 '부엉이':0,
 '盧':0,
 '귀걸이아빠':0,
 '달빛기사단':0,
 '대깨문':0,
 '문각기동대':0,
 '문구라':0,
'문벌구':0,
 '문베충':0,
 '문슬람':0,
 '문유라':0}

# %%
for k,v in dict1.items() : 
    if v == 0 : 
        dict1[k] = 'NEG'
    elif v == 1 : 
        dict1[k] = 'POS'
    elif v == 2 :
        dict1[k] = 'NEUT'

# %%
import pickle

# %%
with open('new_word_sentiment.pickle', 'wb') as f : 
    pickle.dump(dict1, f, pickle.HIGHEST_PROTOCOL)

# %%
with open('new_word_sentiment.pickle', 'rb') as f : 
    dict1 = pickle.load(f)

# %%
dict1
# Out:
# {'각': 'POS',
#  '가즈아': 'POS',
#  '갓': 'POS',
#  '개': 'n',
#  '고고씽': 'POS',
#  'ㄱㄱ': 'NEUT',
#  '고인물': 'POS',
#  '개인전': 'NEG',
#  '개인톡': 'NEG',
#  '관심병': 'NEG',
#  '귀요미': 'POS',
#  '커엽': 'POS',
#  '귀차니즘': 'NEG',
#  '그린라이트': 'POS',
#  '급식충': 'NEG',
#  '기레기': 'NEG',
#  '김여사': 'NEG',
#  '까': 'NEG',
#  '꿀잼': 'POS',
#  '끝판왕': 'NEG',
#  '낫닝겐': 'POS',
#  '낚시': 'NEG',
#  '냥집사': 'NEG',
#  '노답': 'NEG',
#  'ㄴㄷ': 'NEG',
#  '노잼': 'NEG',
#  'ㄴㅈ': 'NEG',
#  'ㅆㄴㅈ': 'NEG',
#  'ㅈㄴㅈ': 'NEG',
#  '뇌피셜': 'NEG',
#  '눈팅': 'NEG',
#  '뉴비': 'NEG',
#  '늅늅': 'NEG',
#  '느금마': 'NEG',
#  '느개비': 'NEG',
#  '느님': 'POS',
#  '누물보': 'NEG',
#  '네다씹': 'NEG',
#  '다능': 'NEG',
#  '덕통사고': 'POS',
#  '돋다': 'POS',
#  '딸바보': 'POS',
#  '떡실신': 'NEG',
#  '똥꼬충': 'NEG',
#  '동의?어보감': 'NEG',
#  '뒷담화': 'NEG',
#  '뚝배기': 'POS',
#  '리즈시절': 'NEG',
#  '마초맨': 'POS',
#  '머글': 'NEG',
#  '먹튀': 'NEG',
#  '멍 때리다': 'NEG',
#  '메퇘지': 'NEG',
#  '몸짱': 'POS',
#  '므흣하다': 'POS',
#  '밍아웃': 'NEG',
#  '반품남': 'NEG',
#  '반품녀': 'NEG',
#  '방가요': 'NEG',
# ...

# %%
dict1.keys()
# Out:
# dict_keys(['각', '가즈아', '갓', '개', '고고씽', 'ㄱㄱ', '고인물', '개인전', '개인톡', '관심병', '귀요미', '커엽', '귀차니즘', '그린라이트', '급식충', '기레기', '김여사', '까', '꿀잼', '끝판왕', '낫닝겐', '낚시', '냥집사', '노답', 'ㄴㄷ', '노잼', 'ㄴㅈ', 'ㅆㄴㅈ', 'ㅈㄴㅈ', '뇌피셜', '눈팅', '뉴비', '늅늅', '느금마', '느개비', '느님', '누물보', '네다씹', '다능', '덕통사고', '돋다', '딸바보', '떡실신', '똥꼬충', '동의?어보감', '뒷담화', '뚝배기', '리즈시절', '마초맨', '머글', '먹튀', '멍 때리다', '메퇘지', '몸짱', '므흣하다', '밍아웃', '반품남', '반품녀', '방가요', '번개', '볍신', '보슬아치', '보이루', '복돌이', '부심', '불곰국', '뷁', '뷔페미니즘', '벅세권', '빠', '빡돌다', '빡세다', '빡치다', '빵국', '빵터지다', '빵셔틀', '뽀록', '뿜다', '사스가', '스까', '스까국', '신컨', '쉴드', '썸', '사이다', '성진국', '썰', '수치플', '스브스', '시발비용', '신박하다', '씹다', '씹덕', '선비', '솔까말', '쌉', '아몰랑', '안구 정화', '안구 테러', '안 생겨요', '알못', '앙 기모띠', '얀데레', '어장 관리', '오나전', '오덕후', '오덕', 'ㅗㅜㅑ', '퍄', '오크', '올ㅋ', '외계어', '웅앵웅', '웜퇘지', '욜로', '용자', '이생망', '인증', '인정하는 부분', '일베충', '일진', '잉여', '오뱅알', 'ㅇㅂㅇ', '왜구루냥', '잠수', '작붕', '저런하다', '조무사', '종결자', '좆문가', '주작', '지름신', '진지충', '짐승남', '짐승돌', '짜지다', '짱', '쩐', '찰지구나', '창렬', '총알', '추카포카', '천조국', '츤데레', '충',
# ...

# %%
keys_list = ['각', '가즈아', '갓', '개', '고고씽', 'ㄱㄱ', '고인물', '개인전', '개인톡', '관심병', '귀요미', '커엽', '귀차니즘', '그린라이트', '급식충', '기레기', '김여사', '까', '꿀잼', '끝판왕', '낫닝겐', '낚시', '냥집사', '노답', 'ㄴㄷ', '노잼', 'ㄴㅈ', 'ㅆㄴㅈ', 'ㅈㄴㅈ', '뇌피셜', '눈팅', '뉴비', '늅늅', '느금마', '느개비', '느님', '누물보', '네다씹', '다능', '덕통사고', '돋다', '딸바보', '떡실신', '똥꼬충', '동의?어보감', '뒷담화', '뚝배기', '리즈시절', '마초맨', '머글', '먹튀', '멍 때리다', '메퇘지', '몸짱', '므흣하다', '밍아웃', '반품남', '반품녀', '방가요', '번개', '볍신', '보슬아치', '보이루', '복돌이', '부심', '불곰국', '뷁', '뷔페미니즘', '벅세권', '빠', '빡돌다', '빡세다', '빡치다', '빵국', '빵터지다', '빵셔틀', '뽀록', '뿜다', '사스가', '스까', '스까국', '신컨', '쉴드', '썸', '사이다', '성진국', '썰', '수치플', '스브스', '시발비용', '신박하다', '씹다', '씹덕', '선비', '솔까말', '쌉', '아몰랑', '안구 정화', '안구 테러', '안 생겨요', '알못', '앙 기모띠', '얀데레', '어장 관리', '오나전', '오덕후', '오덕', 'ㅗㅜㅑ', '퍄', '오크', '올ㅋ', '외계어', '웅앵웅', '웜퇘지', '욜로', '용자', '이생망', '인증', '인정하는 부분', '일베충', '일진', '잉여', '오뱅알', 'ㅇㅂㅇ', '왜구루냥', '잠수', '작붕', '저런하다', '조무사', '종결자', '좆문가', '주작', '지름신', '진지충', '짐승남', '짐승돌', '짜지다', '짱', '쩐', '찰지구나', '창렬', '총알', '추카포카', '천조국', '츤데레', '충', '철컹철컹', '칼빵', '캐', '케미', '캣맘', '컴백', '컴백하다', '코렁탕', '콩라인', '쿰척쿰척', '쿵푸믹 걸스', '클라스', '킹왕짱', '탕진잼', '토끼다', '투더', '틀딱충', '품절남', '품절녀', '포스', '파오후', '파오후 쿰척쿰척', '품절대란', '하이루', '함정', '헐', '혜자', '호갱님', '호모나게이뭐야', '호모나 섹상에 게이뭐람', '호옹이', '혼모노', '홋치', '홍팍', '후방주의', '흑역사', '흑우', '흙수저', '흔한', '흠냐뤼', '히익', '훼이크', 'ㄱ', 'ㄱㄱㅅ', 'ㄱㄷ', 'ㄳ', 'ㄱㅅ', 'ㄱㅇㄷ', 'ㄱㅊ', 'ㄲ', 'ㄲㅂ', 'ㄲㅈ', 'ㄴ', 'ㄴㄴ', 'ㄷㄷ', 'ㄷㄷㄷ', 'ㄷㅊ', 'ㅁㄴㅇㄹ', 'ㅁㅊ', 'ㅂㅂ', 'ㅄ', 'ㅂㅅ', 'ㅅㄱ', 'ㅅㅂ', 'ㅆㅂ', 'ㅅㅅ', 'ㅇ', 'ㅇㅇ', 'ㅇㄱㄹㅇ', 'ㅇㄴ', 'ㅇㄷ', 'ㅇㅂ', 'ㅇㅈ', 'ㅇㅋ', 'ㅇㅎ', 'ㅈㄱㄴ', 'ㅈㄴ', 'ㅈㄹ', 'ㅈㅁ', 'ㅈㅅ', 'ㅉㅉ', 'ㅊㅊ', 'ㅊㅋ', 'ㅋㄷ', 'ㅎㅇ', 'ㅎㅎ', 'ㅗ', '20000', '갑분싸', '갑툭튀', '강전', '강추', '강퇴', '개취', '갠소', '갠전', '광탈', '겨털', '게이', '공구', '귀척', '극혐', '근자감', '글설리', '금사빠', '깜놀', '깝', '까비', '끔살', '낄끼빠빠', '알잘딱깔센', '남사친', '여사친', '남친', '낮져밤이', '내로남불', '냉무', '넘사벽', '너또다', '노모', '눈새', '닥본사', '답정너', '데꿀멍', '돌싱', '듣보잡', '디시', '딩', '롯백', '레기', '맥날', '멘붕', '명존세', '문상', '미드', '미방', '밀당', '반반무', '반반무마니', '발연기', '버정', '버카충', '본방', '볼매', '불금', '비매', '빛삭', '광삭', '브금', '뽀샵', '빨', '빼박캔트', '빼박', '별다줄', '빠샤', '사캐', '사파', '새등', '생선', '생파', '생얼', '쌩얼', '셀카', '수꼴', '스포', '시망', '신상', '심쿵', '썩소', '아만보', '아오안', '악플', '안물', '안궁', '안습', '야동', '야필패', '은꼴사', '어쩔', '엄빠주의', '엄친아', '엑박', '여병추', '여친', '연덕', '열공', '열폭', '영정', '오유', '완소', '옥희', '우좀', '움짤', '웃대', '웃프다', '음마', '이뭐병', '일코', '위꼴사', '일베', '자게이', '자삭', '잤잤', '존망', '좌빨', '좌좀', '절친', '정팅', '제곧내', '존잘', '존예', '존못', '주존꼬', '주존찢', '즐', '지못미', '직찍', '짝남', '짝녀', '짤', '짤방', '차도남', '채금', '출첵', '충공깽', '치맥', '취존', '카공족', '캐붕', '케바케', '키배', '타륵', '트인낭', '패완얼', '프사', '피꺼솟', '피방', '한남', '현백', '현시창', '혐짤', '흠좀무', '흑형', 'ASKY', 'CC', 'DDR', 'DTD', 'chABC', 'CUF', '고나리', '\x92o미', '수듄', '항가항가', '스빈다', '젭라', '말안드뤄', '개이득', 'ㅆㄱㅇㄷ', '개피', '갱', '광클', '길막', '너프', '다굴', '득템', '렙업', '롤', '만렙', '스틸', '먹자', '몹', '물고기방', '반샷', '발컨', '백섭', '본캐', '부캐', '뽀헤', '샷충', '순삭', '앵벌이', '어그로', '열렙', '입롤', '젠', '종특', '주차', '지지', 'gg', 'ㅈㅈ', '쩔', 'ㅋㅋ', '캐리', '하드캐리', '캐삭', '크리', '킬딸', '탐', '테크트리', '테크', '트리', '트롤', '팀전', '쿨타임', '쿨탐', 'ㅌㅌ', '팀킬', 'Team Kill', 'TeamKill', 'PK', 'PlayerKill', 'Player Kill', '현질', '현피', '작', '가놈', '가년', '개드립', '갤럼', '관광', '고담', '네덕', '대첩', '레알', '무뇌충', '병림픽', '병머금', '병먹금', 'ㅂㅁㄱ', '병맛', '삼일한', '운지(Unji)', '유식대장', '일기방패', '일기방패튼튼데스네', '종범', '클린디시', '클린야갤', '탈갤', '퇴갤', 'ㅍㅌㅊ', '후새드', '甲', '갑', '대륙', '떡밥', '반도', '발기', '분탕', '아재', '열도', '오그라들다', '오글거리다', '쩔다', '찌르다', '하다', 'ㅠ', 'ㅜㅜ', 'TT', 'ㅜ.ㅜ', 'ㅠ.ㅠ', 'T^T', 'T0T', 'ㅜ0ㅜ', 'ㅠ0ㅠ', '-_-', '-_-;;', 'ㄱ-', 'ㅡㅡ', ':(', '^^', ':)', ':-)', '^o^', '^-^', '^_^', '^v^', ':D', 'ㅇ-ㅇ', 'ㅇ_ㅇ', 'ㅇㅅㅇ', 'ㅇㅁㅇ', 'OTL', 'orz', '...', '^^7', '깨알같다', '나만 아니면 돼', '리얼돋다', '먹방', '무한이기주의', '빵꾸똥꾸', '옥동자', '작업', '좋은가봉가', '29만원', '503', '706', '간철수', '가카', '닭', '닭근혜', '더듬어민주당', '더듬어만진당', '땅크성님', '런승만', '레이디가카', '맹바기', '반인반신', '데미갓', '슨상님', '원숭이', '원조가카', '저승만', '재규어', '쥐박이', '쩔뚝이', '전땅크', '펭귄', '형보수지', '홍찍자지', 'MC무현', '고무통', '노시개', '노알라', '노짱', '부엉이', '盧', '귀걸이아빠', '달빛기사단', '대깨문', '문각기동대', '문구라', '문벌구', '문베충', '문슬람', '문유라']

# %%
len(keys_list)
# Out:
# 583

# %%
key_morphs_list = []

# %%
import khaiii

# %%
api = khaiii.KhaiiiApi()
api.open()

# %%
for i in range(len(keys_list)) : 
    for word in api.analyze(keys_list[i]) :
        morphs_str = ' + '.join([(m.lex + '/' + m.tag) for m in word.morphs])
        key_morphs_list.append(morphs_str)

# %%
key_morphs_list
# Out:
# ['각/MM',
#  '가/VV + 즈아/EC',
#  '갓/MAG',
#  '개/NNG',
#  '고/NNG + 고/MAG + 씽/NNG',
#  'ㄱㄱ/NNG',
#  '고인물/NNG',
#  '개인전/NNG',
#  '개인/NNG + 톡/JX',
#  '관심병/NNG',
#  '귀요미/NNG',
#  '커엽/NNG',
#  '귀차니즘/NNG',
#  '그린라이트/NNG',
#  '급식충/NNG',
#  '기레기/NNG',
#  '김여사/NNP',
#  '깝/VA + 어/EC',
#  '꿀/NNG + 잼/NNG',
#  '끝판왕/NNP',
#  '낫닝/NNG + 겐/VV',
#  '낚시/NNG',
#  '냥집사/NNG',
#  '노답/NNG',
#  'ㄴㄷ/NNG',
#  '노잼/NNG',
#  'ㄴㅈ/NNG',
#  'ㅆㄴ/NNG + ㅈ/NNG',
#  'ㅈ/NNG + ㄴㅈ/NNG',
#  '뇌/NNG + 피셜/NNG',
#  '눈팅/NNG',
#  '뉴/NNP + 비/NNG',
#  '늅/SH + 늅/SW',
#  '느/NNG + 금/VA + 마/NNG',
#  '느개/NP + 비/NNP',
#  '느님/NP',
#  '누물보/NNG',
#  '네다/MAG + 씹/VV',
#  '다능/NNG',
#  '덕통/NNP + 사고/NNG',
#  '돋/VV + 다/EC',
#  '딸바/NNP + 보/NNG',
#  '떡실신/NNG',
#  '똥꼬충/NNG',
#  '동의/NNG + ?/SP + 어보감/NNG',
#  '뒷담화/NNG',
#  '뚝배기/NNG',
#  '리즈/NNP + 시절/NNG',
#  '마초맨/NNG',
#  '머글/NNG',
#  '먹튀/NNG',
#  '멍/NNG',
#  '때리/VV + 다/EC',
#  '메퇘지/NNG',
#  '몸짱/NNG',
#  '므/VV + 흣/XR + 하/XSA + 다/EC',
#  '밍아웃/NNG',
#  '반품남/NNG',
#  '반/XPN + 품녀/NNG',
# ...

# %%
dict1.values()
# Out:
# dict_values(['POS', 'POS', 'POS', 'n', 'POS', 'NEUT', 'POS', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEUT', 'n', 'NEG', 'POS', 'NEG', 'NEG', 'n', 'POS', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEUT', 'NEG', 'POS', 'POS', 'NEUT', 'POS', 'NEUT', 'POS'
# ...

# %%
dict1_vals = ['POS', 'POS', 'POS', 'n', 'POS', 'NEUT', 'POS', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEUT', 'n', 'NEG', 'POS', 'NEG', 'NEG', 'n', 'POS', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEUT', 'NEG', 'POS', 'POS', 'NEUT', 'POS', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEUT', 'POS', 'NEG', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'NEUT', 'POS', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'POS', 'NEG', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEUT', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'POS', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'POS', 'POS', 'NEG', 'NEUT', 'POS', 'NEUT', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'POS', 'NEUT', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEG', 'POS', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEG', 'POS', 'NEUT', 'NEG', 'POS', 'POS', 'POS', 'NEUT', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'NEUT', 'POS', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'POS', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEUT', 'POS', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'NEG', 'NEUT', 'NEUT', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'POS', 'NEUT', 'NEG', 'NEG', 'POS', 'POS', 'NEUT', 'POS', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEUT', 'POS', 'POS', 'POS', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'NEUT', 'NEG', 'NEUT', 'POS', 'POS', 'NEG', 'POS', 'NEUT', 'NEG', 'NEUT', 'NEG', 'NEUT', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'NEG', 'NEUT', 'NEUT', 'POS', 'NEUT', 'POS', 'POS', 'POS', 'POS', 'POS', 'NEUT', 'POS', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'NEUT', 'NEUT', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'POS', 'NEG', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'POS', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'POS', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'NEUT', 'NEUT', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'POS', 'POS', 'NEG', 'NEUT', 'NEUT', 'NEG', 'NEG', 'NEG', 'NEUT', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'POS', 'NEG', 'POS', 'POS', 'NEG', 'NEG', 'POS', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG', 'NEG']

# %%
new_words_sentiments_dict = {}

# %%
for i in range(len(dict1_vals)) : 
    new_words_sentiments_dict[key_morphs_list[i]] = dict1_vals[i]

# %%
new_words_sentiments_dict
# Out:
# {'각/MM': 'POS',
#  '가/VV + 즈아/EC': 'POS',
#  '갓/MAG': 'POS',
#  '개/NNG': 'n',
#  '고/NNG + 고/MAG + 씽/NNG': 'POS',
#  'ㄱㄱ/NNG': 'NEUT',
#  '고인물/NNG': 'POS',
#  '개인전/NNG': 'NEG',
#  '개인/NNG + 톡/JX': 'NEG',
#  '관심병/NNG': 'NEG',
#  '귀요미/NNG': 'POS',
#  '커엽/NNG': 'POS',
#  '귀차니즘/NNG': 'NEG',
#  '그린라이트/NNG': 'POS',
#  '급식충/NNG': 'NEG',
#  '기레기/NNG': 'NEG',
#  '김여사/NNP': 'NEG',
#  '깝/VA + 어/EC': 'NEG',
#  '꿀/NNG + 잼/NNG': 'POS',
#  '끝판왕/NNP': 'NEG',
#  '낫닝/NNG + 겐/VV': 'POS',
#  '낚시/NNG': 'NEG',
#  '냥집사/NNG': 'NEG',
#  '노답/NNG': 'NEG',
#  'ㄴㄷ/NNG': 'NEG',
#  '노잼/NNG': 'NEG',
#  'ㄴㅈ/NNG': 'NEG',
#  'ㅆㄴ/NNG + ㅈ/NNG': 'NEG',
#  'ㅈ/NNG + ㄴㅈ/NNG': 'NEG',
#  '뇌/NNG + 피셜/NNG': 'NEG',
#  '눈팅/NNG': 'NEG',
#  '뉴/NNP + 비/NNG': 'NEG',
#  '늅/SH + 늅/SW': 'NEG',
#  '느/NNG + 금/VA + 마/NNG': 'NEG',
#  '느개/NP + 비/NNP': 'NEG',
#  '느님/NP': 'POS',
#  '누물보/NNG': 'NEG',
#  '네다/MAG + 씹/VV': 'NEG',
#  '다능/NNG': 'NEG',
#  '덕통/NNP + 사고/NNG': 'POS',
#  '돋/VV + 다/EC': 'POS',
#  '딸바/NNP + 보/NNG': 'POS',
# ...

# %%
# json으로 저장
import json

# %%
with open('./new_words_sentiment.json', 'w', encoding="utf-8") as make_file:
    json.dump(new_words_sentiments_dict, fp=make_file, ensure_ascii=False, indent='\t')
