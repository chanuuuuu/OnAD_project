# %%
dict1 = {'각':'n',
 '가즈아':1,
 '갓':1,
 '개':'n',
 '고고씽':1,
 'ㄱㄱ' :1,
 '고인물':1,
 '개인전':0,
 '개인톡':0,
 '관심병':0,
 '귀요미':1,
 '커엽' : 1,
 '귀차니즘':0,
 '그린라이트':1,
 '급식충':0,
 '기레기':0,
 '김여사':0,
 '까':0,
 '꿀잼':1,
 '끝판왕':0,
 '낫닝겐':1,
 '낚시':0,
 '냥집사':0,
 '노답':0,
 'ㄴㄷ' :0,
 '노잼':0,
 'ㄴㅈ':0,
 'ㅆㄴㅈ':0,
 'ㅈㄴㅈ':0,
 '뇌피셜':0,
 '눈팅':0,
 '뉴비':0,
 '늅늅':0,
 '느금마':0,
 '느개비':0,
 '느님':1,
 '누물보':0,
 '네다씹':0,
 '다능':0,
 '덕통사고':1,
 '돋다':1,
 '딸바보':1,
 '떡실신':0,
 '똥꼬충':0,
 '동의?어보감':0,
 '뒷담화':0,
 '뚝배기':1,
 '리즈시절':0,
 '마초맨':1,
 '머글':0,
 '먹튀':0,
 '멍 때리다':0,
 '메퇘지':0,
 '몸짱':1,
 '므흣하다':1,
 '밍아웃':0,
 '반품남':0,
 '반품녀':0,
 '방가요':0,
 '번개':0,
 '볍신':0,
 '보슬아치':0,
 '보이루':0,
 '복돌이':0,
 '부심':0,
 '불곰국':0,
 '뷁':0,
 '뷔페미니즘':0,
 '벅세권':1,
 '빠':0,
 '빡돌다':0,
 '빡세다':0,
 '빡치다':0,
 '빵국':0,
 '빵터지다':1,
 '빵셔틀':0,
 '뽀록':0,
 '뿜다':1,
 '뿜다':1,
 '사스가':1,
 '스까':0,
 '스까국':0,
 '신컨':1,
 '쉴드':0,
 '썸':1,
 '사이다':1,
 '성진국':1,
 '썰':0,
 '수치플':1,
 '스브스':0,
 '시발비용':0,
 '신박하다':1,
 '씹다':0,
 '씹덕':0,
 '선비':0,
 '솔까말':0,
 '쌉':'n',
 '아몰랑':0,
 '안구 정화':1,
 '안구 테러':0,
 '안 생겨요':0,
 '알못':'n',
 '앙 기모띠':1,
 '얀데레':0,
 '어장 관리':0,
 '오나전':0,
 '오덕후':0,
 '오덕':0,
 'ㅗㅜㅑ':1,
 '퍄' : 1,
 '오크' : 0,
 '올ㅋ':1,
 '외계어':0,
 '웅앵웅':0,
 '웜퇘지':0,
 '욜로':2,
 '용자':1,
 '이생망':0,
 '인증':2,
 '인정하는 부분':2,
 '일베충':0,
 '일진':0,
 '잉여':0,
 '오뱅알':1,
 'ㅇㅂㅇ':1,
 '왜구루냥':2,
 '잠수': 2,
 '작붕': 0,
 '저런하다':0,
 '조무사':0,
 '종결자':2,
 '좆문가':0,
 '주작':0,
 '지름신':2,
 '진지충':0,
 '짐승남':1,
 '짐승돌':1,
 '짜지다':2,
 '짱':1,
 '쩐':2,
 '찰지구나':1,
 '창렬':0,
 '총알':2,
 '추카포카':2,
 '천조국':1,
 '츤데레':0,
 '충':1,
 '철컹철컹':2,
 '칼빵':2,
 "캐":'n',
 '케미':2,
 '캣맘':2,
 '컴백':2,
 '컴백하다':2,
 '코렁탕':0,
 '콩라인':2,
 '쿰척쿰척':2,
 '쿵푸믹 걸스':2,
 '클라스':1,
 '킹왕짱':1,
 '탕진잼':2,
 '토끼다':1,
 '투더':2,
 '틀딱충':0,
 '품절남':2,
 '품절녀':2,
 '포스':1,
 '퍄':1,
 '파오후':0,
 '파오후 쿰척쿰척':0,
 '품절대란':2,
 '하이루':2,
 '함정':2,
 '헐':2,
 '혜자':1,
 '호갱님':0,
 '호모나게이뭐야':2,
 '호모나 섹상에 게이뭐람':2,
 '호옹이':1,
 '혼모노':2,
 '홋치':2,
 '홍팍':2,
 '후방주의':2,
 '흑역사':2,
 '흑우':2,
 '흙수저':2,
 '흔한':2,
 '흠냐뤼':2,
 '히익':1,
 '훼이크':2,
 'ㄱ':2,
 'ㄱㄱ':2,
 'ㄱㄱㅅ':2,
 'ㄱㄷ':2,
 'ㄳ':1,
 'ㄱㅅ':1,
 'ㄱㅇㄷ':1,
 'ㄱㅊ':1,
 'ㄲ':2,
 'ㄲㅂ':2,
 'ㄲㅈ':2,
 'ㄴ':0,
 'ㄴㄴ':2,
 'ㄷㄷ':1,
 'ㄷㄷㄷ':1,
 'ㄷㅊ':0,
 'ㅁㄴㅇㄹ':2,
 'ㅁㅊ':1,
 'ㅂㅂ':2,
 'ㅄ':0,
 'ㅂㅅ':0,
 'ㅅㄱ':2,
 'ㅅㅂ':0,
 'ㅆㅂ':0,
 'ㅅㅅ':1,
 'ㅇ':2, 
 'ㅇㅇ':2,
 'ㅇㄱㄹㅇ':1,
 'ㅇㄴ':0,
 'ㅇㄷ':2,
 'ㅇㅂ':0,
 'ㅇㅈ':1,
 'ㅇㅋ':2,
 'ㅇㅎ':2,
 'ㅈㄱㄴ':0,
 'ㅈㄴ':2,
 'ㅈㄹ':0,
 'ㅈㅁ':1,
 'ㅈㅅ':2,
 'ㅉㅉ':0,
 'ㅊㅊ':1,
 'ㅊㅋ':1,
 'ㅋㄷ':1,
 'ㅎㅇ':2,
 'ㅎㅎ':1,
 'ㅗ':0,
 'ㅗㅜㅑ':1,
 '20000':2,
 'ㄴㄴ':2,
 'ㄷㄷㄷ':1,
 '갑분싸':2,
 '갑툭튀':2,
 '강전':2,
 '강추':1,
 '강퇴':1,
 '개취':2,
 '갠소':1,
 '갠전':2,
 '광탈':0,
 '겨털':2,
 '게이':2,
 '공구':2,
 '귀척':0,
 '극혐':0,
 '근자감':0,
 '글설리':2,
 '금사빠':2,
 '까':0,
 '깜놀':2,
 '깝':2,
 '까비':2,
 '끔살':2,
 '낄끼빠빠':2,
 '알잘딱깔센':2,
 '남사친':2,
 '여사친':2,
 '남친':2,
 '낮져밤이':2,
 '내로남불':0,
 '냉무':2,
 '넘사벽':2,
 '너또다':2,
 '노모':2,
 '눈새':0,
 '닥본사':1,
 '답정너':0,
 '데꿀멍':2,
 '돌싱':2,
 '듣보잡':0,
 '디시':2,
 '딩':2,
 '롯백':2,
 '레기':0,
 '맥날':2,
 '멘붕':0,
 '명존세':0,
 '문상':2,
 '미드':2,
 '미방':2,
 '밀당':2,
 '반반무':2,
 '반반무마니':2,
 '발연기':0,
 '버정':2,
 '버카충':2,
 '본방':2,
 '볼매':1,
 '불금':2,
 '비매':0,
 '빛삭':2,
 '광삭':2,
 '브금':2,
 '뽀샵':2,
 '빨':0,
 '빼박캔트':2,
 '빼박':2,
 '별다줄':2,
 '빠샤':2,
 '사캐':0,
 '사파':2,
 '새등':2,
 '생선':2,
 '생파':2,
 '생얼':2,
 '쌩얼':2,
 '셀카':2,
 '솔까말':2,
 '수꼴':0,
 '스포':0,
 '시망':0,
 '신상':1,
 '심쿵':1,
 '썩소':0,
 '아만보':0,
 '아오안':0,
 '악플':0,
 '안물':0,
 '안궁':0,
 '안습':0,
 '야동':2,
 '야필패':2,
 '은꼴사':1,
 '어쩔':0,
 '엄빠주의':1,
 '엄친아':1,
 '엑박':0,
 '여병추':0,
 '여친':1,
 '연덕':0,
 '열공':1,
 '열폭':0,
 '영정':1,
 '오유':0,
 '완소':1,
 '옥희':1,
 '우좀':0,
 '움짤':2,
 '웃대':2,
 '웃프다':1,
 '음마':1,
 '이뭐병':0,
 '일코':0,
 '위꼴사':1,
 '일베':0,
 '자게이':0,
 '자삭':0,
 '잤잤':1,
 '존망':2,
 '좌빨':0,
'좌좀':0,
 '절친':1,
 '정팅':1,
 '제곧내':2,
 '존잘':1,
 '존예':1,
'존잘':1,
'존못':0,
 '주존꼬':0,
 '주존찢':0,
 '즐':0,
 '지못미':1,
 '직찍':2,
 '짝남':1,
'짝녀':1,
 '짤':1,
'짤방':1,
 '차도남':1,
 '채금':0,
 '출첵':1,
 '충공깽':0,
 '치맥':1,
 '취존':1,
 '카공족':2,
 '캐':2,
 '캐붕':0,
 '케바케':2,
 '키배':1,
 '타륵':1,
 '트인낭':0,
 '패완얼':1,
 '프사':2,
 '피꺼솟':0,
 '피방': 2,
 '한남':0,
 '현백':2,
 '현시창':1,
 '혐짤':0,
 '흠좀무':0,
 '흑형':1,
 'ASKY':0,
 'CC':0,
 'DDR':1,
 'DTD':0,
 'chABC':1,
 'CUF':1,
 '고나리':0,
 'o미':2,
 '수듄':2,
 '오나전':2,
 '항가항가':1,
 '스빈다':2,
 '젭라':1,
 '말안드뤄':1,
 '각':1,
 '개이득':1,
'ㄱㅇㄷ':1,
'ㅆㄱㅇㄷ':1,
 '개피':1,
 '갱':2,
 '광클':1,
 '길막':2,
 '너프':2,
 '다굴':2,
 '득템':1,
 '렙업':1,
 '롤':1,
 '만렙':1,
 '스틸':1,
'먹자':1,
 '몹':1,
 '물고기방':2,
 '반샷':2,
 '발컨':0,
 '백섭':0,
 '본캐':1,
 '부캐':1,
 '뽀헤':0,
 '샷충':0,
 '순삭':1,
 '스틸':1,
 '앵벌이':0,
 '어그로':0,
 '열렙':1,
 '입롤':0,
 '젠':2,
 '종특':0,
'주차':2,
'지지' : 2, 
'gg' : 2,
'ㅈㅈ': 2,
 '쩔': 2,
 'ㅋㅋ':1,
 '캐리':1,
'하드캐리':1,
 '캐삭':0,
 '크리':1,
 '킬딸':0,
 '탐': 2,
'테크트리' : 2, 
'테크' : 2,
'트리' : 2,
'트롤': 0,
 '팀전': 2,
 '쿨타임':2,
'쿨탐' :2,
 'ㅌㅌ':2,
 '팀킬':0,
'Team Kill' :0,
'TeamKill' :0,
 'PK':0,
'PlayerKill':0,
'Player Kill':0,
'현질':0,
'현피':0,
'작':2,
'가놈':0,
'가년':0,
'개드립':0,
 '갤럼':2,
 '관광':0,
 '고담':0,
 '네덕':0,
 '대첩':0,
 '레알':2,
 '무뇌충':0,
 '발컨':0,
 '병림픽':0,
 '병머금':0,
'병먹금':0,
'ㅂㅁㄱ':0,
 '병맛':0,
 '삼일한':0,
 'ㅇㅇ':2,
 '운지(Unji)':0,
 '유식대장':2,
 '일기방패':2,
 '일기방패튼튼데스네':2,
 '종범':0,
 '클린디시':1,
 '클린야갤':1,
 '탈갤':2,
 '퇴갤':2,
 'ㅍㅌㅊ':2,
 '후새드':2,
 '甲':1,
'갑':1,
 '게이':2,
 '대륙':2,
 '떡밥':2,
 '반도':2,
 '발기':2,
 '분탕':0,
 '아재':0,
 '열도':0,
 '오그라들다':0,
 '오글거리다':0,
 '쩔다':1,
 '찌르다':0,
 '하다':2,
 'ㅠ':0,
'ㅜㅜ':0,
'TT':0, 
'ㅜ.ㅜ':0,
'ㅠ.ㅠ':0,
'T^T':0, 
'T0T':0, 
'ㅜ0ㅜ':0,
'ㅠ0ㅠ':0,
 '-_-':0,
'-_-;;':0, 
'ㄱ-':0,
'ㅡㅡ':0,
 ':(' :0,
 '^^':1,
':)':1,
':-)':1, 
'^o^':1,
'^-^':1,
'^_^':1,
'^v^':1,
':D':1,
'ㅇ-ㅇ':2,
'ㅇ_ㅇ':2,
'ㅇㅅㅇ':2,
'ㅇㅂㅇ':2,
'ㅇㅁㅇ':2,
 'OTL':0,
'orz':0,
 '...':0,
 '^^7':1,
 '깨알같다':1,
 '나만 아니면 돼':0,
 '리얼돋다':2,
 '먹방':2,
 '무한이기주의':0,
 '빵꾸똥꾸':0,
 '옥동자':0,
 '작업':2,
 '좋은가봉가':1,
 '29만원':0,
 '503':0,
 '706':0,
 '간철수':0,
 '가카':1,
 '닭' : 0,
'닭근혜':0,
'더듬어민주당':0,
'더듬어만진당':0,
 '땅크성님':0,
 '런승만':0,
 '레이디가카':1,
 '맹바기':0,
 '반인반신':1,
'데미갓':1,
 '슨상님':0,
 '원숭이':0,
 '원조가카':1,
 '저승만':0,
 '재규어':0,
 '쥐박이':0,
 '쩔뚝이':0,
 '전땅크':0,
 '펭귄':0,
 '형보수지':0,
 '홍찍자지':0,
 'MC무현':0,
 '고무통':0,
 '노시개':0,
 '노알라':0,
 '노짱':0,
 '부엉이':0,
 '盧':0,
 '귀걸이아빠':0,
 '달빛기사단':0,
 '대깨문':0,
 '문각기동대':0,
 '문구라':0,
'문벌구':0,
 '문베충':0,
 '문슬람':0,
 '문유라':0}

# %%
for key in dict1.keys() : 
    if dict1[key] == 0 : 
        dict1[key] = 'NEG'
    elif dict1[key] == 1 : 
        dict1[key] = 'POS'
    elif dict1[key] == 2 : 
        dict1[key] = 'NEUT'
    else : dict1[key] = 'NULL'

# %%
dict1
# Out:
# {'각': 'POS',
#  '가즈아': 'POS',
#  '갓': 'POS',
#  '개': 'NULL',
#  '고고씽': 'POS',
#  'ㄱㄱ': 'NEUT',
#  '고인물': 'POS',
#  '개인전': 'NEG',
#  '개인톡': 'NEG',
#  '관심병': 'NEG',
#  '귀요미': 'POS',
#  '커엽': 'POS',
#  '귀차니즘': 'NEG',
#  '그린라이트': 'POS',
#  '급식충': 'NEG',
#  '기레기': 'NEG',
#  '김여사': 'NEG',
#  '까': 'NEG',
#  '꿀잼': 'POS',
#  '끝판왕': 'NEG',
#  '낫닝겐': 'POS',
#  '낚시': 'NEG',
#  '냥집사': 'NEG',
#  '노답': 'NEG',
#  'ㄴㄷ': 'NEG',
#  '노잼': 'NEG',
#  'ㄴㅈ': 'NEG',
#  'ㅆㄴㅈ': 'NEG',
#  'ㅈㄴㅈ': 'NEG',
#  '뇌피셜': 'NEG',
#  '눈팅': 'NEG',
#  '뉴비': 'NEG',
#  '늅늅': 'NEG',
#  '느금마': 'NEG',
#  '느개비': 'NEG',
#  '느님': 'POS',
#  '누물보': 'NEG',
#  '네다씹': 'NEG',
#  '다능': 'NEG',
#  '덕통사고': 'POS',
#  '돋다': 'POS',
#  '딸바보': 'POS',
#  '떡실신': 'NEG',
#  '똥꼬충': 'NEG',
#  '동의?어보감': 'NEG',
#  '뒷담화': 'NEG',
#  '뚝배기': 'POS',
#  '리즈시절': 'NEG',
#  '마초맨': 'POS',
#  '머글': 'NEG',
#  '먹튀': 'NEG',
#  '멍 때리다': 'NEG',
#  '메퇘지': 'NEG',
#  '몸짱': 'POS',
#  '므흣하다': 'POS',
#  '밍아웃': 'NEG',
#  '반품남': 'NEG',
#  '반품녀': 'NEG',
#  '방가요': 'NEG',
# ...

# %%
import pickle
with open('../../data/sentiment_dictionary/KnuSentiLex/pos_pol_word.txt','r') as f :
    pos_pol = f.readlines()

# %%
pos_pol
# Out:
# ['\ufeff출처\n',
#  '1) 표준국어대사전 뜻풀이\n',
#  '-> https://github.com/mrchypark/stdkor\n',
#  '2) 신조어\n',
#  '-> https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%ED%84%B0%EB%84%B7_%EC%8B%A0%EC%A1%B0%EC%96%B4_%EB%AA%A9%EB%A1%9D\n',
#  '3) 이모티콘\n',
#  '-> https://ko.wikipedia.org/wiki/%EC%9D%B4%EB%AA%A8%ED%8B%B0%EC%BD%98\n',
#  '4) SentiWordNet_3.0.0_20130122\n',
#  '-> http://sentiwordnet.isti.cnr.it/\n',
#  '5) SenticNet-5.0\n',
#  '-> http://sentic.net/\n',
#  '6) 감정단어사전0603\n',
#  '-> http://datascience.khu.ac.kr/board/bbs/board.php?bo_table=05_01&wr_id=91 \n',
#  '7) 김은영, “국어 감정동사 연구”, 2004.02, 학위논문(박사) - 전남대학교 국어국문학과 대학원\n',
#  '\n',
#  '\n',
#  '단어 수 : 4863\n',
#  '극성 : 긍정\n',
#  '\n',
#  '(-;\n',
#  '(^^)\n',
#  '(^-^)\n',
#  '(^^*\n',
#  '(^_^)\n',
#  '(^o^)\n',
#  '*^^*\n',
#  '/^o^\\\n',
#  ':(\n',
#  ":'-(\n",
#  ':-(\n',
#  ':-)\n',
#  ':|\n',
#  ';\n',
#  ';)\n',
#  ';-)\n',
#  '^///^\n',
#  '^^\n',
#  '^^//\n',
#  '<3\n',
#  '=)\n',
# ...

# %%
pos_pol[19:]
# Out:
# ['(-;\n',
#  '(^^)\n',
#  '(^-^)\n',
#  '(^^*\n',
#  '(^_^)\n',
#  '(^o^)\n',
#  '*^^*\n',
#  '/^o^\\\n',
#  ':(\n',
#  ":'-(\n",
#  ':-(\n',
#  ':-)\n',
#  ':|\n',
#  ';\n',
#  ';)\n',
#  ';-)\n',
#  '^///^\n',
#  '^^\n',
#  '^^//\n',
#  '<3\n',
#  '=)\n',
#  'XD\n',
#  'ㄱㅅ\n',
#  'ㄱㅇㄷ\n',
#  '가격이 싸다\n',
#  '가까이 사귀어\n',
#  '가까이하다\n',
#  '가다듬어\n',
#  '가다듬어 수습하는\n',
#  '가다듬어 수습하다\n',
#  '가다듬어 정하다\n',
#  '가당히\n',
#  '가뜬하게\n',
#  '가라앉혀 바로잡다\n',
#  '가르치며\n',
#  '가르침\n',
#  '가벼운 마음으로\n',
#  '가볍게 웃다\n',
#  '가볍고\n',
#  '가볍고 보드랍게\n',
#  '가분가분\n',
#  '가분히\n',
#  '가뿐가뿐\n',
#  '가뿐가뿐하다\n',
#  '가뿐가뿐히\n',
#  '가뿐하게\n',
#  '가뿐하다\n',
#  '가뿐한\n',
#  '가뿐한 느낌\n',
#  '가뿐한 느낌이\n',
#  '가뿐히\n',
#  '가장 중요한\n',
#  '가지런하게 하는\n',
#  '가지런하게 하다\n',
#  '가지런하다\n',
#  '가치\n',
#  '가치가\n',
#  '가치있는\n',
#  '각별나다\n',
#  '각별하다\n',
#  '간직하다\n',
#  '감각적이다\n',
#  '감당하다\n',
#  '감동시킬\n',
#  '감동시킬 만한\n',
#  '감모\n',
#  '감싸고\n',
#  '감정이 북받쳐\n',
#  '강렬하게\n',
#  '강세\n',
#  '강인하다\n',
#  '강하게\n',
#  '강하게 하다\n',
#  '강하고\n',
# ...

# %%
pos_pol_dict ={}
for wd in pos_pol[19:] : 
    pos_pol_dict[wd[:-1]] = 'POS'

# %%
pos_pol_dict
# Out:
# {'(-;': 'POS',
#  '(^^)': 'POS',
#  '(^-^)': 'POS',
#  '(^^*': 'POS',
#  '(^_^)': 'POS',
#  '(^o^)': 'POS',
#  '*^^*': 'POS',
#  '/^o^\\': 'POS',
#  ':(': 'POS',
#  ":'-(": 'POS',
#  ':-(': 'POS',
#  ':-)': 'POS',
#  ':|': 'POS',
#  ';': 'POS',
#  ';)': 'POS',
#  ';-)': 'POS',
#  '^///^': 'POS',
#  '^^': 'POS',
#  '^^//': 'POS',
#  '<3': 'POS',
#  '=)': 'POS',
#  'XD': 'POS',
#  'ㄱㅅ': 'POS',
#  'ㄱㅇㄷ': 'POS',
#  '가격이 싸다': 'POS',
#  '가까이 사귀어': 'POS',
#  '가까이하다': 'POS',
#  '가다듬어': 'POS',
#  '가다듬어 수습하는': 'POS',
#  '가다듬어 수습하다': 'POS',
#  '가다듬어 정하다': 'POS',
#  '가당히': 'POS',
#  '가뜬하게': 'POS',
#  '가라앉혀 바로잡다': 'POS',
#  '가르치며': 'POS',
#  '가르침': 'POS',
#  '가벼운 마음으로': 'POS',
#  '가볍게 웃다': 'POS',
#  '가볍고': 'POS',
#  '가볍고 보드랍게': 'POS',
#  '가분가분': 'POS',
#  '가분히': 'POS',
#  '가뿐가뿐': 'POS',
#  '가뿐가뿐하다': 'POS',
#  '가뿐가뿐히': 'POS',
#  '가뿐하게': 'POS',
#  '가뿐하다': 'POS',
#  '가뿐한': 'POS',
#  '가뿐한 느낌': 'POS',
#  '가뿐한 느낌이': 'POS',
#  '가뿐히': 'POS',
#  '가장 중요한': 'POS',
#  '가지런하게 하는': 'POS',
# ...

# %%
with open('knu_pos_pol.pickle', 'wb') as f : 
    pickle.dump(pos_pol_dict,f,pickle.HIGHEST_PROTOCOL)

# %%
with open('../../data/sentiment_dictionary/KnuSentiLex/neg_pol_word.txt','r') as f :
    neg_pol = f.readlines()

# %%
neg_pol[19:]
# Out:
# ['가난\n',
#  '가난뱅이\n',
#  '가난살이\n',
#  '가난살이하다\n',
#  '가난설음\n',
#  '가난에\n',
#  '가난에 쪼들려서\n',
#  '가난하게\n',
#  '가난하고\n',
#  '가난하고 어렵다\n',
#  '가난하고 천한\n',
#  '가난하다\n',
#  '가난하여\n',
#  '가난한\n',
#  '가난한 데다가\n',
#  '가난한 사람을\n',
#  '가난히\n',
#  '가년스럽다\n',
#  '가녕스럽다\n',
#  '가누지 못하고\n',
#  '가누지 못하다\n',
#  '가누지 못할\n',
#  '가누지 못할 정도로\n',
#  '가누지 못함\n',
#  '가눌 수 없게\n',
#  '가눌 수 없을\n',
#  '가눌 수 없이\n',
#  '가당찮다\n',
#  '가당찮이\n',
#  '가두거나 해치거나\n',
#  '가망이 없게\n',
#  '가슴 아파하다\n',
#  '가슴 아파함\n',
#  '가슴 아프게\n',
#  '가슴 아프고\n',
#  '가슴 아프다\n',
#  '가슴속에 근심이나\n',
#  '가슴앓이\n',
#  '가슴앓이하다\n',
#  '가슴이 갑갑할\n',
#  '가슴이 괴롭거나\n',
#  '가슴이 그득한\n',
#  '가슴이 답답하고\n',
#  '가슴이 답답하다\n',
#  '가슴이 답답하며\n',
#  '가슴이 아프다\n',
#  '가슴이 아픈\n',
#  '가슴이 울렁거리는\n',
#  '가슴이 울렁거리다\n',
#  '가슴이 찢어질\n',
#  '가엾고 불쌍하다\n',
#  '가엾고 불쌍하여\n',
#  '가엾고 불쌍한\n',
#  '가엾고 불쌍함\n',
#  '가엾고 애처롭다\n',
#  '가음 아프고\n',
#  '가짜\n',
#  '가치 없는\n',
#  '가치가 없다\n',
#  '가치가 없을\n',
#  '가치가 없이\n',
#  '가치없는\n',
#  '가혹하게\n',
#  '가혹하게 착취하여\n',
#  '간 장애\n',
#  '간사한 짓을\n',
# ...

# %%
neg_pol_dict ={}
for wd in neg_pol[19:] : 
    neg_pol_dict[wd[:-1]] = 'NEG'

# %%
neg_pol_dict
# Out:
# {'가난': 'NEG',
#  '가난뱅이': 'NEG',
#  '가난살이': 'NEG',
#  '가난살이하다': 'NEG',
#  '가난설음': 'NEG',
#  '가난에': 'NEG',
#  '가난에 쪼들려서': 'NEG',
#  '가난하게': 'NEG',
#  '가난하고': 'NEG',
#  '가난하고 어렵다': 'NEG',
#  '가난하고 천한': 'NEG',
#  '가난하다': 'NEG',
#  '가난하여': 'NEG',
#  '가난한': 'NEG',
#  '가난한 데다가': 'NEG',
#  '가난한 사람을': 'NEG',
#  '가난히': 'NEG',
#  '가년스럽다': 'NEG',
#  '가녕스럽다': 'NEG',
#  '가누지 못하고': 'NEG',
#  '가누지 못하다': 'NEG',
#  '가누지 못할': 'NEG',
#  '가누지 못할 정도로': 'NEG',
#  '가누지 못함': 'NEG',
#  '가눌 수 없게': 'NEG',
#  '가눌 수 없을': 'NEG',
#  '가눌 수 없이': 'NEG',
#  '가당찮다': 'NEG',
#  '가당찮이': 'NEG',
#  '가두거나 해치거나': 'NEG',
#  '가망이 없게': 'NEG',
#  '가슴 아파하다': 'NEG',
#  '가슴 아파함': 'NEG',
#  '가슴 아프게': 'NEG',
#  '가슴 아프고': 'NEG',
#  '가슴 아프다': 'NEG',
#  '가슴속에 근심이나': 'NEG',
#  '가슴앓이': 'NEG',
#  '가슴앓이하다': 'NEG',
#  '가슴이 갑갑할': 'NEG',
#  '가슴이 괴롭거나': 'NEG',
#  '가슴이 그득한': 'NEG',
#  '가슴이 답답하고': 'NEG',
#  '가슴이 답답하다': 'NEG',
#  '가슴이 답답하며': 'NEG',
#  '가슴이 아프다': 'NEG',
#  '가슴이 아픈': 'NEG',
#  '가슴이 울렁거리는': 'NEG',
#  '가슴이 울렁거리다': 'NEG',
# ...

# %%
with open('knu_neg_pol.pickle', 'wb') as f : 
    pickle.dump(neg_pol_dict,f,pickle.HIGHEST_PROTOCOL)
