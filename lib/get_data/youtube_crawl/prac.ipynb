# %%
def get_youtube_chatlog(video_id, api_key="AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"):

    print("{}의 채팅로그를 불러옵니다.".format(streamer))
    from bs4 import BeautifulSoup
    import requests

    target_url = "https://www.youtube.com/watch?v=" + video_id
    dict_str = "" 
    chat_log = []
    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
    times = ""
    chat_log.append(streamer)
    
    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )
    if soup.find('strong', 'watch-time-text') == None:
        print("비공개 동영상 입니다.")

    else:
        tmp_times = soup.find('strong', 'watch-time-text').text.split(":")[1][1:].split(".")[:3]
        for part in tmp_times:
            if len(part) == 2:
                part = "0" + part.strip(" ")
            times += part.strip(" ")
 
    for iframe in soup.find_all ( "iframe" ) :
         if "live_chat_replay"  in iframe [ "src" ] :
            next_url = iframe [ "src" ]
    while True :
        try :
            html = session.get (next_url, headers = headers)
            soup = BeautifulSoup (html.text, "lxml" )
            for scrp in soup.find_all ( "script" ) :
                 if  'window[\"ytInitialData\"]' in scrp.text :
                    dict_str = scrp.text.split ( "] = " )[1]

            dict_str = dict_str.replace ( "false" , "False" )
            dict_str = dict_str.replace ( "true" , "True" ) 
            dict_str = dict_str.rstrip ( "  \n ;" )
            dics = eval (dict_str)
            continue_url =  dics [ "continuationContents" ] [ "liveChatContinuation" ] [ "continuations" ] [ 0 ] [ "liveChatReplayContinuationData" ] [ "continuation" ]
            next_url = "https://www.youtube.com/live_chat_replay?continuation=" + continue_url
            for samp in dics [ "continuationContents" ] [ "liveChatContinuation" ] [ "actions" ] [ 1 :] :
                tmp = samp ["replayChatItemAction" ] [ "actions" ] [ 0 ] [ "addChatItemAction" ] [ "item" ] [ "liveChatTextMessageRenderer" ]
                chat_log.append([[str(tmp [ "timestampText" ] [ "simpleText"]),str(tmp['authorName']["simpleText"]),str( tmp[ "message" ] [ "simpleText" ])]])
        
        except Exception as e:
            if len(str(e)) == 29:
                print("현재까지 {}개의 채팅로그를 가져왔습니다.".format(len(chat_log)))
                continue
            elif len(str(e)) == 32:
                print("{}의 채팅로그를 모두 받았읍니다.".format(streamer))
                break
            elif len(str(e)) == 62:
                print("{} 에서 불러올 채팅로그가 없거나 해당 동영상이 비공개입니다.".format(video_id))
                break
     

    if len(chat_log) == 1:
        print("저장할 채팅로그가 없습니다.")
    else:
        print("*"*50)
        users = []
        for i in range(1,len(chat_log)):
            users.append(chat_log[i][0][1])
        with open("{}-{}.txt".format(streamer,times), mode='w', encoding="utf-8") as f:
            f.write("방송 제목 : " + chat_log[0] + "\n")
            f.write("전체 시청자 수 : {} / 전체 채팅 수 : {}".format(len(set(users)),len(chat_log[1:])) + "\n" )
            comment = [x[0] for x in chat_log[1:]]
            for i in comment:
                f.write("[" + i[0] + "]" + " " + "<" + i[1] + ">" + " " + i[2] + '\n')

# %%
import os

# %%
tOAawIXyPGw
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-4-2e6a74aca7fd> in <module>()
#       1
# ----> 2 os.mkdir("gd")
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'gd'

# %% [markdown]
# tOAawIXyPGw
# g9Xxz4RMNs8

# %%
def get_youtube_chatlog(video_id, channel_name):
    '''
    video_id(str) : 라이브 동영상 고유 ID  <!!주의!!> video_id에 일반 동영상 ID를 넣을 경우 아무것도 저장하지 않습니다.
    channel_name(str) : 채팅 로그를 txt로 저장할 때 스트리머 이름과 날짜가 제목에 오게 됩니다. 
                    따라서 stramer에 유튜브 스트리머 이름이나 채널 이름을 넣어주세요.

    # !!참고!! 이 함수의 retrun값은 없습니다. 다만 video_id에 따라 라이브 동영상의 채팅로그가 
    txt 파일로 저장됩니다. (ex) 대도서관-YYYYMMDD.txt 
    '''
    print("{}의 채팅로그를 불러옵니다.".format(channel_name))
    
    from bs4 import BeautifulSoup
    import requests
    import os
    from datetime import datetime as dt

    target_url = "https://www.youtube.com/watch?v=" + video_id
    dict_str = ""     
    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
    
    chat_log = []
    info = {}
    
    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )
    if soup.find('strong', 'watch-time-text') == None:
        print("비공개 동영상 입니다.")

    else:
        tmp_times = soup.find('strong', 'watch-time-text').text[14:-1].replace(".","-").replace(" ","")
        times = dt.strptime(tmp_times, "%Y-%m-%d").strftime("%Y-%m-%d")
        
         
            
    for iframe in soup.find_all ( "iframe" ) :
         if "live_chat_replay"  in iframe [ "src" ] :
            next_url = iframe [ "src" ]
            
    while True :
        try :
            
            html = session.get (next_url, headers = headers)
            soup = BeautifulSoup (html.text, "lxml" )
            for scrp in soup.find_all ( "script" ) :
                 if  'window[\"ytInitialData\"]' in scrp.text :
                    dict_str = scrp.text.split ( "] = " )[1]

            dict_str = dict_str.replace ( "false" , "False" ).replace ( "true" , "True" ).rstrip ( "  \n ;" )
            
            dics = eval (dict_str)
            continue_url =  dics [ "continuationContents" ] [ "liveChatContinuation" ] [ "continuations" ] [ 0 ] [ "liveChatReplayContinuationData" ] [ "continuation" ]
            next_url = "https://www.youtube.com/live_chat_replay?continuation=" + continue_url
            
            for samp in dics [ "continuationContents" ] [ "liveChatContinuation" ] [ "actions" ] [ 1 :] :
                
                tmp = samp ["replayChatItemAction" ] [ "actions" ] [ 0 ] [ "addChatItemAction" ] [ "item" ] [ "liveChatTextMessageRenderer" ]
                info["video_id"] = video_id
                info["video_pulished_at"] = times
                info["nickname"] = str(tmp['authorName']["simpleText"])
                info["timestamp"] = str(tmp [ "timestampText" ] [ "simpleText"])
                info["content"] = str(tmp[ "message" ] [ "simpleText" ])
                
                
                chat_log.append(info)
                
                info = {}
                
        except Exception as e:
            if len(str(e)) == 29:
                print("채팅로그를 받고 있습니다.")
                continue
            elif len(str(e)) == 32:
                print("{}의 채팅로그를 모두 받았읍니다.".format(channel_name))
                break
            elif len(str(e)) == 62:
                print("{} 에서 불러올 채팅로그가 없거나 해당 동영상이 비공개입니다.".format(video_id))
                break
                
            
    

    if len(info) == 1:
        return print("저장할 채팅로그가 없습니다.")
    else:
        return chat_log

# %%
get_youtube_chatlog("tOAawIXyPGw","햇님")
# Out:
# 햇님의 채팅로그를 불러옵니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 채팅로그를 받고 있습니다.
# 햇님의 채팅로그를 모두 받았읍니다.
# [{'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완다',
#   'timestamp': '0:08',
#   'content': 'ㅎㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '엽떡설사',
#   'timestamp': '0:12',
#   'content': '1등'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '독자입니다',
#   'timestamp': '0:12',
#   'content': 'ㅎㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '조윤지',
#   'timestamp': '0:14',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'kk kk',
#   'timestamp': '0:15',
#   'content': 'ㅎㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '애플파인',
#   'timestamp': '0:15',
#   'content': 'ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완다',
#   'timestamp': '0:15',
#   'content': '30 만 축하유'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '워너원사랑해',
#   'timestamp': '0:15',
#   'content': 'ㅇㅅ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Amy Jang',
#   'timestamp': '0:15',
#   'content': '우왕'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇님파다닥',
#   'timestamp': '0:16',
#   'content': '온니~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '0:17',
#   'content': '시작인가요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '윤소영',
#   'timestamp': '0:17',
#   'content': 'ㅎㅇㅎㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '유지현',
#   'timestamp': '0:18',
#   'content': '우와우와'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '한지인',
#   'timestamp': '0:18',
#   'content': '안뇽하세요오'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'eun y',
#   'timestamp': '0:19',
#   'content': '꺅'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '독자입니다',
#   'timestamp': '0:19',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '애플파인',
#   'timestamp': '0:20',
#   'content': '4빠'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김수빈',
#   'timestamp': '0:21',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Seulgi Lee',
#   'timestamp': '0:22',
#   'content': '우와 안녕하세요!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '자루',
#   'timestamp': '0:22',
#   'content': '우오ㅓ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '유지현',
#   'timestamp': '0:22',
#   'content': '김밥너무조아'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '국민아',
#   'timestamp': '0:22',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'j sj',
#   'timestamp': '0:23',
#   'content': '엥 하이..'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김시연',
#   'timestamp': '0:23',
#   'content': '안녕하세용ㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'sven pacheco :v',
#   'timestamp': '0:23',
#   'content': 'holaaaa'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '해린',
#   'timestamp': '0:23',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니히',
#   'timestamp': '0:23',
#   'content': 'ㅎㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '신윤정',
#   'timestamp': '0:23',
#   'content': '잇'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '0:23',
#   'content': '아싸~~~ 이벤트~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황민현',
#   'timestamp': '0:24',
#   'content': '우와'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'zy zy',
#   'timestamp': '0:24',
#   'content': '안녕하세려'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김보영',
#   'timestamp': '0:25',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '강혜수',
#   'timestamp': '0:25',
#   'content': '와~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '차차',
#   'timestamp': '0:25',
#   'content': '안녕하세요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '여백',
#   'timestamp': '0:28',
#   'content': '안녕하세여~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김하은',
#   'timestamp': '0:28',
#   'content': '헐 낮방인가요?????????'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Amy Jang',
#   'timestamp': '0:28',
#   'content': '김밥나도줘용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오이시데스',
#   'timestamp': '0:28',
#   'content': '30 만추카'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '0:28',
#   'content': '메시지 빨리 왔어요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수진',
#   'timestamp': '0:28',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'sven pacheco :v',
#   'timestamp': '0:29',
#   'content': 'holaaa como estas'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '0:29',
#   'content': '오오'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김모모꽁',
#   'timestamp': '0:29',
#   'content': '원래 낮에도하셧어요??????'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '장경서',
#   'timestamp': '0:29',
#   'content': '안녕하세요!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'HJ Kim',
#   'timestamp': '0:30',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '마구',
#   'timestamp': '0:30',
#   'content': '안녕하세요~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최냠냠',
#   'timestamp': '0:30',
#   'content': '우왕'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황민현',
#   'timestamp': '0:30',
#   'content': '우와'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이예림',
#   'timestamp': '0:31',
#   'content': '엥 언니 안녕하세용ㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '0:31',
#   'content': '드디어'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '윤소정',
#   'timestamp': '0:32',
#   'content': '우아아앙ㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '신윤정',
#   'timestamp': '0:32',
#   'content': '우왕ㅇ!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '메론빵',
#   'timestamp': '0:32',
#   'content': '안녕하세요♡♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김시은',
#   'timestamp': '0:32',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정수현',
#   'timestamp': '0:32',
#   'content': '우와~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이영란',
#   'timestamp': '0:33',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '자루',
#   'timestamp': '0:33',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'somee lee',
#   'timestamp': '0:33',
#   'content': '아침에보니 새롭네영'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '행복한고구마',
#   'timestamp': '0:33',
#   'content': '아닛 지금시간에!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '유리',
#   'timestamp': '0:34',
#   'content': '안뇽하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Jane Kim',
#   'timestamp': '0:34',
#   'content': '안녕하요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '둥히',
#   'timestamp': '0:34',
#   'content': '대박대박'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황민현',
#   'timestamp': '0:34',
#   'content': '언니 안녕ㅎ세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Olivia Jeon',
#   'timestamp': '0:34',
#   'content': '엇 언니 오늘 이벤트!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '곽지연',
#   'timestamp': '0:34',
#   'content': '안냐세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '홍수연',
#   'timestamp': '0:34',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정다현',
#   'timestamp': '0:35',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '0:35',
#   'content': '바람 엄청 불어요~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정연',
#   'timestamp': '0:35',
#   'content': '우와 안녕하세여!!@'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '미나울강쥐',
#   'timestamp': '0:35',
#   'content': '안녕하세요~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '굿짱상',
#   'timestamp': '0:36',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '딸기라떼',
#   'timestamp': '0:36',
#   'content': '㉭→→'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '곤듀',
#   'timestamp': '0:36',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '끼링끼링씌',
#   'timestamp': '0:36',
#   'content': '와 안녕하세요!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '시언',
#   'timestamp': '0:37',
#   'content': '안냥하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '0:37',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '포코ღ',
#   'timestamp': '0:37',
#   'content': '오늘은 드뎌 알람이 ♥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수우여언',
#   'timestamp': '0:37',
#   'content': '오잉'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'linzhuyan',
#   'timestamp': '0:38',
#   'content': '대박...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니히',
#   'timestamp': '0:38',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '미완성인간',
#   'timestamp': '0:38',
#   'content': '안녕하세뇨!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'su_달쿄냥',
#   'timestamp': '0:39',
#   'content': '우왕~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '알찬열매슈밍',
#   'timestamp': '0:39',
#   'content': '출근전 언니 방송 보고 가야지.안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '허가영',
#   'timestamp': '0:39',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Seulgi Lee',
#   'timestamp': '0:40',
#   'content': '오늘 토요일인데!! 깜놀!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '소연김',
#   'timestamp': '0:40',
#   'content': '안녕하세용ㅎㅎㅎ갸악 김밥엔 라면!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이창민',
#   'timestamp': '0:40',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '빠게야마',
#   'timestamp': '0:40',
#   'content': '안녕하레여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '미미',
#   'timestamp': '0:41',
#   'content': '하잉 히히히'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최냠냠',
#   'timestamp': '0:41',
#   'content': '안녕하세요~~~~~~~~~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김원경',
#   'timestamp': '0:41',
#   'content': '안녕하세요~~!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇관수',
#   'timestamp': '0:41',
#   'content': '봄날 토욜날 방송 하악'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정수현',
#   'timestamp': '0:42',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '화정',
#   'timestamp': '0:42',
#   'content': '어머 저도 점심먹는중인데ㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Y우정',
#   'timestamp': '0:42',
#   'content': '처음 들어와봐요!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정꾸리ᅳ',
#   'timestamp': '0:42',
#   'content': '30마아안~축하드려요!!!!!!!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '콩가루인절미',
#   'timestamp': '0:43',
#   'content': '꺄 김밥방송'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김하은',
#   'timestamp': '0:43',
#   'content': 'ㅠㅠㅠㅠ 안녕하세용♥️♥️'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '현이공듀',
#   'timestamp': '0:43',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'HJ Kim',
#   'timestamp': '0:43',
#   'content': '오늘웬일로낮부터'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이유리',
#   'timestamp': '0:44',
#   'content': '안녕하세열ㄹㄹㄹㄹㄹㄹ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '히연',
#   'timestamp': '0:44',
#   'content': '안녕하세요~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '세나',
#   'timestamp': '0:44',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김문기',
#   'timestamp': '0:44',
#   'content': '안녕하세요ᆢ나도김밥먹고싶다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김희정',
#   'timestamp': '0:45',
#   'content': '안녕하세요~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '메론빵',
#   'timestamp': '0:45',
#   'content': '김밥이당♡♡♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황민현',
#   'timestamp': '0:45',
#   'content': '언니 30만명 축하해요❤️❤️❤️'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Honam An',
#   'timestamp': '0:46',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'janet 0811',
#   'timestamp': '0:46',
#   'content': '안녕하세뇨~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '히히힣호롱',
#   'timestamp': '0:46',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '0:47',
#   'content': '짱좋아요 안녕하세요♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '0:47',
#   'content': '저속모드좀.... 제발.....ㅠㅠㅠㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'youngha Lee',
#   'timestamp': '0:48',
#   'content': '지각 했어요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최서윤',
#   'timestamp': '0:48',
#   'content': '우와 언니!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수우여언',
#   'timestamp': '0:48',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오혜원',
#   'timestamp': '0:48',
#   'content': 'ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완다',
#   'timestamp': '0:49',
#   'content': '실제론 1빠지만'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'j sj',
#   'timestamp': '0:49',
#   'content': '저 티샤스 오랜만?ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '끼링끼링씌',
#   'timestamp': '0:49',
#   'content': '이게무슨일이야ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '[햇]도니버거',
#   'timestamp': '0:50',
#   'content': '우와!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '?!깨어진꿈결',
#   'timestamp': '0:50',
#   'content': '30만 축하드려요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '방탄과 아미들',
#   'timestamp': '0:50',
#   'content': '뭐먹어용?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수우여언',
#   'timestamp': '0:50',
#   'content': '!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '815 spyme',
#   'timestamp': '0:51',
#   'content': '헤에 이시간에!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'S2셍이',
#   'timestamp': '0:51',
#   'content': '영상으로만 보다가 생방보니깐 신기해요💙💙💙💙'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sharon Kim',
#   'timestamp': '0:52',
#   'content': '채팅이 엄청 올라가네요 대박 ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '슈크림',
#   'timestamp': '0:52',
#   'content': '언니~~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정지오',
#   'timestamp': '0:52',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Honam An',
#   'timestamp': '0:52',
#   'content': '토요일 낮방'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완두콩',
#   'timestamp': '0:52',
#   'content': '안녕~안녕~안녕하세요~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '찌이석',
#   'timestamp': '0:52',
#   'content': '안녕하세요👋🏻'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완다',
#   'timestamp': '0:52',
#   'content': '뒤로갔다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Hyein Jo',
#   'timestamp': '0:53',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '프리지아',
#   'timestamp': '0:53',
#   'content': '안녕하세요~^^'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '0:53',
#   'content': 'ㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '굿짱상',
#   'timestamp': '0:53',
#   'content': '맛있겠다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '고갱',
#   'timestamp': '0:53',
#   'content': '안녕하세요!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김해미',
#   'timestamp': '0:54',
#   'content': '저도내일 김밥싸요!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최서윤',
#   'timestamp': '0:55',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇교햇교',
#   'timestamp': '0:55',
#   'content': '출근해서 보다니 ㅋㄱㄱ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '0:55',
#   'content': '저속모드좀 해줘여ㅠㅠㅠㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이혜정',
#   'timestamp': '0:55',
#   'content': '채팅속도대박'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Jane Kim',
#   'timestamp': '0:55',
#   'content': '하이'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황민현',
#   'timestamp': '0:56',
#   'content': '언닝 축하축하해요♥️♥️♥️♥️♥️♥️♥️'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '전상미',
#   'timestamp': '0:57',
#   'content': '생방인가요???'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Y우정',
#   'timestamp': '0:57',
#   'content': '핸님!!!!!! 너무 팬입니당!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sophie Kim',
#   'timestamp': '0:59',
#   'content': '언니 낮방 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '0:59',
#   'content': '하이하이'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '1:00',
#   'content': '김밤 이벤트~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김현정',
#   'timestamp': '1:00',
#   'content': '저능욥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '끼링끼링씌',
#   'timestamp': '1:01',
#   'content': '왠일이죠ㅋㅋㄱㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '1:01',
#   'content': '김밥 쿡방이라니 ㅜㅜ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '히연',
#   'timestamp': '1:01',
#   'content': '❤️30만 축하드립니다❤️'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '앙팡앙팡',
#   'timestamp': '1:01',
#   'content': '안뇽하세용ㅇㅇㅇㅇㅇㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '성옥현',
#   'timestamp': '1:01',
#   'content': '저는 일어나자마자 피맥중이에요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '행복한고구마',
#   'timestamp': '1:02',
#   'content': '맨날 미국시간 아침에 보다가 밤에 알람뜨니까 넘나 반가워여💜'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최미진',
#   'timestamp': '1:02',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '쪼코비',
#   'timestamp': '1:03',
#   'content': '안녕하세욥!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김모모꽁',
#   'timestamp': '1:03',
#   'content': '저두왓어여!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Queen of august',
#   'timestamp': '1:03',
#   'content': '안뇽하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '예인',
#   'timestamp': '1:03',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '단꿈토끼',
#   'timestamp': '1:03',
#   'content': '어머 햇님♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김태협',
#   'timestamp': '1:04',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오혜원',
#   'timestamp': '1:04',
#   'content': '보고싶었어요.'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '유보람',
#   'timestamp': '1:04',
#   'content': '안녕하세용 ㅎㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇관수',
#   'timestamp': '1:04',
#   'content': '참치 실화ㅋㅋㄱㅋㄱㄱㄱㅋ?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '꽥오리',
#   'timestamp': '1:04',
#   'content': '흑 서울 살고싶어요ㅠㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '박병맛',
#   'timestamp': '1:04',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '홍수연',
#   'timestamp': '1:04',
#   'content': '안녕하세여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'N피카츄우',
#   'timestamp': '1:05',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sunyoung Choi',
#   'timestamp': '1:05',
#   'content': '오잉 언니~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'zihyun',
#   'timestamp': '1:06',
#   'content': '햇하~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김지나',
#   'timestamp': '1:06',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '해린',
#   'timestamp': '1:06',
#   'content': '안녕하세요.'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:06',
#   'content': '이모티콘 세개까지만 사용해주세옇'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '무이무이22',
#   'timestamp': '1:07',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최아람',
#   'timestamp': '1:07',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정지오',
#   'timestamp': '1:08',
#   'content': '김밥~~♡♡♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '멍멍니야옹',
#   'timestamp': '1:09',
#   'content': '우와~ 저 외로웠는데 너무 좋아요ㅡ 주말에 햇님이랑 데이트하는 느낌'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Cecilia Jung',
#   'timestamp': '1:09',
#   'content': '안녕하쉐욭'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '워너원사랑해',
#   'timestamp': '1:09',
#   'content': '밖에 바람 너무 많이불어요ㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이솔',
#   'timestamp': '1:10',
#   'content': '우와 라이브 첨이당'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '1:10',
#   'content': '방송 나오는거에요??'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'youngha Lee',
#   'timestamp': '1:10',
#   'content': '햇 영패밀리예요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김보민',
#   'timestamp': '1:10',
#   'content': '하이하이'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '푸딩딩',
#   'timestamp': '1:11',
#   'content': '제가 라면 끓여드릴게효~~~ 한 줄만 주세용><'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '엄소희',
#   'timestamp': '1:11',
#   'content': '헉 언니 안녕하세요!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '1:11',
#   'content': '와우!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '조윤지',
#   'timestamp': '1:12',
#   'content': '30만명 축하드려욥!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Hyein Jo',
#   'timestamp': '1:13',
#   'content': '언니 팬이에요!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '강혜수',
#   'timestamp': '1:13',
#   'content': '저도 김밥먹고파요 ㅠㅠ 햇님표'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이번엔너',
#   'timestamp': '1:14',
#   'content': '꺄항'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:14',
#   'content': '다들 어서오세용(▰˘◡˘▰)'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '1:14',
#   'content': '먹고 싶은데... 홍대 너무 멀어요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정연',
#   'timestamp': '1:15',
#   'content': '와 달려~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '고은수',
#   'timestamp': '1:15',
#   'content': '아 김밥ㅜㅜㅜㅜㅜ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Olivia Jeon',
#   'timestamp': '1:15',
#   'content': '채팅 넘나 빠른 것'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Yusun Hong',
#   'timestamp': '1:15',
#   'content': '안녕하세용~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '왕자님복숭아',
#   'timestamp': '1:15',
#   'content': '여기 사람 왜ㅜ이렇게ㅜ많아!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:16',
#   'content': '오신분들 추천 한번 부탁드려요٩( ‘ω’ )و'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Jane Kim',
#   'timestamp': '1:17',
#   'content': '챗봐요 엄청 빨름'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '1:17',
#   'content': '소통불가'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은석',
#   'timestamp': '1:17',
#   'content': '예~~~김봡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '독자입니다',
#   'timestamp': '1:18',
#   'content': '넹넹'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '1:18',
#   'content': '넴'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '1:18',
#   'content': '정수리방송 요즘 자주 보내요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '홀릭스',
#   'timestamp': '1:20',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sunyoung Choi',
#   'timestamp': '1:20',
#   'content': '축하해요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'D유니칸',
#   'timestamp': '1:20',
#   'content': '안녕하세요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '무민',
#   'timestamp': '1:20',
#   'content': '넹'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Seulgi Lee',
#   'timestamp': '1:21',
#   'content': '저속모드 ㄴㄴ라니ㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '완다',
#   'timestamp': '1:21',
#   'content': '유튭 쳇 넘빠러'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '방탄과 아미들',
#   'timestamp': '1:21',
#   'content': '배고프다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Su 5',
#   'timestamp': '1:22',
#   'content': '안녕하세요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김민경',
#   'timestamp': '1:22',
#   'content': '김밥이당'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '1:22',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '독자입니다',
#   'timestamp': '1:23',
#   'content': '김밥최고'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '1:23',
#   'content': '안뇽안뇽'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '1:23',
#   'content': '언니 일찍부터 언니 보니 반갑네요~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'HJ Kim',
#   'timestamp': '1:24',
#   'content': 'ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '신승혜',
#   'timestamp': '1:24',
#   'content': '배고파요!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇오뚜기',
#   'timestamp': '1:24',
#   'content': '기다렸다아아아'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '엄소희',
#   'timestamp': '1:25',
#   'content': '일하다가 놀라서 들어왔네욬ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇교햇교',
#   'timestamp': '1:25',
#   'content': '김밥사러가야겠다ㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Cecilia Jung',
#   'timestamp': '1:25',
#   'content': 'ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정수희',
#   'timestamp': '1:26',
#   'content': '꺅'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sophie Kim',
#   'timestamp': '1:26',
#   'content': '넹 언니 ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Hyein Jo',
#   'timestamp': '1:26',
#   'content': '넹 ㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '1:27',
#   'content': '우리끼리 놀아랰ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '1:27',
#   'content': '알아서 놀기'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇관수',
#   'timestamp': '1:27',
#   'content': '싸는거 염탐하는 방송ㅋㄱㅋㄱㄱㄱㄱㄱ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정지선',
#   'timestamp': '1:28',
#   'content': '안녕하세요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '히연',
#   'timestamp': '1:28',
#   'content': 'ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '끼링끼링씌',
#   'timestamp': '1:29',
#   'content': '매니저님들힘드시자나요ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '단꿈토끼',
#   'timestamp': '1:29',
#   'content': '김밥 재료준비하느라 고생하셨어요♡♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '박병맛',
#   'timestamp': '1:29',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ님들끼리몰아욬ㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Su 5',
#   'timestamp': '1:29',
#   'content': '뉴욕에서 보러왔습니다.'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '윤소정',
#   'timestamp': '1:29',
#   'content': '제옆사람도 햇님방송보고있어요....!!!!@!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:29',
#   'content': '다들 어서오세용(▰˘◡˘▰)'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sunyoung Choi',
#   'timestamp': '1:30',
#   'content': '매니저님들도 화이팅'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수우여언',
#   'timestamp': '1:31',
#   'content': 'ㅋㅋㅋㄱㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '행복한고구마',
#   'timestamp': '1:31',
#   'content': '낼 김밥 만들라 그랬는데 오'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정수희',
#   'timestamp': '1:31',
#   'content': '김밥이다아아아'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지명희',
#   'timestamp': '1:31',
#   'content': '농ㅎ엻옂혀고더뎢ㅎ뎓ㅎㅎㄷㅇ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '엄소희',
#   'timestamp': '1:33',
#   'content': '아 진짜 맛있겠다ㅜㅜㅜ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '맑음오늘',
#   'timestamp': '1:34',
#   'content': '우리끼리놀아여 ㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'D유니칸',
#   'timestamp': '1:34',
#   'content': '갑자기 방송켜져서 깜놀'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '전혜원',
#   'timestamp': '1:34',
#   'content': '가고 싶어요♡'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '강혜수',
#   'timestamp': '1:34',
#   'content': '네네 우리끼리 놀게요 ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '츄엉',
#   'timestamp': '1:35',
#   'content': '햄 오지다 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Su 5',
#   'timestamp': '1:35',
#   'content': '맛있게 말아주세요!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇꿀이꿀이',
#   'timestamp': '1:35',
#   'content': '누나 저이따가 갈거에요 김밥받으러!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오혜원',
#   'timestamp': '1:36',
#   'content': '김밥 맛있겠어요.'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '파워쿨톤이수나',
#   'timestamp': '1:36',
#   'content': '우와 오늘 일찍하네여!!!!!꺆'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은혜',
#   'timestamp': '1:36',
#   'content': '님 안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:37',
#   'content': '스트리밍 함께하시는 모든 분들 좋아요👍🏻 한번씩 부탁드립니다💕'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜비혜비',
#   'timestamp': '1:37',
#   'content': '소풍갈 때 두 줄만 주세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '리솔이',
#   'timestamp': '1:39',
#   'content': '와우'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '1:39',
#   'content': '정수리~ 방송... 정수리~~~ 요리 방송'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '자루',
#   'timestamp': '1:39',
#   'content': '와 속도,,'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '치즈치즈',
#   'timestamp': '1:40',
#   'content': '헐 왜 알림이 안뜨지ㅠㅠ방송 이제 시작한건가요?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은석',
#   'timestamp': '1:40',
#   'content': '이야.'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '슈크림',
#   'timestamp': '1:41',
#   'content': '화이팅!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수우여언',
#   'timestamp': '1:42',
#   'content': '여러분안뇽~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '뿅뿅',
#   'timestamp': '1:42',
#   'content': '님들끼리 놀아요♥ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니',
#   'timestamp': '1:42',
#   'content': '오옷!!!!!!!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이슬',
#   'timestamp': '1:43',
#   'content': '오졋다 ㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '휘향이',
#   'timestamp': '1:43',
#   'content': '붓기가. 안빠진 ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'su_달쿄냥',
#   'timestamp': '1:43',
#   'content': '그래도 저속모드해줘요ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '해3',
#   'timestamp': '1:44',
#   'content': '시작하기전에 소통해주어ㅓㅓㅓㅓㅓㅓㅓㅓ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '1:45',
#   'content': '언니이이이이이!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '엄소희',
#   'timestamp': '1:45',
#   'content': '참치인가옄ㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:45',
#   'content': '제발 저속모드좀해주라ㅠㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김태협',
#   'timestamp': '1:46',
#   'content': '김밥 재료지데루다 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '단꿈토끼',
#   'timestamp': '1:46',
#   'content': '맛살크기 실화냐'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Liz_0224_Ed Seo',
#   'timestamp': '1:46',
#   'content': '1시에 올려고 했는데 늦어버렸어요 ㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜비혜비',
#   'timestamp': '1:47',
#   'content': '불통예상'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '반짝햇님반',
#   'timestamp': '1:48',
#   'content': '김밥싸서 소풍가나요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '앙꼬',
#   'timestamp': '1:48',
#   'content': '안녕하세용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이새봄',
#   'timestamp': '1:49',
#   'content': '우왕 언니ㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇딩딩이',
#   'timestamp': '1:49',
#   'content': '안녕하세요오오 ~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니',
#   'timestamp': '1:49',
#   'content': '느낌으로 들어왔ㄹ는데!!!!!!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '코리',
#   'timestamp': '1:49',
#   'content': '언니이ㅣ!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'an정재',
#   'timestamp': '1:49',
#   'content': '오 김밥 ♥♥♥♥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:49',
#   'content': '다들 어서오세용(▰˘◡˘▰)'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '네모모',
#   'timestamp': '1:50',
#   'content': '헐 대박사건 독서실도착했는데 생방봐야하는부분인가'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이창민',
#   'timestamp': '1:51',
#   'content': '냄비에 저거 뭐예요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '박유진',
#   'timestamp': '1:51',
#   'content': '어디가요?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은석',
#   'timestamp': '1:51',
#   'content': '김밥 쪼아'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '1:52',
#   'content': '자주본다 정수리야'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '1:52',
#   'content': '스트리밍 함께하시는 모든 분들 좋아요👍🏻 한번씩 부탁드립니다💕'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오돌희',
#   'timestamp': '1:52',
#   'content': '헐 김밥 나눔 !!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '민경진',
#   'timestamp': '1:52',
#   'content': '고생하셨네요!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'j sj',
#   'timestamp': '1:52',
#   'content': '칼 무섭ㅋㅋㅋㄱㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '조복선',
#   'timestamp': '1:52',
#   'content': '눈빠지게기다렸는데'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'water토끼',
#   'timestamp': '1:52',
#   'content': '지방러는 울어요ㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니',
#   'timestamp': '1:52',
#   'content': '안녕하세요 언니1'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지원Jiwon',
#   'timestamp': '1:52',
#   'content': '꺄~~~~~~~~~~~~~~~~생방으로 보다니~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오혜원',
#   'timestamp': '1:52',
#   'content': '힘내시고 ... 화이팅!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '깡내이',
#   'timestamp': '1:53',
#   'content': 'ㅜㅜㅜㅜ미치겠다김밥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sophie’s happy life',
#   'timestamp': '1:55',
#   'content': '오랜만에 와서 그런데... 햇님 공중파 나오시나요??'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '방탄과 아미들',
#   'timestamp': '1:56',
#   'content': '머리 귀여워요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '성옥현',
#   'timestamp': '1:56',
#   'content': '우와!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지니',
#   'timestamp': '1:57',
#   'content': '헐 시작하자마자 들어왔어 대박'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '최서윤',
#   'timestamp': '1:57',
#   'content': '어디로 받으러가믄되나여ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Dap No',
#   'timestamp': '1:59',
#   'content': '우아아아아아!!!!!!!!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '페이커리',
#   'timestamp': '2:00',
#   'content': '앗 햇님이다~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '아렌',
#   'timestamp': '2:00',
#   'content': '~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜비혜비',
#   'timestamp': '2:00',
#   'content': '양 봐라 ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '2:01',
#   'content': '스트리밍 함께하시는 모든 분들 좋아요👍🏻 한번씩 부탁드립니다💕'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '끼링끼링씌',
#   'timestamp': '2:01',
#   'content': '몇줄싸시려고 도대체ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지원Jiwon',
#   'timestamp': '2:01',
#   'content': '언니 반가워여어어어어'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '휘향이',
#   'timestamp': '2:01',
#   'content': '아이고. 배고파...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Jane Kim',
#   'timestamp': '2:02',
#   'content': '소풍가요?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇꿀이꿀이',
#   'timestamp': '2:02',
#   'content': '누나저 이따 갈거에요!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sophie Kim',
#   'timestamp': '2:02',
#   'content': 'ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Abir salem',
#   'timestamp': '2:15',
#   'content': 'هلا وغلا'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇님파다닥',
#   'timestamp': '2:17',
#   'content': '홧팅!!!!!!!!!!☆'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '한윤희',
#   'timestamp': '2:17',
#   'content': '김밥 맛있죠'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '휘향이',
#   'timestamp': '2:18',
#   'content': '아이거배고파'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '2:18',
#   'content': '햄 어묵 계란 맛살 우엉 단무지 오이 당근 깻잎☆☆'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '2:19',
#   'content': '백만 가면 백줄인가요??'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '델라',
#   'timestamp': '2:19',
#   'content': '안녕하세요😊'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '코리',
#   'timestamp': '2:19',
#   'content': '언니ㅠㅠㅠㅠㅠㅠㅠ보고싶었어요ㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'water토끼',
#   'timestamp': '2:20',
#   'content': '주말방송 좋네요 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김모모꽁',
#   'timestamp': '2:21',
#   'content': '좋아요 1등!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '장계월',
#   'timestamp': '2:24',
#   'content': '김밥싸서 소풍가즈아~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '츄엉',
#   'timestamp': '2:25',
#   'content': '도와주시는분들 소리질러~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이유빈',
#   'timestamp': '2:25',
#   'content': '어디가셔요?????'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '강혜수',
#   'timestamp': '2:26',
#   'content': '오늘은 햇님김밥데이'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜영',
#   'timestamp': '2:27',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '휘향이',
#   'timestamp': '2:27',
#   'content': '김밥은. 역시. 집김밥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이주영',
#   'timestamp': '2:27',
#   'content': '최곱니다👍👍👍👍👍'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'jjin k',
#   'timestamp': '2:29',
#   'content': '까아아악~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '오돌희',
#   'timestamp': '2:30',
#   'content': '라이브 언제 키는지 모르져!!!?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '해3',
#   'timestamp': '2:30',
#   'content': '삼십만 오십만 백만 쭉쭉쭉 햇님 슈스 대작전 화이팅~~~~~~~~~~~~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정수희',
#   'timestamp': '2:31',
#   'content': 'ㅠㅠ정성대박 우런니💘💘'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Rosy Ash',
#   'timestamp': '2:31',
#   'content': '우와'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '파워쿨톤이수나',
#   'timestamp': '2:37',
#   'content': '옆에 도와주시는 분들은 친구분들이신가요???'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Lovely 블리야 놀자블리',
#   'timestamp': '2:38',
#   'content': '오잉?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '2:38',
#   'content': '헐 대박'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ᄀᄇᄅ',
#   'timestamp': '2:39',
#   'content': '언니 안냥하세요~~!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Sophie’s happy life',
#   'timestamp': '2:39',
#   'content': '미쿡에도 오셔요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
# ...
#   'content': '대충 나눔 시간대가 정해져있나여?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '11:26',
#   'content': '한줄=한끼'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '11:26',
#   'content': '+깻잎'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '수진',
#   'timestamp': '11:27',
#   'content': '저는 햇님 방송중 순대복음하구 김밥이 최고 좋아용 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김태협',
#   'timestamp': '11:27',
#   'content': '오이 많이 넣어주세 아삭아삭 하게'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '11:30',
#   'content': '구독100만 김밥 100줄 가나여?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '11:31',
#   'content': '밥이꼬실하네요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '페이커리',
#   'timestamp': '11:32',
#   'content': 'ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '익명[누군가]',
#   'timestamp': '11:33',
#   'content': '배거팡..'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇딩딩이',
#   'timestamp': '11:34',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ와 진짴ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이번엔너',
#   'timestamp': '11:35',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 꼬다리 스틸ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '뾰임',
#   'timestamp': '11:35',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ-ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김동이 엄마',
#   'timestamp': '11:35',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'sana',
#   'timestamp': '11:36',
#   'content': '오양맛살 통으로 들어간 김밥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '박하은',
#   'timestamp': '11:37',
#   'content': '공평잼 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '1밉상겅쥬',
#   'timestamp': '11:39',
#   'content': '고기방송송도 아니것만 상체방송이ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇딩딩이',
#   'timestamp': '11:41',
#   'content': '햇님 양애취니 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김연희',
#   'timestamp': '11:42',
#   'content': '이미 넘나 맛나게 보여융'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Joan',
#   'timestamp': '11:43',
#   'content': '김밥 맛있어 보여요~!!! 집김밥 사랑이죠'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Kim Pia',
#   'timestamp': '11:43',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은별',
#   'timestamp': '11:45',
#   'content': '언니가 싸준 김밥 먹고싶네용 ㅎㅎ ㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'youngha Lee',
#   'timestamp': '11:45',
#   'content': '좋으네요 꼬다리 없는 김밥'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '쭈둥이',
#   'timestamp': '11:46',
#   'content': '김밥 먹으러 갈수도 없고ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '실버카이',
#   'timestamp': '11:48',
#   'content': 'ㅠㅠㅠㅠ인스타 안하는데ㅠㅠㅠ이럴수가ㅠㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '11:48',
#   'content': 'ㄴㄴ 꼬다리 없는 분은 당첨~ 된 걸루 가요~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '프리지아',
#   'timestamp': '11:49',
#   'content': '아 대박 재밌네요 언니방송ㅎㅎㅎㅎㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김수현',
#   'timestamp': '11:49',
#   'content': '인스타안하는데ㅠㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '승현이',
#   'timestamp': '11:50',
#   'content': '제이름불러주세옴'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Abby Kim',
#   'timestamp': '11:54',
#   'content': '누드김밥 어때요? ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김동이 엄마',
#   'timestamp': '11:55',
#   'content': '안녕하세요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '여백',
#   'timestamp': '11:56',
#   'content': '꼬다리가 하나 없는게 햇님김밥 시그니쳐'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '11:57',
#   'content': '오이도완잔커용'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '11:57',
#   'content': '난 제주란 말이야.........'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '익명[누군가]',
#   'timestamp': '11:57',
#   'content': '저한 입만 주세욯'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '한윤희',
#   'timestamp': '11:57',
#   'content': '집에서는 맛쌀도 잘라넣는데 통크게 통으로'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜민',
#   'timestamp': '11:58',
#   'content': '앗...맛있겠다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '쭈둥이',
#   'timestamp': '11:58',
#   'content': '다 가까운 사람들이 가게꾼ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Kim Pia',
#   'timestamp': '11:59',
#   'content': '저도 먹고 싶어요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김수현',
#   'timestamp': '12:02',
#   'content': '인스타안해요ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅍ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노란이',
#   'timestamp': '12:04',
#   'content': '언니 말 편히해도 괜츈해여'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:06',
#   'content': '참치 양 봐...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '12:06',
#   'content': '홍대 가야나... 힝.... 30분 부럽부럽~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '잉여',
#   'timestamp': '12:08',
#   'content': '으아아아 참치김밥 먹고싶다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지민',
#   'timestamp': '12:08',
#   'content': '언니 냄비에 있는건 머에요??밥이에요??'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '1밉상겅쥬',
#   'timestamp': '12:10',
#   'content': '누릉지탕인듯ㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '와우',
#   'timestamp': '12:11',
#   'content': '김밥나눔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ언니 넘 기어워유ㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '연지',
#   'timestamp': '12:12',
#   'content': '언니 김밥 터지는거 아닌가요 ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ᄋ도레미',
#   'timestamp': '12:14',
#   'content': '진짜저김밥너무먹고싶다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '12:16',
#   'content': '김밥 먹방이 아닌 구독자 30만 기념 나눔김밥 싸는 중이에영_ 나눔 장소는 인스타 cnstka486으로 라이브방송하며 공개하시니 참고 부탁드려용^^!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '한윤희',
#   'timestamp': '12:16',
#   'content': '맛있을수밖에 잆는 비주얼'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:17',
#   'content': '마스크끼면 연구원 아니 의사 ㅋㅋㅋㅋ메스김밥 ㅋㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '혜민',
#   'timestamp': '12:18',
#   'content': '부산...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '조지원',
#   'timestamp': '12:20',
#   'content': '저는 오이 빼고 주세요 >_<ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '12:20',
#   'content': '참치요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '유은선',
#   'timestamp': '12:20',
#   'content': '서울이 부럽네여ㅠㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '와잇옥',
#   'timestamp': '12:22',
#   'content': '냄비엔 참치마요에욤'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '콩가루',
#   'timestamp': '12:23',
#   'content': '맛살 엄청 크네 어디꺼에요???'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ᄋ도레미',
#   'timestamp': '12:23',
#   'content': '터짐'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '지민',
#   'timestamp': '12:24',
#   'content': '으앙~~맛있겠다'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '불끄고일롸',
#   'timestamp': '12:26',
#   'content': '냄비=참치'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'love shine _',
#   'timestamp': '12:28',
#   'content': '헐 낮방이라니!!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:28',
#   'content': '욕망 김밥 하나 추가요...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '12:28',
#   'content': '김밥 싸는 힘 봐...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김동이 엄마',
#   'timestamp': '12:29',
#   'content': '칼이 잘 안되는 듯'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '12:31',
#   'content': '정수리 방송도 아닌 하얀손 방송~~~ ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'najin kim',
#   'timestamp': '12:32',
#   'content': '터졌어요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇딩딩이',
#   'timestamp': '12:33',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '연지',
#   'timestamp': '12:34',
#   'content': '터졋엌ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '12:35',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '12:35',
#   'content': '곰돌이 마스크...'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:35',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '페이커리',
#   'timestamp': '12:35',
#   'content': 'ㅋㅋㅋㅋ마스크 ㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '12:36',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '두콩',
#   'timestamp': '12:36',
#   'content': '오오 낮방송 ~~~'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '새벽효',
#   'timestamp': '12:37',
#   'content': 'ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이윤선',
#   'timestamp': '12:37',
#   'content': '김밥 겁나 통통하다 ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'RuMin Ma',
#   'timestamp': '12:38',
#   'content': 'ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '1밉상겅쥬',
#   'timestamp': '12:38',
#   'content': '벽돌수육에 이어 벽돌김밥ㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정연',
#   'timestamp': '12:38',
#   'content': '귀엽ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'Joan',
#   'timestamp': '12:38',
#   'content': '맛 계속보세요~~꼬다리한쪽'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ONCE_둡밍',
#   'timestamp': '12:38',
#   'content': '으엌ㅋㅋㅋㅋ 맛있겟다 와 언니 마스크까지 귀여워욬ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'su_달쿄냥',
#   'timestamp': '12:39',
#   'content': 'ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '12:39',
#   'content': '저개뭐얔ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은별',
#   'timestamp': '12:39',
#   'content': 'ㅋㅋㅋㅋㅋㅋ아언닠ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'NICE EUNICE 나희',
#   'timestamp': '12:40',
#   'content': '김밥 발 없이 마시다니 능력자!!!!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇청',
#   'timestamp': '12:40',
#   'content': '왜쓰신거..ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정다미',
#   'timestamp': '12:41',
#   'content': '안녕하세요 오랜만에왔어요ㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '퐁랜',
#   'timestamp': '12:41',
#   'content': 'ㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '12:41',
#   'content': '김밥 먹방이 아닌 구독자 30만 기념 나눔김밥 싸는 중이에영_ 나눔 장소는 인스타 cnstka486으로 라이브방송하며 공개하시니 참고 부탁드려용^^!'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '여백',
#   'timestamp': '12:42',
#   'content': '찰떡~ 넘 잘어울려요.ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇딩딩이',
#   'timestamp': '12:42',
#   'content': '으앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '니니',
#   'timestamp': '12:42',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ마스킄ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '히연',
#   'timestamp': '12:43',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은별',
#   'timestamp': '12:43',
#   'content': '웃겨용 ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'sk choi',
#   'timestamp': '12:43',
#   'content': '마스크 왜 끼셧어용?'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:43',
#   'content': '언니 터졌어욬ㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌㅋㅌ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '노바디',
#   'timestamp': '12:44',
#   'content': '김이 버거워보이는건 기분탓ㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이은혜',
#   'timestamp': '12:45',
#   'content': 'ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ᄋ도레미',
#   'timestamp': '12:45',
#   'content': 'ㅋㅋㅌㅋㅌㅌㅌㅌ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '황혜정',
#   'timestamp': '12:45',
#   'content': '앉아사 싸시징'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '프리지아',
#   'timestamp': '12:55',
#   'content': '밖에서 하고다니는거녜ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '정연',
#   'timestamp': '12:57',
#   'content': '곰돌곰돌'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '이레인',
#   'timestamp': '12:57',
#   'content': 'ㅋㅋㅋㅋㅋㅋㅋ코밑으로 내려요ㅋㅋ 답답하시겠어요'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '양슬기',
#   'timestamp': '12:57',
#   'content': '김 : 사 살려줘....'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': 'ONCE_둡밍',
#   'timestamp': '13:00',
#   'content': '오 김밥 잘싸셬ㅋㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '안녕미꾸',
#   'timestamp': '13:03',
#   'content': '모두들 안녕하세용^^'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '김동이 엄마',
#   'timestamp': '13:03',
#   'content': '칼이..'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': "방구I'm",
#   'timestamp': '13:05',
#   'content': '터지고있엌ㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '박하은',
#   'timestamp': '13:05',
#   'content': '악 터진당 ㅋㅋㅋㅋㅋㅋ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '햇이슬',
#   'timestamp': '13:07',
#   'content': '김밥 터져도 마시써ㅠㅠ'},
#  {'video_id': 'tOAawIXyPGw',
#   'video_pulished_at': '2018-04-06',
#   'nickname': '진은 핸썸에서 태어났쬬',
#   'timestamp': '13:07',
#   'content': '어머'},
#  ...]

# %%
t1 = "실시간 스트리밍 시작일: 2018. 4. 6."

# %%
te1 = t1[14:-1].replace(".","-").replace(" ","")

# %%
from datetime import datetime as dt
times = dt.strptime(te1, "%Y-%m-%d").strftime("%Y-%m-%d")
times
# Out:
# '2018-04-06'

# %%
t2= "실시간 스트리밍 시작일: 2018. 11. 25."

# %%
from datetime import datetime as dt
dt.strftime("2017-01-02 14:44", "%Y-%m-%d %H:%M")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d19af89109e9> in <module>()
#       1 from datetime import datetime as dt
# ----> 2 dt.strftime("2017-01-02 14:44", "%Y-%m-%d %H:%M")
#
# TypeError: descriptor 'strftime' requires a 'datetime.date' object but received a 'str'

# %%
import datetime
datetime.datetime.strftime("2017-01-02 14:44", "%Y-%m-%d %H:%M")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-66692044ac95> in <module>()
#       1 import datetime
# ----> 2 datetime.datetime.strftime("2017-01-02 14:44", "%Y-%m-%d %H:%M")
#
# TypeError: descriptor 'strftime' requires a 'datetime.date' object but received a 'str'

# %%
x = datetime.datetime.strptime("2017-4-6 ", "%Y-%m-%d ")
x.strftime("%Y-%m-%d")
# Out:
# '2017-04-06'

# %%
# Out:
# 2
