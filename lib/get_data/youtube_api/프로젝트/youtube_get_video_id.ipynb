# %% [markdown]
#     api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
#     chanel_id = "UCLJi9Vk8_y3y_evAahQUEpQ"
#
#    target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&eventType=completed&type=video&maxResults=50&key={}"

# %%
def get_video_id(channel_url, api_key):
    '''
    channel_id : 유튜버 채널의 고유 채널 ID ("https://www.youtube.com/channel/~" 또는 "https://www.youtube.com/user/~" )
    api_key : 자신의 API키   
        
    return => 일반 동영상 고유 ID(list), 라이브 동영상 고유 ID(list)
    '''
    
    import requests
    from bs4 import BeautifulSoup 

    
    
    if "channel" in channel_url:  
        
        api_key = api_key
        channel_id = channel_url.split("/")[-1]
        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)
        
        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일반 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return video_ids, live_video_ids
    
    
    elif "user" in channel_url:
        api_key = api_key

        channel_id = user_to_channelid(channel_url.split("/")[-1], api_key)

        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일단 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

                        
        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)
                                
                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ################################################################################################################

        video_ids = list(set(video_ids) - set(live_video_ids))
        
        return video_ids, live_video_ids

# %%
def user_to_channelid(user_name, api_key):

    import requests
    from bs4 import BeautifulSoup 

    api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]
    print(channel_id)
    
    return channel_id

# %%
get_video_id("https://www.youtube.com/channel/UCIYWRFi7y6fBqosN5m5xxWA", "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak")
# Out:
# 라이브 동영상 없음
# (['vrNBP-PHvFM',
#   'A3BX4wQ0Ck0',
#   'NLN_yWNf0NQ',
#   'gq6M2TdWcyw',
#   'gJlg1caMUb8',
#   'EyrUoD8y_sE',
#   '1JGLafC2GMo',
#   'c5D5lxmYG04',
#   '7aiYcJpYPwc',
#   'CM3u7XOWVj0',
#   'rn2GQ8Hunjk',
#   'wHEebDcj0RE',
#   'G8dWa8zotZw',
#   'QUL_LzWHEM4',
#   'lN_6YwBekRM'],
#  [])

# %%
import requests
from bs4 import BeautifulSoup 


api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channel_id = "UCIYWRFi7y6fBqosN5m5xxWA"
page_token = ""

target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))

total_results = api_dict['pageInfo']['totalResults']
results_per_page = api_dict['pageInfo']['resultsPerPage']
exe_set = round(total_results / results_per_page +0.5)

print(total_results, results_per_page, exe_set)

api_dict
# Out:
# 15 50 1
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/1_CLBgSOQ7znnghWQLcr3YGao7E"',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 15, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/rbHoH_bspX1GzOrFSOYTZX7OR2Q"',
#    'id': {'kind': 'youtube#video', 'videoId': '1JGLafC2GMo'},
#    'snippet': {'publishedAt': '2018-12-17T02:48:48.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'jufla - 불면증',
#     'description': '평범한 대학생의 학교 안가는 날.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1JGLafC2GMo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1JGLafC2GMo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1JGLafC2GMo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/cWT0qkoyHJyas_Q7ch2SYVf7kMU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'wHEebDcj0RE'},
#    'snippet': {'publishedAt': '2018-12-10T09:32:15.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'jufla - next level',
#     'description': '좀 센 노래.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wHEebDcj0RE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wHEebDcj0RE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wHEebDcj0RE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ySYSJYzl7ixPxQG0FuO1XVyr0sI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gq6M2TdWcyw'},
#    'snippet': {'publishedAt': '2018-11-18T07:06:21.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - 지름신(feat. carpe diem)',
#     'description': '펜자랑.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gq6M2TdWcyw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gq6M2TdWcyw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gq6M2TdWcyw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/UxEfEqTe-_TesCqT4rWkFgcTAYw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'vrNBP-PHvFM'},
#    'snippet': {'publishedAt': '2018-11-04T10:25:50.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - 그냥 요새 근황',
#     'description': '2월2.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vrNBP-PHvFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vrNBP-PHvFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vrNBP-PHvFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/P4GRyEcZ_8iy-zXhZbyWypYyQTM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'NLN_yWNf0NQ'},
#    'snippet': {'publishedAt': '2018-10-25T10:34:09.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - 보헤미안(자막有)',
#     'description': 'Is this the real life?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NLN_yWNf0NQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NLN_yWNf0NQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NLN_yWNf0NQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/HU50n2Yp5jo_j_UadrMJBFc4rRo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'c5D5lxmYG04'},
#    'snippet': {'publishedAt': '2018-10-20T05:48:31.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - ghost war review(자막有)',
#     'description': 'Netflix.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c5D5lxmYG04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/c5D5lxmYG04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/c5D5lxmYG04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/EN9gy5K8XxG2eaYwkndW3Mo8mFg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'lN_6YwBekRM'},
#    'snippet': {'publishedAt': '2018-10-14T03:22:43.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - square city (일반인 랩 라이브)(자막有)',
#     'description': '링링링.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lN_6YwBekRM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lN_6YwBekRM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lN_6YwBekRM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/N9_SKUwLBYqWVcUlHg38-IaTlsc"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gJlg1caMUb8'},
#    'snippet': {'publishedAt': '2018-10-13T03:45:14.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Indigo music - indigo cover(jjindda version)',
#     'description': '인딧고.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gJlg1caMUb8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gJlg1caMUb8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gJlg1caMUb8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/CU5n6aCiuoEzxeOiHvUpuF3wi3M"',
#    'id': {'kind': 'youtube#video', 'videoId': 'G8dWa8zotZw'},
#    'snippet': {'publishedAt': '2018-10-13T03:24:00.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Indigo music - workout (jjindda cover)',
#     'description': '드링썸에잇에잇.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/G8dWa8zotZw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/G8dWa8zotZw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/G8dWa8zotZw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/wi_wXx4LcfQZBfhkuIpAPAKC1Bs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'CM3u7XOWVj0'},
#    'snippet': {'publishedAt': '2018-10-11T10:08:31.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': 'Jufla - beach (일반인 노래 라이브)',
#     'description': '감성충만치킨.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CM3u7XOWVj0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CM3u7XOWVj0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CM3u7XOWVj0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/qYNIOwTL9h0aXKDY34S81H-DtYg"',
#    'id': {'kind': 'youtube#video', 'videoId': '7aiYcJpYPwc'},
#    'snippet': {'publishedAt': '2018-10-06T05:37:21.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': '일반인 랩 라이브 - real hiphop(자막有)',
#     'description': '제 haters들에게 바칩니다.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7aiYcJpYPwc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7aiYcJpYPwc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7aiYcJpYPwc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/hZLzR7rcNm_GpVgkh477qHyfg-s"',
#    'id': {'kind': 'youtube#video', 'videoId': 'A3BX4wQ0Ck0'},
#    'snippet': {'publishedAt': '2018-10-05T15:42:43.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': '슈퍼비 -  82bar cover (jjindda version)',
#     'description': '82bar 찢어니 벌스.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A3BX4wQ0Ck0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/A3BX4wQ0Ck0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/A3BX4wQ0Ck0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/UtsZ9cfebZKfJYm83hlLJf3cmsA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'EyrUoD8y_sE'},
#    'snippet': {'publishedAt': '2018-10-03T12:44:06.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': '일반인 랩 자작곡 - korean gang(자막 有)',
#     'description': '한국 갱스터입니다.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EyrUoD8y_sE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EyrUoD8y_sE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EyrUoD8y_sE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Q8FyqdgU2QOAoXflFkG6qq2nuOI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'QUL_LzWHEM4'},
#    'snippet': {'publishedAt': '2018-10-03T08:50:00.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': '일반인 랩 자작곡 live (욕 주의, 면상 주의).자막有',
#     'description': '화질 구림 주의.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QUL_LzWHEM4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QUL_LzWHEM4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QUL_LzWHEM4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/L6zNGnKpahx_8LgsQXXRMjOKKIg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'rn2GQ8Hunjk'},
#    'snippet': {'publishedAt': '2018-09-30T09:36:35.000Z',
#     'channelId': 'UCIYWRFi7y6fBqosN5m5xxWA',
#     'title': '키드밀리,쿠기,나플라,로꼬-스즈란(진짜일반인cover)',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rn2GQ8Hunjk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rn2GQ8Hunjk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rn2GQ8Hunjk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JuFla FeeLite',
#     'liveBroadcastContent': 'none'}}]}

# %%
import requests
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channel_id = "UCLJi9Vk8_y3y_evAahQUEpQ"
page_token = ""

target_url =  '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/FD6T-HS9SmpJbLixPdaqT_fUCro"',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 32, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2yxqZ4n5T4Glw07IJFvXfFX90ss"',
#    'id': {'kind': 'youtube#video', 'videoId': '_ydeVpN28Ts'},
#    'snippet': {'publishedAt': '2018-12-17T19:15:50.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE) 따끈따끈 노아왔어요 놀러와 들어와~ 🌹이노아',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_ydeVpN28Ts/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_ydeVpN28Ts/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_ydeVpN28Ts/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/eLrbDJkeRKDGmIkp1OKlC1N0R8Q"',
#    'id': {'kind': 'youtube#video', 'videoId': 'sqTnYYPukrI'},
#    'snippet': {'publishedAt': '2018-11-19T19:05:09.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE) 머리 안마른 노아가 생방송중 +_+ 🌹이노아',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sqTnYYPukrI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sqTnYYPukrI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sqTnYYPukrI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/jG_VvTCmjaUNql-gOLBgBIharO0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'IsbC6cZ86g0'},
#    'snippet': {'publishedAt': '2018-11-05T19:29:35.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE) 트위치 동시송출 테스트중!! 🌹이노아',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IsbC6cZ86g0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IsbC6cZ86g0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IsbC6cZ86g0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ps0OClphEZS8mNMe8n75AdBpy1I"',
#    'id': {'kind': 'youtube#video', 'videoId': 'GAc3x6-UXMw'},
#    'snippet': {'publishedAt': '2018-10-29T22:24:19.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE) 불면증 심함ㅠㅠ 뽈따구 아직 부어있어요 한밤의 토크 갑시다잇 🌹이노아',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GAc3x6-UXMw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GAc3x6-UXMw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GAc3x6-UXMw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/hJcL84C3F1qHmWiETB0UDjXPFhE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'kB9dZG9yqCk'},
#    'snippet': {'publishedAt': '2018-10-15T18:20:40.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 오늘좀 거지꼴 +_+',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kB9dZG9yqCk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kB9dZG9yqCk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kB9dZG9yqCk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/yENDKt96tLn9T9njFEFpNc-QddY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'BjbWrEQaCNw'},
#    'snippet': {'publishedAt': '2018-10-01T17:43:59.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 서포터네임 내가 알아서 한다 흑흑',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BjbWrEQaCNw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BjbWrEQaCNw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BjbWrEQaCNw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/KBXHAx1915OFpUg6KGEpk-NzwjA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'dbFLDMVsL7I'},
#    'snippet': {'publishedAt': '2018-10-01T13:27:52.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 서포터네임 모집중입니닷!!!',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dbFLDMVsL7I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dbFLDMVsL7I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dbFLDMVsL7I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/vV_iu1RM1NXtMQHiBhmPsRwTlcw"',
#    'id': {'kind': 'youtube#video', 'videoId': '-HQLQ5TxdQU'},
#    'snippet': {'publishedAt': '2018-09-10T17:02:03.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 월요일 인생상담소',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-HQLQ5TxdQU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-HQLQ5TxdQU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-HQLQ5TxdQU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/gtQykL56AvPgrW_OJseF7MN5LiA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'mxvqKpUadF8'},
#    'snippet': {'publishedAt': '2018-09-03T17:46:16.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 빨간맛 노아 -_-',
#     'description': '여우화장대 필터테이프 실험방송 ㅋㅋ 이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mxvqKpUadF8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mxvqKpUadF8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mxvqKpUadF8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/HGf-HR76pmtiWA6OuvfepNxaw9c"',
#    'id': {'kind': 'youtube#video', 'videoId': 'QcZJsYRcx0Q'},
#    'snippet': {'publishedAt': '2018-08-27T17:05:11.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 감기 나았어요 살아났습니닷',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QcZJsYRcx0Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QcZJsYRcx0Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QcZJsYRcx0Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/aQMpKcF_SQbWq4el7Qej5s0hWE4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'cu-nKBd5iWQ'},
#    'snippet': {'publishedAt': '2018-08-20T18:14:47.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 심야에 노아랑 떠들자요',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cu-nKBd5iWQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cu-nKBd5iWQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cu-nKBd5iWQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/hr-WYVbgt0rXml1V1Mp-FWH_HYg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ehwUlnCe-NI'},
#    'snippet': {'publishedAt': '2018-08-06T17:38:54.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 컴퓨터 왜이래 ㅠㅠㅠㅠㅠ',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ehwUlnCe-NI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ehwUlnCe-NI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ehwUlnCe-NI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/57wrdYomDaIt5NoygWghIP3EXgA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'yt6I2Yhm0wU'},
#    'snippet': {'publishedAt': '2018-07-23T15:56:25.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 파자마노아 잠깐만 놀아용',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yt6I2Yhm0wU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yt6I2Yhm0wU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yt6I2Yhm0wU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mRLDsh4hRQliVdBXhv-hMq691RQ"',
#    'id': {'kind': 'youtube#video', 'videoId': 'pzf-3gEzOug'},
#    'snippet': {'publishedAt': '2018-07-09T17:37:50.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 달라진 노아랑 같이 한잔해요',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pzf-3gEzOug/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pzf-3gEzOug/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pzf-3gEzOug/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7jjJFxd_sul2sPSeTbVle__3mWY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'wsy90BcfWtA'},
#    'snippet': {'publishedAt': '2018-07-02T17:39:35.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 오늘 좀 분위기 달라요',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wsy90BcfWtA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wsy90BcfWtA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wsy90BcfWtA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/yuZ1xZBf3E968T_xLE2EdUSkyj4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'TwRPoMzRDWQ'},
#    'snippet': {'publishedAt': '2018-06-25T17:37:38.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 월요병은 좀 어때요',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TwRPoMzRDWQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TwRPoMzRDWQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TwRPoMzRDWQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/I6zSGuBy1chHqKjEciRqchuyE-o"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ArwoM-mqDo8'},
#    'snippet': {'publishedAt': '2018-06-18T18:14:04.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 아쉬운마음은 뒤로하고 잠시 소통합시다 ㅠㅠ',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ArwoM-mqDo8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ArwoM-mqDo8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ArwoM-mqDo8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/o8dDAi2nBWso9W-XL7uyCkJACk0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'aSApSzNndJw'},
#    'snippet': {'publishedAt': '2018-05-28T17:18:07.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 노아와떠염 카몬!',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aSApSzNndJw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aSApSzNndJw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aSApSzNndJw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/OmPvIDBXy3kTWmx_LKbGQDotnms"',
#    'id': {'kind': 'youtube#video', 'videoId': 't7sPlJcWfZM'},
#    'snippet': {'publishedAt': '2018-05-21T17:07:55.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t7sPlJcWfZM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t7sPlJcWfZM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t7sPlJcWfZM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/8OZ1YLE9V4hPb396rjQ4ROndT4o"',
#    'id': {'kind': 'youtube#video', 'videoId': '0qgguywMHlU'},
#    'snippet': {'publishedAt': '2018-05-01T04:54:07.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 머리붙여떠용',
#     'description': '어제자 생방! 설정을 잘못바꿔서 미등록이 되어있었는데 앞으로는 예전처럼 방송끝나고 다 업로드되면 그냥 알림없이 유튜브 섹션에 살포시 놓여있...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0qgguywMHlU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0qgguywMHlU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0qgguywMHlU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/yuuVy7ctObpOT50r5ImpTOYqrQs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'AKYqNKGYciI'},
#    'snippet': {'publishedAt': '2018-04-27T08:00:05.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 감기기운 있어서 잠깐만',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AKYqNKGYciI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AKYqNKGYciI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AKYqNKGYciI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/fmZIYITJgczb-_cYb4QTWGLoMLo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'coQBEcD6QDs'},
#    'snippet': {'publishedAt': '2018-04-02T17:18:11.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 사정이있어서 쌩얼입니다',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/aM3yhi_r_ePVvIBOL17qZYJg7zg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'L2i6eyHS7tg'},
#    'snippet': {'publishedAt': '2018-03-19T16:40:24.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 적적한 밤입니다옹',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L2i6eyHS7tg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L2i6eyHS7tg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L2i6eyHS7tg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7L0Ae1tmYFUJk0GkWw_WKdnpVSc"',
#    'id': {'kind': 'youtube#video', 'videoId': '68kxPPF3LjM'},
#    'snippet': {'publishedAt': '2018-03-12T17:56:09.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 갈곳없는 영혼들이여....',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/68kxPPF3LjM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/68kxPPF3LjM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/68kxPPF3LjM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/t2VMv2AbNGWVjLkbmcTybh3gbWM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'PofxQesy06U'},
#    'snippet': {'publishedAt': '2018-03-05T20:12:38.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 메이크업! 쌩얼-청순-타락;;;',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PofxQesy06U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PofxQesy06U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PofxQesy06U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4s5g19myvHFHK_TjbTRNj8mqhu0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'TOZ1lFodDJM'},
#    'snippet': {'publishedAt': '2018-02-26T14:02:56.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 오늘은 잠깐만 :)',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TOZ1lFodDJM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TOZ1lFodDJM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TOZ1lFodDJM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/RHCSC46cvkCSRiFEK_boQueMxak"',
#    'id': {'kind': 'youtube#video', 'videoId': 'g7EyTktvtL4'},
#    'snippet': {'publishedAt': '2018-02-19T17:10:45.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 설연휴의 저주가 걸렸다',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g7EyTktvtL4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g7EyTktvtL4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g7EyTktvtL4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2VK9XRIE-hdOPoA3IZVx8V6jaa4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'RTNgrtr_dWQ'},
#    'snippet': {'publishedAt': '2018-02-12T17:44:08.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 새집입니닷!!!',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RTNgrtr_dWQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RTNgrtr_dWQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RTNgrtr_dWQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4VzvGIkoke0BSk5bJfxteBmHYLs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'QK2ukMkOHUE'},
#    'snippet': {'publishedAt': '2018-01-22T17:08:37.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 생방중! 다음주는 이사로 쉽니다^^',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QK2ukMkOHUE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QK2ukMkOHUE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QK2ukMkOHUE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mvqVw-c0Fp79On2iWAlz13rxCmI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'll9C6fgpcDs'},
#    'snippet': {'publishedAt': '2018-01-08T17:49:09.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 올해 첫방 겸 테스트방송!',
#     'description': '드디어 유튜브 스트림 시작~!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ll9C6fgpcDs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ll9C6fgpcDs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ll9C6fgpcDs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/DGyY8M_sBXyUNyynPmWL2uPLWFQ"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Sa-KEwL1dIU'},
#    'snippet': {'publishedAt': '2016-11-14T07:27:07.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '♥이노아님 라이브 스트리밍♥',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Sa-KEwL1dIU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Sa-KEwL1dIU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Sa-KEwL1dIU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/SVmSiJ7oduhAnZSlJhoKe-B1UrY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y9myBI82WfY'},
#    'snippet': {'publishedAt': '2016-11-10T09:19:15.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '♥이노아님의 실시간 스트리밍♥',
#     'description': '처음이라 뻘쭘 ㅎㅎㅎㅎ 그래도 유투브에서 소통할 수 있어서 즐거웠습니다!!! 앞으로 정기적으로 할게요~!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y9myBI82WfY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y9myBI82WfY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y9myBI82WfY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
#     'liveBroadcastContent': 'none'}}]}

# %%
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/YlfEcPNbD56nPOUBf0d1S-evAk8"', 'nextPageToken': 'CDIQAA', 'regionCode': 'KR', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NuWHDg1ZDIYYFQE6vebSzbT4UyY"', 'id': {'kind': 'youtube#video', 'videoId': 'kUnUp7ZLjLQ'}, 'snippet': {'publishedAt': '2018-12-23T10:13:37.000Z', 'channelId': 'UCLThzQLfSpLuHimpT1MlcQQ', 'title': 'Top 30 Strongest ONE PIECE Characters 2018', 'description': 'LIT. Subscribe Here: http://tinyurl.com/zdqwgqw Donate Here: https://streamlabs.com/bragodace **** Check out my Patreon: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Brago D. Ace', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/BpbigJhQTL76uyN5vzOTpjLHZhs"', 'id': {'kind': 'youtube#video', 'videoId': 'hIXaF9eUXE0'}, 'snippet': {'publishedAt': '2018-12-23T10:11:53.000Z', 'channelId': 'UC0uqemz3uxjLOoske7_-Bsg', 'title': '김문수-차명진 라이브/청와대 불법 사찰, 文 지지율 급락 등', 'description': '김문수-차명진 라이브.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '김문수TV', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/W_LdBJ-TYOLC8WILJy_uXQU9LWY"', 'id': {'kind': 'youtube#video', 'videoId': '3xLiudHp31M'}, 'snippet': {'publishedAt': '2018-12-23T10:12:27.000Z', 'channelId': 'UCfC0RcYzDQcFtHrce2mpvbA', 'title': 'Dog Park Yard Cam - K9s For Warriors powered by EXPLORE.org', 'description': 'The dog park at K9s For Warriors is where rescued puppies play, socialize and undergo the training that will enable them to become service dogs for US ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Explore Dogs', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/HZDwov_X4NpfSgPGhzhtQTsmjXc"', 'id': {'kind': 'youtube#video', 'videoId': 'xPz7U3lV9no'}, 'snippet': {'publishedAt': '2018-12-23T10:12:36.000Z', 'channelId': 'UC-qnQ5u7hfR0BUruMqiKYEw', 'title': 'NOT ENDING STREAM TILL 1500 LIKES (#FORTNITE #BATTLE #ROYALE)', 'description': 'http://paypal.me/richkids11 Watch my vid https://m.youtube.com/channel/UC-qnQ5u7hfR0BUruMqiKYEw/videos My other vid montage ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Rich Kids', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/x5m0QNzog36iWE_e3Ncj2jVXKfY"', 'id': {'kind': 'youtube#video', 'videoId': 'd6xtkhJEx-k'}, 'snippet': {'publishedAt': '2018-12-23T10:10:20.000Z', 'channelId': 'UCBltWSh2lKOLiyFjhIu-K0A', 'title': 'CoD BlackOut 🌸 PS4 🌸 Drink Night', 'description': "Hi! My name is Charie Blossom . I started live streaming on October 23, 2017. So far I love it! Let's have fun and watch my gaming skills grow. A Girl's Gotta ...", 'thumbnails': {'defau ...

# %%
# Out:
# 'UCyHvSKT_bLDYpkv1JjjsLAg'
