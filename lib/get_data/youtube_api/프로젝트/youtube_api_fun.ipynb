# %% [markdown]
#     api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
#     chanel_id = "UCLJi9Vk8_y3y_evAahQUEpQ"
#
#    target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&eventType=completed&type=video&maxResults=50&key={}"

# %%
def get_video_id_for_channelId(channel_url, api_key):
    '''
    channel_id : 유튜버 채널의 고유 채널 ID ("https://www.youtube.com/channel/~" 또는 "https://www.youtube.com/user/~" )
    api_key : 자신의 API키   
        
    return값 : 일반 동영상 고유 ID(list), 라이브 동영상 고유 ID(list), [총 동영상 수(int), 일반 동영상 수(int), 라이브 동영상 수(int)]
    '''
    import requests
    from bs4 import BeautifulSoup 

    
    
    if "channel" in channel_url:  
        
        api_key = api_key
        channel_id = channel_url.split("/")[-1]
        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            return print("표시할 내용이 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            return print("표시할 내용이 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return video_ids, live_video_ids, [all_video_ids_count, video_ids_count, live_video_ids_count]
    
    
    elif "user" in channel_url:
        api_key = api_key

        channel_id = user_to_channelid(channel_url.split("/")[-1], api_key)

        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            return print("표시할 내용이 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])
        print("일반 동영상 완료")
        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            return print("표시할 내용이 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)
                                
                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]
                        print(api_dict["nextPageToken"])

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return video_ids, live_video_ids, [all_video_ids_count, video_ids_count, live_video_ids_count]

# %%
def user_to_channelid(user_name, api_key):

    import requests
    from bs4 import BeautifulSoup 

    api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]
    
    return channel_id

# %%
get_video_id_for_channelId("https://www.youtube.com/user/hanryang1125","AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak" )
# Out:
# hanryang1125
# UCyHvSKT_bLDYpkv1JjjsLAg
# CDIQAA
# CGQQAA
# CJYBEAA
# CMgBEAA
# CPoBEAA
# CKwCEAA
# CN4CEAA
# CJADEAA
# CMIDEAA
# CPQDEAA
# CKYEEAA
# CNgEEAA
# CIoFEAA
# CLwFEAA
# CO4FEAA
# CKAGEAA
# CNIGEAA
# CIQHEAA
# CLYHEAA
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-196-ad5a99321df8> in <module>()
# ----> 1 get_video_id_for_channelId("https://www.youtube.com/user/hanryang1125","AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak" )
#
# <ipython-input-194-7e243954aaaa> in get_video_id_for_channelId(channel_url, api_key)
#     138                     session = requests.Session ()
#     139                     headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
# --> 140                     html = requests.get (target_url)
#     141                     soup = BeautifulSoup (html.text, "html.parser" )
#     142                     api_dict = eval(soup.text.replace("false","False").replace("true","True"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channe
# Out:
# 'BuzzBean11'

# %%
import time
time.sleep(1)

# %%
video_ids = []

# %%
import requests
from bs4 import BeautifulSoup 


api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channel_id = "UCLJi9Vk8_y3y_evAahQUEpQ"
page_token = ""

target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, page_token, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))

# results_per_page = api_dict['pageInfo']['resultsPerPage']
api_dict
# for result_count in range(results_per_page):
#     vd_id = api_dict["items"][result_count]["id"]["videoId"] 
#     video_ids.append(vd_id)

# print(len(video_ids))
# Out:
# {'error': {'errors': [{'domain': 'usageLimits',
#     'reason': 'keyInvalid',
#     'message': 'Bad Request'}],
#   'code': 400,
#   'message': 'Bad Request'}}

# %%
import requests
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channel_id = "UCyHvSKT_bLDYpkv1JjjsLAg"
page_token = ""

target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/LDjkepi_CjHtu-X3n6o8MSCayy0"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 4517, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/yh4eTql5gQQaZmq884tNxkMFNLg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'pp-399sEEzA'},
#    'snippet': {'publishedAt': '2016-11-15T01:53:13.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '금연 응원 영상 / 논리갑vs팩트갑 (풍월량,침착맨) Eng sub',
#     'description': '방송시작/방종수다 (https://goo.gl/I1gBzx) 다른 모든 재생목록보기 (http://goo.gl/ItOJkB) 트위치 풍월량 방송국 (https://www.twitch.tv/hanryang1125)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pp-399sEEzA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pp-399sEEzA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pp-399sEEzA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/RCGIQ7P3t-Yv1VsbIL4xH7HO_Zw"',
#    'id': {'kind': 'youtube#video', 'videoId': '48_jBvqxmVs'},
#    'snippet': {'publishedAt': '2017-07-08T01:52:48.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '3년드립과 한본어로 멘탈 터짐! 대대손손게임 앙빅',
#     'description': '풍월량 하이라이트(http://goo.gl/ESzXQf) 앙빅 2017(https://goo.gl/qEoB75) 다른 모든 재생목록보기(http://goo.gl/ItOJkB) 트위치 풍월량 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/48_jBvqxmVs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/48_jBvqxmVs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/48_jBvqxmVs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/P6YlWW6_rw4BhhKQaUw7BGspLME"',
#    'id': {'kind': 'youtube#video', 'videoId': 'JALzJrRQamc'},
#    'snippet': {'publishedAt': '2017-06-07T03:42:36.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '유민상 살 안 빼는 이유에 빵터진 풍월량/역시 개그맨 드립 클라스',
#     'description': '개그맨 유민상의 살 안 빼는 이유는?? 유민상과 풍월량의 배틀그라운드 다이어트 수다! 기적의 논리 풍월량 하이라이트(http://goo.gl/ESzXQf) 풍월량...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JALzJrRQamc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JALzJrRQamc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JALzJrRQamc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NLt71YsZ-YKcFecT-GsdA-moTH4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'lK1N-Nr-Qrw'},
#    'snippet': {'publishedAt': '2018-05-01T03:36:40.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '안 사요 안 사!! 지하철 잡상인+ 도네 하이라이트 [미니 메트로]',
#     'description': '잡상인, 군인, 초딩 나오는 하이라이트!! 지하철 노선도 짜는 게임 미니 메트로 도네라이트~ 좋아요&구독 감사합니다(https://goo.gl/s14e16) 미니 메트로...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lK1N-Nr-Qrw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lK1N-Nr-Qrw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lK1N-Nr-Qrw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/c9ami2L1pz-pRFdxSY9KT5eL378"',
#    'id': {'kind': 'youtube#video', 'videoId': 'pmAWgSR7r8g'},
#    'snippet': {'publishedAt': '2018-02-17T00:55:53.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '우리아빠 풍월량] 주니어도 이제 안다! 아빠가 뭐하는지~',
#     'description': '좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf) 풍월량 일상/수다/먹방(https://goo.gl/jcgS6K) 다른 모든 재생목록보기(http:/ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pmAWgSR7r8g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pmAWgSR7r8g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pmAWgSR7r8g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/nM6v4nwFq3TyHwFwRyaZlZ_pxTM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ik06F4BTIy0'},
#    'snippet': {'publishedAt': '2018-10-01T01:51:57.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍월량] 한 달 5만원 벌던 썰 풀다 명치 씨게 맞음!',
#     'description': '방송프로 풍월량의 과거! 옛날 5만원 벌던 썰 풀다가 팩폭 제대로 당했습니다ㅠㅠ 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http:...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ik06F4BTIy0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ik06F4BTIy0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ik06F4BTIy0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/cFl50YajeIJCX_lJDZ-meNIeTlo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'eUfN98lGRj8'},
#    'snippet': {'publishedAt': '2017-12-20T07:34:53.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '[풍월량] 클립으로 돌아보는 2017년 하이라이트',
#     'description': '트위치에서 자동으로 선정된 2017년 풍월량 클립 모음 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf) 재생목록모두보...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eUfN98lGRj8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eUfN98lGRj8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eUfN98lGRj8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/LBu3rO7CjNoiMiDo4D3S2nxwf_k"',
#    'id': {'kind': 'youtube#video', 'videoId': 'mktyCzfvezA'},
#    'snippet': {'publishedAt': '2017-05-14T02:05:41.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '섯다 레전드] 이노옴드을! 암행어사 출두요~! 하이라이트 풍월량',
#     'description': '풍월량 하이라이트(http://goo.gl/ESzXQf) 17.5.13 섯다 복수전(https://goo.gl/nh2kQI) 17.1.27 섯다 설특집(https://goo.gl/BrCSzJ) 재생목록모두 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mktyCzfvezA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mktyCzfvezA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mktyCzfvezA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/st_PrC3l1FE18GXnAZhgnb820co"',
#    'id': {'kind': 'youtube#video', 'videoId': 'BzsQstd7szA'},
#    'snippet': {'publishedAt': '2018-11-15T03:43:39.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': 'ㅂㄷㅂㄷ 나무위키 실시간패치에 정색한 풍월량  ㅋㅋ',
#     'description': '나무위키에 헛소리 적으면 IP밴됩니다!! 메인사진 좋은걸로 부탁드려요~ 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzX...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BzsQstd7szA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BzsQstd7szA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BzsQstd7szA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/kbrb6K92WBxzIpQpN55XIhgH9fk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gFj5bCD0C6I'},
#    'snippet': {'publishedAt': '2017-01-12T00:05:19.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '【오버같이】 파괴광섬 1집 미니앨범 (친구모아 아파트) | 풍월량 작사 띵곡 (Eng sub)',
#     'description': '의식의 흐름, 아무말 대잔치, 작사에 풍월량 / 친모아 명곡 모음입니다. 타이틀 곡은【오버같이】입니다. 풍월량 하이라이트(http://goo.gl/ESzXQf) 친구모...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gFj5bCD0C6I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gFj5bCD0C6I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gFj5bCD0C6I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mAJJH03EAtYDMX9rTP7LVX3lqlw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'PeLmRGm3D6o'},
#    'snippet': {'publishedAt': '2016-02-18T22:00:17.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '초등학교 6학년생과 싸운 30대 아저씨 - 슈퍼마리오메이커 하이라이트',
#     'description': '원본영상 링크 (https://goo.gl/7eUJOA) 슈퍼마리오메이커 (https://goo.gl/qO3ZCJ) 다른 영상 재생목록보기 (http://goo.g...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PeLmRGm3D6o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PeLmRGm3D6o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PeLmRGm3D6o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/T8D0Bjejxrvdq8inTYRp4VV8f9Y"',
#    'id': {'kind': 'youtube#video', 'videoId': 'MeUhrklrMEA'},
#    'snippet': {'publishedAt': '2015-02-02T20:27:59.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍월량 각종게임+ 리듬세상 매드무비  (편집 : *이터니티)',
#     'description': '리듬세상 리믹스노래에 맞춰서 각종 게임영상이 나오는 매드무비입니다. 편집은 시청자 *이터니티님이 수고해주셨습니다. 풍월량 하이라이트...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MeUhrklrMEA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MeUhrklrMEA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MeUhrklrMEA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/iWJ1FFGB-w1algwUqZa7JkTk-14"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gha0tSFlbN8'},
#    'snippet': {'publishedAt': '2016-08-13T23:59:29.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '믿었던 시청자에게 배신당함! 레전드 - 풍월량 하이라이트 (술먹방 16.8.12)',
#     'description': '풍월량 하이라이트 보기 (http://goo.gl/ESzXQf) 술먹방 16.8.12 다시보기 (https://goo.gl/yLoJi9) 풍월량 캠&먹방 라디오 (http://goo.gl/G4S0Dm)...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gha0tSFlbN8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gha0tSFlbN8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gha0tSFlbN8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/t_QXY0eEwGJWnlRYmsbYRRPyUX4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'mjEkkHWxrGg'},
#    'snippet': {'publishedAt': '2018-01-13T02:03:55.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '정신차려 영태야!! [풍월량 1월 첫째 주 하이라이트 2018]',
#     'description': '띵언제조기 풍월량의 2018년 1월 첫째 주 하이라이트 1월1일~6일(월~토) 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf).',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mjEkkHWxrGg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mjEkkHWxrGg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mjEkkHWxrGg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/zGDgczgGrd4eGlnicVSSCEPgkwE"',
#    'id': {'kind': 'youtube#video', 'videoId': '7TB4TGcHrAQ'},
#    'snippet': {'publishedAt': '2018-01-14T03:42:58.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '절대가방! 명품백에 집착 쩌는 펭귄~ 반지의 제왕/휴먼 폴 플랫',
#     'description': '신상 명품백에 집착하는 펭귄 이야기, 레전드 [휴먼 폴 플랫] 버전 반지의 제왕! 좋아요&구독 감사합니다(https://goo.gl/s14e16) 휴먼폴플랫(https://goo.gl/sybX...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7TB4TGcHrAQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7TB4TGcHrAQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7TB4TGcHrAQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/aVioSu5wsrKBF1zoTA7069e0k14"',
#    'id': {'kind': 'youtube#video', 'videoId': 'o-WzQ0GElPw'},
#    'snippet': {'publishedAt': '2018-03-31T02:58:31.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍뎅이 정신공격, 효과는 굉장했다! [골프공게임 하이라이트] Golfing Over It',
#     'description': '항아리게임2 ?? 골프공게임 [Golfing Over It with Alva Majo] Getting Over It 제작자에게 허락받고 만들었다는 또 화나는 게임! 좋아요&구독 감사합니다(https://go...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o-WzQ0GElPw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/o-WzQ0GElPw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/o-WzQ0GElPw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7WCKOCVAltitOmJ8agXK2V9h56o"',
#    'id': {'kind': 'youtube#video', 'videoId': 'pl1fngiYuwI'},
#    'snippet': {'publishedAt': '2018-12-04T02:07:57.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '이 녀석, 전혀 성장하지 않았잖아..?[마녀의집 미러전 하라]',
#     'description': '마녀의 집 풀버전 5년전: https://goo.gl/CzPKw9 2018년: https://youtu.be/fKSj9MJTwFY 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pl1fngiYuwI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pl1fngiYuwI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pl1fngiYuwI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3vzleaFobM9LOjrUpLSRTPOSntU"',
#    'id': {'kind': 'youtube#video', 'videoId': '5UjftmHZQVg'},
#    'snippet': {'publishedAt': '2018-02-10T03:03:15.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '즈언하~좀비옵니다!! [풍월량 2월 첫째 주 하이라이트 2018]',
#     'description': '풍월량 위클리! 똥겜부터 좀비까지!! 풍월량의 2018년 2월 첫째 주 하이라이트 2월 1일~8일(목~목) 1월도 좀 있음! 좋아요&구독 감사합니다(https://goo.gl/s14...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5UjftmHZQVg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5UjftmHZQVg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5UjftmHZQVg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/kZtQgNakJpMBU2d7STdxrTX4trU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'fKEHyZEe3z0'},
#    'snippet': {'publishedAt': '2016-06-25T23:09:41.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '[특집] 천하제일 인성대회! - 최고의 인성러는 누구??? - 데드 바이 데이라이트(Dead by Daylight) 풍월량',
#     'description': '데드 바이 데이라이트 특집으로 최고의 인성장면을 모아봤습니다. 1번부터 9번까지 당신의 인성러는 누구?? 지금 투표하세요! 데드 바이 데이라이...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fKEHyZEe3z0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fKEHyZEe3z0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fKEHyZEe3z0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3t6T_a2uxDDd1QFQdXo3isKzj3o"',
#    'id': {'kind': 'youtube#video', 'videoId': 'qfHrImYoRMs'},
#    'snippet': {'publishedAt': '2018-02-20T23:42:54.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '주니어 세뱃돈 찾아가렴! [풍월량 설날 수다: 아빠의 위엄]',
#     'description': '좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf) 풍월량 일상/수다/먹방(https://goo.gl/jcgS6K) 다른 모든 재생목록보기(http:/ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qfHrImYoRMs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qfHrImYoRMs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qfHrImYoRMs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/R5fkWWe-9BZ_27B1rBNg6FT32bs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'tSCLSjItmNY'},
#    'snippet': {'publishedAt': '2018-03-09T00:45:51.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '온라인 인형뽑기 일본에서 진짜 왔다! [토레바] 주니어 선물해야지',
#     'description': '이 인형뽑기는 [토레바]에서 할 수 있습니다! 온라인으로 할 수 있는 일본 크레인게임 좋아요&구독 감사합니다(https://goo.gl/s14e16) 토레바 인형뽑기(http...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tSCLSjItmNY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tSCLSjItmNY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tSCLSjItmNY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/G846E5d38maZtdSw8-fATrmEphA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ProqXRxVujA'},
#    'snippet': {'publishedAt': '2018-08-10T00:38:33.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '영잘알 풍월량, 젤다의 전설로 웃겨버리기~ [하이라이트]',
#     'description': "젤다 이렇게 웃기게 하는 사람 처음 봤어!! 영잘알 풍월량의 '젤다의 전설 : 야생의 숨결' 하이라이트~ 젤다 풀버전 (https://goo.gl/LOQXlm) 좋아요&구독...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ProqXRxVujA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ProqXRxVujA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ProqXRxVujA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/C_dfI3e7SIZJS17Jiud6Aq_F1aI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'PK96gTqLeEk'},
#    'snippet': {'publishedAt': '2016-11-28T01:24:14.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '【살인코스터】원심분리기! 살면서 한 번밖에 못 타는 롤러코스터 (공포생존게임 플래닛 코스터 Planet Coaster) Eng/JP sub,',
#     'description': '풍월량 하이라이트 보기 (http://goo.gl/ESzXQf) 플래닛 코스터 모두보기 (https://goo.gl/dhSkBc) 다른 모든 재생목록보기 (http://goo.gl/ItOJkB) 트위치 풍월량...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PK96gTqLeEk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PK96gTqLeEk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PK96gTqLeEk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/JWoIzgGSNayKhtmsBobhGG1d4BE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'mTgBGUwq-oA'},
#    'snippet': {'publishedAt': '2018-01-17T03:52:16.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍고티 벌써 확정?! [풍월량 1월 둘째 주 하이라이트 2018]',
#     'description': "고티(Game of the Year)는 '올해의 게임'입니다 풍월량의 2018년 1월 둘째 주 하이라이트 1월7일~11일(일~목) 좋아요&구독 감사합니다(https://goo.gl/s14e16)...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mTgBGUwq-oA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mTgBGUwq-oA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mTgBGUwq-oA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/P8AcqDAmhqLQTzBiy9S76NRF7vY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'XHxeShAGkao'},
#    'snippet': {'publishedAt': '2018-07-20T00:39:30.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': "노답 셋이 모여 환상케미! '새얼간이' 하이라이트! Fallen Bird",
#     'description': '새(Bird)버전 항아리 게임 Fallen Bird 하이라이트 입니다!! 노답 셋이 모이면 레전드가 탄생한다! 환상케미 새얼간이 좋아요&구독 감사합니다(https://goo....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XHxeShAGkao/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XHxeShAGkao/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XHxeShAGkao/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/J90gEZq1ZWa0qV1kMqulitLudIA"',
#    'id': {'kind': 'youtube#video', 'videoId': '7s1RqR0eeI8'},
#    'snippet': {'publishedAt': '2015-10-11T18:09:34.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '낚시낚시낚시낚시 제작자 어디사냐? 찾아간다 ㅣ 슈퍼마리오 메이커 하이라이트 (Super Mario Maker)',
#     'description': '낚시낚시낚시 풀버전보기 (https://youtu.be/0o2xAMZpkE8) 풍월량 하이라이트 보기 (http://goo.gl/ESzXQf) 슈퍼마리오메이커 (https://goo....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7s1RqR0eeI8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7s1RqR0eeI8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7s1RqR0eeI8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/lTE7r-lU6pv6GZIRB3Q481T4dfg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'saSeijf9tCg'},
#    'snippet': {'publishedAt': '2018-09-17T19:17:38.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '프로게이머를 잡은 방송천재!! [풍월량 9월 2주차 핫클립] 위클리 하이라이트 2018',
#     'description': '이렇게 달달한 풍월량은 처음이야!! 자신감 UP 풍월량 2018년 9월 2주차 핫클립 모음 하이라이트~ [풍월량 위클리] 풍월량 위클리 모음https://goo.gl/fu6EdQ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/saSeijf9tCg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/saSeijf9tCg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/saSeijf9tCg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/5ZjUzL9xZO9XV1OOBntzV6rlQuw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'hrvr7aA-Hlc'},
#    'snippet': {'publishedAt': '2017-08-13T00:37:52.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '사적놈 정의구현, 개꿀잼 육아쓰랄 - 하스스톤 풍월량 17.8.12',
#     'description': '하스2017.8(https://goo.gl/9JuHyb) 하스스톤 재생목록(http://goo.gl/s3zILB) 다른 모든 재생목록보기(http://goo.gl/ItOJkB) 트위치 풍월량 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hrvr7aA-Hlc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hrvr7aA-Hlc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hrvr7aA-Hlc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/8MPE_e41yQipArdqtTmGeCAUij0"',
#    'id': {'kind': 'youtube#video', 'videoId': '0ogEbYU2FQo'},
#    'snippet': {'publishedAt': '2018-09-25T01:33:00.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '꽝꽝꽝! 시참겜하다 진심샷건침ㅋㅋ [풍월량 9월 3주차 핫클립] 위클리 하이라이트 2018',
#     'description': '추석 잘보내시구 항상 행복하세요 여러분~ 이번주는 시참게임하다가 화가난다 시리즈!! 풍월량 2018년 9월 3주차 핫클립 모음! 위클리 하이라이트~...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0ogEbYU2FQo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0ogEbYU2FQo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0ogEbYU2FQo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/CIsZP1mDxyVmLFb-eFU431UbhmM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'BkUehZyP264'},
#    'snippet': {'publishedAt': '2017-12-09T03:46:20.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '만화나온 [엽기전설 YT], 20년전 이세계물 웹툰 그린 풍월량!',
#     'description': '이강우 작가님, [리버스] 만화 후기에 등장했던 문하생시절! 그리고 학창시절, 시대를 앞선 만화 그린 썰!! 천재 풍월량? 좋아요&구독 감사합니다(http...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BkUehZyP264/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BkUehZyP264/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BkUehZyP264/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/p7gq3h2bNgpohrEXWpoef8G00so"',
#    'id': {'kind': 'youtube#video', 'videoId': '58H3jZLRKI8'},
#    'snippet': {'publishedAt': '2018-10-17T03:44:18.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍월량이 주인공인 만화 ㄷㄷ [층간격투] 금손풍뎅이님ㄳㄳ',
#     'description': '풍월량이 주인공인 만화가 나왔다!! 잉끼 만화가 되는 게임 [만화가 스토리] The Manga Works 에서 만든 게임이 시청자 손에서 만화로 나옴! 만화가...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/58H3jZLRKI8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/58H3jZLRKI8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/58H3jZLRKI8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4uHsYMpD9RvUsJzp0Nyh2c3XXZc"',
#    'id': {'kind': 'youtube#video', 'videoId': 'WprSLjc8fmY'},
#    'snippet': {'publishedAt': '2017-02-17T20:19:51.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '이거 알면 아재 아님! 【국민학생vs초등학생】 충격 먹은 풍월량 (정모 전 수다) 17.2.15',
#     'description': '풍월량 하이라이트(http://goo.gl/ESzXQf) 풍월량 일상/라디오/먹방(https://goo.gl/jcgS6K) 다른 모든 재생목록보기(http://goo.gl/ItOJkB) 트위치 풍월량 방송국(https:/...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WprSLjc8fmY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WprSLjc8fmY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WprSLjc8fmY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Gk0PTXAa-yb8_gk7GIHuPHLEYds"',
#    'id': {'kind': 'youtube#video', 'videoId': 'lTVCiV6po8o'},
#    'snippet': {'publishedAt': '2018-12-19T01:30:55.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '화를 내어서 무엇하나 [레이지 인 피스 빡침하라]',
#     'description': '좋아요&구독 감사합니다(https://goo.gl/s14e16) 짧은게임/신작(http://goo.gl/frEIeA) 다른 모든 재생목록보기(http://goo.gl/ItOJkB) 트위치 풍월량 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lTVCiV6po8o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lTVCiV6po8o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lTVCiV6po8o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/S7x6HeHwDxEbrIGCoT171HXy-vk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'UHUeLMoa7CA'},
#    'snippet': {'publishedAt': '2016-06-13T20:58:00.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '데드 바이 데이라이트 #13 세계 최고의 인성 POTG (Dead by Daylight)',
#     'description': '데드 바이 데이라이트 (https://goo.gl/NsyCgj) 다른 영상 재생목록보기 (http://goo.gl/ItOJkB) 아프리카 풍월량 방송국 (http://www.afreeca.com...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UHUeLMoa7CA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UHUeLMoa7CA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UHUeLMoa7CA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ERWubMZCZuPZqYtho7gb7ulyj74"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gVC3lfkKj_4'},
#    'snippet': {'publishedAt': '2016-11-19T22:31:35.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '귀여운 고양이 약빤게임! 우리 야옹이에겐 장애가 있어요. (13.7.31)',
#     'description': '2013년 7월 31일 방송인데, 안 올렸던 영상이라 지금 올립니다. 짧은약빤게임 (https://goo.gl/OEBX8A) 짧은게임 영상보기 (http://goo.gl/frEIeA)...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gVC3lfkKj_4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gVC3lfkKj_4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gVC3lfkKj_4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/SDoSHLasszZlRnqLm3-dTN8RMww"',
#    'id': {'kind': 'youtube#video', 'videoId': 'XsNSEcP7Smk'},
#    'snippet': {'publishedAt': '2018-09-11T17:12:40.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '맛있게 매운게 뭔지 보여줘?! [풍월량 9월 1주차 하이라이트] 핫클립 위클리 2018',
#     'description': '이번 주의 나는 쪼금 핫 스파이시..했다!! 그래도 맛있죠?? 풍월량 2018년 9월 1주차 핫클립 모음 하이라이트~ [풍월량 위클리] 풍월량 위클리 모음https...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XsNSEcP7Smk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XsNSEcP7Smk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XsNSEcP7Smk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/lD-Ohmo0hJkrTd6WU8ZMEQpAvwQ"',
#    'id': {'kind': 'youtube#video', 'videoId': 'aNpdCLBpJAM'},
#    'snippet': {'publishedAt': '2018-11-24T03:19:38.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '풍월량이 서유리에게 멱살잡힌 이유는?! [지스타 2킬 우승!] vs홍진호홍진호',
#     'description': 'Google Play ALLSTARS @ G-Star ----------------------------------------------------------------------- 풍월량이 서유리에게 멱살잡힌 이유는?! 팀풍월량 vs 팀홍진호! 대결...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aNpdCLBpJAM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aNpdCLBpJAM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aNpdCLBpJAM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/QuYH03ltuZ-oG1q_UYWfKWPIKS4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'DdN4n7Trlq0'},
#    'snippet': {'publishedAt': '2018-09-02T02:10:06.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '???: 그런 세계도 나빠보이지 않는걸..?',
#     'description': '『한국 축구 금메달 짤/드립모음』 2018 아시안게임 "축구 국가대표팀 여러분들 금메달 축하합니다!!" 드립,짤 출처는 주로 해외축구갤러리(디시인사...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DdN4n7Trlq0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DdN4n7Trlq0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DdN4n7Trlq0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Z6pndRRTXt-BTFhl-DMc8jK01AQ"',
#    'id': {'kind': 'youtube#video', 'videoId': 'tZBVqGHQrH0'},
#    'snippet': {'publishedAt': '2015-10-15T23:33:34.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '악마의 맵 NAK SI 에필로그 일반인연기 ㅣ슈퍼마리오 메이커 (Super Mario Maker) 15.10.13',
#     'description': '슈퍼마리오메이커 (https://goo.gl/qO3ZCJ) 다른 영상 재생목록보기 (http://goo.gl/ItOJkB) 아프리카 풍월량 방송국 (http://www.afreeca....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tZBVqGHQrH0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tZBVqGHQrH0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tZBVqGHQrH0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/8ISBYcNjBOeatUaC2B5WqqSL6dM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Mskqpk7n3Bw'},
#    'snippet': {'publishedAt': '2018-11-10T03:46:57.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '로아 10시간 방송하고 11레벨인 사람이 있다?! [주간 핫클립 하이라이트]',
#     'description': '실시간25000명이 본 그거! 레전드 핫클립만 모음! 로스트아크가 하고 싶어요...! ㅠㅠ 풍월량 2018년 11월 1주차 핫클립 모음! 위클리 하이라이트~ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Mskqpk7n3Bw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Mskqpk7n3Bw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Mskqpk7n3Bw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/6rB-SOQtx-cIVa_vt69JmcZorIQ"',
#    'id': {'kind': 'youtube#video', 'videoId': 'U0puBqRJHRw'},
#    'snippet': {'publishedAt': '2018-11-17T00:30:01.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '어이어이! 훔친건 너의 마음이라구( ͡° ͜ʖ ͡°) [도둑시뮬 하라]',
#     'description': '도둑 시뮬레이터 풀버전 (https://goo.gl/U1Eojk) 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf) 다른 모든 재생목록보기(ht.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U0puBqRJHRw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U0puBqRJHRw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U0puBqRJHRw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/5dk14GU07oVxMVorih99zlrHh-w"',
#    'id': {'kind': 'youtube#video', 'videoId': 'hIsbyWpYEik'},
#    'snippet': {'publishedAt': '2018-06-15T20:19:18.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '데바데 주캐 이응맨으로 의문의 고인물 무빙 해버렸다!',
#     'description': '좋아요&구독 감사합니다(https://goo.gl/s14e16) 데드 바이 데이라이트(https://goo.gl/NsyCgj) 다른 영상 재생목록(http://goo.gl/ItOJkB) 트위치 풍월량 방송국(https://w ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hIsbyWpYEik/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hIsbyWpYEik/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hIsbyWpYEik/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/5q4EokwtW3qN0CkJwPkU8X-_Kkw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'tpA0uRK918Q'},
#    'snippet': {'publishedAt': '2018-08-28T02:38:57.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '흑풍회 시작! 근데 줄타기 장인 좌우밸런스 미쵸따ㅋㅋㅋ 풍월량 중돼발표',
#     'description': '중대발표] 채팅창 관리를 위한 흑풍회가 활동을 시작했습니다! 첫날부터 수상한 분이 보이길래 사상검증을 했더니?! 좋아요&구독 감사합니다(https://...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tpA0uRK918Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tpA0uRK918Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tpA0uRK918Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/uoWE-WG15t-PReMr3nZFy-1edpk"',
#    'id': {'kind': 'youtube#video', 'videoId': '6UmzK9Xplz4'},
#    'snippet': {'publishedAt': '2018-10-09T02:05:35.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '영태곰의 어딘가 이상한 생존기 [곰 시뮬레이터] 이거 봤니?',
#     'description': '진짜 곰이 되는 수상한 게임! 곰 시뮬레이터(Bear Simulator) 곰시뮬레이터 풀버전(https://goo.gl/QS8JpF) 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6UmzK9Xplz4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6UmzK9Xplz4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6UmzK9Xplz4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/qgBZ3VxYZe7hdTqjZLu18Kl_ptk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'sNrBx3DryeU'},
#    'snippet': {'publishedAt': '2018-10-24T01:11:06.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '(커플주의) 생존하랬더니 사랑을해? [림월드 하이라이트]',
#     'description': '림월드 풀버전(https://goo.gl/dmLzv2) 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라이트(http://goo.gl/ESzXQf) 다른 모든 재생목록 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sNrBx3DryeU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sNrBx3DryeU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sNrBx3DryeU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Uk8zW8lhfBP2xtn4j-YYWsqU08o"',
#    'id': {'kind': 'youtube#video', 'videoId': 'nu9S0B56UiM'},
#    'snippet': {'publishedAt': '2017-03-05T02:27:13.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '이거 봤니? 【데드렐름】 14세 귀요미 외국인! (공포/유령/술래잡기/깜놀) 하이라이트',
#     'description': '[이거 봤니?] 는 구작&신작 추천 하이라이트 영상입니다. 풀영상을 보고 싶다면 아래 링크로~! 데드렐름(https://goo.gl/a5BF2v) 풍월량 하이라이트(http://goo....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nu9S0B56UiM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nu9S0B56UiM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nu9S0B56UiM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3WJoBGXjXLR4sl6PQdf7AN1emf0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'm9s8cP-cqrk'},
#    'snippet': {'publishedAt': '2017-05-05T01:47:36.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '15어린이날 특집[아빠와 아들]!!하이라이트/이거봤니?/풍월량&주니어',
#     'description': '2015년 어린이날 주니어와 함께 방송한 영상 하이라이트입니다. 풀버전이 궁금하신 분들은 아래 링크로 고고! 어린이날 특집 보기(https://goo.gl/e3tJAE)...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m9s8cP-cqrk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/m9s8cP-cqrk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/m9s8cP-cqrk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/kp-gV_wmkhwY8L3nxuAXwIxQrpw"',
#    'id': {'kind': 'youtube#video', 'videoId': '5K0ozIAUQrg'},
#    'snippet': {'publishedAt': '2018-01-20T04:18:10.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '깜짝고백! 메모장 켜라♥ [풍월량 1월 셋째 주 하이라이트 2018]',
#     'description': '풍월량 시청자에게 고백발언?! 풍월량의 2018년 1월 셋째 주 하이라이트 1월 13일~18일(토~목) 좋아요&구독 감사합니다(https://goo.gl/s14e16) 풍월량 하이라...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5K0ozIAUQrg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5K0ozIAUQrg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5K0ozIAUQrg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/gQ5LafVV1w6gzyNlCW6BJvbZ64c"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y55Btm2GLRE'},
#    'snippet': {'publishedAt': '2017-11-21T03:04:03.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '방송경력 10년 풍월량의 방송세팅 공개! 궁금했던 장비들~! 가격이 ㅎㄷㄷ',
#     'description': '방송세팅 장비들 1. 게임용 컴퓨터 i7-6700K / 메인보드 ASUS Z170-A STCOM / 램 삼성DDR4 16GB(8x2) / 타이탄 xp / SSD 삼성전자 850 PRO 512GB x2 / 쿨러 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y55Btm2GLRE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y55Btm2GLRE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y55Btm2GLRE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Au7cWZbBoJd_brsp2BfCP4MeKog"',
#    'id': {'kind': 'youtube#video', 'videoId': '_VTzyVQX88E'},
#    'snippet': {'publishedAt': '2015-04-09T10:50:55.000Z',
#     'channelId': 'UCyHvSKT_bLDYpkv1JjjsLAg',
#     'title': '[풍월량]  3단진화',
#     'description': '편집 초초쵸 풍월량 캠&먹방 라디오 (http://goo.gl/G4S0Dm) 다른 영상 재생목록보기 (http://goo.gl/ItOJkB) 아프리카 풍월량 방송국 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_VTzyVQX88E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_VTzyVQX88E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_VTzyVQX88E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '풍월량',
#     'liveBroadcastContent': 'none'}}]}

# %%
api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
user_name = "hanryang1125"


target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&forUsername={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(user_name, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
print(api_dict)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/YlfEcPNbD56nPOUBf0d1S-evAk8"', 'nextPageToken': 'CDIQAA', 'regionCode': 'KR', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NuWHDg1ZDIYYFQE6vebSzbT4UyY"', 'id': {'kind': 'youtube#video', 'videoId': 'kUnUp7ZLjLQ'}, 'snippet': {'publishedAt': '2018-12-23T10:13:37.000Z', 'channelId': 'UCLThzQLfSpLuHimpT1MlcQQ', 'title': 'Top 30 Strongest ONE PIECE Characters 2018', 'description': 'LIT. Subscribe Here: http://tinyurl.com/zdqwgqw Donate Here: https://streamlabs.com/bragodace **** Check out my Patreon: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Brago D. Ace', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/BpbigJhQTL76uyN5vzOTpjLHZhs"', 'id': {'kind': 'youtube#video', 'videoId': 'hIXaF9eUXE0'}, 'snippet': {'publishedAt': '2018-12-23T10:11:53.000Z', 'channelId': 'UC0uqemz3uxjLOoske7_-Bsg', 'title': '김문수-차명진 라이브/청와대 불법 사찰, 文 지지율 급락 등', 'description': '김문수-차명진 라이브.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '김문수TV', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/W_LdBJ-TYOLC8WILJy_uXQU9LWY"', 'id': {'kind': 'youtube#video', 'videoId': '3xLiudHp31M'}, 'snippet': {'publishedAt': '2018-12-23T10:12:27.000Z', 'channelId': 'UCfC0RcYzDQcFtHrce2mpvbA', 'title': 'Dog Park Yard Cam - K9s For Warriors powered by EXPLORE.org', 'description': 'The dog park at K9s For Warriors is where rescued puppies play, socialize and undergo the training that will enable them to become service dogs for US ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Explore Dogs', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/HZDwov_X4NpfSgPGhzhtQTsmjXc"', 'id': {'kind': 'youtube#video', 'videoId': 'xPz7U3lV9no'}, 'snippet': {'publishedAt': '2018-12-23T10:12:36.000Z', 'channelId': 'UC-qnQ5u7hfR0BUruMqiKYEw', 'title': 'NOT ENDING STREAM TILL 1500 LIKES (#FORTNITE #BATTLE #ROYALE)', 'description': 'http://paypal.me/richkids11 Watch my vid https://m.youtube.com/channel/UC-qnQ5u7hfR0BUruMqiKYEw/videos My other vid montage ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Rich Kids', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/x5m0QNzog36iWE_e3Ncj2jVXKfY"', 'id': {'kind': 'youtube#video', 'videoId': 'd6xtkhJEx-k'}, 'snippet': {'publishedAt': '2018-12-23T10:10:20.000Z', 'channelId': 'UCBltWSh2lKOLiyFjhIu-K0A', 'title': 'CoD BlackOut 🌸 PS4 🌸 Drink Night', 'description': "Hi! My name is Charie Blossom . I started live streaming on October 23, 2017. So far I love it! Let's have fun and watch my gaming skills grow. A Girl's Gotta ...", 'thumbnails': {'defau ...

# %%
api_dict['items'][0]["id"]
# Out:
# 'UCyHvSKT_bLDYpkv1JjjsLAg'
