# %%
import requests
from bs4 import BeautifulSoup 
import json

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
page_token = ""

target_url = '''https://www.googleapis.com/youtube/v3/videos?part=snippet&chart=mostPopular&regionCode=KR&pageToken={}&maxResults=5&key={}'''.format(page_token, api_key) 
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )
api_dict = html.json()

popular_channel_list = []


while True:
        target_url = '''https://www.googleapis.com/youtube/v3/videos?part=snippet&chart=mostPopular&regionCode=KR&pageToken={}&maxResults=5&key={}'''.format(page_token, api_key) 
        html = requests.get (target_url)
        api_dict = html.json()

        for result_count in range(len(api_dict["items"])):
            popular_channel_list.append(api_dict["items"][result_count]["snippet"]["channelId"])

        if "nextPageToken" in api_dict:
            page_token = api_dict["nextPageToken"]

        else: break

popular_channel_list
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/q-9oZ5IKjUvMZoN-vHt6aSAUhwM"', 'nextPageToken': 'CAUQAA', 'pageInfo': {'totalResults': 200, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#video', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7A86I-cB6_RMF7LSmZ4AMa6U7YM"', 'id': 'TLW8V53GsXA', 'snippet': {'publishedAt': '2019-01-01T12:04:43.000Z', 'channelId': 'UC5Ida86tt8QKa4Myw7idxNg', 'title': '시장 할머니손맛 vs 인스턴트!! 안 보고 구분할 수 있을까? -각자먹방', 'description': '핫도그티비 페이스북 =\nhttps://www.facebook.com/tvhotdog/\n핫도그티비 유 튜 브 =\nhttps://www.youtube.com/c/%ED%95%AB%EB%8F%84%EA%B7%B8TV1\n핫도그티비 인 스 타 =\nhttps://www.instagram.com/hotdog_tv_/\n\n권기동 페이스북 =\nhttps://www.facebook.com/profile.php?id=100001685894289&ref=bookmarks\n권기동 인스타 =\nhttps://www.instagram.com/kj_93/\n정재열 페이스북 =\nhttps://www.facebook.com/profile.php?id=100001718120320\n정재열 인스타 =\nhttps://www.instagram.com/jaeyori_93/', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TLW8V53GsXA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/TLW8V53GsXA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/TLW8V53GsXA/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/TLW8V53GsXA/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': '핫도그TV', 'tags': ['핫도그', '핫도그티비', '신년', '신정', '떡국', '팥죽', '제육', '각자', '먹방', '각자먹방', '정재열', '권기동', '기동', '재열', '시장', '손맛', '편의점', '인스턴트'], 'categoryId': '24', 'liveBroadcastContent': 'none', 'defaultLanguage': 'ko', 'localized': {'title': '시장 할머니손맛 vs 인스턴트!! 안 보고 구분할 수 있을까? -각자먹방', 'description': '핫도그티비 페이스북 =\nhttps://www.facebook.com/tvhotdog/\n핫도그티비 유 튜 브 =\nhttps://www.youtube.com/c/%ED%95%AB%EB%8F%84%EA%B7%B8TV1\n핫도그티비 인 스 타 =\nhttps://www.instagram.com/hotdog_tv_/\n\n권기동 페이스북 =\nhttps://www.facebook.com/profile.php?id=100001685894289&ref=bookmarks\n권기동 인스타 =\nhttps://www.instagram.com/kj_93/\n정재열 페이스북 =\nhttps://www.facebook.com/profile.php?id=100001718120320\n정재열 인스타 =\nhttps://www.instagram.com/jaeyori_93/'}, 'defaultAudioLanguage': 'ko'}}, {'kind': 'youtube#video', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2xa9TzR_w-tpaWR3hf5ap7bwNPk"', 'id': 'P1YMOaV2M5o', 'snippet': {'publishedAt': '2018-12-31T21:00:00.000Z', 'channelId': 'UCu9BCtGIEr73LXZsKmoujKw', 'title': '대상받으려고 서수길대표에게 미친짓해봤습니다.', 'description': '아프리카TV 대상 수상\n\n보겸TV 유튜브 구독하기 :: https://goo.gl/08r0gG\n보겸TV의 달달한 영상을 바로바로 시청하시려면 구독은 필수!\n\n보겸의 배틀그라운드 영상 모음 :: https://goo.gl/HE4cFd\n보겸의 오버워치 영상 모음 :: https://goo.gl/tSbgv0\n보겸의 롤 하이라이트 모음 :: http://goo.gl/It3CHa\n보겸의 보슐랭가이드/먹방 모음 :: https://goo.gl/em8WLQ\n보겸의 착불택배 개봉기 모음 :: https://goo.gl/o5nTzd\n보겸의 원피스 대백과사전 모음 ::  http://goo.gl/Psk9Uq\n보겸의 클래시로얄 모음 :: https://goo.gl/7wFF3D\n\n보겸이 아프리카TV 방송국 :: http://afreeca.com/bokyem123\n보겸이 인스타그램 :: https://www.instagram.com/great_bk\n보겸이 페이스북  :: https://www.facebook.com/gbk123456\n\n다양한 콘텐츠로 여러분을 찾아 뵙겠습니다!\n광고&섭외 문의는 bokyem123@naver.com로 문의주세요.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/P1YMOaV2M5o/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/P1YMOaV2M5o/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/P1YMOaV2M5o/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/P1YMOaV2M5o/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/P1YMOaV2M5o/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': '보겸 TV', 'tags': ['보겸', 'bokyem', '아프리카tv', 'afreecatv', '아프리카', '대상', '종합게임', '유튜브', 'bj', '유튜버', 'youtuber', 'rewind'], 'categoryId': '24', 'liveBroadcastContent': 'none', 'localized': {'title': '대상받으려고 서수길대표에게 미친짓해봤습니다.', 'description': '아프리카TV 대상 수상\n\n보겸TV 유튜브 구독하기 :: https://goo.gl/08r0gG\n보겸TV의 달달한 영상을 바로바로 시청하시려면 구독은 필수!\n\n보겸의 배틀그라운드 영상 모음 :: https://goo.gl/HE4cFd\n보겸의 오버워치 영상 모음 :: https://goo.gl/tSbgv0\n보겸의 롤 하이라이트 모음 :: http://goo.gl/It3CHa\n보겸의 보슐랭가이드/먹방 모음 :: https://goo.gl/em8WLQ\n보겸의  ...
# ['UC5Ida86tt8QKa4Myw7idxNg',
#  'UCu9BCtGIEr73LXZsKmoujKw',
#  'UCvMGtNVeVFsDfD_J9rcztNw',
#  'UCUj6W_UppMKtTvfTm2XFTTQ',
#  'UCLiK08tsWKL5bNoz1f8sHsw',
#  'UC3J4Xfo5S2dz4OyymYC_AoQ',
#  'UClAfLVQYZSLrMAQQ_SXPVZw',
#  'UCk6bX-MZXdte_7kG8TbMkqg',
#  'UChQ-VMvdGrYZxviQVMTJOHg',
#  'UCkG-Bpd44jV22xkAhzo0n9g',
#  'UCR0VAgd0w8QI7WWQ0E8Srdw',
#  'UCbgqDFODvh-q38ouzoKKkVA',
#  'UCJundLkbjldzL60kFfKm1vQ',
#  'UC9ZLv1m7QDLv991X1-p50AA',
#  'UCiBr0bK06imaMbLc8sAEz0A',
#  'UCg_lS-XS9Fh9I6Rl56Z8fpg',
#  'UCkzI8yaQ6q2aDKS70EzJCLw',
#  'UCLkAepWjdylmXSltofFvsYQ',
#  'UCLICXWvsfMX5XPYGuHNQj6g',
#  'UCMVC92EOs9yDJG5JS-CMesQ',
#  'UCgOLQwRv1r2m9mhE1tfsn3Q',
#  'UC005BPECU5QAR2JVItQOswg',
#  'UCBcFgDKnfyw8GjcHw90MlXA',
#  'UCPJmHR4CG_lRuVwKCo0kjjg',
#  'UCJDEss5wA1ddrCBC40giO8A',
#  'UCMxjwKk3V-69a8mcnU_XKnQ',
#  'UC1ihKJ6GH37xoWdtllZqhLw',
#  'UCFbK0JW_N5RKajamSf5Cbcw',
#  'UC5HSw5OY2vfVFSihpiB-AVQ',
#  'UCUj6rrhMTR9pipbAWBAMvUQ',
#  'UC8rDleR669f72Sha9PQK11A',
#  'UCuw1hxBo5mDVUhgMzRDk3aw',
#  'UCOqCunaF9qVN8bXwsK0HT3g',
#  'UCGYmXLgNJoh5fIqheoVhx4w',
#  'UCB8Fets2QTgay4SrwyHOzpA',
#  'UC1L79yKbmVepsCYusa4KHLQ',
#  'UCmth4hMyizG-_W9jidBqs_A',
#  'UCQJuZxeDv2P05YHcC-tIEVQ',
#  'UCDW6-1BLKS3iGqa3jWZm1yw',
#  'UCdet8uJfTFlACtY05BQmJ1Q',
#  'UChlgI3UHCOnwUGzWzbJ3H5w',
#  'UC0sfSZeoSUeWxys7OKkTelQ',
#  'UCFa96yEoj3G5lHC_mz6X1kQ',
#  'UCyzhIbVGjin9o7RpmPGrtfQ',
#  'UCfmicRK2-WdZMVQDrfcitLA',
#  'UC9095iS0qpApSGWt48oYoBA',
#  'UCwRlXDlvlgpeIYQm7V5TFHw',
#  'UCBkyj16n2snkRg1BAzpovXQ',
#  'UCyCL5k8P1iUOc1EymhhMW1A',
#  'UCxIG1wbiWEXX0Hv41nE6CcQ',
#  'UC-IYpdOqjkER7B6cnChwlhA',
#  'UC8SZ88GQa9XWwZxLNibO3ug',
#  'UCM8BcGB6BWKq3utIMhGKnUA',
#  'UCRuSxVu4iqTK5kCh90ntAgA',
#  'UC2Rwu5MuWLV5I2hNo-ajITg',
#  'UCq7b0GxrMWJg4GIlWwdVx2A',
#  'UCefkahbVepsvh2fv5xpYjLA',
#  'UCucybMZtilvYSg2_f3eAIHg',
#  'UCIIpmDPVk7nzNHEUSHmvkUg',
#  'UCW_WhXrfK3uPgljcdjFbsbg',
#  'UCfYIGbzJclZvYqZNgFSnuOw',
#  'UCq9MDndXc1y3he3uPZLPskQ',
#  'UCt15X5eHLwyP8PpNtQTkuDQ',
#  'UCj2gpUrZ7LMp4Mp1pVMKz0g',
#  'UCslHsYrei2VFZ3ZqHANNyzw',
#  'UC48NSSfUBsmL0k0wKxSqRkw',
#  'UC9kxp0LS5sq8i3k6UJaDZqg',
#  'UCoXoV4ebLAr30fSsCJsg4fQ',
#  'UCAaLhok91QDrweyuDRsmjqQ',
#  'UCFy5EHAmP0_llB-6BE-KfpA',
#  'UCdTDdygpZKdDew2s1s419iw',
#  'UCdk1Sy9_Pm4mAA2T4tgcxIw',
#  'UCStExGHp2hM0Tz3wjP5YPaw',
#  'UCFL1sCAksD6_7JIZwwHcwjQ',
#  'UCBCvzRMEKKvXD9s0zm-7PZA',
#  'UCfTJQQjCFU7GU0ll8TJ50tg',
#  'UC0uqemz3uxjLOoske7_-Bsg',
#  'UCr3G_LF602rAPmF7-xKoPNg',
#  'UCh6O-aBKR-99dg4rPy69CXg',
#  'UCF5ISWf4XHlsmxNUX2p3HEA',
#  'UCauFZeieu7k1hOdE7x-nStg',
#  'UCd-SfbUz8Xa5ypL_EpL3R0A',
#  'UC1reoal0esOCQkomB97e9wQ',
#  'UC69uMhRJcUnvMnMxKT2SS0w',
#  'UCRSEOIfPNgUYY8xkEzxqfVg',
#  'UCid83oPnsL-4ZEo8CyQr6Rg',
#  'UC0eowy4mhkZ6MsDay8VhwfA',
#  'UC9xVGd0xuRsYmla53YAIkJw',
#  'UC-dVHhMUEaXuNb8efhis1dg',
#  'UC5oft5dVf43M2cFmhpJLVGQ',
#  'UCfpaSruWW3S4dibonKXENjA',
#  'UCj2F8cffH0wrnO-1ShEsFIw',
#  'UCHxKSivB6JLZ1SEMdxd1fAg',
#  'UCzQJmmpZjqzJe96CwlrwlHQ',
#  'UCIAH4FXl2DQ4HmLupsyFiug',
#  'UC46BbEkxhjIHUj6EJ_waw-g',
#  'UCtDcEbupijR_gufF7PIEDGQ',
#  'UCbFzvzDu17eDZ3RIeaLRswQ',
#  'UC1r112Pr9Ngcg2NtcE946HQ',
#  'UCq2Ld6DYPkq_61vKvL7EFiw',
#  'UCWUwriihuQ_ybNrAOqbg3yg',
#  'UCIchCOLwLBMD87quHlNuXjQ',
#  'UCCqTZS8j2pt2htweQRCG-SA',
#  'UCem8l1w4OWhkqpoOg1SB4_w',
#  'UCK4WxhNsloFrA8iUaO92r5g',
#  'UCj-durTg1W7uWsB8oq0u7kA',
#  'UCLG_u41jFNyyv2M05JeslZQ',
#  'UClHUx_fmIGEIuLhyIPgue9Q',
#  'UCgZlBRLRB1-0l-qL9BkecLQ',
#  'UCCJkwrmhIqWkSFV-sQol4Qw',
#  'UC8_wgZy23gjTNVQeyfwl92g',
#  'UCWkG1bnN155y64Vq0VCh9Ng',
#  'UCmLiSrat4HW2k07ahKEJo4w',
#  'UCc4OuY3PeWklqBzQ3ySi3xA',
#  'UCpCiIDf9UrfRqte55FHWlYQ',
#  'UCyoqIWgyiQmxYiNP_l7KlyQ',
#  'UCs4UBgRZbxTQQwD6VecNj_w',
#  'UCsU-I-vHLiaMfV_ceaYz5rQ',
#  'UCcgupZyxsOSX9zFI58yq1HQ',
#  'UCQGTr4QurkCMJfVaZRiHB1Q',
#  'UCdWgRSfttvDucq4ApcCg5Mw',
#  'UCn9mJ4htO64-1osMWYu9k5Q',
#  'UCWRQ7bgo-gaBODRYlp3tvYg',
#  'UCqeOY0kedIjM9cfuBes4BSQ',
#  'UCRY0vKmqFmQ4XCJomWMBf-w',
#  'UCXaYpHeNB0DjCNIcpE46-IQ',
#  'UCuPeQ50gyXAl_70p0UT7WAQ',
#  'UCuH8eA3RPhQcOF_-3vRB51A',
#  'UC0OUtQn_vXuKM6RSt0yqdpQ',
#  'UCaZS_XwAu1yBMNoQDD1mR7g',
#  'UCZUPZW5idAxYp-Asj__lVAA',
#  'UC8valWz_8jFnX4tMGCeC62w',
#  'UCtwxuughKbSAV0e4bnz4ORg',
#  'UCWlV3Lz_55UaX4JsMj-z__Q',
#  'UCIA-LPHNERP2MDUQpp2RVHg',
#  'UClzB2iZ5jPoTNz0S-QU6Wiw',
#  'UC-ZHt5Zgadfx-B1CM63Lqew',
#  'UCbuks6fmwRefCTGg9aNwgeQ',
#  'UCdp4_yTBhQmB8E339Lafzow',
#  'UCIXvXBYSc9fQ7Ri5SM1r8xA',
#  'UCPI40-XQA9-GBGj2k8PPqfg',
#  'UCcloDgiDqz8twby7zvG-USg',
#  'UCBCY00Ox6Cins0oRwSLqNGA',
#  'UCyJgLaAwEwGiLTl9ccd2haw',
#  'UCfq4V1DAuaojnr2ryvWNysw',
#  'UC9pVzn6uZ4A-i5bVoFGaH6g',
#  'UCgTIt7bBru_lnfomQfSnOtA',
#  'UC0_YOphWTfGezqXS-EVo7Eg',
#  'UCa56qkMvVvq1IMn4xbXaKEA',
#  'UCYyLIlOJyqkAFKlVjzX5img',
#  'UCX3QXXkYTDn0JDmoVw5bdJg',
#  'UC2BmSdUv0_jZYFBAaYtCrsQ',
#  'UC22go5LdQEw-iDuxFb4C0hw',
#  'UCxgAdCqJvjvrF7LNqSAgzSg',
#  'UCS83hSDCu-fVLvRLQ1aiktQ',
#  'UCTsis4ThrJuNxhCkamq04yg',
#  'UCaNGiz6D2vHP7XLj9d5691A',
#  'UCAtFkapSeoEGPxm5bC3tvaw',
#  'UCwDJ4QXHeW11lFJNoVu2gIw',
#  'UCHcDLOhRi_WkDJ3zOM3FehQ',
#  'UCudWn3bvgyuEw-rTD7zJZOg',
#  'UCquCOGattLleH5erOxiWVmQ',
#  'UCeLPm9yH_a_QH8n6445G-Ow',
#  'UCoUDrzyCl1IwU602xdTsM-g',
#  'UCfTswP_uNy_h86pUjCU410A',
#  'UCYgUhR7EGKauFXgJS0pckGg',
#  'UCNzcxCN_Hh_lu5RCSFXKgGQ',
#  'UCkbJc8jMcTXwhtmN5VMwfXg',
#  'UCKNdfTZCJuOQfWN5Pe5UAAQ',
#  'UCEDN9-LQWdAcr06SMqBbHfg',
#  'UCfIUuMA7U_jImP7oWfTe4Pw',
#  'UCCA8UWUW80iHqK9ymdjRwPg',
#  'UC3W3kEmrLrRfec2qNrE6w4A',
#  'UCkinYTS9IHqOEwR1Sze2JTw',
#  'UCo2qwN2FUPnLLJjHXNusFyQ',
#  'UCYACixxri8vQLQ6BSriQehw',
#  'UCNIiH_4ArJNd_cDZApZ7AFg',
#  'UC0BPsIEZ5cMuedvzQO3J1jw',
#  'UC-e1jt_Mu-9V7Eft-NEocrg',
#  'UCWkG1bnN155y64Vq0VCh9Ng',
#  'UC5D5VhXj_9JWr3IskPYOEdA',
#  'UC3re3ueOE_6VZK85zlEUWFA',
#  'UCcQTRi69dsVYHN3exePtZ1A',
#  'UCjhd8t2btm4VP10Pn7Vvv7w',
#  'UCpcft4FJXgUjnxWoQYsl7Ug',
#  'UCBHPse9d1wZclGjl5nj1C5A',
#  'UCaHGOzOyeYzLQeKsVkfLEGA',
#  'UC9kmlDcqksaOnCkC_qzGacA',
#  'UCmVAoKoauj3nPIZ9hnC3yZQ',
#  'UCG-coSVp89xFSWN4pbVL53w',
#  'UC1EjtvDflBROblEaM1nMPWw',
#  'UCnMBn-PNx1M9TLF0s-sEDeQ',
#  'UCFUpTxU3nlGed-suY-FjjxA',
#  'UCxmBxNybpaLO7x61dm0oD8w',
#  'UCsOW9TPy2TKkqCchUHL04Fg',
#  'UCrhgVHA_uAiT9BoGV9qRKvg',
#  'UCdUcjkyZtf-1WJyPPiETF1g',
#  'UCcwfCXL9ws32ybsEK7aJMLw',
#  'UC2o_y872S6YvaO1K8EYnoxg',
#  'UChbE5OZQ6dRHECsX0tEPEZQ']

# %%
len(popular_channel_list)
# Out:
# 200

# %%
target_url = '''https://www.googleapis.com/youtube/v3/videos?part=snippet&chart=mostPopular&regionCode=KR&pageToken=CAUQAA&maxResults=5&key={}'''.format(api_key)

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ls3I1yo-oJ2mTuB8EeR8mNPOTBg"',
#  'nextPageToken': 'CAoQAA',
#  'prevPageToken': 'CAUQAQ',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/OdSH4iz54mTEdU6JiHotZIQoIqc"',
#    'id': 'Xne0P3ZTQZo',
#    'snippet': {'publishedAt': '2019-01-01T10:46:57.000Z',
#     'channelId': 'UCvMGtNVeVFsDfD_J9rcztNw',
#     'title': '구독자 50만 기념 유튜브 시작 이유와 2018년 영상 리와인드',
#     'description': '다들 정말 감사합니다.\n\n[윾튜브 구독하기] https://goo.gl/AGtkL4\n[윾튜브 순한맛 구독하기]https://goo.gl/GvhM6N\n[페이스북 윾튜브]https://facebook.com/Eukktube\n[페이스북 개인계정] https://facebook.com/kimhumor5\n[페이스북 개인계정2] https://facebook.com/kimstop13\n[페이스북 페이지] https://facebook.com/humorstorage\n[E-Mail] humorstorage3@gmail.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xne0P3ZTQZo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Xne0P3ZTQZo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Xne0P3ZTQZo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Xne0P3ZTQZo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Xne0P3ZTQZo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '윾튜브',
#     'tags': ['유머저장소', '김윾머', '김정지', '윾튜브', '윾머'],
#     'categoryId': '19',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '구독자 50만 기념 유튜브 시작 이유와 2018년 영상 리와인드',
#      'description': '다들 정말 감사합니다.\n\n[윾튜브 구독하기] https://goo.gl/AGtkL4\n[윾튜브 순한맛 구독하기]https://goo.gl/GvhM6N\n[페이스북 윾튜브]https://facebook.com/Eukktube\n[페이스북 개인계정] https://facebook.com/kimhumor5\n[페이스북 개인계정2] https://facebook.com/kimstop13\n[페이스북 페이지] https://facebook.com/humorstorage\n[E-Mail] humorstorage3@gmail.com'},
#     'defaultAudioLanguage': 'ko'}},
#   {'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/TXuEvBtxdvxGtDRTKuSqWsyQGV4"',
#    'id': 'hSpd6anSbOM',
#    'snippet': {'publishedAt': '2019-01-01T08:00:02.000Z',
#     'channelId': 'UCk6bX-MZXdte_7kG8TbMkqg',
#     'title': '행동대장5탄 비행기 타고 제주도 갔는데 최연소4살짜리가 아이폰xs 당첨가능?! - 허팝 (Give iPhone XS to a perosn who helps me)',
#     'description': "행동대장이 드디어 제주도에 출격했습니다! 제주도에 있는 홈플러스에서 진행된 행동대장! 그런데... 예상치 못하게 마트에 허팝이 온 사실과 행동대장을 예측하는 (뭔가 이거 이벤트인가?) 분들이 여러명 등장함으로써 결국 실패를 맞이하였습니다. 앞으로는 정말 그 누구와의 사전에 협의하지 않고, 어느날 갑자기 진행하는 행동대장이 되겠습니다. 아쉽게도 제주도에서는 ㅠㅠ 그럼 다음은 어디서 어떤 게임을 여러분과 진행해볼까요?! 댓글로 많은 의견 부탁드립니다!\n#허팝 #행동대장 #아이폰xs #제주도 #heopop #4yearsold #iphonexs\n[LIKED], [SUBSCRIBE] and [SHARE]!!!\n●Heopop channel : http://goo.gl/pAHo88\n●HeopopLife channel : https://goo.gl/wEKBJb\n●HoopopGames channel : http://goo.gl/upcwMZ\n●Heopop's Instagram : http://goo.gl/tDS7WY\n●Heopop's Facebook : http://goo.gl/vuVDQK",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hSpd6anSbOM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hSpd6anSbOM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hSpd6anSbOM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/hSpd6anSbOM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/hSpd6anSbOM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '허팝Heopop',
#     'tags': ['허팝',
#      'heopop',
#      'gjvkq',
#      '아이폰xs',
#      '행동대장',
#      '갤럭시 노트9',
#      '노트9',
#      '노트10',
#      '갤럭시9',
#      '갤럭시10',
#      '갤럭시x',
#      'iphone xs',
#      'iphone',
#      'give iphone to a person who helps me',
#      '노숙자',
#      '홈플러스',
#      '이마트',
#      '도와주기',
#      '최연소',
#      '나눔',
#      '행동대장 아이폰',
#      '비행기',
#      '제주도',
#      'jeju',
#      '제주도 행동대장',
#      '제주도 나눔',
#      '제주도 마트'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'ko',
#     'localized': {'title': '행동대장5탄 비행기 타고 제주도 갔는데 최연소4살짜리가 아이폰xs 당첨가능?! - 허팝 (Give iPhone XS to a perosn who helps me)',
#      'description': "행동대장이 드디어 제주도에 출격했습니다! 제주도에 있는 홈플러스에서 진행된 행동대장! 그런데... 예상치 못하게 마트에 허팝이 온 사실과 행동대장을 예측하는 (뭔가 이거 이벤트인가?) 분들이 여러명 등장함으로써 결국 실패를 맞이하였습니다. 앞으로는 정말 그 누구와의 사전에 협의하지 않고, 어느날 갑자기 진행하는 행동대장이 되겠습니다. 아쉽게도 제주도에서는 ㅠㅠ 그럼 다음은 어디서 어떤 게임을 여러분과 진행해볼까요?! 댓글로 많은 의견 부탁드립니다!\n#허팝 #행동대장 #아이폰xs #제주도 #heopop #4yearsold #iphonexs\n[LIKED], [SUBSCRIBE] and [SHARE]!!!\n●Heopop channel : http://goo.gl/pAHo88\n●HeopopLife channel : https://goo.gl/wEKBJb\n●HoopopGames channel : http://goo.gl/upcwMZ\n●Heopop's Instagram : http://goo.gl/tDS7WY\n●Heopop's Facebook : http://goo.gl/vuVDQK"},
#     'defaultAudioLanguage': 'ko'}},
#   {'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mQyPeF31NKlfasRDf3VL34gGFa0"',
#    'id': 'vZFRlUMisXw',
#    'snippet': {'publishedAt': '2018-12-30T06:58:39.000Z',
#     'channelId': 'UCJundLkbjldzL60kFfKm1vQ',
#     'title': '유튜브 급식왕 연말시상식 (with. 역대급가수)',
#     'description': '한해동안 구독자 여러분들의 큰 사랑 감사합니다.\n이번 영상은 급식왕 연말 시상식인데 많은 관심 부탁드려요.\n앞으로도 발전하고 재밌는 급식왕이 되겠습니다 !!!\n새해복 많이 받으세요 !!!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vZFRlUMisXw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vZFRlUMisXw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vZFRlUMisXw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vZFRlUMisXw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vZFRlUMisXw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '급식왕',
#     'tags': ['급식왕',
#      '연말시상식',
#      '연예대상',
#      '대상',
#      '가요대전',
#      '가요대상',
#      '연기대상',
#      '대상후보',
#      '도티',
#      '허팝',
#      '박막례',
#      '대도서관',
#      '눈물',
#      '눈물시상식',
#      '수상소감',
#      '시청자반응',
#      '해외반응',
#      'kpop',
#      'mbc',
#      'sbs',
#      'tvn',
#      'mama',
#      '해외시상식',
#      '데드풀',
#      '엠마스톤',
#      '짐캐리',
#      '레드카펫',
#      '아이돌',
#      '유튜버',
#      '아프리카시상식',
#      '양팡',
#      '감스트'],
#     'categoryId': '23',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'ko',
#     'localized': {'title': '유튜브 급식왕 연말시상식 (with. 역대급가수)',
#      'description': '한해동안 구독자 여러분들의 큰 사랑 감사합니다.\n이번 영상은 급식왕 연말 시상식인데 많은 관심 부탁드려요.\n앞으로도 발전하고 재밌는 급식왕이 되겠습니다 !!!\n새해복 많이 받으세요 !!!'},
#     'defaultAudioLanguage': 'ko'}},
#   {'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/l3FoGlUi_GsWx5SB22tpeNJzV6w"',
#    'id': '4ioxDOSepDk',
#    'snippet': {'publishedAt': '2018-12-30T07:54:32.000Z',
#     'channelId': 'UC9ZLv1m7QDLv991X1-p50AA',
#     'title': '회식 맨날 빠지는 밉상친구 언제 어디서든 회식 장소로 만들어주기ㅋㅋㅋㅋㅋ',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ioxDOSepDk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4ioxDOSepDk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4ioxDOSepDk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/4ioxDOSepDk/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': '보물섬',
#     'categoryId': '23',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '회식 맨날 빠지는 밉상친구 언제 어디서든 회식 장소로 만들어주기ㅋㅋㅋㅋㅋ',
#      'description': ''},
#     'defaultAudioLanguage': 'ko'}},
#   {'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2vabzn_H-F-7JPUACv3g21Sx7mw"',
#    'id': '--I39HcV-T4',
#    'snippet': {'publishedAt': '2019-01-01T00:04:55.000Z',
#     'channelId': 'UChQ-VMvdGrYZxviQVMTJOHg',
#     'title': '34',
#     'description': '#34살 #서른네살 #삼십사살\n----------------------------------------\xad\xad-----------\n- 도티의 사생활 인스타 팔로우: https://goo.gl/gbwHli\n- 구독하기 링크클릭!!: http://goo.gl/WwJshS\n- 공식 팬카페 바로가기: http://cafe.ddotty.com\n- 샌드박스 스토어 바로가기: https://goo.gl/zQGkvh\n----------------------------------------\xad\xad-----------\n\n* With Sandbox Network *\n\n＊도티의 특별한 34살\n\n▶구독하기 & 영상 좋아요 버튼을 꼭꼭 눌러주세요 :D\n\n----------------------------------------\xad\xad-----------\nHello Everyone!\nWelcome to DDotty’s channel and just call me “DDotty”!\nI’m recording and editing many gameplay videos by myself & my team,\nlike Minecraft, Clash Royale and other mobile games that I love to play.\nPlease have fun with my videos and if you like, subscribe my channel.\nEvery day is so special because of you and me!\nThank you!\n----------------------------------------\xad\xad-----------\nCOPYRIGHT ⓒ 2019 DDOTTY ALL RIGHTS RESERVED.\n----------------------------------------\xad\xad-----------',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/--I39HcV-T4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/--I39HcV-T4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/--I39HcV-T4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/--I39HcV-T4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/--I39HcV-T4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '도티 TV',
#     'tags': ['도티',
#      '34살',
#      '2019년',
#      '새해',
#      '새해인사',
#      '잠뜰',
#      '도티 잠뜰',
#      '쵸쵸우',
#      '칠각별',
#      '수현',
#      '코아',
#      '도도한친구들',
#      '34초'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '34',
#      'description': '#34살 #서른네살 #삼십사살\n----------------------------------------\xad\xad-----------\n- 도티의 사생활 인스타 팔로우: https://goo.gl/gbwHli\n- 구독하기 링크클릭!!: http://goo.gl/WwJshS\n- 공식 팬카페 바로가기: http://cafe.ddotty.com\n- 샌드박스 스토어 바로가기: https://goo.gl/zQGkvh\n----------------------------------------\xad\xad-----------\n\n* With Sandbox Network *\n\n＊도티의 특별한 34살\n\n▶구독하기 & 영상 좋아요 버튼을 꼭꼭 눌러주세요 :D\n\n----------------------------------------\xad\xad-----------\nHello Everyone!\nWelcome to DDotty’s channel and just call me “DDotty”!\nI’m recording and editing many gameplay videos by myself & my team,\nlike Minecraft, Clash Royale and other mobile games that I love to play.\nPlease have fun with my videos and if you like, subscribe my channel.\nEvery day is so special because of you and me!\nThank you!\n----------------------------------------\xad\xad-----------\nCOPYRIGHT ⓒ 2019 DDOTTY ALL RIGHTS RESERVED.\n----------------------------------------\xad\xad-----------'},
#     'defaultAudioLanguage': 'ko'}}]}

# %%
x = ["a","b","e"] 
y = ["b","C","d"]

for a in x:
    if a in y:
        x.remove(a)

# %%
x
# Out:
# ['a', 'e']
