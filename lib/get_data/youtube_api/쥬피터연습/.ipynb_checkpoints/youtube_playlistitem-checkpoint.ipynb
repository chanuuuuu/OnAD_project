# %% [markdown]
# 대도서관 live 플레이리스트 : PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8

# %%
import requests, json
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8"
page_token = "CLwFEAA"

target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, page_token, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/k4aFq0Ze7nPTnL9WggpAEAyLYfk"',
#  'prevPageToken': 'CLwFEAE',
#  'pageInfo': {'totalResults': 719, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/C2QpMhjQ45fYufgiTrjLtRewvMo"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC45RTgxNDRBMzUwRjQ0MDhC',
#    'snippet': {'publishedAt': '2016-11-03T01:46:45.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE]  걸그룹 만들기 게임 / 아이돌 마스터 / 게임 방송 11/1(화) Game (buzzbean11)',
#     'description': '* 대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방 아이마스',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 700,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '1kfaNcEDlwk'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/oMjzm7VG-mSCMGv83QEp94DL06s"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC4yMUQyQTQzMjRDNzMyQTMy',
#    'snippet': {'publishedAt': '2016-11-03T01:46:35.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE]  대도네집 거실에서 지마켓 홈쇼핑 방송 11/1(화) Game (buzzbean11)',
#     'description': '* 대도가 직접 선택한 지마켓 상품 구매하러 가기 - \nhttp://mobile.gmarket.co.kr/Display/SpecialShopping?lcId=&sid;=148489\n\n*G마켓 멤버쉽 변경\nhttp://mobile.gmarket.co.kr/Couponzone\n\n* 대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VqOeQoOLhXw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VqOeQoOLhXw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VqOeQoOLhXw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VqOeQoOLhXw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VqOeQoOLhXw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 701,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'VqOeQoOLhXw'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/A8YLJ-iZaPcuXW7cm-RIJWp99P4"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC41QTY1Q0UxMTVCODczNThE',
#    'snippet': {'publishedAt': '2016-11-03T01:46:21.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 몬스트럼 / 문명6 로마 엔딩까지! 10/31(월) Game (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PdcudSbnsto/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PdcudSbnsto/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PdcudSbnsto/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PdcudSbnsto/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PdcudSbnsto/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 702,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'PdcudSbnsto'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/peSWuL-dAgrXZM_Zd6eqIm6eAfA"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC5EQUE1NTFDRjcwMDg0NEMz',
#    'snippet': {'publishedAt': '2016-11-03T01:46:06.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 60초 하드모드 / PS VR / 선물 까기 방송  10/29(토) Game (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ERZF7TUb9sU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ERZF7TUb9sU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ERZF7TUb9sU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ERZF7TUb9sU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ERZF7TUb9sU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 703,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'ERZF7TUb9sU'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/C54K8cYud5Hijy1keGdXkGxkwQQ"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC41Mzk2QTAxMTkzNDk4MDhF',
#    'snippet': {'publishedAt': '2016-11-03T01:45:57.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] PS VR 상어 습격! / 60초 빡겜모드 / 문명6 로마로 세계정복 10/28(금) (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jJo2jmh4PwA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jJo2jmh4PwA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jJo2jmh4PwA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jJo2jmh4PwA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jJo2jmh4PwA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 704,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'jJo2jmh4PwA'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/GL8-5hEK9m4bDMe4KGsUmz_YA3g"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC4zMDg5MkQ5MEVDMEM1NTg2',
#    'snippet': {'publishedAt': '2016-11-03T01:45:27.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 몬스트럼 / 60초 하드모드 / 문명6 로마 10/27(목) (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JvWWZLzbIRA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JvWWZLzbIRA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JvWWZLzbIRA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi
},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/XJ1A2efbDVKe2Igmw2AXjHmzBLg"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC4yODlGNEE0NkRGMEEzMEQy',
#    'snippet': {'publishedAt': '2016-11-03T01:42:56.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 게임 방송 입니다핫!  10/16(일) (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/70Rf9uADh-M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/70Rf9uADh-M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/70Rf9uADh-M/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/70Rf9uADh-M/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/70Rf9uADh-M/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 717,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '70Rf9uADh-M'}}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ff5fXrMNeOJXu2wilEdycAMtCFg"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC41NkI0NEY2RDEwNTU3Q0M2',
#    'snippet': {'publishedAt': '2016-11-03T01:40:20.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE]  60초 쌍둥이 엔딩? / 아이돌마스터 / 몬스트럼 어깡이 / 게임방송! 11/2(수) Game (buzzbean11)',
#     'description': '* 대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방 아이마스',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kJvhxHsXovo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kJvhxHsXovo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kJvhxHsXovo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kJvhxHsXovo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kJvhxHsXovo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'playlistId': 'PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8',
#     'position': 718,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'kJvhxHsXovo'}}}]}

# %%
def playlistitem(api_key, playlist_id):
    '''
    # !! 이 함수는 재생목록에 있는 동영상 정보를 리턴합니다. !!
    제공하는 정보 : 재생목록 안에 있는 동영상의 '고유 ID·제목·업로드 날짜·동영상 설명', 재생목록 안에 있는 동영상 수
    
    '''
    api_key = api_key
    playlist_id = param
    page_token = ""
    
    target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, 
                                                                                                                                           page_token, api_key)

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
        
    total_results = api_dict['pageInfo']['totalResults']
    results_per_page = api_dict['pageInfo']['resultsPerPage']

    exe_set = round(total_results / results_per_page +0.5)
    infomation = {}

    published_date = api_dict["items"][0]["snippet"]["publishedAt"]
    video_title = api_dict["items"][0]["snippet"]["title"]
    video_description = api_dict["items"][0]["snippet"]["description"]
    
    if exe_set == 0:
        return print("표시할 내용이 없음")
        
    else:
        for total_set in range(exe_set):
            
                print(total_set, exe_set)
                target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, page_token, api_key)
                session = requests.Session ()
                headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                html = requests.get (target_url)
                soup = BeautifulSoup (html.text, "html.parser" )
                api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                
                
                if "nextPageToken" in api_dict:
                    page_token = api_dict["nextPageToken"]
                    print(api_dict["nextPageToken"])
            
                
                if total_set < (exe_set-1):
                        for result_count in range(results_per_page):
                            
                            video_id = api_dict["items"][result_count]["snippet"]["resourceId"]["videoId"]
                            published_date = api_dict["items"][result_count]["snippet"]["publishedAt"]
                            video_title = api_dict["items"][result_count]["snippet"]["title"]
                            video_description = api_dict["items"][result_count]["snippet"]["description"]
                            
                            infomation[video_id] = []
                            infomation[video_id].appned(video_title)
                            infomation[video_id].appned(published_date)
                            infomation[video_id].appned(video_description)
                            
                            
                            
                else:
                        for last_page in range(total_results % results_per_page):
                            video_id = api_dict["items"][last_page]["snippet"]["resourceId"]["videoId"]
                            published_date = api_dict["items"][last_page]["snippet"]["publishedAt"]
                            video_title = api_dict["items"][last_page]["snippet"]["title"]
                            video_description = api_dict["items"][last_page]["snippet"]["description"]
                            
                            infomation[video_id] = []
                            infomation[video_id].appned(video_title)
                            infomation[video_id].appned(published_date)
                            infomation[video_id].appned(video_description)
                            
                            
                            

        return video_in_playlist
    
playlistitem("AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak","PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ce1da5d1f832> in <module>()
#      83         return video_in_playlist
#      84
# ---> 85 test = test()
#      86 test
#
# NameError: name 'test' is not defined

# %%
x = {}
x[1] = []

# %%
results_per_page = api_dict['pageInfo']['resultsPerPage']
results_per_page
# Out:
# 50

# %%
len(api_dict["items"])
# Out:
# 17

# %%
import requests, json
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "UCSHVH_AWVUc-C8-D8mh8W6A"

target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&type=video&eventType=completed&maxResults=50&key={}".format(param, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/x2E9eYRJI1mEZgDK4_D2nKO9pmI"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 762, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/sRghGyjCFGpcOT33P9ce_iy4DXY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'R9ycS5gqxFs'},
#    'snippet': {'publishedAt': '2016-10-27T16:49:33.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관] 아프리카TV를 나와서 유튜브 라이브로 옮긴 이유 (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R9ycS5gqxFs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R9ycS5gqxFs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/R9ycS5gqxFs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/uG43SrCxx3HtbVrCspJ92Oo0fF4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'cicIbnPN3JY'},
#    'snippet': {'publishedAt': '2017-01-22T17:09:05.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 일요일 깜짝 방송! 대도 상담소! 1부 1/22(일) 헷! 실시간 방송 (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 생방송 게임 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cicIbnPN3JY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cicIbnPN3JY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cicIbnPN3JY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/nGehHZAxMF2loD3qs3tL8c8kdKw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'a0mZpv2Iyrw'},
#    'snippet': {'publishedAt': '2016-11-29T10:03:27.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 60초! EBS 대도서관 잡쇼 촬영 낮 방송 11/29(화) Game LIVE (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a0mZpv2Iyrw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a0mZpv2Iyrw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a0mZpv2Iyrw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/DN5RY_NOrSeXMoJoN_CLGcV5k5k"',
#    'id': {'kind': 'youtube#video', 'videoId': '_mFZXMktzWQ'},
#    'snippet': {'publishedAt': '2018-05-18T17:50:47.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 식인종 섬 탈출 게임 (7일차 2부) 더 포레스트 정식판 5/18(금) 대도서관 GAME Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_mFZXMktzWQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_mFZXMktzWQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_mFZXMktzWQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/qDZ41vVpJcToTwjRSTNtkpGCkb4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'rOv2YxbgFmM'},
#    'snippet': {'publishedAt': '2017-11-04T16:43:29.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 아내가 준 생일선물 공개! 토크 방송 11/4(토) 하핫! GAME CAST 라이브 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rOv2YxbgFmM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rOv2YxbgFmM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rOv2YxbgFmM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/oZqA7vALwa_iUDrsSMpmGiTQI9o"',
#    'id': {'kind': 'youtube#video', 'videoId': '3IAIWUjt298'},
#    'snippet': {'publishedAt': '2017-06-20T17:20:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 야심한 밤, 상담 방송 6/20(화) 앗! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '다이아 페스티벌 이벤트 링크 - http://naver.me/5B91MWfw (20분을 뽑아서 티켓을 무료로 드립니다.) * 좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3IAIWUjt298/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3IAIWUjt298/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3IAIWUjt298/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/J-aRETspGWN38nAWdKqj4UpFTDs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'a1P9MeeymxY'},
#    'snippet': {'publishedAt': '2018-12-16T16:52:09.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 뉴이스트W 콘서트에 다녀왔어요! 12/16(일) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/KXY9nNKJMFeGTO1V2TXCUFr-rfY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'faPzTQCKOTU'},
#    'snippet': {'publishedAt': '2017-11-18T17:35:25.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] WOW를 시작하는 방법 (2부) 가이드 - 월드 오브 워크래프트 11/18(토) 헤! GAME 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/faPzTQCKOTU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/faPzTQCKOTU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/faPzTQCKOTU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/czM3_YsD8NhcJ6chTxGUTFdEMkc"',
#    'id': {'kind': 'youtube#video', 'videoId': '_sIDS23z2MQ'},
#    'snippet': {'publishedAt': '2018-06-29T18:52:57.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 심해 생물 탐험 게임 - 서브 나우티카 정식판 (6일차) 게임 방송, 서브 노티카 6/29(금) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_sIDS23z2MQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_sIDS23z2MQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_sIDS23z2MQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/45dMehYCUxBv58185jVn1u0khHs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'rOzrlStzTQo'},
#    'snippet': {'publishedAt': '2018-01-09T17:48:46.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 오늘의 토크 방송 1/9(화) 헤헷! 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rOzrlStzTQo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rOzrlStzTQo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rOzrlStzTQo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/RyH5j4q_FFA6KBrl-NdQ5E_1gMU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'vRX9gDbL26M'},
#    'snippet': {'publishedAt': '2018-08-27T18:09:29.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 미스트 서바이벌 (2일차 2부) - 더 포레스트 좀비 버전 게임 8/27(월) 핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vRX9gDbL26M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vRX9gDbL26M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vRX9gDbL26M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/XBvhQC6v95D6Fbutfw9tgmLFtac"',
#    'id': {'kind': 'youtube#video', 'videoId': 'CsszWr9YYvw'},
#    'snippet': {'publishedAt': '2017-02-09T22:47:23.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 어서오세욧! 톡방! 2/9 (목) 핫! 실시간 방송 (buzzbean11)',
#     'description': '유튜브 방송이 끊기시는 분들 - 1) 구글 크롬을 깐다 / 2) 구글 크롬 주소창에 아래 링크를 복사해서 붙여넣는다. / 3) 구글 크롬에서 h264ify 설치한다....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CsszWr9YYvw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CsszWr9YYvw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CsszWr9YYvw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2_6ph7ygeaYNTWLey1VbdReb02M"',
#    'id': {'kind': 'youtube#video', 'videoId': '8t1VkR4DChg'},
#    'snippet': {'publishedAt': '2018-05-07T17:45:22.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] Talk Day 토크 데이 5/7(월) 하핫! 대도서관 Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8t1VkR4DChg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8t1VkR4DChg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8t1VkR4DChg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/BO1SG8yHo0tCPtFZWgt4LUy4vG0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Bgc18WSxJN0'},
#    'snippet': {'publishedAt': '2018-09-21T18:33:58.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 러스티 레이크 최신작 : 큐브 이스케이프 패러독스 챕터2 9/21(금) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bgc18WSxJN0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Bgc18WSxJN0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Bgc18WSxJN0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/vlMlulCrBwIOXXdXpF2h7N31iaU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'rHqIwDboDiA'},
#    'snippet': {'publishedAt': '2017-02-02T06:08:20.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 히트맨 새로운 타겟 등장! 치는 남자 힛맨! 2/1 (수) 핫! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 생방송 게임 방송 / 공포게임, 병맛게임, PS VR, PS4, 오버워치, 마인크래프트 등 다양한 게임을 실시간...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rHqIwDboDiA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rHqIwDboDiA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rHqIwDboDiA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/J40WRvsXmUlEIydF_HV4jZh31RA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'z-NChX5q7Nc'},
#    'snippet': {'publishedAt': '2017-11-18T17:00:38.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] WOW를 시작하는 방법 (1부) 가이드 - 월드 오브 워크래프트 11/18(토) 하핫! GAME 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z-NChX5q7Nc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z-NChX5q7Nc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z-NChX5q7Nc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k
/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/q1IFNOZq7qYCoMwrIMurQDPBZKw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZslliBgkWFo'},
#    'snippet': {'publishedAt': '2018-08-01T17:04:20.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] JR 종현 님과 합동 게임 방송! (뉴이스트W) 8/1(수) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZslliBgkWFo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZslliBgkWFo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZslliBgkWFo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/CNKw2AjoB974VeW8xNh4_SyYK10"',
#    'id': {'kind': 'youtube#video', 'videoId': 'iSfIqbpGEyw'},
#    'snippet': {'publishedAt': '2017-08-08T17:38:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 맛있는 라면 먹방 + 총각김치 8/8(화) 핫! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 카카오톡에서 "대도서관" 을 친구추가 하시고 메시지를 보내는 창에서 톱니바퀴...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iSfIqbpGEyw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iSfIqbpGEyw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iSfIqbpGEyw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/fNKshBrJm-PAv6gCl2pvkgueUhU"',
#    'id': {'kind': 'youtube#video', 'videoId': 't1GQ5sfTtr0'},
#    'snippet': {'publishedAt': '2018-11-06T19:17:04.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 마녀의 집 (하드모드 - 완전 다름, 엑스트라 모드) 리마스터링 버전! 11/6(화) 헤헷! 대도서관 Game Live Show',
#     'description': "대청자 첫번째 캐릭터 '꾸냥이' 클라우드 펀딩 - https://tumblbug.com/deadotv * 좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t1GQ5sfTtr0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t1GQ5sfTtr0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t1GQ5sfTtr0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/a8IOrDoA5QQYf84TZdyeer5lVA8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'k2Je2GZ7ntM'},
#    'snippet': {'publishedAt': '2017-07-20T17:01:32.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 수다 방송! 7/20(목) 헷! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 카카오톡에서 "대도서관" 을 친구추가 하시고 메시지를 보내는 창에서 톱니바퀴...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/k2Je2GZ7ntM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/k2Je2GZ7ntM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/k2Je2GZ7ntM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/aq-F5PuMx2ArUzlcJ0H2IIRh9sg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'NPzgoWoo4kI'},
#    'snippet': {'publishedAt': '2017-01-20T19:10:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 레지던트 이블7 데모 진엔딩 / 눈산에서 생존게임 - 코나 1/20(금) 헷! Game 게임 실시간 방송 (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 생방송 게임 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NPzgoWoo4kI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NPzgoWoo4kI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NPzgoWoo4kI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/xUoPsDU3ZoGp9Px1hYwgS6e_buA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'JnIJp_H8v4g'},
#    'snippet': {'publishedAt': '2018-08-08T18:29:09.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 아마야도 버스정류장 - 공포 쯔꾸르 게임 8/8(수) 헤헷! 대도서관 Game Live Show',
#     'description': 'CBS 표준 FM 98.1MHz 시사자키 정관용입니다! 에 대도가 일주일 간, DJ가 되었습니다! 8/15일~24일까지 오후 6:30~8:00 - 초대 손님 제안하기 - https://goo.gl/f...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JnIJp_H8v4g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JnIJp_H8v4g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JnIJp_H8v4g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/bBzRC2BRuvIv82fVNlfZkaj155Q"',
#    'id': {'kind': 'youtube#video', 'videoId': 'x_w1szSTaF4'},
#    'snippet': {'publishedAt': '2018-05-23T18:17:56.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 물건팔기 왕 게임! 상인의 전설! 5/23(수) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x_w1szSTaF4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x_w1szSTaF4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x_w1szSTaF4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/qPfCIrN9rNmLJh_zV-ge9SceGow"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Oo5kaFowtd4'},
#    'snippet': {'publishedAt': '2017-03-01T16:38:11.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 갓겜!! 호라이즌 제로 던 2일차! 1부 3/1(수) 핫! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '유튜브 방송이 끊기시는 분들 - 1) 구글 크롬을 깐다 / 2) 구글 크롬 주소창에 아래 링크를 복사해서 붙여넣는다. / 3) 구글 크롬에서 h264ify 설치한다....',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Oo5kaFowtd4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Oo5kaFowtd4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Oo5kaFowtd4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3QWYcPOaMc5vAv49Xohcr8H7zyM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'i007aNICJU8'},
#    'snippet': {'publishedAt': '2016-12-07T17:17:52.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 에일리언 아이솔레이션 4일차 생방송 게임방송 12/7(수) Game 실시간 방송 핫! (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i007aNICJU8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i007aNICJU8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i007aNICJU8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NfsAjj0eoinGdrHFOviMf8OiPh8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'zROJzNh2fPc'},
#    'snippet': {'publishedAt': '2018-07-02T18:27:53.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 특급 대형 잠수함 만듭시다! 서브 나우티카 (7일차) 서브 노티카 7/2(월) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zROJzNh2fPc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zROJzNh2fPc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zROJzNh2fPc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/iXmdpO6Ra7XwAhPS7-c6zkWIvzk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'czFI4G1mhbg'},
#    'snippet': {'publishedAt': '2018-11-17T18:56:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 인도 발리우드 배우 암살하기! - 히트맨2 (4일차) 11/17(토) 헤헷! 대도서관 Game Live Show',
#     'description': "대청자 첫번째 캐릭터 '꾸냥이' 클라우드 펀딩 - https://tumblbug.com/deadotv * 좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/czFI4G1mhbg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/czFI4G1mhbg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/czFI4G1mhbg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/jz5ABrbr7otNNmMpPhaEgPtYQCc"',
#    'id': {'kind': 'youtube#video', 'videoId': '5UCE8VbefQQ'},
#    'snippet': {'publishedAt': '2018-08-17T17:46:31.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 60초! 완전 바뀐 new 업데이트!! 짜르봄버 모드! 8/17(금) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5UCE8VbefQQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5UCE8VbefQQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5UCE8VbefQQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/K3GxWwTPjzUTtti6YgGZNbYDVsM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SK-_jxgk0g8'},
#    'snippet': {'publishedAt': '2017-05-18T17:53:28.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 60초! 짜르봄버 하드모드 / 수다방송 5/18(목) 핫! GAME 게임 실시간 방송 (buzzbean11)',
#     'description': '카카오톡에서 "대도서관" 을 친구추가 하시고 메시지를 보내는 창에서 톱니바퀴 버튼을 누르고 \'야간 알람 받기\' 를 설정해 두시면 방송 알람이...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SK-_jxgk0g8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SK-_jxgk0g8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SK-_jxgk0g8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/9hg37qoGAZ9kTbyHTzRrI-p36oQ"',
#    'id': {'kind': 'youtube#video', 'videoId': '8rQrJ8eizfc'},
#    'snippet': {'publishedAt': '2018-09-20T18:55:44.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 러스티 레이크 최신작 : 큐브 이스케이프 패러독스 챕터1 / 데스티니 가디언스 9/20(목) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8rQrJ8eizfc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8rQrJ8eizfc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8rQrJ8eizfc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/KJL5l93aAg-CpCKelXgf81IM1Q0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'PjyJ3bRncI4'},
#    'snippet': {'publishedAt': '2018-05-18T17:50:07.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 식인종 섬 탈출 게임(7일차 1부) 더 포레스트 정식판 5/18(금) 대도서관 GAME Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PjyJ3bRncI4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PjyJ3bRncI4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PjyJ3bRncI4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/tEshAds3AvEt3LPHovTHjcKjQQ8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'FYNMaOwJ1X4'},
#    'snippet': {'publishedAt': '2018-09-27T18:38:31.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 루카노르 백작 (2일차) - 공포 쯔꾸르 게임, 오랜만에 명작! 9/27(목) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FYNMaOwJ1X4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FYNMaOwJ1X4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FYNMaOwJ1X4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ByB4uVJQvterfA2RTWGf5oJihjY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'qw0E8j0BVA4'},
#    'snippet': {'publishedAt': '2018-07-30T18:17:07.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 그림자 복도 / 챕터2 오늘은 진짜 깹니다!!!! 7/30(월) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qw0E8j0BVA4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qw0E8j0BVA4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qw0E8j0BVA4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/WWfqzsF3sYOJW48F8HWVEcmj5DU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'bt9VWXDbrn4'},
#    'snippet': {'publishedAt': '2016-11-21T16:53:06.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 최고의 놀이동산을 만들자! 플래닛 코스터 11/21(월) Game (buzzbean11)',
#     'description': '대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bt9VWXDbrn4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bt9VWXDbrn4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bt9VWXDbrn4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/0hCUQBl_e8IBT_zIaYNSZytZ-jw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'PB283J_CCYI'},
#    'snippet': {'publishedAt': '2018-06-05T18:21:52.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 폐가를 인수해 리모델링해서 파는 게임! (1일차) 하우스 플리퍼 6/5(화) 헤헷 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PB283J_CCYI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PB283J_CCYI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PB283J_CCYI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mU7WWPC3okhKFqKiLEQLXjKRemY"',
#    'id': {'kind': 'youtube#video', 'videoId': '4XDRJQlrmKY'},
#    'snippet': {'publishedAt': '2018-09-26T18:53:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 고양이 게임 / 60 파섹! / 루카노르 백작 - 공포 쯔꾸르 게임 9/26(수) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4XDRJQlrmKY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4XDRJQlrmKY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4XDRJQlrmKY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/9mKXXJADoVlT4LcfVBbo4R69mrI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'yZRVfkvrNLk'},
#    'snippet': {'publishedAt': '2018-01-11T20:27:22.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 신작!~ 러스티 레이크 파라다이스!! 기묘한 게임 1/11(목) 헤헷! GAME 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yZRVfkvrNLk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yZRVfkvrNLk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yZRVfkvrNLk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ZIvBu9sv3fTSg9xqcbC8TUg0tPc"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SMc0qv1ymSc'},
#    'snippet': {'publishedAt': '2018-11-03T18:31:05.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 마녀의 집 리마스터링 버전! 게임 방송! 11/3(토) 헤헷! 대도서관 Game Live Show',
#     'description': "대청자 첫번째 캐릭터 '꾸냥이' 클라우드 펀딩 - https://tumblbug.com/deadotv * 좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SMc0qv1ymSc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SMc0qv1ymSc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SMc0qv1ymSc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/wmaVDG0zu9i8ojFtsVWakESp6Vc"',
#    'id': {'kind': 'youtube#video', 'videoId': '0ZwE4tuMLiQ'},
#    'snippet': {'publishedAt': '2018-05-30T18:27:39.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 디트로이트 비컴 휴먼!!! (3일차) 일본에서 컴백한 대도! 5/30(수) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0ZwE4tuMLiQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0ZwE4tuMLiQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0ZwE4tuMLiQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/uUvMAU9Bh2aPgVRacD2iCANI4RE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'D-Ldruz2Jj8'},
#    'snippet': {'publishedAt': '2018-04-03T19:01:27.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE] 2회차 레이트 쉬프트 Late Shift 한글판 - 선택따라 바뀌는 실사 영화 게임 4/3(화) GAME 생방송',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D-Ldruz2Jj8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D-Ldruz2Jj8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D-Ldruz2Jj8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/K5XcbHXDjpBN9-ytLcBMZ6aFFGo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Tv4VE--eVvQ'},
#    'snippet': {'publishedAt': '2018-08-04T18:55:24.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 쓰레기 모아서 해상에서 생존하기 게임! (3일차) 래프트 RAFT 8/4(토) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tv4VE--eVvQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Tv4VE--eVvQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Tv4VE--eVvQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/_vRBJyT6bxfba9BkEyCS4rqlotg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ejn_A7mIYhQ'},
#    'snippet': {'publishedAt': '2018-05-26T19:12:17.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 60초! 짜르봄버 모드 / 디트로이트 비컴 휴먼 (2일차) 5/26(토) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ejn_A7mIYhQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ejn_A7mIYhQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ejn_A7mIYhQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4nj92ff0VyNuIhyRNeCAglfzZrg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'thPcYa_KOrg'},
#    'snippet': {'publishedAt': '2018-12-13T19:03:33.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 강추! 신작 놀이동산 만들기! 파키텍트 게임 방송! 12/13(목) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}}]}

# %%
_mFZXMktzWQ
