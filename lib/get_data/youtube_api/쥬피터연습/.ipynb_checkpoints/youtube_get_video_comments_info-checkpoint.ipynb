# %% [markdown]
# video_id = ImwrZUnHif0

# %%
def get_video_comments_info(video_id, api_key="AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"):
    '''
    video_id = 동영상 고유 ID, api_key = api 키 값
    
    return => 작성자의 채널 고유 ID(str), 작성자 이름(str), 작성 날짜(str, YYMMDD), 댓글내용(str), 댓글의 좋아요 수(int)
    
    '''
    import requests
    from bs4 import BeautifulSoup 
    import json

    video_id = video_id
    api_key = api_key
    page_token = ""

    target_url = '''https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&order=time&pageToken={}&maxResults=100&key={}'''.format(video_id, page_token, api_key) 
    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
    html = requests.get (target_url)
    api_dict = html.json()


    total_results = api_dict['pageInfo']['totalResults']
    results_per_page = api_dict['pageInfo']['resultsPerPage']
    exe_set = round(total_results / results_per_page +0.5)

    comments_info = []
    if exe_set == 0:
        print("댓글 없음")
    
    else:
        while True:
                target_url = '''https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&order=time&pageToken={}&maxResults=100&key={}'''.format(video_id, page_token, api_key) 
                session = requests.Session ()
                headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                html = requests.get (target_url)
                api_dict = html.json()

                for result_count in range(len(api_dict["items"])):
                            tmp = []
                            tmp.append(api_dict['items'][result_count]["snippet"]["topLevelComment"]["snippet"]["authorChannelId"]['value']) # 작성자의 채널 고유 ID
                            tmp.append(api_dict['items'][result_count]["snippet"]["topLevelComment"]["snippet"]['authorDisplayName']) # 작성자 이름
                            tmp.append(api_dict['items'][result_count]["snippet"]["topLevelComment"]["snippet"]["publishedAt"][2:10].replace("-","")) # 작성 날짜
                            tmp.append(api_dict['items'][result_count]["snippet"]["topLevelComment"]["snippet"]["textOriginal"].replace("<br />", ' ').replace(" &quot;", '"').replace("&quot; ", '"').replace("\n"," ")) # 댓글내용
                            tmp.append(api_dict['items'][result_count]["snippet"]["topLevelComment"]["snippet"]["likeCount"]) # 댓글의 좋아요 수

                            comments_info.append(tmp)

                if "nextPageToken" in api_dict:
                    page_token = api_dict["nextPageToken"]
                    
                else: break
                    
                    
    return comments_info

# %%
comments_info = get_video_comments_info("ImwrZUnHif0")

# %%
viewer_id = [x[0] for x in comments_info]

# %%
viewer_id
# Out:
# ['UCpeF6ejF50qlZz8-hQ1G2sA',
#  'UCI7XShVw-54RfKDVBMnSbMQ',
#  'UCJpWJlNnz7mAs4y-l47Xxkw',
#  'UCwun-qbGYRx3uZwnq8K2I6w',
#  'UCB3RToxV3uFwAakDx48z5_Q',
#  'UCYI47xcs_MmVm4K_TuR8aQA',
#  'UChCvSuMYJuqIxk6c2n8LDoA',
#  'UCqwV7b1Z5nMWR1rhu06JDWQ',
#  'UCwGh84672OETjeWXnh8TWSg',
#  'UCkrbK-SjSiUf_2ulgZZ6QNA',
#  'UCkOgnmVnCrLuelmqFJ_XLvg',
#  'UCwQvRYrdHj3fSOTY1IIafbQ',
#  'UCEGbO3loXamxG5z4fuRC06w',
#  'UCApd3JpjW78MMzezLS3MM0g',
#  'UCVT1u656jiv7Dm29AIV3Few',
#  'UCXKK4XN3q3i8lvsnf4bIZqA',
#  'UC4yuMbKB8fLN0pvGqX5_-BQ',
#  'UC2qUTuMrZnrGaKLCnHPN7Gg',
#  'UC0as0D4uyIoBkPxmG5zF4jg',
#  'UCpBgLQhXNwOlSHguxu4Mb7Q',
#  'UCXBNbMyB-1gG703HwG70nDw',
#  'UC5wORmIho7b2q2gQB_BwHag',
#  'UCR-6iRJTe-lyAY0Nmnz1wKw',
#  'UCWmvH9M2_zj2PyK2xqrh90g',
#  'UCNUqJkRqQy0Ta90A1PwY0UA',
#  'UCi9FoVp8yPTCErY0qyQTRgQ',
#  'UCUOFz69bHHuf3k04S65hBSA',
#  'UCGM5nr8Jo4v2CEMpeCI5mvw',
#  'UCyM1pQP3HMyhV12zhbW-eQQ',
#  'UC_ukOzT_fHJrpf59nunTm7w',
#  'UCxAUBxS8_gT1fSkEUWC-bAA',
#  'UC0rCqqZP5_MTd8sgL2d0zgA',
#  'UCo6tUb6qYfx00oAvuQdV50Q',
#  'UCSWUfo0RWbPiFu8Osd5exgQ',
#  'UCltc122obmcnAxZwjLhv_ZA',
#  'UC1wAXEca8QTS3iqrGKwRswg',
#  'UCneFnfC8q7dGLiLcttiajyQ',
#  'UCCoXZJZGMzn2dj8YzTYFbxA',
#  'UCP7Ej0Jsggb082SC1Ybv7Ow',
#  'UCFnSgB9O9U9hDGW8XToQVlQ',
#  'UCyM1F6Vh4IBwvUApVxHB5vA',
#  'UCldmX2GFJ5UNFaad4ATkLkg',
#  'UCtgfB_Lc4nyqG69OUFyjFKw',
#  'UCYmbKTJELat8fnbSM2OzMuA',
#  'UCJuITOJbNyygfApBj07uMbg',
#  'UCfErZvdkb1bypKLd2QNwC4w',
#  'UC4CxL9O-T7N5mKgubCGYlpw',
#  'UC8BLzzM9jL1IhRzd-BVYuDw',
#  'UCAsIcAMUCZMkqJXwbGQr_WQ',
#  'UC44NUfNctGJZ4P6jEGncJqQ',
#  'UC24R75x3830umGFQfdmNy1Q',
#  'UC2fI2OrAXTdjGswCpCugFiw',
#  'UCfdqVgqOlwLnqFs-t1eu31A',
#  'UCrs9NahV3r3ZsB-wpmYW8mg',
#  'UCeGQo5rUf9OI_29sfvlQe1A',
#  'UCPeljleSurIitpTbfHYtk3A',
#  'UCsvFMRUUxiGi_35th45jJJw',
#  'UCWfWVh8QM640ZoM_2pXdg6w',
#  'UCdQmtFlRZk6qS7AqvgY9GJw',
#  'UCUteHAi_ahWI6gVEu-JdZdw',
#  'UCcR81XY17RqKBJSqAfnJ7hg',
#  'UCNUqJkRqQy0Ta90A1PwY0UA',
#  'UCYmbKTJELat8fnbSM2OzMuA',
#  'UCnOuHViq5HouhI_uyqmnupw',
#  'UC3WCiFanItbd9-Prsg7tICQ',
#  'UCu7gCXb5i8VnEVIefZZHOjw',
#  'UCRQINhIpr91FGX5xsQKWf8g',
#  'UCmpqlFcOsnOTtnolr-3MZKQ',
#  'UC8OmvzMVCIIDwsFVA4DTy_w',
#  'UCjqFGPC40fFICjm8wNYGkQw',
#  'UCznFvEuFIYhRtxQT6ICpauA',
#  'UCskHfPhGO0CziZISvYyOVSQ',
#  'UCbS9uSLrZcE3H9ND8TNiOIA',
#  'UCCZUDS89Gn6-4-_E12LfsYA',
#  'UCf6785WkHkl_4S-dWq6wJGw',
#  'UCGM5nr8Jo4v2CEMpeCI5mvw',
#  'UCFbp5JtG636NKCCKVDTPdHA',
#  'UCl9dOmWhxvQqUxEaTjiJrTQ',
#  'UCXCY4lIOIgTznvrioD5LdSg',
#  'UCMaAhREHaTIsm3k7teofy-A',
#  'UCbSw9v7aRa2ng0zTKD7O_kA',
#  'UCzhBD92vxVWVGQldoih3sPQ',
#  'UCN2GSBu_U3Ef_oG8GUtzqCA',
#  'UCDVxul96JZTIx3KoRkrktsw',
#  'UC4Q-fHWu8ycH7KmqfSTfEsg',
#  'UCUOFz69bHHuf3k04S65hBSA',
#  'UCeHbpMJlJ5jzhaMyffiLfUw',
#  'UC2iV89btMYRc4wLHZpNu31A',
#  'UCCbe0VBL3Nto6GbLmwaXcuQ',
#  'UC3nhZLcHICxwlGT5BtciG4w',
#  'UC7lVauap8KyzBsq4nXQr4JQ',
#  'UCebL7ue1kQbacmvsRdv5BNg',
#  'UCofteShMq7hdN4BU8HrssfA',
#  'UCSw_haf35mmBPK9lbI2xD3A',
#  'UCn66BjXiuFXEaNA4ZYj_gEQ',
#  'UCnw1_JNSe-IvX06hedDIVOg',
#  'UCieMiV-aAbFGfPUJ-doRe-Q',
#  'UCwu4rdxk-ZQ42iFcTdvGX0A',
#  'UChjkI3e6lkPbeXFw4J6cbQA',
#  'UCnM6NllPHtlhffRr_l4x7UQ',
#  'UC_cuixLsFhzbDBw2sb5Nlow',
#  'UCXP3xMrkVIWlRgHvwcc4Edg',
#  'UCSWUfo0RWbPiFu8Osd5exgQ',
#  'UCppL-WiCvJ5tMof6oD3OuzA',
#  'UCAySYfHMFTrxTQnLZ-UCeDw',
#  'UCejw8nwjM8YCh-p5TMh8NXw',
#  'UCejw8nwjM8YCh-p5TMh8NXw',
#  'UCgpzoXnRzdYPxhtftEvEbOw',
#  'UCfiOh2fqMsvH0xKa6Hk41aw',
#  'UCqUGAy8TOUJrdJo4oeaETRw',
#  'UC8t3RB54uS3S4fqKQwu0OCw',
#  'UCHsetHnxtlzKJNOks4hjZaw',
#  'UCfkxYG68kiL-MX79D2UwX4A',
#  'UCwmWku6hV15WteIZSp10nuw',
#  'UC41YzIuZlAUwdNZFabUCE0A',
#  'UCvtS09Ko9T50kKNgFPKX1ow',
#  'UCCRXQTdqxoFW7FnFVya0Wpw',
#  'UCsOLMcZkojo__e8VSxH9eIg',
#  'UCdoZTyq_psrbIlrpYQKWaaA',
#  'UCdoZTyq_psrbIlrpYQKWaaA',
#  'UCONVY2A2L3PxxTu-H8K2OrA',
#  'UCBaTbcXTuOE2R9fOYG5DPFg',
#  'UCQTxZByG2L803J4fkhRnmPw',
#  'UClnnyyoRseQi-Pmuu9y5zcg',
#  'UCVR9fyszpa-aw97B8rUUTgw',
#  'UCoahd09YNGsrlfqke8TJULw',
#  'UCFlcbKYbHoq__8HpPDO999A',
#  'UCQl-BR_VWos8v-9ktnmGkIA',
#  'UCkLdGYzIKYnCkHkuEValfAA',
#  'UCSMOJ335tr1UdwI9aXQ9ssQ',
#  'UCOMHT55UR8nkYczemq6WhOg',
#  'UC9_pi6hntrtGrEGkbY9Cu8Q',
#  'UCB9UaKcGIUNByXnQjTcVfSA',
#  'UC3wKBfV9X-1K3QPG_IVnv8Q',
#  'UCWWJFQzX0ppXlrnRFhkwcvw',
#  'UCuOvqsstTzh2tSOlhTP0LiQ',
#  'UCLYmMiXt6G0rJlRVp2NP7Qg',
#  'UCfHAH7IR9XLOeK5vggjUpDg',
#  'UCN-aKRGqj35pwZU7hkqetBQ',
#  'UCHxEyWCKGiwj4Hd4Ur4ZWmQ',
#  'UCN0R0rF5END1PYWTEuQDOTg',
#  'UCu6Ca08movdt59vzuEVhp0w',
#  'UCgfeWhqoPRlhdu8CvPwtkUA',
#  'UCsQREwfubld8WgfQNxwgzNg',
#  'UCvohnh7ijNfU6oMgFBqTV-A',
#  'UCltIO31cSRuszaURvLm-K7A',
#  'UCx6U2bKfHubwJsjel7omrvg',
#  'UCz-aVHkbvh3q59zYwjnpWXQ',
#  'UCFR-yTax4iBCnpQ0et9s23w',
#  'UCxrb64tLdIYIhzJfOIO2pxg',
#  'UC0k4nSKjdzILUPal04nNXjQ',
#  'UCS_b050ypZFgdgvIOf33KvQ',
#  'UC02b0Oex165MENBtn7NvJrQ',
#  'UCb7yOkQYlNuDaH8u7K9vamQ',
#  'UCibGldsv_r0-zSRLmfVsFbg',
#  'UCU8_8GN1OLyYpENKg5YD_Ag',
#  'UCV29NmN5fD6Qli4dKCGl0ug',
#  'UCDLZeNOWGxyZbJj8Ua27_Ug',
#  'UCugeZJ6fPA-R-sq8kUAfnEQ',
#  'UC3_zFXOY_FwIQfWyGVElIRg',
#  'UCKJIF3bQtAHiRR5aqNNUMiw',
#  'UCHcEZx8CFG9ht7Fi-3GmqSA',
#  'UCg46fzeqowNF0Yc1SAWd4mw',
#  'UCVmHqfm94YD2lM_TE2ZKpOQ',
#  'UCEoPhAIo6_CRF5ikRcv3EDg',
#  'UCq8JJ8ewwgTPoTkkOMIodSA',
#  'UC44OwgCzPXKE8ao1x4mQQ4g',
#  'UCbN7_FyUG_o2-QowaEwgZkA',
#  'UC5O2Pr10naA-7k8RimCXMrg',
#  'UC8TV4r0EKnGHRx7bgTS_esg',
#  'UCVmOuUAJKK9Q82-l_-EOnvA',
#  'UC7XYdS9HNapKCXU1tV19x7w',
#  'UCARQ8WAbg19TW5NSFMhQGUw',
#  'UCK3HcXNjgg8SBaEslpVH8Hg',
#  'UC20Zga1lmghp5gztHma_p4A',
#  'UC65MNfL5gLNRO7e4ebpKj6w',
#  'UCWLssZQW9PH0Q0X52_YmrAw',
#  'UCul6vU5Ps_Ijsb4uX-sPbcQ',
#  'UCfzwvcZlnyqISaLdjKoEktg',
#  'UCQDXtNV-KQZvq90jdBweqWQ',
#  'UCjT_lIkU0DwhhDrdQZEBF9w',
#  'UCoAdzjhfuATkU-weVB_9aMA',
#  'UC6YeymganTsj_1XhhIQa0Jw',
#  'UCL-LufaTXtUh_7oPxHPB0OQ',
#  'UCEyrJWy1nE1NY_8fDDrL-sQ',
#  'UC0S0u733p0xtJnDmRZITDnQ',
#  'UCjWjrUxzUN_tHp2iOh-ew1g',
#  'UCHPpViswdKUOfvjA-mb85Sg',
#  'UCyY4k6nwn_0GkwSn2dPsSlQ',
#  'UCyDjj6s0iSFLZ-t8G8TKoAw',
#  'UC-5qEs8gu7of5BywYjhZTVA',
#  'UC7DpXDbPHLuMFH8gYbepd5Q',
#  'UCOPf8ktgvRe9x-3vfGACzZQ',
#  'UCVmU--PHxuAaKR6M2NvCqyg',
#  'UCUHbD-bTo7_3GatiT_6mOLA',
#  'UCFtlgQ1Fgj2T10Q3ka_vPpw',
#  'UCefEbJgDiHkTANXvv8cfjUw',
#  'UCqrOatdgcGYCd5gZm1WVyYA',
#  'UCqrOatdgcGYCd5gZm1WVyYA',
#  'UCqrOatdgcGYCd5gZm1WVyYA',
#  'UC-BSywa1RvOpd9821aPp9yA',
#  'UCDuVtPGL-o7EbOmJYXbzTAw',
#  'UCkAa65xH8Rr17iwx8ViidXQ',
#  'UCLavFXp9kXhEMOICEJ6NFpw',
#  'UC2sm4I-5aMToJy2Bb2-_g0Q',
#  'UCjKDviz11h9HPjDbHXcztoQ',
#  'UCg28WIfJuBon2vO59yasvvw',
#  'UCV7T_SC_4xinjD1c-BSY7zg',
#  'UCHzEoT_9Nw3Yjyk7BcsAwbQ',
#  'UCRQwCZzblYtWYVJuxc_KVvA',
#  'UCVt4RkN_4CCVJl9-3NTSbPg',
#  'UC8N69w1fxnpvoxnfAmWWhEw',
#  'UC0VRHpjMxXd3CgXIcnk8UBg',
#  'UCOy6Lw8POVYfKfGMn4jBjqg',
#  'UCT9YM0AEBTz2Fxio1eqItHg',
#  'UCW6MNB7_QKV_AoxfKW90d0g',
#  'UCGW3qGuoNsRzxRwuoDbzvEg',
#  'UC2Z2dOFRvjSfblnEdoZsVPw',
#  'UCjVDjNcDKjE-sAC-adVuwAg',
#  'UCERasN2HWikTQZdFzUzWvpg',
#  'UCgTHrMJjuCtcJayWYg875fw',
#  'UCwjXVqIHrvr3eZ5UvU1SYyQ',
#  'UCrRgVdONaekOi4GwQS1f4MQ',
#  'UCrRgVdONaekOi4GwQS1f4MQ',
#  'UCXH_6rRUMzn6v7z3fG_r9SA',
#  'UC8Q7rSz3Hz5r4OvR4VPrDdQ',
#  'UCJ1tXjxu6UnTXc_r6RcOhig',
#  'UCL-5CwZooQTIe8a1e99M8sw',
#  'UCeo8llg76ibcubTOz_JFIsA',
#  'UC41xrsDIon-3PSdIoSsFe8w',
#  'UCejcqCX0kyMnewpOeznY8oA',
#  'UCpvL6whSJG_Fa9e_bThPgYA',
#  'UCMb71t-QcfXLumvSgH6kJcA',
#  'UCW5Mb2_u_GhauPcNHptxASA',
#  'UCFbYuD4CiAKKJ2kCwg3dL5w',
#  'UCoyg25zn62hanKZh7y-6NMg',
#  'UCM2I84CysyUEspZdxoy1BBQ',
#  'UC4nxFg0-dUVbln_M6UE-y_Q',
#  'UC64-aoAPj8UYBpRGg9AIVFA',
#  'UCawhZDKIIw_WM0X8QhwbCDg',
#  'UC2jEkMV-pCEyoEIV5MJK5lQ',
#  'UCHJsXiMTlFX_i79bD3qGl7w',
#  'UClXDAg1XCvI4a7iKPG9F-qQ',
#  'UCBM3E8_uXCpiOPKI5bov8Ww',
#  'UCMZqVKy5hvszpJo5r3aBi4g',
#  'UCCgpkwJ5OCoMPqm1a9dxHEw',
#  'UCM2oyyxJcibw719m24vu4UQ',
#  'UChrIq5MFtRQlYBG4PDxOanw',
#  'UC0M9d1jyR_XeV_2-iSOTCLA',
#  'UCmhad9R0m5MudvEh_TT33oA',
#  'UCUKwBQEF98CrTywwIu0ZMOA',
#  'UC6X1ZHJmScphwkT1W6XX29w',
#  'UCQodQyeMH6i96qbWhc9FSxg',
#  'UCLaSFph7l_ppkQXlVq9-New',
#  'UCLX8jBcIO437hYFfPztwnnQ',
#  'UCL20RPCOQz83n5QYHRTlvjw',
#  'UCZ7FsoJfvOoMlq_cJaymuvA',
#  'UCbMtzivTy1MaZTHnlWP0Tww',
#  'UCFpp9W2F3ZFnzoy3vMaPLAA',
#  'UCk8XVEGb_IM00KgCVKdPDUA',
#  'UC3HEQLO3wFjQzFyBcjarxKw',
#  'UC3HEQLO3wFjQzFyBcjarxKw',
#  'UCSkbHv5B9KsvLu0PTCnnIrQ',
#  'UCgpqbM0pajgHVVaFvGi19YA',
#  'UCmTy4_IkJkxsGLYopG0BUnA',
#  'UCbICrfIljNY8jjB7wuLfV9g',
#  'UClD2acHq2MMfAST5SgeUwbg',
#  'UCWfeH6AwX5CF7EZ-k7zV76g',
#  'UCb-e0TiEf_cctWCkbHrnwMw',
#  'UCGRAzTD-BRdwMeadCcz3x2Q',
#  'UClSVACM5GKsEEeycCUaK8_w',
#  'UCY8OwrhSs1YRJPVpFLM7ceA',
#  'UC-hSGOagdXR_En5TeejkCgw',
#  'UC1PxKLfVjPuAXX5rFJ_WJuA',
#  'UCvVKKxQKmyoqI_JzJrX5VlA',
#  'UC2ge_WV6a2zPzEJbmtsBoxg',
#  'UCwm3dh1Imh1Obs0uPEJTA1w',
#  'UCGiPLP07a5bYezt8OLRpnaA',
#  'UCwtWNwspi8mPQERly7OZMGw',
#  'UCJFNFyO7uk-mle9vzA4Hozg',
#  'UCO0UsZNxv2cy4dM5E4XG3Jg',
#  'UCshcULA1omfzzj6ADyqtbQA',
#  'UCLPk3YxXotmdM693MiaEyGw',
#  'UCcq0B8PRb1qzYX1W9hcw5kQ',
#  'UCCa-5Acvst8GU0klZKSQa6w',
#  'UCbyZJS8x4IYV8XMsGaiYMIw',
#  'UCUIH6lKQl3JT6uqwIY1qoww',
#  'UChZoKEhDkoVKE1-ShybIM0w',
#  'UC8RAeRs4Qc12BxI5GNOBrNQ',
#  'UCTGqcNkVOUM8rn_Z_j9M8tA',
#  'UC2qmHCu_xAaQ_JaHMVoFqhA',
#  'UCRUVNf7t_ES_mJXQeaGiJEQ',
#  'UCx5nH2B5NwSWu6cUx_7dR7w',
#  'UCUaJq-I3iPOZmsXWsmLv4gA',
#  'UCGepd2DHtfG3l_daY-fTkBg',
#  'UCvxYSKMQ2uSj4CPmJaQYyQQ',
#  'UC-_HuXBC8G_Rc4JCfBvj7mw',
#  'UCixzRoqTZzS53fDGy6X_YHw',
#  'UCvENGDp519vsG4amF5yIDcQ',
#  'UCq_97GhkCizsyGE9OkVTHuw',
#  'UCsswxstN9aXkEjbf70GPuuw',
#  'UCkhmCde19kYC-I7QmQ3fqWA',
#  'UCk-1pQkA_GnXmtoHJUGIFqA',
#  'UCo5o2bAOjpjPmczXG3ixspw',
#  'UC9kGP1tpnRv8VMq3ECmS4yA',
#  'UCS2r50NMhkk1Nk2b74XolOQ',
#  'UCw5RikzBU6Rkk4PEdhuPaaQ',
#  'UC6zUwc1aynB_hgtDSgdalPw',
#  'UCtPH90romrfAYvWrfUPKOnA',
#  'UCk63eAN5Qzer1mgtXxjVrfQ',
#  'UCIksojAy5JxqtsvVbJYevdw',
#  'UCAHmXN684UAgS90hQHpIdeA',
#  'UCRD-rGIlqJ2DBrG8ZbyIcuA',
#  'UC0rw88HfcBv5xBFP0Wcatlg',
#  'UCp0qfuHZwBJ7pbTCKRybPzA',
#  'UCv5dddzI7XO9SEkoQ4jhjgA',
#  'UCMTuZPlz54HIF83YNydnV3Q',
#  'UCdDtX7sqLeuCW7e0XXm4nVA',
#  'UCAiWoMd6ME7vAClTcpbso2A',
#  'UCX1rHHTE4eowPaupbFw60hQ',
#  'UCvhSA2Tm_4w86pmK8Hdj__g',
#  'UCecuO9wnbfXsqLp1NMnwL_w',
#  'UCbmM_VCBTcTMESsrMyOz3xg',
#  'UC2aJVVnZPsq_FI0jnnuBOBw',
#  'UCyWplpfqdzcEPrii4wi2tsQ',
#  'UCB2USiAaqukJr-UwetAwA3g',
#  'UCm9_RENTRGeojSRWk-E6h3w',
#  'UCoq21UUg_DZejPfFVEaeAQA',
#  'UCJcTZSzywfF1J2EJhGQ_WNw',
#  'UCqQbniUyuCDYBVqoY-cugUQ',
#  'UCEHtGly41D6-HAv4QYb9fhQ',
#  'UCQRa70Tqr8rLavCA-vWDOpw',
#  'UCiydg51g211U0z1tEheJ5BA',
#  'UCRQuzGtgc2OlgJf91Z0MtRw',
#  'UCwLNjHshbwBIubKznqLBbpw',
#  'UC4Q-fHWu8ycH7KmqfSTfEsg',
#  'UCGHIJKjWVNg_3SaCBkRT7WA',
#  'UCGHIJKjWVNg_3SaCBkRT7WA',
#  'UCtwqBZvj1Xs0ycd2irgjpIQ',
#  'UCB-oS28zuZlwUjTRGbxB7RQ',
#  'UCHpeFvFMVf_F7zi7lkqSHmA',
#  'UClk3lRHuW2n5JEVsX1nj_Fw',
#  'UCTRG6YDkCEPzKuFSkw_gGSg',
#  'UCmCuVULoiemNwDi7NAki_NA',
#  'UCh7bhYX-1PSLMsyy3Fli7bw',
#  'UCKEIOsxP3GyA7ANVyAiw_xg',
#  'UCPvnB1qffu-ntwilHq_SSRg',
#  'UCTXMQqXM1W_HiqHKQGdPOXA',
#  'UCP5E0rJeNBPA0f7csRiK-6w',
#  'UCTERmU0G1uJu1Ugda7Gq4bQ',
#  'UCbT9uPG_E1ilbXnel0Abk4g',
#  'UCaiv7dcBuiwuJ55UUA-ynhg',
#  'UCGzljmZDiSVAMGE6_4Yte9g',
#  'UCQC2DHGsFMU0kxNLZFl2zsQ',
#  'UCbyfuj2QISKTfeIF9ohw4WQ',
#  'UCWjmXPhwyXi2Te_wWL09rwQ',
#  'UCLHTWe0KCRgaX0LRxLVYaPw',
#  'UCjKm9EEb0QVTnWTzsuRaCxQ',
#  'UCtkGOqJ9C1fozT8ASFtgKDg',
#  'UCEoOJ2Yy_gfNCwrkdmcdx9g',
#  'UCIXkTqMN3ettrtqlLIgKYYw',
#  'UC_grPJbrH2ju8u3yXQ-DVnA',
#  'UCinF12uIVmzbqw-UMIwlWEQ',
#  'UCvQbTRp9jlHDnPqd8_IfthA',
#  'UClXsouD1dqICE8oK75p9dgA',
#  'UCU20-MQs1l3h_vE1IEnpYew',
#  'UCz2ZsE0dRirP8TKdBbox0Fg',
#  'UCSUwYvmijYHCn_A_a7Kr0pw',
#  'UCtIfxx29KRApfu7WBQPKR9g',
#  'UCBwmJ4Ook5tk00WGa1-dAMQ',
#  'UCePWn8Xvn-z3SQi3BP8vlrQ',
#  'UCkItm-EaG2X5r9QIbUr7i5A',
#  'UCWS28ADgPlsRuw17Gao1xYQ',
#  'UC2vUJ6l4aLrffw1sGUbykTg',
#  'UCTKrGBtoXe-u9HhqzVUtspg',
#  'UCipt3dAL7YyyzQUbI-firyw',
#  'UCXyXHAMS1j2qyL79BLeWtEw',
#  'UC44mV0tn21RN658RHpayvcQ',
#  'UC6yvlECTjysZDtrJbmtvQ8w',
#  'UCd6mBzk-T1ACImLRy48Vz5A',
#  'UCx8mwHt-ViR3OMr1T4wBmGQ',
#  'UCkG2B4LYsrHnXZ7U-ALPKHw',
#  'UCLL3kkbKKvQHDIMuf0_YKLw',
#  'UCLbSkGJaGPKMa1g8Fil5CmA',
#  'UCZRQvllE149zfFseuvydtag',
#  'UCmJn0YKyK-UcfwnPZevdlyA',
#  'UCkKImHmf86yGtkVpS4aKbAA',
#  'UCyBEotjrRRN4aaok1AKIQ_w',
#  'UCxcLpdr64AbG6ebijRNIVrg',
#  'UCNyKj7_CJqTxBn4KpqSah7Q',
#  'UC9jK8P1TV7nFXEKSHPdQfXA',
#  'UC4gBJxSes3_J1eAMmX3Hhlw',
#  'UCg4f9LNpE4ioHrYiV9y8ssQ',
#  'UCC-a-TQ7WbMxNKOfwbVJ7DA',
#  'UCS9ak3UxDvPomuLJBN0NNTQ',
#  'UCafHJaBnNmYnktjj243Dwkw',
#  'UC6kpZZ4c-scbUAtoNNp-p_g',
#  'UCNnHWvfuCzpxOoojJYJPmRw',
#  'UCc2ou-6cIfS6qwniiRCjr_w',
#  'UCB-y3M3xYWUpwSplTWIOy_Q',
#  'UCYdNYko6SA5qa-PCLFIwlHg',
#  'UCtjosnzXX7CtUYyCnG0k0Sg',
#  'UCj2mU9r06jgjbS-ZnklzkHA',
#  'UCbBkCXHdcVBMkty14r3wFrw',
#  'UCit-jGaPxZYBIcrhnKYCvNg',
#  'UC5nyMZIjqc8M8eLf_BLIPfA',
#  'UCK9OpvMOPAtZhr5xLglDqmw',
#  'UCkieC5_CRu3zYtdOr6aQGhw',
#  'UCD-Rxxy_IPmkgnL1_LBxMyQ',
#  'UCSD71sc7SH1i90zWgQpnj0Q',
#  'UC9rjJkRo4ZBfQ_nSTGD_V2Q',
#  'UC1DQMb-na2j2-zlnw2KZFMg',
#  'UCadM7gmAusRrpMA2iWCq8pg',
#  'UCS0XqPaQvbtt2iB9DPpspkw',
#  'UCY8sZfE32aD8PxpBIsrg5fA',
#  'UC6c6m__g9Z2O6qg9gyRXp1A',
#  'UCDC095VywpAarTw8wswyGBg',
#  'UC-n9SSoAHwWgEMtAnXE2wpA',
#  'UCUG-Sot_rCDaC6MW25T4ZAw',
#  'UCnPFk0GmPbD8SoO27ulPZYA',
#  'UCGp5OPN_sD6HtoIPSp1l7cw',
#  'UCwf5-C3H-vfUwS6O7gHgYew',
#  'UCEItb7SBMn-KYMpi4Zi9QUg',
#  'UCEItb7SBMn-KYMpi4Zi9QUg',
#  'UCyWplpfqdzcEPrii4wi2tsQ',
#  'UCyWplpfqdzcEPrii4wi2tsQ',
#  'UCkNIKzAo2Xl76GinUWR4pSA',
#  'UC0ACR1ozZyvlonBcKA15DLA',
#  'UCvBEW51KwgrTF8FzmWwwkpA',
#  'UCf_FF5u6wp7SN_2xJsdng_g',
#  'UCRukpwOSjhP5ibrc9R80KCQ',
#  'UCS5vst2as1rnqVx-8gDtj1w',
#  'UC3-IFHNFXtsxUWQI68HkXag',
#  'UCgxx2Ie6vfvfiQYAMBYYy0Q',
#  'UCsswxstN9aXkEjbf70GPuuw',
#  'UCK8z0E9V6sl-hlpMQkG8E1A',
#  'UCtd4RkoGapKwyj5auNEW_jA',
#  'UCqfAS6ClvawKlVKKEJe7PEA',
#  'UCBWmW8l-9Rib53q5ho9_1ow',
#  'UCaZ9SbcpUceOUXyAEFb10FA',
#  'UCiTm5ZKEUfYVK9Xt3dqx4dA',
#  'UCDZPdUo34cvghvjvvWq96KA',
#  'UCDjWt9pJ8TBl2YLVhgb-I7A',
#  'UCdRnbOdMFeJWxl0mlhmZoSw',
#  'UCs5NlOT63TxfAeVOh2EoRyA',
#  'UC86XIA-HIHv1kuBtpNgO6wA',
#  'UCjN0vbzwirVwrO9BtIQMN0A',
#  'UCLnTjXtcOR4ggHQYotmIvQQ',
#  'UCXkPlx6v8PDBnfKjDHtm8xQ',
#  'UCpDgyRtS2t-NLfHMwF_G8SA',
#  'UCkgnrv5XkxhR4vFxthOSWsA',
#  'UCjQPNcZx0pd4T2CEG3qrlAw',
#  'UCowbm5BG_SxcwkcoAD-rfaQ',
#  'UC5gGsCMm-Mgfcfp55FQrpsA',
#  'UCaXGWruUnGpqZbZCsj39uHw',
#  'UC3185wk1JP39WV2d1KLyoiA',
#  'UCn-PYrH0YSKGQRiRq_-BF8A',
#  'UCiy9oSWNbask3yMS5n8lWXQ',
#  'UCB-dct5BkxLcj5wgCU-EiUA',
#  'UC7LZMdTLR5C6ppLpWqk_vVA',
#  'UC4fiJPLP71rhbtUuB8yoxIw',
#  'UC5x1gNXJfnIjJvW-hu5Bcmw',
#  'UCL9ZsH8qo57mdVzaekQNHMw',
#  'UCavFK6UNAzy9vfO-BtvdM3A',
#  'UC8MbH6yTZqUN7Z6fLT1zZXg',
#  'UCGOBRvGbMuUttuB-hVWAPFg',
#  'UCZytXBrVl0jctFN-s5DQWtg',
#  'UC5JASUuaoMfSlRItv2oU3AA',
#  'UCIJqV9V_RRWNdxVlKuKFNGg',
#  'UCynaHMqRAWC-54LJONyYmzA',
#  'UCynaHMqRAWC-54LJONyYmzA',
#  'UCY7CohiH-cer0H7eAmqvYFQ',
#  'UCOL7Zc9iNd9fSk6O2vEPBLw',
#  'UC8q7kWsZUKv_17kxJJeSstQ',
#  'UCJd-_6DhJhDTmO0KFSGS0vg',
#  'UCZGvMd9btxU0ceiBajardyg',
#  'UCkzLHiCAERFDWyocpbS9dgw',
#  'UC7ilsCKj9xXA2yUJI5WpgTw',
#  'UCpsBIuaz_9LgLib8jTZ2E-A',
#  'UC1JAVyMpoz-fgV8icdHoUlw',
#  'UC0C4IU6e5eubLsZLPAQn1Bw',
#  'UCaWoS9azHGVGk1rl7Cw22EQ',
#  'UCNA70t_AKjEhF6A9hE83mSg',
#  'UC2_IpgMpUMi2jnCH4vimItg',
#  'UC1oYiEznht5gmN2rzCyfmxA',
#  'UClk9fD3BYSrvd21T3L4wE9g',
#  'UC65-6G-P-3qFcKXBEiHEXxQ',
#  'UCqq57itva5u0-OsReGJV0DQ',
#  'UCHnnHAbiIJ1lOovlwb_FWMA',
#  'UC2zQyKl4tQ8i3BwQpS7_veg',
#  'UCNgajS3LO9x4mI3LKnjPbXw',
#  'UC8FnEK6t2hJNh1SJSeKQPsg',
#  'UCZ7jUiwIw4GZg-mLToEM6jg',
#  'UCsIZDvgXGxeJ6pLMVZcQ84w',
#  'UCBjPHgFeauELxgd4jZUMqBQ',
#  'UCclOXwNyro8A6Ui5HzJznAQ',
#  'UCNwVB9QLZrz6OG2KwnSUr5g',
#  'UC4ZT3GHbMEPpRDxOilvwqiA',
#  'UCFnwLmtfkcxu3KXlTFzmDmQ',
#  'UCzRwHyEASw2CpHUyzsdZw0w',
#  'UCztU0GS4Jy7LdpC-YePln1w',
#  'UChTF7aaYs3yWPP2EiPKFe3g',
#  'UCez276pKwOBJuJ9YH2rrZHQ',
#  'UCIhq-_mToATJEGgmjX_h_iw',
#  'UCH7S_RKYpeuFeZ0zXRBPQOA',
#  'UCWEVzUvK-FA6NgrxSGgfsWg',
#  'UCf02efJDihBWebUdbTLUHcA',
#  'UCijFQOxGBL5ArAGED9bnLYw',
#  'UC0NbupreWRjQckzhzGQuQFw',
#  'UChbvadho0FArDQEhY9TgR2A',
#  'UC5T_JPXGlLPuadQwtDH0Y5A',
#  'UCxym37JllmfnN4E1NpDQBTA',
#  'UC1x0n51JOKEaNTxPuJ2wzGg',
#  'UCRF14AVoshNI5vJ5kqK4VkA',
#  'UCt7FJ9EjEJnY_hBoRqek8RA',
#  'UCzK6Xs7teuc_QjUV-1KE1iw',
#  'UCqwremnDx0Au6e8OvRM8z5A',
#  'UCXhwYs0JGszof-FmUzGeRww',
#  'UC5iqZq0GHJeUmgfpBtJzq-w',
#  'UCK9UMlIN1RFIlOSjxpfQ7XQ',
#  'UCJRDqIkXkNmXZ8bp9rFiWsg',
#  'UCmb-mowaqFqmbl04ygRhigw',
#  'UC4i9V7o_k0tD2ayETUC6zdw',
#  'UChoxdQArqXIejrbvATE-_oA',
#  'UCmyNNBBbcMUNITQVhXCdDOQ',
#  'UCV3q_o0zZ9GX6QooFTZMAJw',
#  'UCqfcEwucc6EewC9UIM8M-fA',
#  'UCJ_FhFNlmNj156VurjMZrWw',
#  'UCVYM_RipPHHNnUliLgqARtw',
#  'UCuot9AXZqoFv-OaNCwaNh9A',
#  'UCvVVGkq3TTfZcD1-FyBShIw',
#  'UCJg_CniYH3_XVwt9jMh9RyQ',
#  'UC7lVauap8KyzBsq4nXQr4JQ',
#  'UCuy7fbV3zpUrw1-CtwPVV7w',
#  'UCdZx96CpHUfrVJOetpz62Sg',
#  'UCiVhaSAIZvXstxiOajHrFig',
#  'UCdBdg8ltKyDJDy-Fj22iW0w',
#  'UC-FqkTZQ8SoosPpirvDPd0A',
#  'UCd3jdEjo6FMU9-o0dPQ96dQ',
#  'UCsoO0kEfnXB5Rie4pEf9SJg',
#  'UC_-T0IRCLVs5sS8ciO01M7w',
#  'UCwrAkkwa_nq1wMiM1LbhVZQ',
#  'UCPuaTRky57y4UNJlqYzGpsA',
#  'UCrSHKq10mekkZYIYzGkRC_Q',
#  'UCxZpAa7m495x87fsNK56-Lw',
#  'UCYdS8rPxYCSKMrHFqPe6b0A',
#  'UCYLbkqI8In1ozEYSUwT_LjA',
#  'UCidUO-9DB55wDMPQu3cwaxQ',
#  'UC1FYQMvzb-hmucx-NwDjcZA',
#  'UCL291suGHZaXCOcBg8Vuetg',
#  'UC3pXsecwpVaiCNKZAe9AI2Q',
#  'UCIm0RErEhdj05s81S1JIDKw',
#  'UClbCfuST30xhhrbxLt9r0rw',
#  'UCngQdqLEWKWMTZ_3xSurc9A',
#  'UC6IAMoId2DWh1l1fjGWS1Eg',
#  'UCWajdbphnPX9oMRvDJ_bTdg',
#  'UCZMSYfdruPq7Y-WdJc69TQA',
#  'UCou07MCVtYIY-XIOujy4eng',
#  'UCPSK8WRGnSdoKqki8cjLdyg',
#  'UCPSK8WRGnSdoKqki8cjLdyg',
#  'UC4QD-xW6jfLxk9kjF9x0Lcg',
#  'UCdzDdoJtdVLm0f5RX4fR4EQ',
#  'UC11wlX-7CyY28nSDcEOFqSQ',
#  'UCn0hJeDaFa2UFLFuMj8vuug',
#  'UCmOIu_04W8Qwwyj7WyZDa0g',
#  'UCrGdWbegbvXwdsRnDUxao4A',
#  'UCjmBYSHDk4dCWbNNdw4rxEQ',
#  'UClcOWwdziMcX7H0cf-mG-Ew',
#  'UCv4CxG4hpS3pHtq4CRCVDDA',
#  'UCvC4R3hd3Cm931cVZBCwHsA',
#  'UCha14WkljPDCwMpoRde_qaA',
#  'UCgI083t4BZ34gTyVnd4Qgag',
#  'UCAbowhU2cDHkQR70YiHpoEA',
#  'UCNyw2n_5Jai7AuSflSfIpvQ',
#  'UCIGA0H6nBdNGs8zT4u6OumQ',
#  'UCc64rWIGUNWVi1DfiEjZHeg',
#  'UCjpaL3i3O7YKvxRWuGqE10A',
#  'UCciocRmd6iqU1AAzYYkDCDw',
#  'UCd3WGFMs-1nyVA_Xb8ZM0xw',
#  'UCrZGkJzo3F1KsAYQx9PxTFw',
#  'UCyq9cHlsvX2rQMSvBbJbeHg',
#  'UCmcCa45m9AoydqXfS7SGNog',
#  'UCAIaK1UIdkPmJfv5yfefMOg',
#  'UCnbUoBBVoi2XZM0wJD2D4oA',
#  'UCwfFOB5SmT1w98vKqkbDRzg',
#  'UCJTmnL5wp3CYSHqjkc4gOKw',
#  'UCK_bxGROH0OTkMLTp7M8TEg',
#  'UCVUKGSDrmmDUrlz_PdkQvig',
#  'UCekeS1n0b0ohJ5HPUO8Ri9A',
#  'UCzFa5BeXGOz0yWaesxu1blg',
#  'UC9WIWZmLlBCDC43dGBFW79Q',
#  'UCdowZUaGNh2Auy_6_x7vbCA',
#  'UCnn5rgjnb0H8HBkC90TGkUA',
#  'UCJ07fdpcGwgqd8Spn_ueb0Q',
#  'UCiKcI1R5RwZytwHZb4VoyOg',
#  'UCbqHCmQM-wnLDAwOe9blUjw',
#  'UC_-0tcJisZpMAeZH9L5wNWA',
#  'UCIJSixKCjjc1lAR8jQHNCGA',
#  'UC7G-GS95_GIdLtm1QOAQQWg',
#  'UC_tFl_shnomP99JBHAKh4kg',
#  'UCEKqQBmlkz1qDj3tosfd9pg',
#  'UCiJ9NygqhwQRdlnSgGCsChQ',
#  'UCWvXedpf0RxHsu-f2XqH2Cg',
#  'UCibne71VF2SGKr2sO7JgEMA',
#  'UCnRebxgB83Qp6h7wrhsCYkQ',
#  'UCdb52WvaaQVhQR4bDi6Rcrg',
#  'UCpCP2JvcDcrB_pbPkLL7F-Q',
#  'UCj5dOEFheI1OCqAioaGNG1Q',
#  'UCueoutXmhTrWhZrIxueLVBw',
#  'UCoxKTqRBGoomFqikYGY1WaA',
#  'UCPBQjtpmzqjrZrQqjQqUK0g',
#  'UCCSOvhjltJknNn5Hgibjzzw',
#  'UCWRHj8hF1S36h9FQ3ylO8jQ',
#  'UCeOpQiJe0LbkUaeeZuLPRoA',
#  'UCZtm6CNHtkxdl508i2I1u3Q',
#  'UCLBL7p9WBdAMNWsSNOMVAeA',
#  'UC4u6D2wgog2AVbBHwm8d-VQ',
#  'UCnEfofhyOAAf6FfM8g4lkrQ',
#  'UCtQ4lrcXJPx-TAPbnhNWazg',
#  'UCtsHDuT7k0K4Fu00seL7OCA',
#  'UCBplWYIO4qzxbuMhuIauR0A',
#  'UC8VehkOZan1p9i_ywu40QrA',
#  'UCAz8zU59pTh21z62Fp6RoCQ',
#  'UC50qVijm17wrGTgcz8v7saA',
#  'UCxb59TOxxuMTKlmNRWBefjA',
#  'UCq9zRGyyTFHUjkoUdEM3RGw',
#  'UCRPLI9x6-t9N5_sHSIL6uTg',
#  'UCjCJ_aHX1Meoi7gFTbVxIjQ',
#  'UCPVeCGygtPHca4zyPBfvCzg',
#  'UCKgiX-ApJP0Ef52HvZ2Xf1g',
#  'UC5fqJxENKTssbuq97LGqJ8g',
#  'UCkbIpCnF3IVb3ngsB8NwRKQ',
#  'UCrr8uazWJ9IiPPMtTqtPhlQ',
#  'UCOzn8tU-TEOzrs35o2nnqMw',
#  'UC67G7cU92It1SXzGoi4A2eA',
#  'UCYalWIgOmMVdrYnm6M7Rsew',
#  'UCy0idQIonIH5W1VqgQ1tdJg',
#  'UCMOYu_aS4FMQaRUA_2Vkq8A',
#  'UC-ASaovaGGEkaD7k8CpQMSQ',
#  'UCXUyHdxqOWGhE4fuKXeNoTg',
#  'UCRnNNkQ9sB9Ml1LpCAiqJug',
#  'UCunuFRUxhcLRYqI_46RCI-A',
#  'UCb0fpZX8t7to5L18jUtiDfw',
#  'UC3RKE-JgDzrqDmdKE6VC0MQ',
#  'UC7bl8xvg5O-NOGt-lIO2fsA',
#  'UCXRwlOOhXU3IA4_tATaUPSA',
#  'UCmDQTM4YPEtcUbfZ3WsYfzQ',
#  'UCXRwlOOhXU3IA4_tATaUPSA',
#  'UCwPv1YlC5tro2Ju5LGeE6ag',
#  'UCG1FDrJW4qI2D3GH6nnAUfw',
#  'UCiUr4KXkkKUmuWm2xSjdQew',
#  'UCyWplpfqdzcEPrii4wi2tsQ',
#  'UCZECU_7utQoTkpmh8w89tnA',
#  'UCD2MSgXp1IQDjyAtIaJoMiA',
#  'UCOPKbYX3YvsQ0i2Y1w9DL3g',
#  'UCbJuqRT-w9CdyKvBaYQh9AA',
#  'UCmJ72l8xgfThUIa-NcaGQFQ',
#  'UCVphGXPTWgBnH03YyVcBq9A',
#  'UC6qQYRYFO8hbHPRkcwoPS4A',
#  'UCzx7xlpd7SWcrHKoCs1ZkZw',
#  'UCWiM8PymUtDg9Td4ZdyFQXw',
#  'UCg8SAFkB7yBOr1kcchCEvgQ']

# %%
"""     """
