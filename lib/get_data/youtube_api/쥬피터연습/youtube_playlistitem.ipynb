# %% [markdown]
# 대도서관 live 플레이리스트 : PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8

# %%
import requests, json
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8"
page_token = "CLwFEAA"

target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, page_token, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/k4aFq0Ze7nPTnL9WggpAEAyLYfk"',
#  'prevPageToken': 'CLwFEAE',
#  'pageInfo': {'totalResults': 719, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/C2QpMhjQ45fYufgiTrjLtRewvMo"',
#    'id': 'UEx5T0o1Wk5JbC16Q2s5cW9wWERkQ2RPWTdXNnZFcWtqOC45RTgxNDRBMzUwRjQ0MDhC',
#    'snippet': {'publishedAt': '2016-11-03T01:46:45.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 LIVE]  걸그룹 만들기 게임 / 아이돌 마스터 / 게임 방송 11/1(화) Game (buzzbean11)',
#     'description': '* 대도서관의 유튜브 라이브 실시간 스트리밍 방송 / 공포게임, 병맛게임, PS VR, 오버워치, 마인크래프트 등 다양한 게임을 실시간 방송으로 만나보세요! 게임 방송 문명6 먹방 아이마스',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1kfaNcEDlwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
def playlistitem(api_key, playlist_id):
    '''
    # !! 이 함수는 재생목록에 있는 동영상 정보를 리턴합니다. !!
    제공하는 정보 : 재생목록 안에 있는 동영상의 '고유 ID·제목·업로드 날짜·동영상 설명', 재생목록 안에 있는 동영상 수
    
    '''
    api_key = api_key
    playlist_id = param
    page_token = ""
    
    target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, 
                                                                                                                                           page_token, api_key)

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
        
    total_results = api_dict['pageInfo']['totalResults']
    results_per_page = api_dict['pageInfo']['resultsPerPage']

    exe_set = round(total_results / results_per_page +0.5)
    infomation = {}

    published_date = api_dict["items"][0]["snippet"]["publishedAt"]
    video_title = api_dict["items"][0]["snippet"]["title"]
    video_description = api_dict["items"][0]["snippet"]["description"]
    
    if exe_set == 0:
        return print("표시할 내용이 없음")
        
    else:
        for total_set in range(exe_set):
            
                print(total_set, exe_set)
                target_url = "https://www.googleapis.com/youtube/v3/playlistItems?part=snippet&playlistId={}&pageToken={}&maxResults=50&key={}".format(param, page_token, api_key)
                session = requests.Session ()
                headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                html = requests.get (target_url)
                soup = BeautifulSoup (html.text, "html.parser" )
                api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                
                
                if "nextPageToken" in api_dict:
                    page_token = api_dict["nextPageToken"]
                    print(api_dict["nextPageToken"])
            
                
                if total_set < (exe_set-1):
                        for result_count in range(results_per_page):
                            
                            video_id = api_dict["items"][result_count]["snippet"]["resourceId"]["videoId"]
                            published_date = api_dict["items"][result_count]["snippet"]["publishedAt"]
                            video_title = api_dict["items"][result_count]["snippet"]["title"]
                            video_description = api_dict["items"][result_count]["snippet"]["description"]
                            
                            infomation[video_id] = []
                            infomation[video_id].append(video_title)
                            infomation[video_id].append(published_date)
                            infomation[video_id].append(video_description)
                            
                            
                            
                else:
                        for last_page in range(total_results % results_per_page):
                            video_id = api_dict["items"][last_page]["snippet"]["resourceId"]["videoId"]
                            published_date = api_dict["items"][last_page]["snippet"]["publishedAt"]
                            video_title = api_dict["items"][last_page]["snippet"]["title"]
                            video_description = api_dict["items"][last_page]["snippet"]["description"]
                            
                            infomation[video_id] = []
                            infomation[video_id].append(video_title)
                            infomation[video_id].append(published_date)
                            infomation[video_id].append(video_description)
                            
                            
                            

        return infomation
    
playlistitem("AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak","PLyOJ5ZNIl-zCk9qopXDdCdOY7W6vEqkj8" )
# Out:
# 0 15
# CDIQAA
# 1 15
# CGQQAA
# 2 15
# CJYBEAA
# 3 15
# CMgBEAA
# 4 15
# CPoBEAA
# 5 15
# CKwCEAA
# 6 15
# CN4CEAA
# 7 15
# CJADEAA
# 8 15
# CMIDEAA
# 9 15
# CPQDEAA
# 10 15
# CKYEEAA
# 11 15
# CNgEEAA
# 12 15
# CIoFEAA
# 13 15
# CLwFEAA
# 14 15
# {'Edp_hHy5F2A': ['대도 생방송] 게임 방송입니닷! 12/19(수) 하핫! 대도서관 Game Live Show',
#   '2018-12-19T18:22:24.000Z',
#   '* 좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷!\n* 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!\n\n* 랜선라이프, 공포 게임, 병맛 게임, 게임 방송, game cast, 홈 스위트 홈, Home Sweet Home, 호러 게임, 이블위딘2, 대도서관, 대도님, buzzbean, greatlibrary, The evil within 2, steam, 스팀 게임, 강추 게임, Getting over it, 항아리 게임, 슈퍼마리오 오디세이, 닌텐도 스위치, ps4, KIDS, 키즈, monster hunter world, 디트로이트 비컴 휴먼, KPOP, 강아지, 단꼬, 꼬똥 드 툴레아, 델타룬'],
#  'hot9g_cG51Y': ['대도 생방송] 파키텍트 (4일차) - 디자인 굿! 흑자 굿! 핑크랜드! 12/19(수) 하핫! 대도서관 Game Live Show',
#   '2018-12-19T15:03:45.000Z',
# ...

# %%
x = {}
x[1] = []

# %%
results_per_page = api_dict['pageInfo']['resultsPerPage']
results_per_page
# Out:
# 50

# %%
len(api_dict["items"])
# Out:
# 17

# %%
import requests, json
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "UCLJi9Vk8_y3y_evAahQUEpQ"

target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&type=video&maxResults=50&key={}".format(param, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/0Ps4_c5rARsc5wi3_0sEZVqI3q4"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 401, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/xu-wybRHre0slaYoLOeRuvzcwSE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'wFvBMw2z0LY'},
#    'snippet': {'publishedAt': '2015-09-09T05:47:09.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '이노아🌹 모노노케 히메 - 아시타카의 전설 (Legend of Ashitaka)',
#     'description': '지브리 애니메이션 "모노노케 히메" 메인타이틀 "아시타카의 전설" ジブリ「もののけ姫」よりメインテーマ「アシタカせっき」',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wFvBMw2z0LY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wFvBMw2z0LY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "UCLJi9Vk8_y3y_evAahQUEpQ"

target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&eventType=completed&type=video&maxResults=50&key={}".format(param, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/osXLeCHcuL0q2Eqx12yTeCBt0aU"',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 33, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/fmZIYITJgczb-_cYb4QTWGLoMLo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'coQBEcD6QDs'},
#    'snippet': {'publishedAt': '2018-04-02T17:18:11.000Z',
#     'channelId': 'UCLJi9Vk8_y3y_evAahQUEpQ',
#     'title': '(LIVE)이노아🌹 사정이있어서 쌩얼입니다',
#     'description': '이노아 생방송중! :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/coQBEcD6QDs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'INOA이노아',
# ...

# %%
api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "DudQ_m-ZtdA"

target_url = "https://www.googleapis.com/youtube/v3/liveChat/messages?liveChatId={}&part=authorDetails&maxResults=2000&key={}".format(param, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'error': {'errors': [{'domain': 'youtube.liveChat',
#     'reason': 'liveChatNotFound',
#     'message': 'The live chat that you are trying to retrieve cannot be found. Check the value of the requests <code>liveChatId</code> parameter to ensure that it is correct.'}],
#   'code': 404,
#   'message': 'The live chat that you are trying to retrieve cannot be found. Check the value of the requests <code>liveChatId</code> parameter to ensure that it is correct.'}}

# %%
api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = "coQBEcD6QDs"

target_url = "https://www.googleapis.com/youtube/v3/liveBroadcasts?part=snippet&ibroadcastStatus=all&id={}&maxResults=50&key={}".format(param, api_key)

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

# 우선 동영상 페이지에 requests를 실행 html 소스를 손에 넣어 live_chat_replay의 선두 url을 입수
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'error': {'errors': [{'domain': 'global',
#     'reason': 'required',
#     'message': 'Login Required',
#     'locationType': 'header',
#     'location': 'Authorization'}],
#   'code': 401,
#   'message': 'Login Required'}}

# %%
# Out:
# {'2', '4', '5'}

# %%
# Out:
# ['1', '4', '2', '3', '5']
