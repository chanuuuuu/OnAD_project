# %%
def get_video_id(channel_url, api_key="AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY"):
    '''
    channel_url : 유튜버 채널의 고유 채널 ID ("https://www.youtube.com/channel/~" 또는 "https://www.youtube.com/user/~" )
    api_key : 자신의 API키   
        
    return => 채널 고유 ID(str), 일반 동영상 고유 ID(list), 라이브 동영상 고유 ID(list)
    '''
    
    import requests
    from bs4 import BeautifulSoup 

    
    
    if "channel" in channel_url:  
        
        api_key = api_key
        channel_id = channel_url.split("/")[-1]
        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)
        
        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일반 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return channel_id, video_ids, live_video_ids
    
    
    elif "user" in channel_url:
        api_key = api_key

        channel_id = user_to_channelid(channel_url.split("/")[-1], api_key)

        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일단 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

                        
        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)
                                
                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        video_ids = list(set(video_ids) - set(live_video_ids))
        
        return channel_id, video_ids, live_video_ids

# %%
def user_to_channelid(user_name, api_key="AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY"):

    import requests
    from bs4 import BeautifulSoup 

    api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]
    print(channel_id)
    
    return channel_id

# %%
a,video_ids,c = get_video_id("https://www.youtube.com/channel/UCTWfu-AgYYNctOuhTZI8dsg","AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak" )
# Out:
# 라이브 동영상 없음

# %%
video_ids
# Out:
# ['B91H0KtuCjI',
#  'pB1Nolfz-2M',
#  'Myrdk2KZqu4',
#  'g7XLNIZfFOQ',
#  'rWzbHC-0OfM',
#  '7tjQJ5v4keA',
#  '4hW1hpDXSxw']

# %%
AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY

# %%
def get_video_info(video_id, api_key="AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"):
    '''
    video_id_list : 비디오 고유 ID(str) ,api_key : api 키값(str)
    
    return =>  동영상 정보 (list)
               [동영상 제목(str), 동영상 설명(str), 동영상 게시 일자(str,YYMMDD),
               동영상 태그(str), 동영상 카테고리와 분류 번호(str), 동영상 썸네일 주소(str),
               조회수(int), 좋아요 수(int), 싫어요 수(int), 즐겨찾기 수(int), 댓글 수(int)]
    '''
    
    import requests
    from bs4 import BeautifulSoup 

    categories = {'1': '영화/애니메이션', '2': '자동차', '10': '음악', '15': '동물', '17': '스포츠', '18': '단편 영화', '19': '여행/이벤트',
     '20': '게임', '21': '동영상 블로그', '22': '인물/블로그', '23': '코미디', '24': '엔터테인먼트', '25': '뉴스/정치', '26': '노하우/스타일',
     '27': '교육', '28': '과학기술', '30': '영화', '31': '애니메/애니메이션', '32': '액션/모험', '33': '고전', '34': '코미디', '35': '다큐멘터리',
     '36': '드라마', '37': '가족', '38': '외국', '39': '공포', '40': '공상과학/판타지', '41': '스릴러', '42': '단편', '43': '프로그램','44': '예고편'}
    
    video_id = video_id
    api_key = api_key
    param = ["snippet", "statistics"]
    video_info = []

    for part in param:    
            target_url = '''https://www.googleapis.com/youtube/v3/videos?part={}&id={}&key={}'''.format(part, video_id, api_key) 
            session = requests.Session ()
            headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
            html = requests.get (target_url)
            soup = BeautifulSoup (html.text, "html.parser" )
            api_dict = eval(soup.text.replace("false","False").replace("true","True"))

            print(api_dict)
            if part == "snippet":
                video_info.append(video_id)
                video_info.append(api_dict["items"][0]["snippet"]["title"])  # 동영상 제목
                video_info.append(api_dict["items"][0]["snippet"]["description"].replace("\n"," "))  # 동영상 설명
                video_info.append(api_dict["items"][0]["snippet"]['publishedAt'][2:10].replace("-","")) # 동영상 게시 일자
                video_info.append(api_dict["items"][0]["snippet"]['tags'])  # 동영상 태그
                video_info.append(categories[api_dict["items"][0]["snippet"]["categoryId"]] + "(" + api_dict["items"][0]["snippet"]["categoryId"] + ")")  # 동영상 카테고리
                video_info.append(api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url'])  # 동영상 썸네일 주소

            else:
                video_info.append(api_dict["items"][0]["statistics"]['viewCount'])  # 조회수
                video_info.append(api_dict["items"][0]["statistics"]["likeCount"])  # 좋아요 수
                video_info.append(api_dict["items"][0]["statistics"]["dislikeCount"])  # 싫어요 수
                video_info.append(api_dict["items"][0]["statistics"]["favoriteCount"])  # 즐겨찾기 (나중에 볼 영상) 수
                video_info.append(api_dict["items"][0]["statistics"]["commentCount"]) # 댓글 수
            
    return video_info

# %%
samp = get_video_info("g7XLNIZfFOQ")
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/MtHFMVmrxV9iguNPtNkAugCSfJ4"', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#video', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Dj-21A2FPfHpHkKBksf2cms53WI"', 'id': 'g7XLNIZfFOQ', 'snippet': {'publishedAt': '2018-11-19T13:07:28.000Z', 'channelId': 'UCTWfu-AgYYNctOuhTZI8dsg', 'title': '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠', 'description': "치치 브이로그 CHICHILOG #2\n~ 오늘은 힐링영상입니당.\n\n\n하하..또 오랜만입니다 여러분 :-)\n지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요.\n소소하지만. 찍은 영상을 다시 확인하니,\n치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ\n여러분에게 저의 소중한 치치의 자는 모습을 공개할게요.\n헤헤. 모두 힐링시간이 되었으면 해요~\n\n🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서\n '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!\n\n\n🎧  노래정보(Music info)\n * Old bossa\n * Fortaleza\n\n\n\n-\n@ Film by Haejin\n@ Edit of film by Namgyeong & Haejin", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': '해진의 심취존', 'tags': ['치치', 'CHICHI', '브이로그', 'VLOG', '집냥이', '개냥이', '고양이', '집사', '반려묘', '반려동물'], 'categoryId': '19', 'liveBroadcastContent': 'none', 'localized': {'title': '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠', 'description': "치치 브이로그 CHICHILOG #2\n~ 오늘은 힐링영상입니당.\n\n\n하하..또 오랜만입니다 여러분 :-)\n지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요.\n소소하지만. 찍은 영상을 다시 확인하니,\n치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ\n여러분에게 저의 소중한 치치의 자는 모습을 공개할게요.\n헤헤. 모두 힐링시간이 되었으면 해요~\n\n🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서\n '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!\n\n\n🎧  노래정보(Music info)\n * Old bossa\n * Fortaleza\n\n\n\n-\n@ Film by Haejin\n@ Edit of film by Namgyeong & Haejin"}}}]}
# {'kind': 'youtube#videoListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/apaRjUgqIv8E02rpSV4kk98oTug"', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#video', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/f4uj2lCYJQ-f8PD15xdLYNEKc9Y"', 'id': 'g7XLNIZfFOQ', 'statistics': {'viewCount': '79', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '3'}}]}

# %%
samp
# Out:
# ['g7XLNIZfFOQ',
#  '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠',
#  "치치 브이로그 CHICHILOG #2 ~ 오늘은 힐링영상입니당.   하하..또 오랜만입니다 여러분 :-) 지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요. 소소하지만. 찍은 영상을 다시 확인하니, 치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ 여러분에게 저의 소중한 치치의 자는 모습을 공개할게요. 헤헤. 모두 힐링시간이 되었으면 해요~  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#  '181119',
#  ['치치', 'CHICHI', '브이로그', 'VLOG', '집냥이', '개냥이', '고양이', '집사', '반려묘', '반려동물'],
#  '여행/이벤트(19)',
#  'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg',
#  '79',
#  '12',
#  '0',
#  '0',
#  '3']

# %%
import requests
from bs4 import BeautifulSoup 

categories = {'1': '영화/애니메이션', '2': '자동차', '10': '음악', '15': '동물', '17': '스포츠', '18': '단편 영화', '19': '여행/이벤트',
 '20': '게임', '21': '동영상 블로그', '22': '인물/블로그', '23': '코미디', '24': '엔터테인먼트', '25': '뉴스/정치', '26': '노하우/스타일',
 '27': '교육', '28': '과학기술', '30': '영화', '31': '애니메/애니메이션', '32': '액션/모험', '33': '고전', '34': '코미디', '35': '다큐멘터리',
 '36': '드라마', '37': '가족', '38': '외국', '39': '공포', '40': '공상과학/판타지', '41': '스릴러', '42': '단편', '43': '프로그램','44': '예고편'}

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = ["snippet"]
video_info = []
video = "g7XLNIZfFOQ"
info = []
info.append(video)
for part in param:    
        target_url = '''https://www.googleapis.com/youtube/v3/videos?part={}&id={}&key={}'''.format(part, video, api_key) 
        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )
        api_dict = eval(soup.text.replace("false","False").replace("true","True"))



        if part == "snippet":
            info.append(api_dict["items"][0]["snippet"]["title"])  # 동영상 제목
            info.append(api_dict["items"][0]["snippet"]["description"].replace("\n"," "))  # 동영상 설명

            info.append(api_dict["items"][0]["snippet"]['tags'])  # 동영상 태그
            info.append(categories[api_dict["items"][0]["snippet"]["categoryId"]] + "(" + api_dict["items"][0]["snippet"]["categoryId"] + ")")  # 동영상 카테고리
            info.append(api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url'])  # 동영상 썸네일 주소

        else:
            info.append(api_dict["items"][0]["statistics"]['viewCount'])  # 조회수
            info.append(api_dict["items"][0]["statistics"]["likeCount"])  # 좋아요 수
            info.append(api_dict["items"][0]["statistics"]["dislikeCount"])  # 싫어요 수
            info.append(api_dict["items"][0]["statistics"]["favoriteCount"])  # 즐겨찾기 (나중에 볼 영상) 수
            info.append(api_dict["items"][0]["statistics"]["commentCount"]) # 댓글 수

        video_info.append(info)

print(video_info)
# Out:
# [['g7XLNIZfFOQ', '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠', "치치 브이로그 CHICHILOG #2 ~ 오늘은 힐링영상입니당.   하하..또 오랜만입니다 여러분 :-) 지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요. 소소하지만. 찍은 영상을 다시 확인하니, 치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ 여러분에게 저의 소중한 치치의 자는 모습을 공개할게요. 헤헤. 모두 힐링시간이 되었으면 해요~  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin", ['치치', 'CHICHI', '브이로그', 'VLOG', '집냥이', '개냥이', '고양이', '집사', '반려묘', '반려동물'], '여행/이벤트(19)', 'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg']]

# %%
api_dict["items"][0]["snippet"]
# Out:
# {'publishedAt': '2018-11-19T13:07:28.000Z',
#  'channelId': 'UCTWfu-AgYYNctOuhTZI8dsg',
#  'title': '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠',
#  'description': "치치 브이로그 CHICHILOG #2\n~ 오늘은 힐링영상입니당.\n\n\n하하..또 오랜만입니다 여러분 :-)\n지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요.\n소소하지만. 찍은 영상을 다시 확인하니,\n치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ\n여러분에게 저의 소중한 치치의 자는 모습을 공개할게요.\n헤헤. 모두 힐링시간이 되었으면 해요~\n\n🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서\n '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!\n\n\n🎧  노래정보(Music info)\n * Old bossa\n * Fortaleza\n\n\n\n-\n@ Film by Haejin\n@ Edit of film by Namgyeong & Haejin",
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/g7XLNIZfFOQ/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'channelTitle': '해진의 심취존',
#  'tags': ['치치',
#   'CHICHI',
#   '브이로그',
#   'VLOG',
#   '집냥이',
#   '개냥이',
#   '고양이',
#   '집사',
#   '반려묘',
#   '반려동물'],
#  'categoryId': '19',
#  'liveBroadcastContent': 'none',
#  'localized': {'title': '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠',
#   'description': "치치 브이로그 CHICHILOG #2\n~ 오늘은 힐링영상입니당.\n\n\n하하..또 오랜만입니다 여러분 :-)\n지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요.\n소소하지만. 찍은 영상을 다시 확인하니,\n치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ\n여러분에게 저의 소중한 치치의 자는 모습을 공개할게요.\n헤헤. 모두 힐링시간이 되었으면 해요~\n\n🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서\n '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!\n\n\n🎧  노래정보(Music info)\n * Old bossa\n * Fortaleza\n\n\n\n-\n@ Film by Haejin\n@ Edit of film by Namgyeong & Haejin"}}

# %%
api_dict["items"][0]["snippet"]["title"]  # 동영상 제목
api_dict["items"][0]["snippet"]["description"]  # 동영상 설명
api_dict["items"][0]["snippet"]['tags']  # 동영상 태그
api_dict["items"][0]["snippet"]["categoryId"]  # 동영상 카테고리
api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url']  # 동영상 썸네일 주소


api_dict["items"][0]["statistics"]['viewCount']  # 조회수
api_dict["items"][0]["statistics"]["likeCount"]  # 좋아요 수
api_dict["items"][0]["statistics"]["dislikeCount"]  # 싫어요 수
api_dict["items"][0]["statistics"]["favoriteCount"]  # 즐겨찾기 (나중에 볼 영상) 수
api_dict["items"][0]["statistics"]["commentCount"] # 댓글 수
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-04640f6bfd69> in <module>()
# ----> 1 api_dict["items"][0]["snippet"]["title"]  # 동영상 제목
#       2 api_dict["items"][0]["snippet"]["description"]  # 동영상 설명
#       3 api_dict["items"][0]["snippet"]['tags']  # 동영상 태그
#       4 api_dict["items"][0]["snippet"]["categoryId"]  # 동영상 카테고리
#       5 api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url']  # 동영상 썸네일 주소
#
# KeyError: 'snippet'

# %%
import requests
from bs4 import BeautifulSoup 

categories = {'1': '영화/애니메이션', '2': '자동차', '10': '음악', '15': '동물', '17': '스포츠', '18': '단편 영화', '19': '여행/이벤트',
 '20': '게임', '21': '동영상 블로그', '22': '인물/블로그', '23': '코미디', '24': '엔터테인먼트', '25': '뉴스/정치', '26': '노하우/스타일',
 '27': '교육', '28': '과학기술', '30': '영화', '31': '애니메/애니메이션', '32': '액션/모험', '33': '고전', '34': '코미디', '35': '다큐멘터리',
 '36': '드라마', '37': '가족', '38': '외국', '39': '공포', '40': '공상과학/판타지', '41': '스릴러', '42': '단편', '43': '프로그램','44': '예고편'}

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
video = "B91H0KtuCjI"
param = ["snippet", "statistics"]


target_url = '''https://www.googleapis.com/youtube/v3/videos?part=snippet&id={}&key={}'''.format(video, api_key) 
session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )
api_dict = eval(soup.text.replace("false","False").replace("true","True"))


api_dict["items"][0]["snippet"]['publishedAt'][2:10].replace("-","")
# Out:
# '180928'
