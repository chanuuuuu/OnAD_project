# %%
def get_video_id(channel_url, api_key="AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY"):
    '''
    channel_url : 유튜버 채널의 고유 채널 ID ("https://www.youtube.com/channel/~" 또는 "https://www.youtube.com/user/~" )
    api_key : 자신의 API키   
        
    return => 채널 고유 ID(str), 일반 동영상 고유 ID(list), 라이브 동영상 고유 ID(list)
    '''
    
    import requests
    from bs4 import BeautifulSoup 

    
    
    if "channel" in channel_url:  
        
        api_key = api_key
        channel_id = channel_url.split("/")[-1]
        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)
        
        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일반 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return channel_id, video_ids, live_video_ids
    
    
    elif "user" in channel_url:
        api_key = api_key

        channel_id = user_to_channelid(channel_url.split("/")[-1], api_key)

        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일단 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

                        
        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)
                                
                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        video_ids = list(set(video_ids) - set(live_video_ids))
        
        return channel_id, video_ids, live_video_ids

# %%
def user_to_channelid(user_name, api_key="AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY"):

    import requests
    from bs4 import BeautifulSoup 

    api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]
    print(channel_id)
    
    return channel_id

# %%
a,video_ids,c = get_video_id("https://www.youtube.com/channel/UCTWfu-AgYYNctOuhTZI8dsg","AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak" )
# Out:
# 라이브 동영상 없음

# %%
video_ids
# Out:
# ['B91H0KtuCjI',
#  'pB1Nolfz-2M',
#  'Myrdk2KZqu4',
#  'g7XLNIZfFOQ',
#  'rWzbHC-0OfM',
#  '7tjQJ5v4keA',
#  '4hW1hpDXSxw']

# %%
AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY

# %%
import requests
from bs4 import BeautifulSoup 

categories = {'1': '영화/애니메이션', '2': '자동차', '10': '음악', '15': '동물', '17': '스포츠', '18': '단편 영화', '19': '여행/이벤트',
 '20': '게임', '21': '동영상 블로그', '22': '인물/블로그', '23': '코미디', '24': '엔터테인먼트', '25': '뉴스/정치', '26': '노하우/스타일',
 '27': '교육', '28': '과학기술', '30': '영화', '31': '애니메/애니메이션', '32': '액션/모험', '33': '고전', '34': '코미디', '35': '다큐멘터리',
 '36': '드라마', '37': '가족', '38': '외국', '39': '공포', '40': '공상과학/판타지', '41': '스릴러', '42': '단편', '43': '프로그램','44': '예고편'}

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
param = ["snippet", "statistics"]
video_info = []

for video in video_ids:
    info = []
    info.append(video)
    for part in param:    
            target_url = '''https://www.googleapis.com/youtube/v3/videos?part={}&id={}&key={}'''.format(part, video, api_key) 
            session = requests.Session ()
            headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
            html = requests.get (target_url)
            soup = BeautifulSoup (html.text, "html.parser" )
            api_dict = eval(soup.text.replace("false","False").replace("true","True"))
            
            

            if part == "snippet":
                info.append(api_dict["items"][0]["snippet"]["title"])  # 동영상 제목
                info.append(api_dict["items"][0]["snippet"]["description"].replace("\n"," "))  # 동영상 설명
                info.append(api_dict["items"][0]["snippet"]['tags'])  # 동영상 태그
                info.append(categories[api_dict["items"][0]["snippet"]["categoryId"]])  # 동영상 카테고리
                info.append(api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url'])  # 동영상 썸네일 주소
                
            else:
                info.append(api_dict["items"][0]["statistics"]['viewCount'])  # 조회수
                info.append(api_dict["items"][0]["statistics"]["likeCount"])  # 좋아요 수
                info.append(api_dict["items"][0]["statistics"]["dislikeCount"])  # 싫어요 수
                info.append(api_dict["items"][0]["statistics"]["favoriteCount"])  # 즐겨찾기 (나중에 볼 영상) 수
                info.append(api_dict["items"][0]["statistics"]["commentCount"]) # 댓글 수
                
            video_info.append(info)

print(video_info)
# Out:
# [['B91H0KtuCjI', '대학원생브이로그(Graduate student vlog) #1 ⋅  학회에 다녀오다!', '저는 사실 박사과정의 대학원생입니다. ㅎㅎ 오늘은 9월에 다녀왔던 학회 브이로그에요. 부담이 덜한 소규모의 워크샵이여서 마음 편히 다녀왔어요! 매년 오크밸리에 가고 있는데, 너무 공기도 좋고 놀기도 좋아요! 항상 힐링하는 기분~. 가족 여행으로 꼭 추천하고 싶은 곳입니다. (뮤지엄 산도 꼭 들러보세요!)  요즘 너무 바쁜데 영상 다시 보니까 기분이 좋네요 ㅎ_ㅎ  그리고 영상에서 소개해드린 치치가 먹는 사료는 네이처스 로직 캣 치킨 입니다. (https://smartstore.naver.com/allkillpet/products/2361070627?NaPm=ct%3Djmrr0eoa%7Cci%3Dcheckout%7Ctr%3Dppc%7Ctrx%3D%7Chk%3D608a5cb53a6596c2d4cfc0091648c377bfc44693)  재밌게 보셨다면, 더 많은 영상을 위해 [해진의 심취존] 좋아요와 구독하기 부탁드려요!   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin', ['오크밸리', '원주', '원주여행', '강원도', '학회', '대학원생', '브이로그', 'vlog', '힐링', '워크샵'], '여행/이벤트', 'https://i.ytimg.com/vi/B91H0KtuCjI/sddefault.jpg', '214', '17', '0', '0', '7'], ['B91H0KtuCjI', '대학원생브이로그(Graduate student vlog) #1 ⋅  학회에 다녀오다!', '저는 사실 박사과정의 대학원생입니다. ㅎㅎ 오늘은 9월에 다녀왔던 학회 브이로그에요. 부담이 덜한 소규모의 워크샵이여서 마음 편히 다녀왔어요! 매년 오크밸리에 가고 있는데, 너무 공기도 좋고 놀기도 좋아요! 항상 힐링하는 기분~. 가족 여행으로 꼭 추천하고 싶은 곳입니다. (뮤지엄 산도 꼭 들러보세요!)  요즘 너무 바쁜데 영상 다시 보니까 기분이 좋네요 ㅎ_ㅎ  그리고 영상에서 소개해드린 치치가 먹는 사료는 네이처스 로직 캣 치킨 입니다. (https://smartstore.naver.com/allkillpet/products/2361070627?NaPm=ct%3Djmrr0eoa%7Cci%3Dcheckout%7Ctr%3Dppc%7Ctrx%3D%7Chk%3D608a5cb53a6596c2d4cfc0091648c377bfc44693)  재밌게 보셨다면, 더 많은 영상을 위해 [해진의 심취존] 좋아요와 구독하기 부탁드려요!   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin', ['오크밸리', '원주', '원주여행', '강원도', '학회', '대학원생', '브이로그', 'vlog', '힐링', '워크샵'], '여행/이벤트', 'https://i.ytimg.com/vi/B91H0KtuCjI/sddefault.jpg', '214', '17', '0', '0', '7'], ['pB1Nolfz-2M', '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #3 ⋅ 마지막 이야기; 조계지, 티엔즈팡과 샤오롱바오, 훠궈 먹방', "~ 상하이 브이로그 마지막 이야기 ~ ~ Shanghai vlog the last story ~    📢 NOTICE 셋째 날은 비가 와서 카메라에 방수커버를 이용했어요. 그래서 소리가 너무 작게 들리거나 혹은 들리지 않는 문제가 발생했습니다. 예상치 못했던 문제 때문에 노래와 자막으로 소리를 대신하려고 합니다. 보시는 데 불편함이 있을 수도 있지만, 최선을 다해서 편집했어요. 양해 부탁드립니다.   여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 셋째 날에는 프랑스 조계지와 티엔즈팡, 스타벅스 리저브 로스터리에 갔어요. 그리고 저녁으로 맛있는 샤오롱바오도 먹었답니다.  넷째 날(마지막 날)에는 훠궈를 먹으러 갔다가.. 이상한 중국인 아저씨를 만나는 헤프닝이 있었어요. 그래도 정신을 차리고 카페 헤이티까지 들렸답니다. 우여곡절이 많았지만, 동생과 함께한 즐거운 여행이었어요.   🎈 더 많은 영상을 위해서 [해진의 심취존] 채널  '구독하기'와 영상 '좋아요' 부탁드려요 :D      -  🎬 상하이 3번째 날 일정 정보 (Shanghai 3rd day schedule info)  #프랑스조계지  #티엔즈팡  #스타벅스리저브로스터리  #Fuchun_xiaolong : 고기국수, 샤오롱바오    🎬 상하이 4번째 날 일정 정보 (Shanghai 3rd day schedule info)  #훠궈집 - 818플라자 (정확한 위치를 모르겠어요)  #헤이티 - Hkri Taikoo Hui 쇼핑몰    🎧 노래정보 (Music info)  # ride of joy (https://soundcloud.com/aka-dj-quads/ride-of-joy)  # donnie trumpet & the social experiment  # 버스커버스커 - 야우리송  # old bassa  # fortaleza  # your soul  # spectrum  # this is a jazz space     - @ Film by Haejin @ Edit of film by Namgyeong & Haejin", ['상하이', 'shanghai', '브이로그', 'vlog', '샤오롱바오', '여행', '중국', 'china', '스타벅스리저브로스터리', '훠궈', '헤이티', '여행정보', '조계지', '프랑스조계지', '티엔즈팡', '난징시루', '우롱티', '보이차'], '여행/이벤트', 'https://i.ytimg.com/vi/pB1Nolfz-2M/sddefault.jpg', '384', '17', '0', '0', '4'], ['pB1Nolfz-2M', '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #3 ⋅ 마지막 이야기; 조계지, 티엔즈팡과 샤오롱바오, 훠궈 먹방', "~ 상하이 브이로그 마지막 이야기 ~ ~ Shanghai vlog the last story ~    📢 NOTICE 셋째 날은 비가 와서 카메라에 방수커버를 이용했어요. 그래서 소리가 너무 작게 들리거나 혹은 들리지 않는 문제가 발생했습니다. 예상치 못했던 문제 때문에 노래와 자막으로 소리를 대신하려고 합니다. 보시는 데 불편함이 있을 수도 있지만, 최선을 다해서 편집했어요. 양해 부탁드립니다.   여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 셋째 날에는 프랑스 조계지와 티엔즈팡, 스타벅스 리저브 로스터리에 갔어요. 그리고 저녁으로 맛있는 샤오롱바오도 먹었답니다.  넷째 날(마지막 날)에는 훠궈를 먹으러 갔다가.. 이상한 중국인 아저씨를 만나는 헤프닝이 있었어요. 그래도 정신을 차리고 카페 헤이티까지 들렸답니다. 우여곡절이 많았지만, 동생과 함께한 즐거운 여행이었어요.   🎈 더 많은 영상을 위해서 [해진의 심취존] 채널  '구독하기'와 영상 '좋아요' 부탁드려요 :D      -  🎬 상하이 3번째 날 일정 정보 (Shanghai 3rd day schedule info)  #프랑스조계지  #티엔즈팡  #스타벅스리저브로스터리  #Fuchun_xiaolong : 고기국수, 샤오롱바오    🎬 상하이 4번째 날 일정 정보 (Shanghai 3rd day schedule info)  #훠궈집 - 818플라자 (정확한 위치를 모르겠어요)  #헤이티 - Hkri Taikoo Hui 쇼핑몰    🎧 노래정보 (Music info)  # ride of joy (https://soundcloud.com/aka-dj-quads/ride-of-joy)  # donnie trumpet & the social experiment  # 버스커버스커 - 야우리송  # old bassa  # fortaleza  # your soul  # spectrum  # this is a jazz space     - @ Film by Haejin @ Edit of film by Namgyeong & Haejin", ['상하이', 'shanghai', '브이로그', 'vlog', '샤 ...

# %%
video_info
# Out:
# [['B91H0KtuCjI',
#   '대학원생브이로그(Graduate student vlog) #1 ⋅  학회에 다녀오다!',
#   '저는 사실 박사과정의 대학원생입니다. ㅎㅎ 오늘은 9월에 다녀왔던 학회 브이로그에요. 부담이 덜한 소규모의 워크샵이여서 마음 편히 다녀왔어요! 매년 오크밸리에 가고 있는데, 너무 공기도 좋고 놀기도 좋아요! 항상 힐링하는 기분~. 가족 여행으로 꼭 추천하고 싶은 곳입니다. (뮤지엄 산도 꼭 들러보세요!)  요즘 너무 바쁜데 영상 다시 보니까 기분이 좋네요 ㅎ_ㅎ  그리고 영상에서 소개해드린 치치가 먹는 사료는 네이처스 로직 캣 치킨 입니다. (https://smartstore.naver.com/allkillpet/products/2361070627?NaPm=ct%3Djmrr0eoa%7Cci%3Dcheckout%7Ctr%3Dppc%7Ctrx%3D%7Chk%3D608a5cb53a6596c2d4cfc0091648c377bfc44693)  재밌게 보셨다면, 더 많은 영상을 위해 [해진의 심취존] 좋아요와 구독하기 부탁드려요!   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin',
#   ['오크밸리', '원주', '원주여행', '강원도', '학회', '대학원생', '브이로그', 'vlog', '힐링', '워크샵'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/B91H0KtuCjI/sddefault.jpg',
#   '214',
#   '17',
#   '0',
#   '0',
#   '7'],
#  ['B91H0KtuCjI',
#   '대학원생브이로그(Graduate student vlog) #1 ⋅  학회에 다녀오다!',
#   '저는 사실 박사과정의 대학원생입니다. ㅎㅎ 오늘은 9월에 다녀왔던 학회 브이로그에요. 부담이 덜한 소규모의 워크샵이여서 마음 편히 다녀왔어요! 매년 오크밸리에 가고 있는데, 너무 공기도 좋고 놀기도 좋아요! 항상 힐링하는 기분~. 가족 여행으로 꼭 추천하고 싶은 곳입니다. (뮤지엄 산도 꼭 들러보세요!)  요즘 너무 바쁜데 영상 다시 보니까 기분이 좋네요 ㅎ_ㅎ  그리고 영상에서 소개해드린 치치가 먹는 사료는 네이처스 로직 캣 치킨 입니다. (https://smartstore.naver.com/allkillpet/products/2361070627?NaPm=ct%3Djmrr0eoa%7Cci%3Dcheckout%7Ctr%3Dppc%7Ctrx%3D%7Chk%3D608a5cb53a6596c2d4cfc0091648c377bfc44693)  재밌게 보셨다면, 더 많은 영상을 위해 [해진의 심취존] 좋아요와 구독하기 부탁드려요!   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin',
#   ['오크밸리', '원주', '원주여행', '강원도', '학회', '대학원생', '브이로그', 'vlog', '힐링', '워크샵'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/B91H0KtuCjI/sddefault.jpg',
#   '214',
#   '17',
#   '0',
#   '0',
#   '7'],
#  ['pB1Nolfz-2M',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #3 ⋅ 마지막 이야기; 조계지, 티엔즈팡과 샤오롱바오, 훠궈 먹방',
#   "~ 상하이 브이로그 마지막 이야기 ~ ~ Shanghai vlog the last story ~    📢 NOTICE 셋째 날은 비가 와서 카메라에 방수커버를 이용했어요. 그래서 소리가 너무 작게 들리거나 혹은 들리지 않는 문제가 발생했습니다. 예상치 못했던 문제 때문에 노래와 자막으로 소리를 대신하려고 합니다. 보시는 데 불편함이 있을 수도 있지만, 최선을 다해서 편집했어요. 양해 부탁드립니다.   여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 셋째 날에는 프랑스 조계지와 티엔즈팡, 스타벅스 리저브 로스터리에 갔어요. 그리고 저녁으로 맛있는 샤오롱바오도 먹었답니다.  넷째 날(마지막 날)에는 훠궈를 먹으러 갔다가.. 이상한 중국인 아저씨를 만나는 헤프닝이 있었어요. 그래도 정신을 차리고 카페 헤이티까지 들렸답니다. 우여곡절이 많았지만, 동생과 함께한 즐거운 여행이었어요.   🎈 더 많은 영상을 위해서 [해진의 심취존] 채널  '구독하기'와 영상 '좋아요' 부탁드려요 :D      -  🎬 상하이 3번째 날 일정 정보 (Shanghai 3rd day schedule info)  #프랑스조계지  #티엔즈팡  #스타벅스리저브로스터리  #Fuchun_xiaolong : 고기국수, 샤오롱바오    🎬 상하이 4번째 날 일정 정보 (Shanghai 3rd day schedule info)  #훠궈집 - 818플라자 (정확한 위치를 모르겠어요)  #헤이티 - Hkri Taikoo Hui 쇼핑몰    🎧 노래정보 (Music info)  # ride of joy (https://soundcloud.com/aka-dj-quads/ride-of-joy)  # donnie trumpet & the social experiment  # 버스커버스커 - 야우리송  # old bassa  # fortaleza  # your soul  # spectrum  # this is a jazz space     - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['상하이',
#    'shanghai',
#    '브이로그',
#    'vlog',
#    '샤오롱바오',
#    '여행',
#    '중국',
#    'china',
#    '스타벅스리저브로스터리',
#    '훠궈',
#    '헤이티',
#    '여행정보',
#    '조계지',
#    '프랑스조계지',
#    '티엔즈팡',
#    '난징시루',
#    '우롱티',
#    '보이차'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/pB1Nolfz-2M/sddefault.jpg',
#   '384',
#   '17',
#   '0',
#   '0',
#   '4'],
#  ['pB1Nolfz-2M',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #3 ⋅ 마지막 이야기; 조계지, 티엔즈팡과 샤오롱바오, 훠궈 먹방',
#   "~ 상하이 브이로그 마지막 이야기 ~ ~ Shanghai vlog the last story ~    📢 NOTICE 셋째 날은 비가 와서 카메라에 방수커버를 이용했어요. 그래서 소리가 너무 작게 들리거나 혹은 들리지 않는 문제가 발생했습니다. 예상치 못했던 문제 때문에 노래와 자막으로 소리를 대신하려고 합니다. 보시는 데 불편함이 있을 수도 있지만, 최선을 다해서 편집했어요. 양해 부탁드립니다.   여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 셋째 날에는 프랑스 조계지와 티엔즈팡, 스타벅스 리저브 로스터리에 갔어요. 그리고 저녁으로 맛있는 샤오롱바오도 먹었답니다.  넷째 날(마지막 날)에는 훠궈를 먹으러 갔다가.. 이상한 중국인 아저씨를 만나는 헤프닝이 있었어요. 그래도 정신을 차리고 카페 헤이티까지 들렸답니다. 우여곡절이 많았지만, 동생과 함께한 즐거운 여행이었어요.   🎈 더 많은 영상을 위해서 [해진의 심취존] 채널  '구독하기'와 영상 '좋아요' 부탁드려요 :D      -  🎬 상하이 3번째 날 일정 정보 (Shanghai 3rd day schedule info)  #프랑스조계지  #티엔즈팡  #스타벅스리저브로스터리  #Fuchun_xiaolong : 고기국수, 샤오롱바오    🎬 상하이 4번째 날 일정 정보 (Shanghai 3rd day schedule info)  #훠궈집 - 818플라자 (정확한 위치를 모르겠어요)  #헤이티 - Hkri Taikoo Hui 쇼핑몰    🎧 노래정보 (Music info)  # ride of joy (https://soundcloud.com/aka-dj-quads/ride-of-joy)  # donnie trumpet & the social experiment  # 버스커버스커 - 야우리송  # old bassa  # fortaleza  # your soul  # spectrum  # this is a jazz space     - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['상하이',
#    'shanghai',
#    '브이로그',
#    'vlog',
#    '샤오롱바오',
#    '여행',
#    '중국',
#    'china',
#    '스타벅스리저브로스터리',
#    '훠궈',
#    '헤이티',
#    '여행정보',
#    '조계지',
#    '프랑스조계지',
#    '티엔즈팡',
#    '난징시루',
#    '우롱티',
#    '보이차'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/pB1Nolfz-2M/sddefault.jpg',
#   '384',
#   '17',
#   '0',
#   '0',
#   '4'],
#  ['Myrdk2KZqu4',
#   '치치 브이로그 (CHICHILOG) #1 ⋅ 치치 목욕하는 날',
#   "치치 브이로그 CHICHILOG #1  ~ 저의 치치를 소개합니다.   오랜만입니당 여러분 :-D  오늘은 치치와 함께 돌아왔어요. 음, 우선 치치는 저의 반려묘에요. 저와 함께 한지는 1년이 조금 지났답니다. 이 날은 공부하다가 시간이 조금 나서 치치를 목욕시켰어요. 치치가 목청이 좋아.. 울 때 엄청 크게 울지만, 순하고 착해서 목욕도 잘 따라와 줘서 항상 고마워요. ㅎㅎ  치치의 첫 브이로그는 '목욕이야기'로 시작해볼께요. 앞으로 치치와의 이야기도 기대 많이 해주세요.   🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['반려묘',
#    '고양이',
#    '집사',
#    '목욕',
#    '고양이 목욕',
#    '고양이 브이로그',
#    '애완동물',
#    '치치',
#    'cat',
#    'chichi'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/Myrdk2KZqu4/sddefault.jpg',
#   '164',
#   '16',
#   '0',
#   '0',
#   '7'],
#  ['Myrdk2KZqu4',
#   '치치 브이로그 (CHICHILOG) #1 ⋅ 치치 목욕하는 날',
#   "치치 브이로그 CHICHILOG #1  ~ 저의 치치를 소개합니다.   오랜만입니당 여러분 :-D  오늘은 치치와 함께 돌아왔어요. 음, 우선 치치는 저의 반려묘에요. 저와 함께 한지는 1년이 조금 지났답니다. 이 날은 공부하다가 시간이 조금 나서 치치를 목욕시켰어요. 치치가 목청이 좋아.. 울 때 엄청 크게 울지만, 순하고 착해서 목욕도 잘 따라와 줘서 항상 고마워요. ㅎㅎ  치치의 첫 브이로그는 '목욕이야기'로 시작해볼께요. 앞으로 치치와의 이야기도 기대 많이 해주세요.   🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['반려묘',
#    '고양이',
#    '집사',
#    '목욕',
#    '고양이 목욕',
#    '고양이 브이로그',
#    '애완동물',
#    '치치',
#    'cat',
#    'chichi'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/Myrdk2KZqu4/sddefault.jpg',
#   '164',
#   '16',
#   '0',
#   '0',
#   '7'],
#  ['g7XLNIZfFOQ',
#   '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠',
#   "치치 브이로그 CHICHILOG #2 ~ 오늘은 힐링영상입니당.   하하..또 오랜만입니다 여러분 :-) 지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요. 소소하지만. 찍은 영상을 다시 확인하니, 치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ 여러분에게 저의 소중한 치치의 자는 모습을 공개할게요. 헤헤. 모두 힐링시간이 되었으면 해요~  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['치치', 'CHICHI', '브이로그', 'VLOG', '집냥이', '개냥이', '고양이', '집사', '반려묘', '반려동물'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg',
#   '79',
#   '12',
#   '0',
#   '0',
#   '3'],
#  ['g7XLNIZfFOQ',
#   '치치 브이로그 (CHICHILOG) ⋅ #2 치치와 낮잠',
#   "치치 브이로그 CHICHILOG #2 ~ 오늘은 힐링영상입니당.   하하..또 오랜만입니다 여러분 :-) 지난 어느 날, 치치와 누워서 낮잠자는 순간을 남겨보았어요. 소소하지만. 찍은 영상을 다시 확인하니, 치치는 자는 모습까지 너무 사랑스러워요.ㅜㅜ 여러분에게 저의 소중한 치치의 자는 모습을 공개할게요. 헤헤. 모두 힐링시간이 되었으면 해요~  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!   🎧  노래정보(Music info)  * Old bossa  * Fortaleza    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['치치', 'CHICHI', '브이로그', 'VLOG', '집냥이', '개냥이', '고양이', '집사', '반려묘', '반려동물'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/g7XLNIZfFOQ/sddefault.jpg',
#   '79',
#   '12',
#   '0',
#   '0',
#   '3'],
#  ['rWzbHC-0OfM',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #1 ⋅ 첫번째 이야기; 신천지, 예원, 야시장, 동방명주 야경',
#   "~ 상하이 브이로그 1번째 이야기 ~ (Shanghai vlog the 1st story)   여름 방학에 동생이랑 🇨🇳상하이에 다녀왔어요. 한번도 싸우지 않고 돌아왔습니다. 상하이 너무 힘들었거든요... 첫날은 영상 찍는 게 익숙하지 않아서 많이 어색한 영상이네요. 점점 영상이 많아지니 기대해주세요~!  더 많은 영상을 위해서는 [해진의 심취존] 채널 '구독하기' 와 영상 '좋아요' 부탁드릴게요. :-D   -  🎬  상하이 일정 정보 DAY 1. (Shanghai schedule & info)    * 신천지    - 신천지 식당 : KKAB    - 카페 :  pree    * 예원    * 에어비앤비 (airbnb) : 난징동루    * 쇼우닝루 야시장    * 와이탄 & 동방명주 야경    🎧  노래정보 (Music info)     Dixie Outlandish   (youtube audio library)     nafla - soft   (https://soundcloud.com/naflada/soft)     This is a Jazz Space  (youtube audio library)     OENN - meet me in montauk  (https://soundcloud.com/oennmusic/meet-me-in-montauk)     Wanderoo - Blue Dream  (https://soundcloud.com/brandnewsoul/blue-dream)    -  @ A film by haejin. @ edit a film by haejin & namgyeong",
#   ['상하이',
#    'shanghai',
#    '여행',
#    '여행브이로그',
#    'vlog',
#    'travlevlog',
#    '여동생',
#    '동생',
#    '자매',
#    '대학원생',
#    '학생',
#    '여름방학',
#    '여름여행',
#    '상하이여행'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/rWzbHC-0OfM/sddefault.jpg',
#   '905',
#   '34',
#   '0',
#   '0',
#   '18'],
#  ['rWzbHC-0OfM',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai vlog) #1 ⋅ 첫번째 이야기; 신천지, 예원, 야시장, 동방명주 야경',
#   "~ 상하이 브이로그 1번째 이야기 ~ (Shanghai vlog the 1st story)   여름 방학에 동생이랑 🇨🇳상하이에 다녀왔어요. 한번도 싸우지 않고 돌아왔습니다. 상하이 너무 힘들었거든요... 첫날은 영상 찍는 게 익숙하지 않아서 많이 어색한 영상이네요. 점점 영상이 많아지니 기대해주세요~!  더 많은 영상을 위해서는 [해진의 심취존] 채널 '구독하기' 와 영상 '좋아요' 부탁드릴게요. :-D   -  🎬  상하이 일정 정보 DAY 1. (Shanghai schedule & info)    * 신천지    - 신천지 식당 : KKAB    - 카페 :  pree    * 예원    * 에어비앤비 (airbnb) : 난징동루    * 쇼우닝루 야시장    * 와이탄 & 동방명주 야경    🎧  노래정보 (Music info)     Dixie Outlandish   (youtube audio library)     nafla - soft   (https://soundcloud.com/naflada/soft)     This is a Jazz Space  (youtube audio library)     OENN - meet me in montauk  (https://soundcloud.com/oennmusic/meet-me-in-montauk)     Wanderoo - Blue Dream  (https://soundcloud.com/brandnewsoul/blue-dream)    -  @ A film by haejin. @ edit a film by haejin & namgyeong",
#   ['상하이',
#    'shanghai',
#    '여행',
#    '여행브이로그',
#    'vlog',
#    'travlevlog',
#    '여동생',
#    '동생',
#    '자매',
#    '대학원생',
#    '학생',
#    '여름방학',
#    '여름여행',
#    '상하이여행'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/rWzbHC-0OfM/sddefault.jpg',
#   '905',
#   '34',
#   '0',
#   '0',
#   '18'],
#  ['7tjQJ5v4keA',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai travel vlog) #2 ⋅ 상하이 디즈니랜드에 다녀왔어요!',
#   "~ 상하이 브이로그 두번째 이야기 ~ ~ Shanghai vlog the 2nd story ~    여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 둘째 날에는 디즈니 랜드에서 하루를 보냈는데요. 긴 대기시간 +  중국 분들의 새치기 + 마지막에 온 태풍까지 너무 힘들었지만~~~~~~~ 너무 즐거운 시간들이었어요! 다음 번엔 다른 도시의 디즈니랜드에 가고 싶네요.   김자매의 소소한 즐거움을 영상으로 확인해 주세요.  더 많은 영상을 위해서 [해진의 심취존] 채널 ' '구독하기'와 영상 '좋아요' 부탁드려요 :D   -  🎬 상하이 2번째 날 일정 정보 (Shanghai 2rd day schedule info)  # 아침 식사 : 길거리 가게 지단빙  # 디즈니 랜드 (Disneyland)    🎧 노래정보 (Music info)   # Blue bird   # Chill day        (https://soundcloud.com/lakeyinspired/chill-day)   # Longing        (https://soundcloud.com/joakimkarud/longing)   # 버스커버스커 - 야우리송    # I found me        (https://soundcloud.com/lakeyinspired/i-found-me)   # Breakfast in bed        (https://soundcloud.com/jazzinuf/breakfast-in-bed)   # True        ()   # A bouquet of roses        (https://soundcloud.com/aka-dj-quads/a-bouquet-of-roses)   # Physical        (https://soundcloud.com/kiraraisworking/physical-olivia-newton-john-cover)    # Ride of joy        (https://soundcloud.com/aka-dj-quads/ride-of-joy)    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['상하이',
#    '브이로그',
#    'vlog',
#    'shanghai',
#    'sister',
#    'kimsister',
#    'korean',
#    '한국',
#    '중국',
#    'china',
#    'disneyland',
#    '디즈니랜드'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/7tjQJ5v4keA/sddefault.jpg',
#   '354',
#   '10',
#   '0',
#   '0',
#   '4'],
#  ['7tjQJ5v4keA',
#   '동생과의 🇨🇳상하이 여행 브이로그(Shanghai travel vlog) #2 ⋅ 상하이 디즈니랜드에 다녀왔어요!',
#   "~ 상하이 브이로그 두번째 이야기 ~ ~ Shanghai vlog the 2nd story ~    여름방학에 동생과 🇨🇳상하이에 다녀왔어요! 둘째 날에는 디즈니 랜드에서 하루를 보냈는데요. 긴 대기시간 +  중국 분들의 새치기 + 마지막에 온 태풍까지 너무 힘들었지만~~~~~~~ 너무 즐거운 시간들이었어요! 다음 번엔 다른 도시의 디즈니랜드에 가고 싶네요.   김자매의 소소한 즐거움을 영상으로 확인해 주세요.  더 많은 영상을 위해서 [해진의 심취존] 채널 ' '구독하기'와 영상 '좋아요' 부탁드려요 :D   -  🎬 상하이 2번째 날 일정 정보 (Shanghai 2rd day schedule info)  # 아침 식사 : 길거리 가게 지단빙  # 디즈니 랜드 (Disneyland)    🎧 노래정보 (Music info)   # Blue bird   # Chill day        (https://soundcloud.com/lakeyinspired/chill-day)   # Longing        (https://soundcloud.com/joakimkarud/longing)   # 버스커버스커 - 야우리송    # I found me        (https://soundcloud.com/lakeyinspired/i-found-me)   # Breakfast in bed        (https://soundcloud.com/jazzinuf/breakfast-in-bed)   # True        ()   # A bouquet of roses        (https://soundcloud.com/aka-dj-quads/a-bouquet-of-roses)   # Physical        (https://soundcloud.com/kiraraisworking/physical-olivia-newton-john-cover)    # Ride of joy        (https://soundcloud.com/aka-dj-quads/ride-of-joy)    - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['상하이',
#    '브이로그',
#    'vlog',
#    'shanghai',
#    'sister',
#    'kimsister',
#    'korean',
#    '한국',
#    '중국',
#    'china',
#    'disneyland',
#    '디즈니랜드'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/7tjQJ5v4keA/sddefault.jpg',
#   '354',
#   '10',
#   '0',
#   '0',
#   '4'],
#  ['4hW1hpDXSxw',
#   '브이로그(vlog) #1 ⋅ 주말에 고향에 다녀왔어요.',
#   "일상 VLOG #1   약 한 달 전,  주말에 할아버지집을 다녀왔어요. 친구와 첫 영상 편집도 하고, 맛있는 것도 먹고,  쇼핑도 신나게 하고 왔답니다.  소소하지만 즐거운 저의 일상을 공유할게요.  할아버지와 함께한 브이로그 영상은 따로 준비했으니, 많이 기대해 주세요.  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!  * 설명에 오류가 하나 있었어요! 코코가 메리의 엄마라고 적혀있는데, 사실 코코는 메리의 아들입니다 ㅎㅎ   🎧  노래정보(Music info)   # Island(https://soundcloud.com/oennmusic/island)   # This is a jazz space   # Okinawa (https://soundcloud.com/92914/okinawa)   # Humming man (https://soundcloud.com/men-i-trust/humming-man)   # Highway Drivin : Bloo, Young West, Nafla (https://soundcloud.com/louismaui/6-highway-drivin-bloo-young-west-nafla-prod-louis-maui)   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['브이로그',
#    'vlog',
#    '일상브이로그',
#    '주말',
#    'weekend',
#    '친구',
#    '편집',
#    '왜관',
#    'waegwan',
#    '부산',
#    '할아버지',
#    '카페',
#    'cafe',
#    'favemoment',
#    'ohrosycake',
#    '오로지케이크',
#    '칠일곱창',
#    '맛집',
#    '쇼핑'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/4hW1hpDXSxw/sddefault.jpg',
#   '185',
#   '19',
#   '0',
#   '0',
#   '6'],
#  ['4hW1hpDXSxw',
#   '브이로그(vlog) #1 ⋅ 주말에 고향에 다녀왔어요.',
#   "일상 VLOG #1   약 한 달 전,  주말에 할아버지집을 다녀왔어요. 친구와 첫 영상 편집도 하고, 맛있는 것도 먹고,  쇼핑도 신나게 하고 왔답니다.  소소하지만 즐거운 저의 일상을 공유할게요.  할아버지와 함께한 브이로그 영상은 따로 준비했으니, 많이 기대해 주세요.  🎈 영상을 즐겁게 보셨다면, 더 많은 영상을 위해서  '좋아요' 와  [해진의 심취존] '구독하기' 부탁드려요!  * 설명에 오류가 하나 있었어요! 코코가 메리의 엄마라고 적혀있는데, 사실 코코는 메리의 아들입니다 ㅎㅎ   🎧  노래정보(Music info)   # Island(https://soundcloud.com/oennmusic/island)   # This is a jazz space   # Okinawa (https://soundcloud.com/92914/okinawa)   # Humming man (https://soundcloud.com/men-i-trust/humming-man)   # Highway Drivin : Bloo, Young West, Nafla (https://soundcloud.com/louismaui/6-highway-drivin-bloo-young-west-nafla-prod-louis-maui)   - @ Film by Haejin @ Edit of film by Namgyeong & Haejin",
#   ['브이로그',
#    'vlog',
#    '일상브이로그',
#    '주말',
#    'weekend',
#    '친구',
#    '편집',
#    '왜관',
#    'waegwan',
#    '부산',
#    '할아버지',
#    '카페',
#    'cafe',
#    'favemoment',
#    'ohrosycake',
#    '오로지케이크',
#    '칠일곱창',
#    '맛집',
#    '쇼핑'],
#   '여행/이벤트',
#   'https://i.ytimg.com/vi/4hW1hpDXSxw/sddefault.jpg',
#   '185',
#   '19',
#   '0',
#   '0',
#   '6']]

# %%
api_dict["items"][0]["snippet"]["title"]  # 동영상 제목
api_dict["items"][0]["snippet"]["description"]  # 동영상 설명
api_dict["items"][0]["snippet"]['tags']  # 동영상 태그
api_dict["items"][0]["snippet"]["categoryId"]  # 동영상 카테고리
api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url']  # 동영상 썸네일 주소


api_dict["items"][0]["statistics"]['viewCount']  # 조회수
api_dict["items"][0]["statistics"]["likeCount"]  # 좋아요 수
api_dict["items"][0]["statistics"]["dislikeCount"]  # 싫어요 수
api_dict["items"][0]["statistics"]["favoriteCount"]  # 즐겨찾기 (나중에 볼 영상) 수
api_dict["items"][0]["statistics"]["commentCount"] # 댓글 수
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-04640f6bfd69> in <module>()
# ----> 1 api_dict["items"][0]["snippet"]["title"]  # 동영상 제목
#       2 api_dict["items"][0]["snippet"]["description"]  # 동영상 설명
#       3 api_dict["items"][0]["snippet"]['tags']  # 동영상 태그
#       4 api_dict["items"][0]["snippet"]["categoryId"]  # 동영상 카테고리
#       5 api_dict["items"][0]["snippet"]["thumbnails"]["standard"]['url']  # 동영상 썸네일 주소
#
# KeyError: 'snippet'

# %%
# Out:
# str
