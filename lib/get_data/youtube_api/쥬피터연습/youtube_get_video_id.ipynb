# %% [markdown]
#     api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
#     chanel_id = "UCLJi9Vk8_y3y_evAahQUEpQ"
#
#    target_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&eventType=completed&type=video&maxResults=50&key={}"

# %%
def get_video_id(channel_id, api_key="AIzaSyCzerFuw3AJr6o29InSBHBW9Rfy5xzIyTY"):
    '''
    channel_url : 유튜버 채널의 고유 채널 ID 
    ( 도메인에서 직접 긁어올 시 "https://www.youtube.com/channel/***" 또는 "https://www.youtube.com/user/***"에서 * 부분 )
    
    api_key : 자신의 API키   
        
    return => [일반 동영상 고유 ID(list), 라이브 동영상 고유 ID(list)](list)
    '''
    
    import requests
    from bs4 import BeautifulSoup 

    
    
    if len(channel_id) == 24:  
        
        api_key = api_key
        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)
        
        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일반 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&eventType=completed&type=video&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        all_video_ids_count = len(video_ids)
        live_video_ids_count = len(live_video_ids)
        video_ids = list(set(video_ids) - set(live_video_ids))
        video_ids_count = len(video_ids)
        
        return [video_ids, live_video_ids]
    
    
    else:
        
        api_key = api_key
        channel_id = user_to_channelid(channel_id, api_key)

        page_token = ""

        target_url = 'https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'.format(channel_id, page_token, api_key) 

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )
        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']
        exe_set = round(total_results / results_per_page +0.5)

        video_ids = []
        live_video_ids = []

        if exe_set == 0:
            print("일단 동영상 없음")

        else:
            for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                video_ids.append(vd_id)

                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

                        
        ##############################################################################################################    
        page_token = ""

        target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&maxResults=50&key={}'''.format(channel_id, api_key )

        session = requests.Session ()
        headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

        html = requests.get (target_url)
        soup = BeautifulSoup (html.text, "html.parser" )

        api_dict = eval(soup.text.replace("false","False").replace("true","True"))

        total_results = api_dict['pageInfo']['totalResults']
        results_per_page = api_dict['pageInfo']['resultsPerPage']

        exe_set = round(total_results / results_per_page +0.5)

        if exe_set == 0:
            print("라이브 동영상 없음")

        else:
              for total_set in range(exe_set):

                    target_url = '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&eventType=completed&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key)
                    session = requests.Session ()
                    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }
                    html = requests.get (target_url)
                    soup = BeautifulSoup (html.text, "html.parser" )
                    api_dict = eval(soup.text.replace("false","False").replace("true","True"))

                    for result_count in range(len(api_dict["items"])):
                                vd_id = api_dict["items"][result_count]["id"]["videoId"]
                                live_video_ids.append(vd_id)
                                
                    if "nextPageToken" in api_dict:
                        page_token = api_dict["nextPageToken"]

        ################################################################################################################

        video_ids = list(set(video_ids) - set(live_video_ids))
        
        return [video_ids, live_video_ids]

# %%
def user_to_channelid(user_name, api_key="AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"):

    import requests
    from bs4 import BeautifulSoup 

    api_key = api_key
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]

    
    return channel_id

# %%
https://www.youtube.com/user/hanryang1125

# %%
def user_to_channelid(user_name, api_key="AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"):

    import requests
    from bs4 import BeautifulSoup 

    api_key = api_key
    user_name = user_name


    target_url = '''https://www.googleapis.com/youtube/v3/channels?part=snippet&forUsername={}&key={}'''.format(user_name, api_key) 

    session = requests.Session ()
    headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

    html = requests.get (target_url)
    soup = BeautifulSoup (html.text, "html.parser" )

    api_dict = eval(soup.text.replace("false","False").replace("true","True"))
    
    channel_id = api_dict['items'][0]["id"]

    
    return channel_id

# %%
user_to_channelid("yumcast11")
# Out:
# 'UCoDLLyiqum2JOBI4Dty8eUA'

# %%
len(video_ids),len(live_video_ids),len(video_ids + live_video_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60a414520f89> in <module>
# ----> 1 len(video_ids),len(live_video_ids),len(video_ids + live_video_ids)
#
# NameError: name 'video_ids' is not defined

# %%
len(video_ids),len(live_video_ids),len(video_ids + live_video_ids)
# Out:
# (490, 515, 1005)

# %%
len(video_ids),len(live_video_ids),len(video_ids + live_video_ids)
# Out:
# (482, 515, 997)

# %%
len(video_ids),len(live_video_ids),len(video_ids + live_video_ids)
# Out:
# (488, 515, 1003)

# %%
import requests
from bs4 import BeautifulSoup 

api_key = "AIzaSyDoxv6yPVLKSMJwXVF0-HKnkdl0DcgE8Ak"
channel_id = "UCSHVH_AWVUc-C8-D8mh8W6A"
page_token = ""

target_url =  '''https://www.googleapis.com/youtube/v3/search?part=snippet&channelId={}&order=date&type=video&pageToken={}&maxResults=50&key={}'''.format(channel_id, page_token, api_key) 

session = requests.Session ()
headers ={ 'user-agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36' }

html = requests.get (target_url)
soup = BeautifulSoup (html.text, "html.parser" )

api_dict = eval(soup.text.replace("false","False").replace("true","True"))
api_dict
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/tUh5MMbxpP9vp50zfQOKwgfhIFo"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 2109, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/clm8K2JfYBLCHSXqrvDPSCpPZ2c"',
#    'id': {'kind': 'youtube#video', 'videoId': 'qejvAoASwiE'},
#    'snippet': {'publishedAt': '2018-12-24T02:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 31화 - 사천왕 깨러 갑니다!! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qejvAoASwiE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qejvAoASwiE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qejvAoASwiE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/1TBSQoSiwHGLZqofTai2MFi_CiM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'isJDT98fLBA'},
#    'snippet': {'publishedAt': '2018-12-23T18:52:40.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 헤드라이너 - 논란이냐 명예냐 / 포켓몬스터 렛츠고 피카츄! - 최강의 이상해꽃 마스터 따기! 게임 방송 12/23(일) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/isJDT98fLBA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/isJDT98fLBA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/isJDT98fLBA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/-FYoT124f-L6D0RRcPE2-bBcY_w"',
#    'id': {'kind': 'youtube#video', 'videoId': '7sX9mNsEXXM'},
#    'snippet': {'publishedAt': '2018-12-23T10:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '꽃 심어서 대박 예쁜 놀이공원 만들자! 꽃데월드 2편 - 대박 놀이동산 만들기 게임 파키텍트(Parkitect)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7sX9mNsEXXM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7sX9mNsEXXM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7sX9mNsEXXM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/k3jDQUUp-2xI1Erot0JZ3QS8_lc"',
#    'id': {'kind': 'youtube#video', 'videoId': 'uxs0_zdp5d0'},
#    'snippet': {'publishedAt': '2018-12-23T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 대포통장이 개설 됐어요! 보이스피싱 주의!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uxs0_zdp5d0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uxs0_zdp5d0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uxs0_zdp5d0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/gfS84TcytAIeoGi_nlhRGgdZiOI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SPtpz_IXnnk'},
#    'snippet': {'publishedAt': '2018-12-23T02:45:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 30화 - 전설의 파이어를 만났다! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SPtpz_IXnnk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SPtpz_IXnnk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SPtpz_IXnnk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/smwcw9UOS5gV8NwnHlIWYmhYBdw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'qNw1L45HCP0'},
#    'snippet': {'publishedAt': '2018-12-22T16:49:24.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 사극 드라마에 출연하고 왔습니다! 12/22(토) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qNw1L45HCP0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qNw1L45HCP0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qNw1L45HCP0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/GtV8f6CBU-D1r-4cy4NH43t4-b0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'KpTmg60lLnw'},
#    'snippet': {'publishedAt': '2018-12-22T11:00:02.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 29화 - 미뇽에서 망나뇽으로 진화! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KpTmg60lLnw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KpTmg60lLnw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KpTmg60lLnw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/38hr2wHoIDV_RX9LOWx478GRRAA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'n0XiieLAFNU'},
#    'snippet': {'publishedAt': '2018-12-22T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '와! 언더테일 후속작! 대도서관! 델타룬 3화 (Deltarune)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/n0XiieLAFNU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/n0XiieLAFNU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/n0XiieLAFNU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4fp3R1mYhJxykKMyIBD3Pzk0ZA8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'EyCRiCxwORo'},
#    'snippet': {'publishedAt': '2018-12-22T02:30:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 아이돌 단골샵에서 귀걸이 했어요!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EyCRiCxwORo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EyCRiCxwORo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EyCRiCxwORo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/eeg4TabjbuJGudsarUDsYTfbGsI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'kObLneK4Cb0'},
#    'snippet': {'publishedAt': '2018-12-21T19:22:38.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 히트맨2 - 한정타겟 마약왕 유튜버를 암살하랏! / 파키텍트 - 대흑자 시대!! 대박쳤다! 12/21(금) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kObLneK4Cb0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kObLneK4Cb0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kObLneK4Cb0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3ybDmL8aPEoYZ72J1k8fngBG5qs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'lds88u3h8Rk'},
#    'snippet': {'publishedAt': '2018-12-21T11:09:28.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "대도서관이 찰떡같이 설명해주는 '알함브라 궁전의 추억' 속 AR 게임!",
#     'description': "본 영상은 tvN측과 함께 제작했습니다 * '알함브라 궁전의 추억' 매주 토,일 밤 9시 tvN 방송! #알함브라궁전의추억 #현빈 #박신혜 * 대도서관...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lds88u3h8Rk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lds88u3h8Rk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lds88u3h8Rk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7wKV1hkF9xQ38oRNvzzqhSvjUGU"',
#    'id': {'kind': 'youtube#video', 'videoId': 'qnJ-NQLBx7M'},
#    'snippet': {'publishedAt': '2018-12-21T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 28화 - 로켓단을 해산시켰습니다! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qnJ-NQLBx7M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qnJ-NQLBx7M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qnJ-NQLBx7M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/nvBCF_eZ3jBQSwPZ-VDhuxqoLJ8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Zh9jI048tx4'},
#    'snippet': {'publishedAt': '2018-12-21T06:06:51.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 자장가라 쓰고 기상송이라 하지!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zh9jI048tx4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zh9jI048tx4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Zh9jI048tx4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/J1Dc7eKCstKHow5Fzjh8xirjndY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Edp_hHy5F2A'},
#    'snippet': {'publishedAt': '2018-12-20T19:18:24.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 파키텍트 (5일차) 꿈의 흑자 놀이동산 완성!!! 12/20(목) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Edp_hHy5F2A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Edp_hHy5F2A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Edp_hHy5F2A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/xauaxtCSiGX8HrdTcH83sVO0QIM"',
#    'id': {'kind': 'youtube#video', 'videoId': '7WpF0dbWZw0'},
#    'snippet': {'publishedAt': '2018-12-20T11:45:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '배드드림 피버 5화 최종화 -  러스티 레이크 시리즈가 생각나는 코마 후속작! (Bad Dream Fever)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7WpF0dbWZw0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7WpF0dbWZw0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7WpF0dbWZw0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/mKrK55iDPoMTn5AHJKkJW0rd7uc"',
#    'id': {'kind': 'youtube#video', 'videoId': '6TKL3zXA2YI'},
#    'snippet': {'publishedAt': '2018-12-20T09:34:22.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 27화 - 전설의 포켓몬 썬더가 눈 앞에 나타났다! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6TKL3zXA2YI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6TKL3zXA2YI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6TKL3zXA2YI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/kZMu_7wkYvIqiIfLlgpbyS_lVAA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'hot9g_cG51Y'},
#    'snippet': {'publishedAt': '2018-12-19T19:34:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 파키텍트 (4일차) - 디자인 굿! 흑자 굿! 핑크랜드! 12/19(수) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hot9g_cG51Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hot9g_cG51Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hot9g_cG51Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/L5WKW802uH2y2QJIu6jul4KL3Zw"',
#    'id': {'kind': 'youtube#video', 'videoId': 'UTvgSjtod04'},
#    'snippet': {'publishedAt': '2018-12-19T15:15:46.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 토크 방송입니닷! 12/19(수) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UTvgSjtod04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UTvgSjtod04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UTvgSjtod04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NaVVkAxxAyGEpfoR3kwAIZXP4XI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'iyUsMXAAI5o'},
#    'snippet': {'publishedAt': '2018-12-19T12:30:19.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '꽃 심어서 대박 예쁜 놀이공원 만들자! 꽃데월드 1편 - 대박 놀이동산 만들기 게임 파키텍트(Parkitect)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iyUsMXAAI5o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iyUsMXAAI5o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iyUsMXAAI5o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/6Jxa7jePCQlAhrznZthyuuuY7CA"',
#    'id': {'kind': 'youtube#video', 'videoId': '0mS191h-iwM'},
#    'snippet': {'publishedAt': '2018-12-19T11:02:18.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 뉴이스트W 콘서트 다녀온 후기!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0mS191h-iwM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0mS191h-iwM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0mS191h-iwM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/hJSkXB4LTabLdYSP-D14VMmLiXk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'T7-i35hvdYw'},
#    'snippet': {'publishedAt': '2018-12-19T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대박 놀이동산 만들기 게임! 파키텍트(Parkitect) - 빚더미 월드 2편',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T7-i35hvdYw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/T7-i35hvdYw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/T7-i35hvdYw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Fi5Amy3HIn9_UnCbafLLNmOj9Q4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'XnwMHmT4EwY'},
#    'snippet': {'publishedAt': '2018-12-19T06:01:05.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 26화 - 카레먹다 온 질퍽이?! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XnwMHmT4EwY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XnwMHmT4EwY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XnwMHmT4EwY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/fDtCGADAr9somPyvbPuQFC4WLgk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'vgZ7zCbMnEE'},
#    'snippet': {'publishedAt': '2018-12-18T13:59:38.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대박 놀이동산 만들기 게임! 파키텍트(Parkitect) - 빚더미 월드 1편',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vgZ7zCbMnEE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vgZ7zCbMnEE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vgZ7zCbMnEE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/sXP8HhIgHrfnRokY5qWWHz2rUOE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'I3g3rWry9go'},
#    'snippet': {'publishedAt': '2018-12-18T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '마임맨만 보면 미치는 남자가 있다?!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/I3g3rWry9go/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/I3g3rWry9go/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/I3g3rWry9go/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/UUCwn452cVQjgI5kCRPLWsDIfyo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ugk08_mcmII'},
#    'snippet': {'publishedAt': '2018-12-17T19:18:35.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 파키텍트 (3일차) - 빚 독촉을 이겨내고 흑자 전환한 놀이동산 게임 12/17(월) 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ugk08_mcmII/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ugk08_mcmII/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ugk08_mcmII/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/hnH-owF9wArehMHY8XIt1PUmZl4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ELuVDRdIrwY'},
#    'snippet': {'publishedAt': '2018-12-17T11:12:03.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 25화 - 희귀한 '마'씨 포켓몬들! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ELuVDRdIrwY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ELuVDRdIrwY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ELuVDRdIrwY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Nzo0CyCGdZSDZ4x9ba1S1y9o_Ik"',
#    'id': {'kind': 'youtube#video', 'videoId': 'KPOEXcCz0jc'},
#    'snippet': {'publishedAt': '2018-12-17T08:54:49.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '박명수 VS 대도서관, 핵인싸 힙지수 테스트! [힙스터 비상대책 위원회]',
#     'description': '힙대위 2탄 선우정아편 풀버전 보러가기 : https://youtu.be/C72R0_7tI-Y * 대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KPOEXcCz0jc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KPOEXcCz0jc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KPOEXcCz0jc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/J-aRETspGWN38nAWdKqj4UpFTDs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'a1P9MeeymxY'},
#    'snippet': {'publishedAt': '2018-12-16T16:52:09.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 뉴이스트W 콘서트에 다녀왔어요! 12/16(일) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a1P9MeeymxY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/yDuYVSqtT76BmXh8yJMSZc5ncss"',
#    'id': {'kind': 'youtube#video', 'videoId': 'YkXL0HvNCDc'},
#    'snippet': {'publishedAt': '2018-12-16T10:45:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 24화 - 우주가는 포켓몬? 폴리곤! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YkXL0HvNCDc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YkXL0HvNCDc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YkXL0HvNCDc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/O2ArSot0p8Xq8YjpZVLb0CoygDA"',
#    'id': {'kind': 'youtube#video', 'videoId': '0DoQ8HukU7k'},
#    'snippet': {'publishedAt': '2018-12-16T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 인싸와 아싸의 화법 차이!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0DoQ8HukU7k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0DoQ8HukU7k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0DoQ8HukU7k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/QTbv07DGGdCmUCd6shYzuk7O1Vg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'lrRIVykItho'},
#    'snippet': {'publishedAt': '2018-12-16T02:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 23화 -시라소몬 VS 홍수몬! 당신의 선택은? (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lrRIVykItho/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lrRIVykItho/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lrRIVykItho/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/78EBRkrJly6_dE9RLbBY3f1ye6c"',
#    'id': {'kind': 'youtube#video', 'videoId': 't9S8qxrGEoA'},
#    'snippet': {'publishedAt': '2018-12-15T19:20:38.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 놀이동산 만들기 게임의 끝판왕인듯? 파키텍트 (2일차) 12/15(토) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t9S8qxrGEoA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t9S8qxrGEoA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t9S8qxrGEoA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Vr2ZKlYZrBHoPOVCRmyQV2eME7k"',
#    'id': {'kind': 'youtube#video', 'videoId': 'xWiGhEHfNGc'},
#    'snippet': {'publishedAt': '2018-12-15T10:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '와! 언더테일 후속작! 대도서관! 델타룬 2화 (Deltarune)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xWiGhEHfNGc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xWiGhEHfNGc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xWiGhEHfNGc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/BfTcwm3LHsQZlKiYYIpcuTWK9zo"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Eebtp2d-ozo'},
#    'snippet': {'publishedAt': '2018-12-15T08:45:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 22화 - 전설의 포켓몬 프리저 등장! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Eebtp2d-ozo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Eebtp2d-ozo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Eebtp2d-ozo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4wmMj_aoJMq6z4pkYSX_8ZakqN8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'HcPzL76UZNY'},
#    'snippet': {'publishedAt': '2018-12-14T11:58:44.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "생방송으로 5,000명이 속았다! '무주의 맹시' 실험 (inattentional blindness Test)",
#     'description': '제 방에 그린 스크린을 설치하고 생방송으로 무주의 맹시 실험 테스트를 해봤습니다! 5천명의 생방송 시청자분들께서 과연 무언가 바뀐 것을...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HcPzL76UZNY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HcPzL76UZNY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HcPzL76UZNY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/7dizKdG8wdso_nI0f0RpKtTwd2c"',
#    'id': {'kind': 'youtube#video', 'videoId': '-1-s0ODcifM'},
#    'snippet': {'publishedAt': '2018-12-14T10:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 21화 - 피카츄 만능설! 바위도 밀어요! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-1-s0ODcifM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-1-s0ODcifM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-1-s0ODcifM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/P3tt1IBQpK1mz3kwvATZU1I5d2s"',
#    'id': {'kind': 'youtube#video', 'videoId': 'XRBv1DJCoEE'},
#    'snippet': {'publishedAt': '2018-12-14T08:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 20화 - 서핑보드 타는 핵인싸 피카츄! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XRBv1DJCoEE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XRBv1DJCoEE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XRBv1DJCoEE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/TqNbMaQ7Et-YZhhn1i5nVIp0pIs"',
#    'id': {'kind': 'youtube#video', 'videoId': 'AVwXxtKkdwI'},
#    'snippet': {'publishedAt': '2018-12-14T02:45:02.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '공룡판 몬스트럼! 공룡을 피해 탈출하는 공포게임 2화 (OAKWOOD)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AVwXxtKkdwI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AVwXxtKkdwI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AVwXxtKkdwI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/4nj92ff0VyNuIhyRNeCAglfzZrg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'thPcYa_KOrg'},
#    'snippet': {'publishedAt': '2018-12-13T19:03:33.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 강추! 신작 놀이동산 만들기! 파키텍트 게임 방송! 12/13(목) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/thPcYa_KOrg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/3LmD25llC9_6FKOvdV7gOoiHwck"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SImf-mlfEXU'},
#    'snippet': {'publishedAt': '2018-12-13T10:45:01.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 19화 - 잠만보를 타고 다녀요! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SImf-mlfEXU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SImf-mlfEXU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SImf-mlfEXU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/vH1PCrRqI23fMaHzWEcWsJSOWPY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'TNVlBr8wcwk'},
#    'snippet': {'publishedAt': '2018-12-13T09:45:00.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 18화 - 알로라 식스테일을 얻다! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TNVlBr8wcwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TNVlBr8wcwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TNVlBr8wcwk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ixpoC2LwKJjrVVHH663N84xLJx4"',
#    'id': {'kind': 'youtube#video', 'videoId': 'p8PJ450jZG8'},
#    'snippet': {'publishedAt': '2018-12-13T07:55:54.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '[검색량 배틀] 차은우 VS 스폰지밥! 무엇이 더 많이 검색 됐을까?!',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/p8PJ450jZG8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/p8PJ450jZG8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/p8PJ450jZG8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ugS-mmw0Rq8iFqC2myUaNhEblxM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'c0fxxTkD-L0'},
#    'snippet': {'publishedAt': '2018-12-12T19:27:08.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 오늘 레드 잡는다! - 포켓몬스터 렛츠고 피카츄! 12/12(수) 헤헷! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c0fxxTkD-L0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/c0fxxTkD-L0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/c0fxxTkD-L0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/03WkyTzP_DWXWnKCrAPqDxxS39Y"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Jbi0TMFvYhc'},
#    'snippet': {'publishedAt': '2018-12-12T10:50:09.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '공룡판 몬스트럼! 공룡을 피해 탈출하는 공포게임 1화 (OAKWOOD)',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jbi0TMFvYhc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jbi0TMFvYhc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jbi0TMFvYhc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Jp0mlPgYEMLCUtNJXWKQQQcox-8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'DISGjMFdR0E'},
#    'snippet': {'publishedAt': '2018-12-12T09:08:33.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 17화 - 대카츄(?) 너로 정했다! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DISGjMFdR0E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DISGjMFdR0E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DISGjMFdR0E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/tXlblX9LXtKkwBwt0RfhvoFa0yg"',
#    'id': {'kind': 'youtube#video', 'videoId': 'mw9AQH2xvtw'},
#    'snippet': {'publishedAt': '2018-12-12T05:48:52.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도서관 수다방] 아버지의 사업 꼭 물려받아야 할까요?',
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mw9AQH2xvtw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mw9AQH2xvtw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mw9AQH2xvtw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/jfTlv1DxOliE6uj8sfl5PcVA36c"',
#    'id': {'kind': 'youtube#video', 'videoId': 'WQmCgJ_Tjr4'},
#    'snippet': {'publishedAt': '2018-12-11T18:45:26.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] (2부) 와! 델타룬! 언더테일 후속작! 대도서관! 샌즈! 12/11(화) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WQmCgJ_Tjr4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WQmCgJ_Tjr4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WQmCgJ_Tjr4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/vo-Og5ZAb5mpbEmwdUInF3ly-ds"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Kzh0Fp9CtRM'},
#    'snippet': {'publishedAt': '2018-12-11T17:38:43.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': '대도 생방송] 오크우드 - 공룡판 몬스트럼 / (1부) 와! 델타룬! 언더테일 후속작!12/11(화) 하핫! 대도서관 Game Live Show',
#     'description': '좋아요 엄지척 버튼과 구독 버튼을 눌러주셔서 감사합니닷! * 우측 상단에 종 그림이 알람버튼 입니다. 눌러서 켜놓으시면 생방송 알람이 갑니다!...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kzh0Fp9CtRM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Kzh0Fp9CtRM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Kzh0Fp9CtRM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/wEGekccuLsZuPPAWxlaE15Z2F9g"',
#    'id': {'kind': 'youtube#video', 'videoId': '2aIM46wY_LI'},
#    'snippet': {'publishedAt': '2018-12-11T12:14:43.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 16화 - 체육관 접수하러 왔습니다!! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2aIM46wY_LI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2aIM46wY_LI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2aIM46wY_LI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/ZKvW8TKSCD-2Tv3-kD3Z1VAvjgk"',
#    'id': {'kind': 'youtube#video', 'videoId': 'aE1c1x57hj4'},
#    'snippet': {'publishedAt': '2018-12-11T08:30:02.000Z',
#     'channelId': 'UCSHVH_AWVUc-C8-D8mh8W6A',
#     'title': "포켓몬스터 레츠고! 피카츄 15화 - 보스를 잡기 위한 방탈출 게임! (Pokémon Let's Go Pikachu)",
#     'description': '대도서관 공식 인스타그램 : https://www.instagram.com/buzzbean11 * 대도서관 공식 블로그 : https://blog.naver.com/uncledd * 광고 문의 : jw.jun@cj.net * 대도서관 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aE1c1x57hj4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aE1c1x57hj4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aE1c1x57hj4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '대도서관TV (buzzbean11)',
#     'liveBroadcastContent': 'none'}}]}

# %%
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/YlfEcPNbD56nPOUBf0d1S-evAk8"', 'nextPageToken': 'CDIQAA', 'regionCode': 'KR', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NuWHDg1ZDIYYFQE6vebSzbT4UyY"', 'id': {'kind': 'youtube#video', 'videoId': 'kUnUp7ZLjLQ'}, 'snippet': {'publishedAt': '2018-12-23T10:13:37.000Z', 'channelId': 'UCLThzQLfSpLuHimpT1MlcQQ', 'title': 'Top 30 Strongest ONE PIECE Characters 2018', 'description': 'LIT. Subscribe Here: http://tinyurl.com/zdqwgqw Donate Here: https://streamlabs.com/bragodace **** Check out my Patreon: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/kUnUp7ZLjLQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Brago D. Ace', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/BpbigJhQTL76uyN5vzOTpjLHZhs"', 'id': {'kind': 'youtube#video', 'videoId': 'hIXaF9eUXE0'}, 'snippet': {'publishedAt': '2018-12-23T10:11:53.000Z', 'channelId': 'UC0uqemz3uxjLOoske7_-Bsg', 'title': '김문수-차명진 라이브/청와대 불법 사찰, 文 지지율 급락 등', 'description': '김문수-차명진 라이브.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/hIXaF9eUXE0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '김문수TV', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/W_LdBJ-TYOLC8WILJy_uXQU9LWY"', 'id': {'kind': 'youtube#video', 'videoId': '3xLiudHp31M'}, 'snippet': {'publishedAt': '2018-12-23T10:12:27.000Z', 'channelId': 'UCfC0RcYzDQcFtHrce2mpvbA', 'title': 'Dog Park Yard Cam - K9s For Warriors powered by EXPLORE.org', 'description': 'The dog park at K9s For Warriors is where rescued puppies play, socialize and undergo the training that will enable them to become service dogs for US ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3xLiudHp31M/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Explore Dogs', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/HZDwov_X4NpfSgPGhzhtQTsmjXc"', 'id': {'kind': 'youtube#video', 'videoId': 'xPz7U3lV9no'}, 'snippet': {'publishedAt': '2018-12-23T10:12:36.000Z', 'channelId': 'UC-qnQ5u7hfR0BUruMqiKYEw', 'title': 'NOT ENDING STREAM TILL 1500 LIKES (#FORTNITE #BATTLE #ROYALE)', 'description': 'http://paypal.me/richkids11 Watch my vid https://m.youtube.com/channel/UC-qnQ5u7hfR0BUruMqiKYEw/videos My other vid montage ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xPz7U3lV9no/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Rich Kids', 'liveBroadcastContent': 'none'}}, {'kind': 'youtube#searchResult', 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/x5m0QNzog36iWE_e3Ncj2jVXKfY"', 'id': {'kind': 'youtube#video', 'videoId': 'd6xtkhJEx-k'}, 'snippet': {'publishedAt': '2018-12-23T10:10:20.000Z', 'channelId': 'UCBltWSh2lKOLiyFjhIu-K0A', 'title': 'CoD BlackOut 🌸 PS4 🌸 Drink Night', 'description': "Hi! My name is Charie Blossom . I started live streaming on October 23, 2017. So far I love it! Let's have fun and watch my gaming skills grow. A Girl's Gotta ...", 'thumbnails': {'defau ...

# %%
# Out:
# 'UCyHvSKT_bLDYpkv1JjjsLAg'
