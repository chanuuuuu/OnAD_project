# %%
def call_file_list(path) : 
    """
        path : 파일 경로
    """
    from os import listdir
    path_dir = path
    file_list = listdir(path_dir)
    return file_list

# %%
call_file_list('./')
# Out:
# ['#beyou0728',
#  '#cocopopp671',
#  '#ddahyoni',
#  '#hanryang1125',
#  '#looksam',
#  '#rhdgurwns',
#  '#saddummy',
#  '#yapyap30',
#  '#zilioner',
#  '.ipynb_checkpoints',
#  '사용자 사전에 추가하기.ipynb',
#  '파일확인용.ipynb']

# %%
import pickle

# %%
with open('./#beyou0728/matching_2018-12-04_#beyou0728.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [('네', '넹'),
#  ('ㅇ', '넹'),
#  ('그것', '그걸 왜 터트려요'),
#  ('터트리', '그걸 왜 터트려요'),
#  ('어요', '그걸 왜 터트려요'),
#  ('리', '터 뜨 린 다!'),
#  ('ㄴ', '터 뜨 린 다!'),
#  ('생기', '고양이 옆라인 사람처럼 생겻는데'),
#  ('엇', '고양이 옆라인 사람처럼 생겻는데'),
#  ('그것', '그거 외국인도 그런데'),
#  ('하', '사람도 비슷할텐데'),
#  ('ㄹ텐데', '사람도 비슷할텐데'),
#  ('빠', '빵떡같이'),
#  ('ㅇ', '빵떡같이'),
#  ('키', '킹록렌즈'),
#  ('ㅇ', '킹록렌즈'),
#  ('아', '냥이눈알 겁나 튀어나와 있음'),
#  ('나오', '냥이눈알 겁나 튀어나와 있음'),
#  ('아', '냥이눈알 겁나 튀어나와 있음'),
#  ('지', '생물마다 다르징'),
#  ('ㅇ', '생물마다 다르징'),
#  ('이', '수정체 같은 역할인듯'),
#  ('ㄴ듯', '수정체 같은 역할인듯'),
#  ('이', '다있는데여'),
#  ('어', '다있는데여'),
#  ('끼', '렌즈꼇나보네'),
#  ('엇', '렌즈꼇나보네'),
#  ('떨어지', '홍채랑 각막이랑 떨어져있어요'),
#  ('그것', '그건 눈때문이 아니라 얼굴 때문이죠'),
#  ('ㄴ', '그건 눈때문이 아니라 얼굴 때문이죠'),
#  ('배우', '과학안배웠죠'),
#  ('었', '과학안배웠죠'),
#  ('하', '눈은 다 똥글똥글함'),
#  ('ㅁ', '눈은 다 똥글똥글함'),
#  ('이', '프로토스인가 ;;'),
#  ('ㄴ가', '프로토스인가 ;;'),
#  ('배우', '생물안배운듯'),
#  ('ㄴ', '생물안배운듯'),
#  ('끼', '렌즈낀거임'),
#  ('ㄴ', '렌즈낀거임'),
#  ('이', '렌즈낀거임'),
#  ('ㅁ', '렌즈낀거임'),
#  ('키우', '고양이 안키워본사람은 모름'),
#  ('어', '고양이 안키워본사람은 모름'),
#  ('보', '고양이 안키워본사람은 모름'),
#  ('ㄴ', '고양이 안키워본사람은 모름'),
#  ('하', '그렇다고합시다'),
#  ('ㅂ시다', '그렇다고합시다'),
#  ('나오', '사람도 그렇게 튀어나와잇음'),
#  ('아', '사람도 그렇게 튀어나와잇음'),
#  ('그것', '그거 백안임'),
#  ('이', '그거 백안임'),
#  ('ㅁ', '그거 백안임'),
#  ('시', '만화 그만 보세요'),
#  ('어요', '만화 그만 보세요'),
#  ('하', '그렇다고 합시다~~~'),
#  ('ㅂ시다', '그렇다고 합시다~~~'),
#  ('시', '어디서 배우셨음?'),
#  ('었', '어디서 배우셨음?'),
#  ('치', '외국인 눈 쳐보셈'),
#  ('어', '외국인 눈 쳐보셈'),
#  ('살', '사륜안입니다'),
#  ('ㅠ', '사륜안입니다'),
#  ('ㄴ', '사륜안입니다'),
#  ('이', '사륜안입니다'),
#  ('ㅂ니다', '사륜안입니다'),
#  ('하', '그렇다고 합니다'),
#  ('ㅂ니다', '그렇다고 합니다'),
#  ('크', '사람 눈알 커요 ㄷㄷ'),
#  ('어요', '사람 눈알 커요 ㄷㄷ'),
#  ('살', '사륜안 아니냐'),
#  ('ㅠ', '사륜안 아니냐'),
#  ('ㄴ', '사륜안 아니냐'),
#  ('이', '무슨 만화본거임?'),
#  ('ㅁ', '무슨 만화본거임?'),
#  ('살', '사륜안 ㄷㄷ'),
#  ('ㅠ', '사륜안 ㄷㄷ'),
#  ('ㄴ', '사륜안 ㄷㄷ'),
#  ('배우', '만화에서 배운거에요?'),
#  ('ㄴ', '만화에서 배운거에요?'),
#  ('움직이', '눈 감고 눈동자에 손 올리고 눈알 이리저리 움직여보세요'),
#  ('어', '눈 감고 눈동자에 손 올리고 눈알 이리저리 움직여보세요'),
#  ('시', '눈 감고 눈동자에 손 올리고 눈알 이리저리 움직여보세요'),
#  ('어요', '눈 감고 눈동자에 손 올리고 눈알 이리저리 움직여보세요'),
#  ('골', '고륜안 ㄷㄷ'),
#  ('ㅠ', '고륜안 ㄷㄷ'),
#  ('ㄴ', '고륜안 ㄷㄷ'),
#  ('치', '구글쳐보셈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('어', '구글쳐보셈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('보', '누나가 누나 눈알을 안봐서 그래'),
#  ('아서', '누나가 누나 눈알을 안봐서 그래'),
#  ('그러', '누나가 누나 눈알을 안봐서 그래'),
#  ('어', '누나가 누나 눈알을 안봐서 그래'),
#  ('ㄱ', '동양인처럼 검은색 말고 회색홍채 보셈'),
#  ('ㅗ', '동양인처럼 검은색 말고 회색홍채 보셈'),
#  ('보', '아무튼 봤음'),
#  ('았', '아무튼 봤음'),
#  ('나오', '우리도 눈동자가 뽈록 튀어나와있음'),
#  ('아', '우리도 눈동자가 뽈록 튀어나와있음'),
#  ('하', '나이봇이 인정함 ㅋㅋㅋ'),
#  ('ㅁ', '나이봇이 인정함 ㅋㅋㅋ'),
#  ('살', '고양이 닌자 사륜안 ㄷㄷㄷㄷ'),
#  ('ㅠ', '고양이 닌자 사륜안 ㄷㄷㄷㄷ'),
#  ('ㄴ', '고양이 닌자 사륜안 ㄷㄷㄷㄷ'),
#  ('하', '해부했네'),
#  ('았', '해부했네'),
#  ('게', '사린겐'),
#  ('ㄴ', '사린겐'),
#  ('배우', '경험에서 배웠구나아'),
#  ('었', '경험에서 배웠구나아'),
#  ('하', '그것은 불합리한 의심입니다.'),
#  ('ㄴ', '그것은 불합리한 의심입니다.'),
#  ('이', '그것은 불합리한 의심입니다.'),
#  ('ㅂ니다', '그것은 불합리한 의심입니다.'),
#  ('튀어나오', '튀어나온거말하는거아닌데'),
#  ('ㄴ', '튀어나온거말하는거아닌데'),
#  ('아니', '튀어나온거말하는거아닌데'),
#  ('ㄴ데', '튀어나온거말하는거아닌데'),
#  ('치', '고양이눈 구글에 쳐보셈'),
#  ('어', '고양이눈 구글에 쳐보셈'),
#  ('ㅇ', '눈알 티어나오는 사람 못 봤죠?'),
#  ('ㅗ', '눈알 티어나오는 사람 못 봤죠?'),
#  ('보', '눈알 티어나오는 사람 못 봤죠?'),
#  ('았', '눈알 티어나오는 사람 못 봤죠?'),
#  ('ㄴ가요', '혹시 동물과 대화가 가능하신가요?'),
#  ('튀어나오', '아니 동글하게 튀어나온거 아닌데 인간도 똑같다니까요'),
#  ('ㄴ', '아니 동글하게 튀어나온거 아닌데 인간도 똑같다니까요'),
#  ('ㄴ데', '아니 동글하게 튀어나온거 아닌데 인간도 똑같다니까요'),
#  ('끝나', '사과하면 끝날일입니다'),
#  ('ㄹ', '사과하면 끝날일입니다'),
#  ('이', '사과하면 끝날일입니다'),
#  ('ㅂ니다', '사과하면 끝날일입니다'),
#  ('이', '맞아여'),
#  ('어', '맞아여'),
#  ('이', '맞으면 맞는거임'),
#  ('ㅁ', '맞으면 맞는거임'),
#  ('ㅇ', '피유님도 우기는중'),
#  ('ㅠ', '피유님도 우기는중'),
#  ('누구', '누가 우기는건지'),
#  ('걸', '누가 우기는건지'),
#  ('ㄴ지', '누가 우기는건지'),
#  ('우', '욱이'),
#  ('ㄱ', '욱이'),
#  ('하', '맞으면 사과할게요 ㅎㅎ'),
#  ('ㄹ게요', '맞으면 사과할게요 ㅎㅎ'),
#  ('어떡하', '틀리면 어떡할래요'),
#  ('ㄹ래요', '틀리면 어떡할래요'),
#  ('우', '욱이네'),
#  ('ㄱ', '욱이네'),
#  ('하', '눈알 셀카 찍어서 비교해보자'),
#  ('아', '눈알 셀카 찍어서 비교해보자'),
#  ('오', '와서 딱밤한대 때려'),
#  ('아서', '와서 딱밤한대 때려'),
#  ('줍', '주워담아'),
#  ('어', '주워담아'),
#  ('우', '욱이?'),
#  ('ㄱ', '욱이?'),
#  ('나오', '원래 냥이 눈 좀 튀어나와있음'),
#  ('아', '원래 냥이 눈 좀 튀어나와있음'),
#  ('보', '우기는거봐;;'),
#  ('아', '우기는거봐;;'),
#  ('타', '2탄 시작인가'),
#  ('ㄴ', '2탄 시작인가'),
#  ('이', '2탄 시작인가'),
#  ('ㄴ가', '2탄 시작인가'),
#  ('아', '맞으면 축하해줌'),
#  ('주', '맞으면 축하해줌'),
#  ('ㅁ', '맞으면 축하해줌'),
#  ('아', '축하해줄게'),
#  ('때리', '때려주세요'),
#  ('어', '때려주세요'),
#  ('시', '때려주세요'),
#  ('어요', '때려주세요'),
#  ('루', '우끼 = 룩삼'),
#  ('ㄱ', '우끼 = 룩삼'),
#  ('튀어나오', '아니 튀어나온거 말하는거 아니라고'),
#  ('ㄴ', '아니 튀어나온거 말하는거 아니라고'),
#  ('ㅇ', '네 피유님이 다 맞워요'),
#  ('ㅠ', '네 피유님이 다 맞워요'),
#  ('어쩌', '저쩔래'),
#  ('ㄹ래', '저쩔래'),
#  ('오', '와서 뺨따구 때려주셈'),
#  ('아서', '와서 뺨따구 때려주셈'),
#  ('줍', '주워담아 얼른..'),
#  ('어', '주워담아 얼른..'),
#  ('우', '욱이네 닭강정 맛있지'),
#  ('ㄱ', '욱이네 닭강정 맛있지'),
#  ('아니', '아님말고 ㅎ'),
#  ('ㅁ', '아님말고 ㅎ'),
#  ('ㄱ', '아님말고 ㅎ'),
#  ('ㅗ', '아님말고 ㅎ'),
#  ('오', '맞으면 와서 때려주셈'),
#  ('아서', '맞으면 와서 때려주셈'),
#  ('ㄱ', '맞으면 맞는거고'),
#  ('ㅗ', '맞으면 맞는거고'),
#  ('시', '트위치 공식 척척박사님이십니다;'),
#  ('ㅂ니다', '트위치 공식 척척박사님이십니다;'),
#  ('치마', '그치만...'),
#  ('ㄴ', '그치만...'),
#  ('미아', '미안 ㅋ'),
#  ('ㄴ', '미안 ㅋ'),
#  ('미아', '미안!'),
#  ('ㄴ', '미안!'),
#  ('그것', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그거 아직도 한을 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('아지', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그거 아직도 한을 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㄱㄷ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그거 아직도 한을 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㅗ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그거 아직도 한을 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('그러', '그랫쥬?'),
#  ('엇', '그랫쥬?'),
#  ('ㄹ', '트수가 미아내....'),
#  ('치마', '그치만..'),
#  ('ㄴ', '그치만..'),
#  ('하', '왜케화났어'),
#  ('게', '왜케화났어'),
#  ('나', '왜케화났어'),
#  ('았', '왜케화났어'),
#  ('키', '킹치만...'),
#  ('ㅇ', '킹치만...'),
#  ('치마', '킹치만...'),
#  ('ㄴ', '킹치만...'),
#  ('아니', '아님곰보~'),
#  ('ㅁ', '아님곰보~'),
#  ('미아', '미안'),
#  ('ㄴ', '미안'),
#  ('미아', '미안 ㅋ'),
#  ('ㄴ', '미안 ㅋ'),
#  ('ㄹ', '트수가 미안해??'),
#  ('하', '트수가 미안해??'),
#  ('아', '트수가 미안해??'),
#  ('나', '난 아님 ㅎㅎ'),
#  ('ㄴ', '난 아님 ㅎㅎ'),
#  ('아니', '난 아님 ㅎㅎ'),
#  ('ㅁ', '난 아님 ㅎㅎ'),
#  ('ㅇ', '피유님이 맞으면 트위치 제일 척척 박사 하셈'),
#  ('ㅠ', '피유님이 맞으면 트위치 제일 척척 박사 하셈'),
#  ('치', '구글에 feline eye structure라고 쳐보세여'),
#  ('어', '구글에 feline eye structure라고 쳐보세여'),
#  ('이', '구글에 feline eye structure라고 쳐보세여'),
#  ('어', '구글에 feline eye structure라고 쳐보세여'),
#  ('치마', '그치만...'),
#  ('ㄴ', '그치만...'),
#  ('하', '그냥 미안해'),
#  ('아', '그냥 미안해'),
#  ('그러', '그랫죠?'),
#  ('엇', '그랫죠?'),
#  ('나', '난 안그랬음 ㅎㅎ'),
#  ('ㄴ', '난 안그랬음 ㅎㅎ'),
#  ('그러', '난 안그랬음 ㅎㅎ'),
#  ('었', '난 안그랬음 ㅎㅎ'),
#  ('이', '척척박사니까 맞겠징'),
#  ('지', '척척박사니까 맞겠징'),
#  ('ㅇ', '척척박사니까 맞겠징'),
#  ('그러', '그래 미안해'),
#  ('어', '그래 미안해'),
#  ('하', '그래 미안해'),
#  ('아', '그래 미안해'),
#  ('스마', '스만!'),
#  ('ㄴ', '스만!'),
#  ('하', '지금 말했죠'),
#  ('았', '지금 말했죠'),
#  ('하', '지금했죠'),
#  ('았', '지금했죠'),
#  ('오', '와 시;ㅁ쿵'),
#  ('아', '와 시;ㅁ쿵'),
#  ('하', '근데 지금 말했네'),
#  ('았', '근데 지금 말했네'),
#  ('돌아오', '끠태식이 돌아왓구나?'),
#  ('앗', '끠태식이 돌아왓구나?'),
#  ('하', '말했죠'),
#  ('았', '말했죠'),
#  ('ㅇ', '피유님 마음씨도 예쁘네요'),
#  ('ㅠ', '피유님 마음씨도 예쁘네요'),
#  ('치', '사람 눈을 쳐보셔야지'),
#  ('어', '사람 눈을 쳐보셔야지'),
#  ('시', '사람 눈을 쳐보셔야지'),
#  ('어야지', '사람 눈을 쳐보셔야지'),
#  ('치', '고양이 눈 구조를 쳐보자'),
#  ('어', '고양이 눈 구조를 쳐보자'),
#  ('내', '방금 화냈죠^^'),
#  ('었', '방금 화냈죠^^'),
#  ('ㅇ', '피유님 요즘 왤케 이쁘세요'),
#  ('ㅠ', '피유님 요즘 왤케 이쁘세요'),
#  ('시', '피유님 요즘 왤케 이쁘세요'),
#  ('어요', '피유님 요즘 왤케 이쁘세요'),
#  ('되', '1대 척척박사님한테 까불면 안됨'),
#  ('ㅁ', '1대 척척박사님한테 까불면 안됨'),
#  ('었', '혹시 칼 대셨습니까'),
#  ('치', 'feline eye structure 구글에 쳐보고 사람 눈은 네이버에 쳐보세여'),
#  ('어', 'feline eye structure 구글에 쳐보고 사람 눈은 네이버에 쳐보세여'),
#  ('치', 'feline eye structure 구글에 쳐보고 사람 눈은 네이버에 쳐보세여'),
#  ('어', 'feline eye structure 구글에 쳐보고 사람 눈은 네이버에 쳐보세여'),
#  ('어', 'feline eye structure 구글에 쳐보고 사람 눈은 네이버에 쳐보세여'),
#  ('오', '와!'),
#  ('아', '와!'),
#  ('제모', '노래제목머에여'),
#  ('ㄱ', '노래제목머에여'),
#  ('이', '노래제목머에여'),
#  ('어', '노래제목머에여'),
#  ('오', '와 진짜 눈 2개네 ㄷㄷㄷ'),
#  ('아', '와 진짜 눈 2개네 ㄷㄷㄷ'),
#  ('크', '그냥 커여운데'),
#  ('어', '그냥 커여운데'),
#  ('이', '그냥 커여운데'),
#  ('어', '그냥 커여운데'),
#  ('울', '그냥 커여운데'),
#  ('ㄴ데', '그냥 커여운데'),
#  ('크', '커 ㅡㅡ엽'),
#  ('어', '커 ㅡㅡ엽'),
#  ('끼', '렌즈꼈네'),
#  ('었', '렌즈꼈네'),
#  ('저것', '저거 우리도 저렇다니까'),
#  ('이', '그러니까 그게 각막위에 뭐가 하나 더있다는 거임?'),
#  ('ㅁ', '그러니까 그게 각막위에 뭐가 하나 더있다는 거임?'),
#  ('저러', '우리눈도 저런데'),
#  ('ㄴ데', '우리눈도 저런데'),
#  ('보', '뭘봐요?'),
#  ('아요', '뭘봐요?'),
#  ('저것', '저거 덮혀있는게 사람눈아니냐'),
#  ('까', '고양이 눈 구조를 보자니깐여'),
#  ('ㄴ', '고양이 눈 구조를 보자니깐여'),
#  ('어', '고양이 눈 구조를 보자니깐여'),
#  ('하', '사람 눈알도 같이 비교해야죠'),
#  ('아야죠', '사람 눈알도 같이 비교해야죠'),
#  ('저것', '저거 고양이 렌즈임'),
#  ('떨어트리', '눈에 물방울 떨어트린거아님?'),
#  ('ㄴ', '눈에 물방울 떨어트린거아님?'),
#  ('아니', '눈에 물방울 떨어트린거아님?'),
#  ('ㅁ', '눈에 물방울 떨어트린거아님?'),
#  ('거', '딴건 모르겠고 귀엽네요'),
#  ('ㄴ', '딴건 모르겠고 귀엽네요'),
#  ('보', '뭘봐요'),
#  ('아요', '뭘봐요'),
#  ('나', 'ㅇㅇ 난 저럼'),
#  ('ㄴ', 'ㅇㅇ 난 저럼'),
#  ('저러', 'ㅇㅇ 난 저럼'),
#  ('ㅁ', 'ㅇㅇ 난 저럼'),
#  ('크', '냥클렌즈'),
#  ('ㄹ', '냥클렌즈'),
#  ('치', '사람눈 쳐봐'),
#  ('어', '사람눈 쳐봐'),
#  ('보', '사람눈 쳐봐'),
#  ('아', '사람눈 쳐봐'),
#  ('저러', '나도 저럼 ㅋ'),
#  ('ㅁ', '나도 저럼 ㅋ'),
#  ('다고', '아니 구조는 같다곸ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('하고', '아니 구조는 같다곸ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('끼', '고양이가 렌즈꼈네'),
#  ('었', '고양이가 렌즈꼈네'),
#  ('저러', 'ㅇㅇ 내눈 저럼'),
#  ('ㅁ', 'ㅇㅇ 내눈 저럼'),
#  ('것', '옆꺼풀말하는거네'),
#  ('나', '난 저런데요'),
#  ('ㄴ', '난 저런데요'),
#  ('저러', '난 저런데요'),
#  ('ㄴ데요', '난 저런데요'),
#  ('보', '과학적으로 봐야징 ㅋㅋㅋㅋㅋㅋ'),
#  ('아야', '과학적으로 봐야징 ㅋㅋㅋㅋㅋㅋ'),
#  ('지', '과학적으로 봐야징 ㅋㅋㅋㅋㅋㅋ'),
#  ('ㅇ', '과학적으로 봐야징 ㅋㅋㅋㅋㅋㅋ'),
#  ('치', '사람눈 쳐봐요'),
#  ('어', '사람눈 쳐봐요'),
#  ('보', '사람눈 쳐봐요'),
#  ('아요', '사람눈 쳐봐요'),
#  ('까', '아깐아니라메요'),
#  ('ㄴ', '아깐아니라메요'),
#  ('ㅇ', '피유 화난다 그만하자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㅠ', '피유 화난다 그만하자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('화나', '피유 화난다 그만하자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㄴ다', '피유 화난다 그만하자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('끼', '렌즈꼈네'),
#  ('었', '렌즈꼈네'),
#  ('말', '마짜나'),
#  ('아', '마짜나'),
#  ('멀', '먼소리야 ㅋㅋㅋ'),
#  ('ㄴ', '먼소리야 ㅋㅋㅋ'),
#  ('하', '당연한거아니에요?'),
#  ('ㄴ', '당연한거아니에요?'),
#  ('생기', '생긴게 다르긴 함'),
#  ('ㄴ', '생긴게 다르긴 함'),
#  ('기', '생긴게 다르긴 함'),
#  ('ㄴ', '생긴게 다르긴 함'),
#  ('하', '생긴게 다르긴 함'),
#  ('ㅁ', '생긴게 다르긴 함'),
#  ('보', '사람눈 같이 봐봐요'),
#  ('아', '사람눈 같이 봐봐요'),
#  ('보', '사람눈 같이 봐봐요'),
#  ('아요', '사람눈 같이 봐봐요'),
#  ('치', '그렇다고쳐'),
#  ('어', '그렇다고쳐'),
#  ('생기', '구조는 똑같은데 다르게 생김'),
#  ('ㅁ', '구조는 똑같은데 다르게 생김'),
#  ('그러', '그래'),
#  ('어', '그래'),
#  ('말', '아 마짜나;'),
#  ('되', '이해가 안돼 ㅋㅋㅋㅋ'),
#  ('어', '이해가 안돼 ㅋㅋㅋㅋ'),
#  ('ㅇ', '피유말이 맞다'),
#  ('ㅠ', '피유말이 맞다'),
#  ('치', '그렇다고쳐'),
#  ('어', '그렇다고쳐'),
#  ('아', '사람눈도 옆에서 보는거 봐봐요'),
#  ('아요', '사람눈도 옆에서 보는거 봐봐요'),
#  ('하', '그만해 그만해'),
#  ('아', '그만해 그만해'),
#  ('하', '그만해 그만해'),
#  ('아', '그만해 그만해'),
#  ('말', '마짜나~'),
#  ('아', '마짜나~'),
#  ('ㄴ', '보이는건 똑같이 보일거에요'),
#  ('것', '맞는걸로 해주자'),
#  ('되', '이제 군고구마 상황 된다'),
#  ('ㄴ다', '이제 군고구마 상황 된다'),
#  ('ㄹ', '트수 눈들은 다 냥이 눈알이에요'),
#  ('하', '아 그 얘기한거구나'),
#  ('ㄴ', '아 그 얘기한거구나'),
#  ('이', '아 그 얘기한거구나'),
#  ('ㅇ', 'ㅋㅋ 피유 복장터진다'),
#  ('ㅠ', 'ㅋㅋ 피유 복장터진다'),
#  ('복자', 'ㅋㅋ 피유 복장터진다'),
#  ('ㅇ', 'ㅋㅋ 피유 복장터진다'),
#  ('하', '그만해 못이겨'),
#  ('아', '그만해 못이겨'),
#  ('이기', '그만해 못이겨'),
#  ('어', '그만해 못이겨'),
#  ('시', '아니 저 눈으로 살아보셧습니까?'),
#  ('엇', '아니 저 눈으로 살아보셧습니까?'),
#  ('하', '맞는 소리 했네'),
#  ('았', '맞는 소리 했네'),
#  ('하', '외질도 비슷함'),
#  ('ㅁ', '외질도 비슷함'),
#  ('하', '니가 그렇다면 그런거겠지..'),
#  ('나', '근데 왜 화가 난거에요???'),
#  ('ㄴ', '근데 왜 화가 난거에요???'),
#  ('거', '그건니생니고'),
#  ('ㄴ', '그건니생니고'),
#  ('ㄱ', '그건니생니고'),
#  ('ㅗ', '그건니생니고'),
#  ('보이', '20도 더 넓게 보인다고하네요'),
#  ('ㄴ다고', '20도 더 넓게 보인다고하네요'),
#  ('ㅇ', '피유 우승!피유 우승!피유 우승!'),
#  ('ㅠ', '피유 우승!피유 우승!피유 우승!'),
#  ('핑', '피유 우승!피유 우승!피유 우승!'),
#  ('ㅠ', '피유 우승!피유 우승!피유 우승!'),
#  ('핑', '피유 우승!피유 우승!피유 우승!'),
#  ('ㅠ', '피유 우승!피유 우승!피유 우승!'),
#  ('물어보', '고양이한테 물어봤는데 아니래요'),
#  ('았', '고양이한테 물어봤는데 아니래요'),
#  ('이기', '못이긴데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㄴ데', '못이긴데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('하', '맞다고해~'),
#  ('아', '맞다고해~'),
#  ('ㅇ', '피유 승리!'),
#  ('ㅠ', '피유 승리!'),
#  ('알', '제가 고양이라서 아는데 아니라구요 ㅡㅡ'),
#  ('ㅇ', '피유말이 다맞아 ~~'),
#  ('ㅠ', '피유말이 다맞아 ~~'),
#  ('ㅇ', '피유우승!'),
#  ('ㅠ', '피유우승!'),
#  ('갸', '걍 맞다고 해주자'),
#  ('ㅇ', '걍 맞다고 해주자'),
#  ('하', '고양이가 어케 보는지도 검색ㄱㄱ'),
#  ('게', '고양이가 어케 보는지도 검색ㄱㄱ'),
#  ('그것', '그건 니생이고'),
#  ('ㄴ', '그건 니생이고'),
#  ('하', '사실 맞아요 죄송해요'),
#  ('어요', '사실 맞아요 죄송해요'),
#  ('시', '고양이상 모르세욘?'),
#  ('어요', '고양이상 모르세욘?'),
#  ('ㄴ', '고양이상 모르세욘?'),
#  ('되', '군고구마 된다고 맞다고해라'),
#  ('ㄴ다고', '군고구마 된다고 맞다고해라'),
#  ('하', '군고구마 된다고 맞다고해라'),
#  ('아라', '군고구마 된다고 맞다고해라'),
#  ('그것', '그건 모르는거지 고양이랑 얘기하기전에는 ㅋㅋ'),
#  ('ㄴ', '그건 모르는거지 고양이랑 얘기하기전에는 ㅋㅋ'),
#  ('하', '맞다고해줄게'),
#  ('아', '맞다고해줄게'),
#  ('새', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㄱ', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('매', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㅇ', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㄴ가', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('모', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㅅㅂ', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㅗ', '고양이눈도 색맹인가? 밝은색 못보는'),
#  ('ㅇ', '피유우승!!'),
#  ('ㅠ', '피유우승!!'),
#  ('그러', '그래 피유가 맞다'),
#  ('어', '그래 피유가 맞다'),
#  ('ㅇ', '그래 피유가 맞다'),
#  ('ㅠ', '그래 피유가 맞다'),
#  ('하', '맞다고 해줘어어'),
#  ('아', '맞다고 해줘어어'),
#  ('주', '맞다고 해줘어어'),
#  ('하', '맞다고 해줍시다 진짜 ㅡㅡ'),
#  ('아', '맞다고 해줍시다 진짜 ㅡㅡ'),
#  ('주', '맞다고 해줍시다 진짜 ㅡㅡ'),
#  ('ㅂ시다', '맞다고 해줍시다 진짜 ㅡㅡ'),
#  ('시', '그만들하세요'),
#  ('어요', '그만들하세요'),
#  ('그것', '그건 니생각이고~'),
#  ('ㄴ', '그건 니생각이고~'),
#  ('ㄱ', '그건 니생각이고~'),
#  ('ㅗ', '그건 니생각이고~'),
#  ('보', '이건 고양이 입장도 들어봐야함'),
#  ('아야', '이건 고양이 입장도 들어봐야함'),
#  ('하', '이건 고양이 입장도 들어봐야함'),
#  ('ㅁ', '이건 고양이 입장도 들어봐야함'),
#  ('다르', '감자한태 오즈 눈셀카 찍어서 보내 달라하자'),
#  ('아', '감자한태 오즈 눈셀카 찍어서 보내 달라하자'),
#  ('박히', '눈 2개 박혀있는거 똑같구만'),
#  ('어', '눈 2개 박혀있는거 똑같구만'),
#  ('새', '고양이 색맹인거빼고 똑같다든데'),
#  ('ㄱ', '고양이 색맹인거빼고 똑같다든데'),
#  ('들', '고양이 색맹인거빼고 똑같다든데'),
#  ('ㄴ데', '고양이 색맹인거빼고 똑같다든데'),
#  ('ㄴ데', '현생 고양이 5년차인데 피유님 말이 맞습니다'),
#  ('ㅇ', '현생 고양이 5년차인데 피유님 말이 맞습니다'),
#  ('ㅠ', '현생 고양이 5년차인데 피유님 말이 맞습니다'),
#  ('오', '와 피유님 맞워요~~~짝짝짝'),
#  ('아', '와 피유님 맞워요~~~짝짝짝'),
#  ('ㅇ', '와 피유님 맞워요~~~짝짝짝'),
#  ('ㅠ', '와 피유님 맞워요~~~짝짝짝'),
#  ('이', '그런 논리면 세상 사람들 눈 다다르다'),
#  ('하', '그만해라 운다'),
#  ('아라', '그만해라 운다'),
#  ('울', '그만해라 운다'),
#  ('ㄴ다', '그만해라 운다'),
#  ('ㅇ', '피유가 이겼다~~~'),
#  ('ㅠ', '피유가 이겼다~~~'),
#  ('이기', '피유가 이겼다~~~'),
#  ('었', '피유가 이겼다~~~'),
#  ('롤', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('ㅗ', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('지', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('ㄴ', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('아니', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('ㅁ', '세로로 보이진 않을거아님 ㅋㅋㅋ'),
#  ('ㄴ데', '현직 고양이인데 똑같이 보입니다'),
#  ('보이', '현직 고양이인데 똑같이 보입니다'),
#  ('ㅂ니다', '현직 고양이인데 똑같이 보입니다'),
#  ('갑', '고양이가보는시각 이런식으로 검색해봐'),
#  ('ㅗ', '고양이가보는시각 이런식으로 검색해봐'),
#  ('하', '고양이가보는시각 이런식으로 검색해봐'),
#  ('아', '고양이가보는시각 이런식으로 검색해봐'),
#  ('아', '고양이가보는시각 이런식으로 검색해봐'),
#  ('말', '채리가 다 마져요 ㅋㅋㅋ'),
#  ('아', '채리가 다 마져요 ㅋㅋㅋ'),
#  ('지', '채리가 다 마져요 ㅋㅋㅋ'),
#  ('어요', '채리가 다 마져요 ㅋㅋㅋ'),
#  ('보이', '흐릿하게 보임'),
#  ('ㅁ', '흐릿하게 보임'),
#  ('아', '유튜브 들어가'),
#  ('동그랗', '사람눈도 동그란데'),
#  ('ㄴ데', '사람눈도 동그란데'),
#  ('오', '밥먹고 왔는데 분위기가'),
#  ('았', '밥먹고 왔는데 분위기가'),
#  ('아야지', '고양이한테 물어봐야지 왜 네이버에 물어보시나요'),
#  ('ㅇ', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('ㅠ', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('ㅇ', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('ㅠ', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('구마', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('ㄴ', '나만 피유가 하는말 이해되냐? 피유 맞는말이구만'),
#  ('이', '채리가 척척박사라서 맞음'),
#  ('자', '삼 ㅡㅡ 장'),
#  ('ㅇ', '삼 ㅡㅡ 장'),
#  ('하', '갓구글에 검색합시다'),
#  ('ㅂ시다', '갓구글에 검색합시다'),
#  ('보', '왜 이미지를봐'),
#  ('아', '왜 이미지를봐'),
#  ('ㅇ', '피유가 채팅창 보는 눈=고양이 눈'),
#  ('ㅠ', '피유가 채팅창 보는 눈=고양이 눈'),
#  ('차', '피유가 채팅창 보는 눈=고양이 눈'),
#  ('ㅇ', '피유가 채팅창 보는 눈=고양이 눈'),
#  ('ㄴ', '시야각이 크고 약간 뿌옇게보이는거지 다르게 보이진않음'),
#  ('으시', '근데 무슨 얘기가 하고싶으신거임'),
#  ('ㄴ', '근데 무슨 얘기가 하고싶으신거임'),
#  ('이', '근데 무슨 얘기가 하고싶으신거임'),
#  ('ㅁ', '근데 무슨 얘기가 하고싶으신거임'),
#  ('누구', '누가 빨리 논문 찾아와라'),
#  ('찾아오', '누가 빨리 논문 찾아와라'),
#  ('아라', '누가 빨리 논문 찾아와라'),
#  ('나오', '유튜브에 나옴'),
#  ('ㅁ', '유튜브에 나옴'),
#  ('ㅇ', '피유 이악물고있죠?'),
#  ('ㅠ', '피유 이악물고있죠?'),
#  ('치', '진짜 이런거 쳐보는애도있구나'),
#  ('어', '진짜 이런거 쳐보는애도있구나'),
#  ('이', '너무 허튼소리라 아무도 글안썻구연'),
#  ('쓰', '너무 허튼소리라 아무도 글안썻구연'),
#  ('엇', '너무 허튼소리라 아무도 글안썻구연'),
#  ('열', '너무 허튼소리라 아무도 글안썻구연'),
#  ('ㄴ', '너무 허튼소리라 아무도 글안썻구연'),
#  ('버리', '이악물어버렷네'),
#  ('엇', '이악물어버렷네'),
#  ('대', '댄진주ㅜㄹ'),
#  ('ㄴ', '댄진주ㅜㄹ'),
#  ('지', '댄진주ㅜㄹ'),
#  ('ㄴㅈ', '댄진주ㅜㄹ'),
#  ('ㅜㅜ', '댄진주ㅜㄹ'),
#  ('말', '우리 채리가 다 마져요'),
#  ('아', '우리 채리가 다 마져요'),
#  ('지', '우리 채리가 다 마져요'),
#  ('어요', '우리 채리가 다 마져요'),
#  ('게으르', '게으른거바라'),
#  ('ㄴ', '게으른거바라'),
#  ('저', '정ㅡ화'),
#  ('으', '정ㅡ화'),
#  ('ㅇ', '피유민망하니까 사과하라고안할꼐'),
#  ('ㅠ', '피유민망하니까 사과하라고안할꼐'),
#  ('보이', '님 카메라 렌즈 바꾸면 다르게보임?'),
#  ('ㅁ', '님 카메라 렌즈 바꾸면 다르게보임?'),
#  ('치', '구글에 쳐보세요 있어요'),
#  ('시', '구글에 쳐보세요 있어요'),
#  ('시', '사과하세요그냥'),
#  ('어요', '사과하세요그냥'),
#  ('우', '웅이가보는 세상 처럼요?'),
#  ('ㅇ', '웅이가보는 세상 처럼요?'),
#  ('갑', '웅이가보는 세상 처럼요?'),
#  ('ㅗ', '웅이가보는 세상 처럼요?'),
#  ('그것', '그건 색을 다르게 보는거야'),
#  ('ㄴ', '그건 색을 다르게 보는거야'),
#  ('보이', '개는 흑백으로 보인다함'),
#  ('ㄴ다', '개는 흑백으로 보인다함'),
#  ('하', '개는 흑백으로 보인다함'),
#  ('ㅁ', '개는 흑백으로 보인다함'),
#  ('그것', '그건 니생각이고~'),
#  ('ㄴ', '그건 니생각이고~'),
#  ('ㄱ', '그건 니생각이고~'),
#  ('ㅗ', '그건 니생각이고~'),
#  ('크', '동물이 우리를보면 커보이지않을까요?'),
#  ('어', '동물이 우리를보면 커보이지않을까요?'),
#  ('ㅇ', '네 맞워요 피유님이 맞워요'),
#  ('ㅠ', '네 맞워요 피유님이 맞워요'),
#  ('오', '와 인정인정'),
#  ('아', '와 인정인정'),
#  ('가깝', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('ㄴ', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('보이', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('ㄴ다', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('하', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('았', '다큐에서 보면 가까운 물체는 흐리게 보인다 했음'),
#  ('해보', '그런생각 많이해봄'),
#  ('ㅁ', '그런생각 많이해봄'),
#  ('하', '사람눈이 가시광선에 민감해'),
#  ('아', '사람눈이 가시광선에 민감해'),
#  ('ㅇ', '피유말이 맞네'),
#  ('ㅠ', '피유말이 맞네'),
#  ('하', '맞다고해~'),
#  ('아', '맞다고해~'),
#  ('시', '고양이 당사자와 해결하세요'),
#  ('어요', '고양이 당사자와 해결하세요'),
#  ('보', '다르게 볼 수 있음'),
#  ('ㄹ', '다르게 볼 수 있음'),
#  ('보', '어안렌즈는 들어봤지만'),
#  ('았', '어안렌즈는 들어봤지만'),
#  ('오', '와 마자마자'),
#  ('아', '와 마자마자'),
#  ('말', '와 마자마자'),
#  ('뭐', '마루는 님을 뭘로볼까요?'),
#  ('ㄹ', '마루는 님을 뭘로볼까요?'),
#  ('보', '마루는 님을 뭘로볼까요?'),
#  ('ㄹ까요', '마루는 님을 뭘로볼까요?'),
#  ('그것', '그건 각막이라고!!!!'),
#  ('ㄴ', '그건 각막이라고!!!!'),
#  ('알', '고양이가 시력이 안좋아서 흐리게 보이는 대신 넓게 보입니다'),
#  ('ㄴ', '고양이가 시력이 안좋아서 흐리게 보이는 대신 넓게 보입니다'),
#  ('ㅂ니다', '고양이가 시력이 안좋아서 흐리게 보이는 대신 넓게 보입니다'),
#  ('새', '흑백이 아니라 보이는 색도 다 다르고 시야도 다 다름'),
#  ('ㄱㄷ', '흑백이 아니라 보이는 색도 다 다르고 시야도 다 다름'),
#  ('ㅗ', '흑백이 아니라 보이는 색도 다 다르고 시야도 다 다름'),
#  ('ㅁ', '흑백이 아니라 보이는 색도 다 다르고 시야도 다 다름'),
#  ('하', '맞다고해줍시다'),
#  ('아', '맞다고해줍시다'),
#  ('주', '맞다고해줍시다'),
#  ('ㅂ시다', '맞다고해줍시다'),
#  ('채', '책오한테 전화해보시던가요'),
#  ('ㄱ', '책오한테 전화해보시던가요'),
#  ('ㅇ', '책오한테 전화해보시던가요'),
#  ('ㅗ', '책오한테 전화해보시던가요'),
#  ('하', '책오한테 전화해보시던가요'),
#  ('아', '책오한테 전화해보시던가요'),
#  ('되', '서로 의사소통이 잘 안됐던걸로'),
#  ('었', '서로 의사소통이 잘 안됐던걸로'),
#  ('것', '서로 의사소통이 잘 안됐던걸로'),
#  ('말', '마자요마자~'),
#  ('말', '마자요마자~'),
#  ('하', '맞다고할께요 ㅋ'),
#  ('ㄹ께', '맞다고할께요 ㅋ'),
#  ('오', '지금왔는데 왜 싸우고있냐'),
#  ('았', '지금왔는데 왜 싸우고있냐'),
#  ('ㅇ', '피유 우승!!'),
#  ('ㅠ', '피유 우승!!'),
#  ('이', '저 폭력적인 피유로 돌아가자'),
#  ('ㄴ', '저 폭력적인 피유로 돌아가자'),
#  ('ㅇ', '저 폭력적인 피유로 돌아가자'),
#  ('ㅠ', '저 폭력적인 피유로 돌아가자'),
#  ('하', '고양이 당사자와 합의했습니다'),
#  ('았', '고양이 당사자와 합의했습니다'),
#  ('못하', '강아지는 거의 색깔구분을 못한다고 들음'),
#  ('ㄴ다고', '강아지는 거의 색깔구분을 못한다고 들음'),
#  ('누', '사람중에도 고양이눈 있눈뎀'),
#  ('ㄴ', '사람중에도 고양이눈 있눈뎀'),
#  ('데', '사람중에도 고양이눈 있눈뎀'),
#  ('ㅁ', '사람중에도 고양이눈 있눈뎀'),
#  ('오', '와'),
#  ('아', '와'),
#  ('오', '와 유레카!'),
#  ('아', '와 유레카!'),
#  ('ㄱ', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('ㅗ', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('ㅇ', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('혀', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('ㄱ', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('주', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('ㄴ', '공혁준한테 물어보삼 ㅋㄷㅋㄷ'),
#  ('ㄴ데', '잠자리도 눈이 몇개인데 그럴수있음'),
#  ('그렇', '잠자리도 눈이 몇개인데 그럴수있음'),
#  ('ㄹ', '잠자리도 눈이 몇개인데 그럴수있음'),
#  ('웃기', '포즈가 웃긴데'),
#  ('ㄴ데', '포즈가 웃긴데'),
#  ('부터', '다음부턴 말을 정확하게 해주세요'),
#  ('ㄴ', '다음부턴 말을 정확하게 해주세요'),
#  ('아', '다음부턴 말을 정확하게 해주세요'),
#  ('시', '다음부턴 말을 정확하게 해주세요'),
#  ('어요', '다음부턴 말을 정확하게 해주세요'),
#  ('뭐', '아니 뭔 소리야 저게 눈이 아니고 뭔데'),
#  ('ㄴ', '아니 뭔 소리야 저게 눈이 아니고 뭔데'),
#  ('아야', '빻양이'),
#  ('항', '빻양이'),
#  ('ㅇ', '피유님이 다맞워용'),
#  ('ㅠ', '피유님이 다맞워용'),
#  ('혀', '혁준이한테 물어보자'),
#  ('ㄱ', '혁준이한테 물어보자'),
#  ('주', '혁준이한테 물어보자'),
#  ('ㄴ', '혁준이한테 물어보자'),
#  ('ㅇ', '오케이 다음부턴 정확하게 말하고 트수는 우기지말자'),
#  ('ㅗ', '오케이 다음부턴 정확하게 말하고 트수는 우기지말자'),
#  ('부터', '오케이 다음부턴 정확하게 말하고 트수는 우기지말자'),
#  ('ㄴ', '오케이 다음부턴 정확하게 말하고 트수는 우기지말자'),
#  ('ㄹ', '오케이 다음부턴 정확하게 말하고 트수는 우기지말자'),
#  ('그렇', '그랬구나 오해했어요'),
#  ('었', '그랬구나 오해했어요'),
#  ('하', '그랬구나 오해했어요'),
#  ('았', '그랬구나 오해했어요'),
#  ('하', '죄송합니다'),
#  ('ㅂ니다', '죄송합니다'),
#  ('그렇', '그랬구나'),
#  ('었', '그랬구나'),
#  ('ㅇ', '우와 피유님은 생각도 귀엽네요 대다내'),
#  ('ㅠ', '우와 피유님은 생각도 귀엽네요 대다내'),
#  ('어', '우와 피유님은 생각도 귀엽네요 대다내'),
#  ('것', '비긴걸로 하지않을래?'),
#  ('오', '맞와요'),
#  ('아요', '맞와요'),
#  ('되', '인증된 척척박사'),
#  ('ㄴ', '인증된 척척박사'),
#  ('ㅇ', '황 유'),
#  ('ㅠ', '황 유'),
#  ('뭐', '백악관 영어로 뭘까요?'),
#  ('ㄹ까요', '백악관 영어로 뭘까요?'),
#  ('ㄴ', '척척박사 노채리'),
#  ('ㅗ', '척척박사 노채리'),
#  ('과', '호박관'),
#  ('ㄴ', '호박관'),
#  ('그것', '그건 청와대고'),
#  ('ㄴ', '그건 청와대고'),
#  ('ㄱ', '그건 청와대고'),
#  ('ㅗ', '그건 청와대고'),
#  ('아', '백악관 나이트클럽 가보셨구나'),
#  ('시', '백악관 나이트클럽 가보셨구나'),
#  ('었', '백악관 나이트클럽 가보셨구나'),
#  ('과', '호박관'),
#  ('ㄴ', '호박관'),
#  ('보', '자주가시나봐요'),
#  ('아요', '자주가시나봐요'),
#  ('ㅇ', '피유님은 로아 안하세요?'),
#  ('ㅠ', '피유님은 로아 안하세요?'),
#  ('시', '피유님은 로아 안하세요?'),
#  ('어요', '피유님은 로아 안하세요?'),
#  ('크', '초커? 이쁘시네요'),
#  ('어', '초커? 이쁘시네요'),
#  ('ㅇ', '오'),
#  ('ㅗ', '오'),
#  ('ㅇ', '오'),
#  ('ㅗ', '오'),
#  ('오', '와;;;;'),
#  ('아', '와;;;;'),
#  ('ㄱ', '호주 수도좀 고만물어봐라 에휴'),
#  ('ㅗ', '호주 수도좀 고만물어봐라 에휴'),
#  ('물어보', '호주 수도좀 고만물어봐라 에휴'),
#  ('아라', '호주 수도좀 고만물어봐라 에휴'),
#  ('이렇', '이럴수가'),
#  ('ㄹ', '이럴수가'),
#  ('오', '와 한손 타자 빠르네'),
#  ('아', '와 한손 타자 빠르네'),
#  ('소', '와 한손 타자 빠르네'),
#  ('ㄴ', '와 한손 타자 빠르네'),
#  ('ㅁ', '수도문제 강자임 이분'),
#  ('이부', '수도문제 강자임 이분'),
#  ('ㄴ', '수도문제 강자임 이분'),
#  ('ㅇ', '오ㅋㅋ'),
#  ('ㅗ', '오ㅋㅋ'),
#  ('오', '왜 개목걸이하고왓어요*'),
#  ('앗', '왜 개목걸이하고왓어요*'),
#  ('이', '며용'),
#  ('소', '한손타자 ㄷㄷ'),
#  ('ㄴ', '한손타자 ㄷㄷ'),
#  ('되', '아 돼쑈!'),
#  ('어', '아 돼쑈!'),
#  ('들키', '들킴 ㅎ'),
#  ('ㅁ', '들킴 ㅎ'),
#  ('손', '소노'),
#  ('ㅗ', '소노'),
#  ('쑈', '대쑝~'),
#  ('ㅇ', '대쑝~'),
#  ('나', '화났다'),
#  ('았', '화났다'),
#  ('ㅇ', '척 척 박 사 피 유'),
#  ('ㅠ', '척 척 박 사 피 유'),
#  ('지', '급 발 질'),
#  ('ㄹ', '급 발 질'),
#  ('이', '현기차인줄 급발진'),
#  ('ㄴ', '현기차인줄 급발진'),
#  ('ㄹ', '트수샊!끼들'),
#  ('수새', '트수샊!끼들'),
#  ('ㄲ', '트수샊!끼들'),
#  ('어', '삐졌다 삐졌네'),
#  ('지', '삐졌다 삐졌네'),
#  ('었', '삐졌다 삐졌네'),
#  ('어', '삐졌다 삐졌네'),
#  ('지', '삐졌다 삐졌네'),
#  ('었', '삐졌다 삐졌네'),
#  ('시', '왜 화나셨어여'),
#  ('었', '왜 화나셨어여'),
#  ('이', '왜 화나셨어여'),
#  ('았', '잘못했으니 사과하세요'),
#  ('시', '잘못했으니 사과하세요'),
#  ('어요', '잘못했으니 사과하세요'),
#  ('ㄴ', '이즈 노벤'),
#  ('ㅗ', '이즈 노벤'),
#  ('ㄴ', '대노'),
#  ('ㅗ', '대노'),
#  ('시', '잘못하셧어요'),
#  ('엇', '잘못하셧어요'),
#  ('멀', '머지 갑자기 왜이러심 ㅋㅋㅋㅋ'),
#  ('시', '머지 갑자기 왜이러심 ㅋㅋㅋㅋ'),
#  ('ㅁ', '머지 갑자기 왜이러심 ㅋㅋㅋㅋ'),
#  ('ㅇ', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('ㅠ', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('때', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('ㄴ', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('시', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('어요', '피유님 욕하고싶을땐 마이크 끄고 씨게 박아주세요'),
#  ('배', '이즈 밴당해서...'),
#  ('ㄴ', '이즈 밴당해서...'),
#  ('배', '이즈 밴해서 화났구만'),
#  ('ㄴ', '이즈 밴해서 화났구만'),
#  ('나', '이즈 밴해서 화났구만'),
#  ('았', '이즈 밴해서 화났구만'),
#  ('빠', '이즈벤해서 빡침'),
#  ('ㄱ', '이즈벤해서 빡침'),
#  ('시', '방금 왜 급발진 하신거임?'),
#  ('ㄴ', '방금 왜 급발진 하신거임?'),
#  ('이', '방금 왜 급발진 하신거임?'),
#  ('ㅁ', '방금 왜 급발진 하신거임?'),
#  ('화나', '화날 일이 아닌데 ㅋㅋ'),
#  ('ㄹ', '화날 일이 아닌데 ㅋㅋ'),
#  ('아니', '화날 일이 아닌데 ㅋㅋ'),
#  ('ㄴ데', '화날 일이 아닌데 ㅋㅋ'),
#  ('배', '이와중에 이즈밴 ㅋ'),
#  ('ㄴ', '이와중에 이즈밴 ㅋ'),
#  ('버', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('ㅇ', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('시', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('ㄴ', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('이', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('ㅁ', '벙금 급발진 왜 하신거임 ㅋㅋㅋ'),
#  ('오', '팩트왔다'),
#  ('았', '팩트왔다'),
#  ('아야', '얍줌마들여기로왓군'),
#  ('합', '얍줌마들여기로왓군'),
#  ('롭', '얍줌마들여기로왓군'),
#  ('앗', '얍줌마들여기로왓군'),
#  ('굴', '얍줌마들여기로왓군'),
#  ('ㄴ', '얍줌마들여기로왓군'),
#  ('무', '문복이'),
#  ('ㄴ', '문복이'),
#  ('무', '문복아...'),
#  ('ㄴ', '문복아...'),
#  ('보', '문복아...'),
#  ('ㄱ', '문복아...'),
#  ('오', '와 트수위키'),
#  ('아', '와 트수위키'),
#  ('ㄹ', '와 트수위키'),
#  ('트', '암튼 다르게 보인다는 말이네'),
#  ('ㄴ', '암튼 다르게 보인다는 말이네'),
#  ('보이', '암튼 다르게 보인다는 말이네'),
#  ('ㄴ다는', '암튼 다르게 보인다는 말이네'),
#  ('하', '가시거리는 사람이 길다고 함'),
#  ('ㅁ', '가시거리는 사람이 길다고 함'),
#  ('ㅇ', '아오 듣기싫어'),
#  ('ㅗ', '아오 듣기싫어'),
#  ('누구', '누가 저렇게 설명해줘 ㅋㅋ'),
#  ('하', '누가 저렇게 설명해줘 ㅋㅋ'),
#  ('아', '누가 저렇게 설명해줘 ㅋㅋ'),
#  ('주', '누가 저렇게 설명해줘 ㅋㅋ'),
#  ('어', '누가 저렇게 설명해줘 ㅋㅋ'),
#  ('ㅇ', '오'),
#  ('ㅗ', '오'),
#  ('차', '초록창에 물어봐놓고 친구있는척 ㅆㅅㅌㅊ'),
#  ('ㅇ', '초록창에 물어봐놓고 친구있는척 ㅆㅅㅌㅊ'),
#  ('물어보', '초록창에 물어봐놓고 친구있는척 ㅆㅅㅌㅊ'),
#  ('아', '초록창에 물어봐놓고 친구있는척 ㅆㅅㅌㅊ'),
#  ('말', '마 자 아 님'),
#  ('아니', 'ㅇㅇ 아님'),
#  ('ㅁ', 'ㅇㅇ 아님'),
#  ('말', '우리 채리가 다 마자요'),
#  ('지', '진텐이다...'),
#  ('ㄴ', '진텐이다...'),
#  ('테', '진텐이다...'),
#  ('ㄴ', '진텐이다...'),
#  ('ㄹ', '트수가 더 잘앎'),
#  ('알', '트수가 더 잘앎'),
#  ('ㅁ', '트수가 더 잘앎'),
#  ('쓰', '대써요'),
#  ('어요', '대써요'),
#  ('었', '고양이였던거임'),
#  ('ㅁ', '고양이였던거임'),
#  ('하', '저희가 한게 저말인데요?'),
#  ('ㄴ', '저희가 한게 저말인데요?'),
#  ('이', '저희가 한게 저말인데요?'),
#  ('ㄴ데요', '저희가 한게 저말인데요?'),
#  ('하', '당연한거 아님?'),
#  ('ㄴ', '당연한거 아님?'),
#  ('아니', '당연한거 아님?'),
#  ('ㅁ', '당연한거 아님?'),
#  ('누구', '누가 그렇게 말함 ㅋㅋㅋ'),
#  ('하', '누가 그렇게 말함 ㅋㅋㅋ'),
#  ('ㅁ', '누가 그렇게 말함 ㅋㅋㅋ'),
#  ('ㄹ', '절 대 잘 알 아'),
#  ('예쁘', '제눈이 그렇게 예뻐요'),
#  ('어요', '제눈이 그렇게 예뻐요'),
#  ('ㄹ', '이건 트수잘못 맞네'),
#  ('ㅁ', '매직아이 기술임 그거'),
#  ('그것', '매직아이 기술임 그거'),
#  ('ㄹ', '트수눈 괭이눈'),
#  ('ㄹ', '트수는 짐승이자너'),
#  ('ㄹ', '트수 ㅅㅋㄱ들'),
#  ('ㅇ', '피유님 얼굴색이 검은색으로 보여요'),
#  ('ㅠ', '피유님 얼굴색이 검은색으로 보여요'),
#  ('보이', '피유님 얼굴색이 검은색으로 보여요'),
#  ('어요', '피유님 얼굴색이 검은색으로 보여요'),
#  ('나', '화났다'),
#  ('았', '화났다'),
#  ('ㄴ데', '제가 고양이인데 사람 눈이랑 똑같습니다'),
#  ('치', '고양이가 채팅쳤어요'),
#  ('었', '고양이가 채팅쳤어요'),
#  ('ㄹ', '우리 씹수만 믿으라구 BloodTrail'),
#  ('오', '와 피유님 발상 천재'),
#  ('아', '와 피유님 발상 천재'),
#  ('ㅇ', '와 피유님 발상 천재'),
#  ('ㅠ', '와 피유님 발상 천재'),
#  ('시', '님님 근데 왜 목에 머리끈을 끼셨어요'),
#  ('었', '님님 근데 왜 목에 머리끈을 끼셨어요'),
#  ('물어보', '저희집 고양이한테 물어봤는데 맞답니다'),
#  ('았', '저희집 고양이한테 물어봤는데 맞답니다'),
#  ('ㅇ', '야짤나오네 ㄷㄷ'),
#  ('ㅗ', '야짤나오네 ㄷㄷ'),
#  ('시', '신 ㅡㅡ남'),
#  ('ㄴ', '신 ㅡㅡ남'),
#  ('ㄱ', '고봐세'),
#  ('ㅗ', '고봐세'),
#  ('보', '고봐세'),
#  ('아', '고봐세'),
#  ('새', '색맹인거빼고 똑같음'),
#  ('ㄱ', '색맹인거빼고 똑같음'),
#  ('하', '시야랑 색깔이 흐리다고 함'),
#  ('ㅁ', '시야랑 색깔이 흐리다고 함'),
#  ('물어보', '도라에몽한테 물어봤는데 맞뎁니다'),
#  ('았', '도라에몽한테 물어봤는데 맞뎁니다'),
#  ('ㅂ니다', '도라에몽한테 물어봤는데 맞뎁니다'),
#  ('거', '허걱.'),
#  ('ㄱ', '허걱.'),
#  ('보이', '우리 저러고 보여요 ㅎ히'),
#  ('어요', '우리 저러고 보여요 ㅎ히'),
#  ('ㅇ', '오목한데?'),
#  ('ㅗ', '오목한데?'),
#  ('하', '오목한데?'),
#  ('ㄴ데', '오목한데?'),
#  ('뭐', '뭔 차이'),
#  ('ㄴ', '뭔 차이'),
#  ('아니', '흐리다는거 아님?'),
#  ('ㅁ', '흐리다는거 아님?'),
#  ('서리', '안경에 김서린거 아닌가여'),
#  ('ㄴ', '안경에 김서린거 아닌가여'),
#  ('아니', '안경에 김서린거 아닌가여'),
#  ('ㄴ가', '안경에 김서린거 아닌가여'),
#  ('이', '안경에 김서린거 아닌가여'),
#  ...]

# %%
data[0][1]
# Out:
# '넹'
