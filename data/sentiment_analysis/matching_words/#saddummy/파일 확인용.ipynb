# %%
import pickle

# %%
with open('matching_2018-12-14_#saddummy.pickle', 'rb') as f : 
    a = pickle.load(f)

# %%
a
# Out:
# [('이거', '쌍소리가 이걸 ㄷㄷㄷㄷ'),
#  ('ㄹ', '쌍소리가 이걸 ㄷㄷㄷㄷ'),
#  ('아니', '힙합 아닙니까'),
#  ('ㅂ니까', '힙합 아닙니까'),
#  ('ㄱ', '둘이 한곡해'),
#  ('ㅗ', '둘이 한곡해'),
#  ('ㄱ', '둘이 한곡해'),
#  ('푸', '랩퍼'),
#  ('어', '랩퍼'),
#  ('푸', '랩퍼 쌍베'),
#  ('어', '랩퍼 쌍베'),
#  ('아니', '힙합 DNA 아닙니까'),
#  ('ㅂ니까', '힙합 DNA 아닙니까'),
#  ('이것', '이거 뭐지'),
#  ('진', '쌍지노ㄷㄷ'),
#  ('ㅗ', '쌍지노ㄷㄷ'),
#  ('이것', '이거뭐지 ㅋㅋㅋㅋㅋ'),
#  ('이것', '이거머징'),
#  ('지', '이거머징'),
#  ('ㅇ', '이거머징'),
#  ('지', '저게뭐징 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('ㅇ', '저게뭐징 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'),
#  ('이것', '이거 머징'),
#  ('지', '이거 머징'),
#  ('ㅇ', '이거 머징'),
#  ('이것', '이거머징..'),
#  ('지', '이거머징..'),
#  ('ㅇ', '이거머징..'),
#  ('이', '래퍼였어??'),
#  ('었', '래퍼였어??'),
#  ('이것', '이거머징'),
#  ('지', '이거머징'),
#  ('ㅇ', '이거머징'),
#  ('서수', '서순무엇'),
#  ('ㄴ', '서순무엇'),
#  ('서수', '서순좋다'),
#  ('ㄴ', '서순좋다'),
#  ('이것', '이거머징'),
#  ('지', '이거머징'),
#  ('ㅇ', '이거머징'),
#  ('이것', '이거머징?'),
#  ('지', '이거머징?'),
#  ('ㅇ', '이거머징?'),
#  ('이것', '이거머징?'),
#  ('지', '이거머징?'),
#  ('ㅇ', '이거머징?'),
#  ('이것', '이거머지;;'),
#  ('멀', '이거머지;;'),
#  ('서수', '서순좋다'),
# ...
